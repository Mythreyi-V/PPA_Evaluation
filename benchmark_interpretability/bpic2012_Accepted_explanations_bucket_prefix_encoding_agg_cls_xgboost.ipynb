# %% [markdown]
# ### BPIC2012
# Bucket: Prefix
#
# Encoding: Aggregation
#
# Classifier: XGBoost
#
# The notebook has all the code for running the benchmark and deriving explanations

# %%
import EncoderFactory
from DatasetManager import DatasetManager
import BucketFactory

import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import StandardScaler

import time
import os
import sys
from sys import argv
import pickle
from collections import defaultdict

from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import lime
import lime.lime_tabular
from lime import submodular_pick;
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

def imp_df(column_names, importances):
        df = pd.DataFrame({'feature': column_names,
                       'feature_importance': importances}) \
           .sort_values('feature_importance', ascending = False) \
           .reset_index(drop = True)
        return df

# plotting a feature importance dataframe (horizontal barchart)
def var_imp_plot(imp_df, title, num_feat):
        imp_df.columns = ['feature', 'feature_importance']
        b= sns.barplot(x = 'feature_importance', y = 'feature', data = imp_df.head(num_feat), orient = 'h', palette="Blues_r") 
        b.set_title(title, fontsize = 14) 
    
        for item in b.get_yticklabels():
            item.set_fontsize(13)

# %%
def generate_global_explanations(train_X,train_Y, cls, feature_combiner):
    
    print("The number of testing instances is ",len(train_Y))
    print("The total number of columns is",train_X.shape[1]);
    print("The total accuracy is ",cls.score(train_X,train_Y));
       
    sns.set(style="darkgrid")
    sns.set(rc={'figure.figsize':(10,10), "font.size":18,"axes.titlesize":18,"axes.labelsize":18})
    sns.set
    feat_names = feature_combiner.get_feature_names()
    base_imp = imp_df(feat_names, cls.feature_importances_)
    base_imp.head(15)
    #var_imp_plot(base_imp, 'Feature importance using Random forest', 15)
    return base_imp

# %%
from lime import submodular_pick
def generate_local_explanations(explainer,test_xi, cls,test_y, submod=False, test_all_data=None):
    
    print("Actual value ", test_y)
    num_features=6;# maximum is 6 ,if it is larger than 6, the features displayed are different.
    exp = explainer.explain_instance(test_xi, 
                                 cls.predict_proba, num_features=num_features, labels=[0,1])
    
    #exp.show_in_notebook(show_table=True, show_all=False);
    probability_result=cls.predict_proba([test_xi])[0];
    print(probability_result);
    print ('Explanation for class %s' % class_names[1])
    print ('\n'.join(map(str, exp.as_list(label=1))))
    return exp
    #%matplotlib inline
    #fig = exp.as_pyplot_figure()
        
    if submod==True:
        sp_obj=submodular_pick.SubmodularPick(explainer, test_all_data, cls.predict_proba, 
                                      sample_size=20, num_features=num_features,num_exps_desired=4)
        [exp.as_pyplot_figure(label=exp.available_labels()[0]) for exp in sp_obj.sp_explanations];

# %%
dataset_ref = "bpic2012"
params_dir = "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "agg"
cls_method = "xgboost"
gap = 1
n_iter = 1

if bucket_method == "state":
    bucket_encoding = "last"
else:
    bucket_encoding = "agg"

method_name = "%s_%s"%(bucket_method, cls_encoding)

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"]
    #"insurance": ["insurance_activity", "insurance_followup"],
    #"sepsis_cases": ["sepsis_cases_1", "sepsis_cases_2", "sepsis_cases_4"]
}

encoding_dict = {
    "laststate": ["static", "last"],
    "agg": ["static", "agg"],
    "index": ["static", "index"],
    "combined": ["static", "last", "agg"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]
methods = encoding_dict[cls_encoding]
    
train_ratio = 0.8
random_state = 22

# create results directory
if not os.path.exists(os.path.join(params_dir)):
    os.makedirs(os.path.join(params_dir))
    
print(datasets)
# Out:
# ['bpic2012_accepted']

# %%
for dataset_name in datasets:
    
    # load optimal params
    optimal_params_filename = os.path.join(params_dir, "optimal_params_%s_%s_%s.pickle" % (cls_method, dataset_name, method_name))
    print(optimal_params_filename)
    if not os.path.isfile(optimal_params_filename) or os.path.getsize(optimal_params_filename) <= 0:
        continue
        
    with open(optimal_params_filename, "rb") as fin:
        args = pickle.load(fin)
        
    print(args)
    bucket_list=[5,10,15,20,25] #:)
    # read the data
    dataset_manager = DatasetManager(dataset_name)
    data = dataset_manager.read_dataset()
    cls_encoder_args = {'case_id_col': dataset_manager.case_id_col, 
                        'static_cat_cols': dataset_manager.static_cat_cols,
                        'static_num_cols': dataset_manager.static_num_cols, 
                        'dynamic_cat_cols': dataset_manager.dynamic_cat_cols,
                        'dynamic_num_cols': dataset_manager.dynamic_num_cols, 
                        'fillna': True}

    # determine min and max (truncated) prefix lengths
    min_prefix_length = 1
    if "traffic_fines" in dataset_name:
        max_prefix_length = 10
    elif "bpic2017" in dataset_name:
        max_prefix_length = min(20, dataset_manager.get_pos_case_length_quantile(data, 0.90))
    else:
        max_prefix_length = min(40, dataset_manager.get_pos_case_length_quantile(data, 0.90))

    # split into training and test
    train, test = dataset_manager.split_data_strict(data, train_ratio, split="temporal")
    
    if gap > 1:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s_gap%s.csv" % (cls_method, dataset_name, method_name, gap))
    else:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s.csv" % (cls_method, dataset_name, method_name))
        
    start_test_prefix_generation = time.time()
    dt_test_prefixes = dataset_manager.generate_prefix_data(test, min_prefix_length, max_prefix_length)
    test_prefix_generation_time = time.time() - start_test_prefix_generation
            
    offline_total_times = []
    online_event_times = []
    train_prefix_generation_times = []
    explained=False
    impotance=None
    exp_ddict=dict()
    exp_rdict=dict()
    model_dict=dict()
    importance_dict=dict()
    for ii in range(n_iter):
        # create prefix logs
        start_train_prefix_generation = time.time()
        dt_train_prefixes = dataset_manager.generate_prefix_data(train, min_prefix_length, max_prefix_length, gap)
        train_prefix_generation_time = time.time() - start_train_prefix_generation
        train_prefix_generation_times.append(train_prefix_generation_time)
            
        # Bucketing prefixes based on control flow
        bucketer_args = {'encoding_method':bucket_encoding, 
                         'case_id_col':dataset_manager.case_id_col, 
                         'cat_cols':[dataset_manager.activity_col], 
                         'num_cols':[], 
                         'random_state':random_state}
        if bucket_method == "cluster":
            bucketer_args["n_clusters"] = int(args["n_clusters"])
        bucketer = BucketFactory.get_bucketer(bucket_method, **bucketer_args)

        start_offline_time_bucket = time.time()
        bucket_assignments_train = bucketer.fit_predict(dt_train_prefixes)
        offline_time_bucket = time.time() - start_offline_time_bucket

        bucket_assignments_test = bucketer.predict(dt_test_prefixes)

        preds_all = []
        test_y_all = []
        nr_events_all = []
        offline_time_fit = 0
        current_online_event_times = []
        
        for bucket in set(bucket_assignments_test):
            print("Bucket" , bucket )
            #args has only one value - some error and so just using it
            #if bucket_method == "prefix":
            #    current_args = args[bucket]
            #else:
            current_args = args
            relevant_train_cases_bucket = dataset_manager.get_indexes(dt_train_prefixes)[bucket_assignments_train == bucket]
            relevant_test_cases_bucket = dataset_manager.get_indexes(dt_test_prefixes)[bucket_assignments_test == bucket]
            dt_test_bucket = dataset_manager.get_relevant_data_by_indexes(dt_test_prefixes, relevant_test_cases_bucket)
            
            nr_events_all.extend(list(dataset_manager.get_prefix_lengths(dt_test_bucket)))
            print('number events', len(nr_events_all))
            
            if len(relevant_train_cases_bucket) == 0:
                preds = [dataset_manager.get_class_ratio(train)] * len(relevant_test_cases_bucket)
                current_online_event_times.extend([0] * len(preds))
            else:
                dt_train_bucket = dataset_manager.get_relevant_data_by_indexes(dt_train_prefixes, relevant_train_cases_bucket) # one row per event
                train_y = dataset_manager.get_label_numeric(dt_train_bucket)

                if len(set(train_y)) < 2:
                    preds = [train_y[0]] * len(relevant_test_cases_bucket)
                    current_online_event_times.extend([0] * len(preds))
                    test_y_all.extend(dataset_manager.get_label_numeric(dt_test_bucket))
                else:
                    start_offline_time_fit = time.time()
                    feature_combiner = FeatureUnion([(method, EncoderFactory.get_encoder(method, **cls_encoder_args)) for method in methods])

                    if cls_method == "rf":
                        cls = RandomForestClassifier(n_estimators=500,
                                                     max_features=current_args['max_features'],
                                                     random_state=random_state)

                    elif cls_method == "xgboost":
                        cls = xgb.XGBClassifier(objective='binary:logistic',
                                                n_estimators=500,
                                                learning_rate= current_args['learning_rate'],
                                                subsample=current_args['subsample'],
                                                max_depth=int(current_args['max_depth']),
                                                colsample_bytree=current_args['colsample_bytree'],
                                                min_child_weight=int(current_args['min_child_weight']),
                                                seed=random_state)

                    elif cls_method == "logit":
                        cls = LogisticRegression(C=2**current_args['C'],
                                                 random_state=random_state)

                    elif cls_method == "svm":
                        cls = SVC(C=2**current_args['C'],
                                  gamma=2**current_args['gamma'],
                                  random_state=random_state)

                    if cls_method == "svm" or cls_method == "logit":
                        pipeline = Pipeline([('encoder', feature_combiner), ('scaler', StandardScaler()), ('cls', cls)])
                    else:
                        pipeline = Pipeline([('encoder', feature_combiner), ('cls', cls)])

                    pipeline.fit(dt_train_bucket, train_y)
                    #get the explainations for the model now
        
                    print("Training model iteration ", ii )
                    
                    #get the training data as a matrix
                    trainingdata=feature_combiner.fit_transform(dt_train_bucket);
                    if bucket in bucket_list:
                        importance = generate_global_explanations(trainingdata,train_y, cls, feature_combiner)
                        #create an explainer now that can be passed later
                        class_names=['regular','deviant']# regular is 0, deviant is 1, 0 is left, 1 is right
                        explainer = lime.lime_tabular.LimeTabularExplainer(trainingdata,
                                                    feature_names = feature_combiner.get_feature_names(),
                                                   class_names=class_names, discretize_continuous=True)
                        importance_dict[bucket]=importance
                        #exp_dict[bucket]=explainer
                        model_dict[bucket]=cls
                    
                    
                    offline_time_fit += time.time() - start_offline_time_fit

                    # predict separately for each prefix case
                    preds = []
                    
                    test_all_grouped = dt_test_bucket.groupby(dataset_manager.case_id_col)
                    print(dt_test_bucket.shape)
                    count_d=0
                    count_r=0
                    for _, group in test_all_grouped:
                        
                        test_y_group = dataset_manager.get_label_numeric(group)
                        test_y_all.extend(test_y_group)
                            
                        start = time.time()
                        _ = bucketer.predict(group)
                        
                        if cls_method == "svm":
                            pred = pipeline.decision_function(group)
                        else:
                            preds_pos_label_idx = np.where(cls.classes_ == 1)[0][0]
                            pred = pipeline.predict_proba(group)[:,preds_pos_label_idx]
                            #print(test_y_group)
                            if bucket in bucket_list and (count_d<3 or count_r<3):
                                test_x_group= feature_combiner.fit_transform(group)
                                print(test_x_group.shape,test_y_group[0], _)
                                test_x=np.transpose(test_x_group[0])
                                print('Generating local Explanations for', dataset_manager.get_case_ids(group))
                                exp=generate_local_explanations(explainer, test_x, cls, test_y_group )
                                if(test_y_group[0]==1):
                                    count_d=count_d+1
                                    exp_ddict[bucket+count_d]=exp
                                else:
                                    count_r=count_r+1
                                    exp_rdict[bucket+count_r]=exp
                                
                        pipeline_pred_time = time.time() - start
                        current_online_event_times.append(pipeline_pred_time / len(group))
                        preds.extend(pred)
                        

            preds_all.extend(preds)

      
   
        dt_results = pd.DataFrame({"actual": test_y_all, "predicted": preds_all, "nr_events": nr_events_all})
        for nr_events, group in dt_results.groupby("nr_events"):
            if len(set(group.actual)) < 2:
                print(dataset_name, method_name, cls_method, nr_events, "auc", np.nan)
            else:
                #if nr_events in [5, 10, 25] and explained=False:
                #    generate_local_explanations(explainer,group[j],cls )
                #    explained=True
                print(dataset_name, method_name, cls_method, nr_events, "auc", roc_auc_score(group.actual, group.predicted))
        print(dataset_name, method_name, cls_method, -1, -1, "auc", roc_auc_score(dt_results.actual, dt_results.predicted))
# Out:
# params\optimal_params_xgboost_bpic2012_accepted_prefix_agg.pickle
# {'colsample_bytree': 0.5095289912261165, 'learning_rate': 0.19509445196561492, 'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.8227788091796178}
# prefix
# Bucket 1
# number events 937
# Training model iteration  0
# (937, 18)
# Bucket 2
# number events 1874
# Training model iteration  0
# (1874, 18)
# Bucket 3
# number events 2811
# Training model iteration  0
# (2811, 18)
# Bucket 4
# number events 3748
# Training model iteration  0
# (3748, 18)
# Bucket 5
# number events 4685
# Training model iteration  0
# The number of testing instances is  3747
# The total number of columns is 104
# The total accuracy is  1.0
# (4685, 18)
# (1, 104) 0 [5]
# Generating local Explanations for 0    204466_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.81270427 0.18729572]
# Explanation for class deviant
# ('agg__Resource_10932.0 <= 0.00', -0.1715083233762882)
# ('agg__Resource_11201.0 <= 0.00', 0.12001140928706186)
# ('63.05 < agg__max_timesincelastevent <= 668.93', 0.0746490188206425)
# ('agg__max_open_cases > 752.00', -0.05577997169372432)
# ('agg__min_open_cases > 745.00', 0.052755828444337655)
# ('agg__mean_open_cases > 748.80', -0.044086290671397285)
# (1, 104) 0 [5]
# Generating local Explanations for 0    204469_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.8592038  0.14079618]
# Explanation for class deviant
# ('agg__Resource_10932.0 <= 0.00', -0.13531156025475277)
# ('agg__Resource_10913.0 <= 0.00', 0.11949768057149658)
# ('agg__Resource_10910.0 <= 0.00', 0.08505074595990476)
# ('63.05 < agg__max_timesincelastevent <= 668.93', 0.06258677431485597)
# ('agg__min_open_cases > 745.00', 0.05894909322865216)
# ('static__AMOUNT_REQ <= 7000.00', -0.05118786935681493)
# (1, 104) 0 [5]
# Generating local Explanations for 0    204472_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9339784  0.06602161]
# Explanation for class deviant
# ('agg__Resource_10932.0 <= 0.00', -0.1515383338977865)
# ('agg__Resource_10913.0 <= 0.00', 0.1086597892795721)
# ('agg__Resource_11180.0 <= 0.00', 0.1082805971541311)
# ('agg__min_open_cases > 745.00', 0.0601948951850639)
# ('63.05 < agg__max_timesincelastevent <= 668.93', 0.0542857143340778)
# ('agg__max_open_cases > 752.00', -0.05252308984503565)
# (1, 104) 1 [5]
# Generating local Explanations for 0    204475_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.7397013 0.2602987]
# Explanation for class deviant
# ('agg__Resource_10629.0 <= 0.00', -0.20476777916453617)
# ('agg__Resource_10913.0 <= 0.00', 0.15602487537916876)
# ('agg__Resource_11180.0 <= 0.00', 0.14264831437153846)
# ('agg__Resource_10932.0 <= 0.00', -0.12975822142191437)
# ('agg__min_open_cases > 745.00', 0.047923422140258264)
# ('agg__max_open_cases > 752.00', -0.04728986079339062)
# (1, 104) 0 [5]
# Generating local Explanations for 0    204481_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.05708069 0.9429193 ]
# Explanation for class deviant
# ('agg__Resource_10931.0 <= 0.00', -0.18358360610844274)
# ('agg__Resource_10932.0 <= 0.00', -0.12527378177502616)
# ('agg__Resource_10913.0 <= 0.00', 0.12472634390811597)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.10842927724206053)
# ('670.00 < agg__min_timesincemidnight <= 813.00', -0.04668185452290628)
# ('agg__max_open_cases > 752.00', -0.04607644462805836)
# (1, 104) 0 [5]
# Generating local Explanations for 0    204484_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.2927932 0.7072068]
# Explanation for class deviant
# ('agg__Resource_10629.0 <= 0.00', -0.2095477901430325)
# ('agg__Resource_10932.0 <= 0.00', -0.15568886057982984)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.0955685317806947)
# ('agg__min_open_cases > 745.00', 0.04832696836429618)
# ('agg__std_timesincelastevent > 299.07', -0.04680820318424546)
# ('agg__max_month <= 10.00', 0.038898686257329375)
# (1, 104) 0 [5]
# Generating local Explanations for 0    204499_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9540329  0.04596709]
# Explanation for class deviant
# ('agg__Resource_10629.0 <= 0.00', -0.23188702551863136)
# ('agg__Resource_10932.0 <= 0.00', -0.14474107321883498)
# ('agg__std_timesincelastevent <= 2.49', 0.061747060255495916)
# ('agg__max_timesincecasestart <= 6.98', -0.055455259752097474)
# ('agg__std_timesincecasestart <= 3.10', 0.05532981626848304)
# ('agg__mean_timesincecasestart <= 1.90', 0.05518660579380296)
# (1, 104) 0 [5]
# Generating local Explanations for 0    204514_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.08843249 0.9115675 ]
# Explanation for class deviant
# ('agg__Resource_11180.0 <= 0.00', 0.12366754548307225)
# ('agg__Resource_11201.0 <= 0.00', 0.11259491717759942)
# ('static__AMOUNT_REQ <= 7000.00', -0.05240303471312594)
# ('agg__mean_timesincelastevent > 134.34', 0.05098750708527751)
# ('agg__min_open_cases > 745.00', 0.04775778585441776)
# ('agg__max_timesincecasestart > 671.70', 0.04244700430987638)
# (1, 104) 1 [5]
# Generating local Explanations for 0    204523_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.5458385 0.4541615]
# Explanation for class deviant
# ('agg__std_timesincecasestart <= 3.10', 0.07637823892946366)
# ('agg__mean_timesincemidnight > 1153.70', 0.06455915222731262)
# ('agg__max_timesincecasestart <= 6.98', -0.06037034313815849)
# ('static__AMOUNT_REQ <= 7000.00', -0.0507621762452207)
# ('agg__mean_timesincecasestart <= 1.90', 0.048753263891274635)
# ('agg__mean_open_cases > 748.80', -0.04553909671712371)
# (1, 104) 1 [5]
# Generating local Explanations for 0    204541_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.05918592 0.9408141 ]
# Explanation for class deviant
# ('agg__Resource_11180.0 <= 0.00', 0.15043107242390874)
# ('agg__min_open_cases > 745.00', 0.06796748610949495)
# ('agg__mean_timesincemidnight > 1153.70', 0.05710403617990034)
# ('agg__max_open_cases > 752.00', -0.0475571334569089)
# ('670.00 < agg__min_timesincemidnight <= 813.00', -0.04674725369663126)
# ('agg__max_timesincemidnight > 1250.00', -0.04483267942113588)
# Bucket 6
# number events 5622
# Training model iteration  0
# (5622, 18)
# Bucket 7
# number events 6559
# Training model iteration  0
# (6559, 18)
# Bucket 8
# number events 7496
# Training model iteration  0
# (7496, 18)
# Bucket 9
# number events 8433
# Training model iteration  0
# (8433, 18)
# Bucket 10
# number events 9370
# Training model iteration  0
# The number of testing instances is  3742
# The total number of columns is 110
# The total accuracy is  1.0
# (9370, 18)
# (1, 110) 0 [10]
# Generating local Explanations for 0    204466_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.8847149  0.11528511]
# Explanation for class deviant
# ('agg__Resource_10932.0 <= 0.00', -0.1554495066259402)
# ('agg__Resource_11200.0 <= 0.00', 0.10616438329332317)
# ('agg__min_timesincemidnight > 953.00', 0.062000290469673675)
# ('0.00 < agg__Activity_A_ACCEPTED-COMPLETE <= 1.00', 0.0527048771173261)
# ('0.82 < agg__std_open_cases <= 2.19', -0.05161646933397969)
# ('54.76 < agg__std_timesincelastevent <= 268.47', 0.04120912658687777)
# (1, 110) 0 [10]
# Generating local Explanations for 0    204469_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.90530306 0.09469695]
# Explanation for class deviant
# ('agg__Resource_11200.0 <= 0.00', 0.12617458390698935)
# ('agg__Resource_10932.0 <= 0.00', -0.11740972489370591)
# ('agg__Resource_11201.0 <= 0.00', 0.09848208716052331)
# ('agg__std_open_cases <= 0.82', 0.059700205343868155)
# ('agg__Activity_A_ACCEPTED-COMPLETE <= 0.00', -0.058528051336552096)
# ('54.76 < agg__std_timesincelastevent <= 268.47', 0.049536965350298036)
# (1, 110) 0 [10]
# Generating local Explanations for 0    204472_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.23971659 0.7602834 ]
# Explanation for class deviant
# ('agg__Resource_11200.0 <= 0.00', 0.1387500712126003)
# ('agg__Resource_10932.0 <= 0.00', -0.12433002369122059)
# ('agg__std_timesincelastevent > 268.47', 0.0849247124362834)
# ('agg__mean_timesincelastevent > 104.56', -0.0788215530949123)
# ('agg__max_timesincecasestart > 1045.62', -0.061795912569457996)
# ('0.82 < agg__std_open_cases <= 2.19', -0.05937411528677157)
# (1, 110) 1 [10]
# Generating local Explanations for 0    204475_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.96412945 0.03587057]
# Explanation for class deviant
# ('agg__Resource_11200.0 <= 0.00', 0.11636746020215445)
# ('agg__Resource_10932.0 <= 0.00', -0.10643327887267105)
# ('agg__mean_timesincelastevent > 104.56', -0.06362805280543271)
# ('agg__Activity_A_ACCEPTED-COMPLETE <= 0.00', -0.052810941326502096)
# ('54.76 < agg__std_timesincelastevent <= 268.47', 0.05065585711138039)
# ('agg__max_timesincecasestart > 1045.62', -0.0463376642484276)
# (1, 110) 0 [10]
# Generating local Explanations for 0    204481_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.25446087 0.7455391 ]
# Explanation for class deviant
# ('agg__Resource_11200.0 <= 0.00', 0.12803696641336756)
# ('agg__mean_timesincelastevent > 104.56', -0.08091455645201608)
# ('agg__std_timesincelastevent > 268.47', 0.07150498742137339)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.05922729608930622)
# ('agg__mean_timesincecasestart > 504.69', -0.053397176793661676)
# ('0.00 < agg__Activity_A_ACCEPTED-COMPLETE <= 1.00', 0.05327949067330685)
# (1, 110) 0 [10]
# Generating local Explanations for 0    204484_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.94280565 0.05719432]
# Explanation for class deviant
# ('agg__Resource_10932.0 <= 0.00', -0.1409956125109953)
# ('agg__std_timesincelastevent > 268.47', 0.06888642943137326)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.06399538895657061)
# ('agg__mean_timesincelastevent > 104.56', -0.06165230736874504)
# ('agg__Activity_A_ACCEPTED-COMPLETE <= 0.00', -0.05221283883057676)
# ('agg__max_timesincecasestart > 1045.62', -0.04656827725697126)
# (1, 110) 0 [10]
# Generating local Explanations for 0    204499_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.915065 0.084935]
# Explanation for class deviant
# ('agg__Resource_11200.0 <= 0.00', 0.14196648982861707)
# ('agg__max_timesincecasestart <= 32.33', 0.14158736037065622)
# ('agg__Resource_10932.0 <= 0.00', -0.129509254012628)
# ('agg__mean_timesincecasestart <= 15.15', 0.10674406451785547)
# ('agg__std_timesincelastevent <= 6.11', -0.06586267234391771)
# ('agg__std_timesincemidnight <= 14.23', 0.06557857545139355)
# (1, 110) 0 [10]
# Generating local Explanations for 0    204514_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.19491553 0.80508447]
# Explanation for class deviant
# ('agg__Resource_11200.0 <= 0.00', 0.12843098959834945)
# ('agg__Resource_10932.0 <= 0.00', -0.11238849267664683)
# ('agg__std_timesincelastevent > 268.47', 0.09343354439118352)
# ('0.00 < agg__Activity_A_ACCEPTED-COMPLETE <= 1.00', 0.05875358760951254)
# ('agg__min_open_cases > 741.00', 0.05325481132096755)
# ('agg__mean_timesincecasestart > 504.69', -0.05058397189457152)
# (1, 110) 1 [10]
# Generating local Explanations for 0    204523_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.5296224  0.47037762]
# Explanation for class deviant
# ('agg__Resource_11200.0 <= 0.00', 0.12816487448099154)
# ('agg__max_timesincecasestart <= 32.33', 0.10871864137135803)
# ('agg__mean_timesincecasestart <= 15.15', 0.0995562354718062)
# ('agg__std_timesincelastevent <= 6.11', -0.0792237560668648)
# ('agg__std_timesincemidnight <= 14.23', 0.07483759006144987)
# ('agg__std_open_cases <= 0.82', 0.0660004158743018)
# (1, 110) 1 [10]
# Generating local Explanations for 0    204541_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.67517895 0.32482105]
# Explanation for class deviant
# ('agg__Resource_11200.0 <= 0.00', 0.14186911852368783)
# ('agg__Resource_10932.0 <= 0.00', -0.11179602902600665)
# ('agg__Resource_11201.0 <= 0.00', 0.08880542030805204)
# ('agg__std_timesincelastevent > 268.47', 0.06608166006339852)
# ('0.82 < agg__std_open_cases <= 2.19', -0.06187493941985908)
# ('0.00 < agg__Activity_A_ACCEPTED-COMPLETE <= 1.00', 0.05247624133879133)
# Bucket 11
# number events 10307
# Training model iteration  0
# (10307, 18)
# Bucket 12
# number events 11244
# Training model iteration  0
# (11244, 18)
# Bucket 13
# number events 12181
# Training model iteration  0
# (12181, 18)
# Bucket 14
# number events 13118
# Training model iteration  0
# (13118, 18)
# Bucket 15
# number events 14055
# Training model iteration  0
# The number of testing instances is  3654
# The total number of columns is 122
# The total accuracy is  1.0
# (14055, 18)
# (1, 122) 0 [15]
# Generating local Explanations for 0    204466_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.7224598  0.27754024]
# Explanation for class deviant
# ('agg__Resource_11049.0 <= 0.00', -0.20339392721676516)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.17372494304558392)
# ('agg__Resource_10881.0 <= 0.00', -0.13571215074837456)
# ('agg__Resource_11200.0 <= 0.00', 0.10932175540548784)
# ('agg__mean_timesincemidnight > 1056.43', 0.05768210501496673)
# ('agg__mean_weekday > 3.00', 0.0566707519780532)
# (1, 122) 0 [15]
# Generating local Explanations for 0    204469_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.06368667 0.93631333]
# Explanation for class deviant
# ('agg__Resource_11049.0 <= 0.00', -0.23231721146388873)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.14285489654647476)
# ('agg__Resource_11200.0 <= 0.00', 0.12198319157162987)
# ('agg__Resource_10932.0 <= 0.00', -0.11912004144889732)
# ('static__AMOUNT_REQ <= 7000.00', -0.10269010169761399)
# ('agg__Resource_11119.0 <= 0.00', 0.10138659630941574)
# (1, 122) 0 [15]
# Generating local Explanations for 0    204472_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.03356773 0.9664323 ]
# Explanation for class deviant
# ('agg__Resource_11049.0 <= 0.00', -0.21504611879652177)
# ('agg__Resource_11200.0 <= 0.00', 0.1522332013899712)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.14632542938090146)
# ('agg__Activity_W_Valideren aanvraag-SCHEDULE <= 0.00', -0.12233563432625938)
# ('static__AMOUNT_REQ <= 7000.00', -0.10854758117284537)
# ('agg__Resource_11119.0 <= 0.00', 0.10111414570215839)
# (1, 122) 1 [15]
# Generating local Explanations for 0    204475_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.44215178 0.5578482 ]
# Explanation for class deviant
# ('agg__Resource_11049.0 <= 0.00', -0.22939648688452238)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.16491586761092353)
# ('agg__Resource_10932.0 <= 0.00', -0.11781413354039891)
# ('agg__Activity_W_Valideren aanvraag-SCHEDULE <= 0.00', -0.11772798767088803)
# ('agg__Resource_11200.0 <= 0.00', 0.09894257772272362)
# ('agg__Resource_11119.0 <= 0.00', 0.09329498249839067)
# (1, 122) 0 [15]
# Generating local Explanations for 0    204481_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.04983521 0.9501648 ]
# Explanation for class deviant
# ('agg__Resource_11049.0 <= 0.00', -0.2344944351423472)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.12725876950679826)
# ('agg__mean_timesincelastevent > 642.84', -0.12325541227688908)
# ('agg__Activity_W_Valideren aanvraag-SCHEDULE <= 0.00', -0.11932055302179496)
# ('agg__Resource_10932.0 <= 0.00', -0.11211803050186685)
# ('11806.00 < static__AMOUNT_REQ <= 20000.00', 0.09059571422563682)
# (1, 122) 0 [15]
# Generating local Explanations for 0    204484_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9757361  0.02426393]
# Explanation for class deviant
# ('agg__Resource_11049.0 <= 0.00', -0.24747273775419457)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.15380327856806786)
# ('agg__Resource_10881.0 <= 0.00', -0.14797645777542545)
# ('agg__Resource_11200.0 <= 0.00', 0.13172708101099337)
# ('agg__Resource_11119.0 <= 0.00', 0.10496283950909761)
# ('11806.00 < static__AMOUNT_REQ <= 20000.00', 0.08607418776548834)
# (1, 122) 0 [15]
# Generating local Explanations for 0    204499_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.45295525 0.54704475]
# Explanation for class deviant
# ('agg__Resource_11049.0 <= 0.00', -0.23025718612202054)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.16781601584232417)
# ('agg__Resource_11200.0 <= 0.00', 0.12006610555962174)
# ('agg__mean_timesincelastevent > 642.84', -0.12006028593025822)
# ('agg__std_timesincecasestart > 2626.48', 0.0642245781459261)
# ('agg__mean_timesincemidnight > 1056.43', 0.06246942830998753)
# (1, 122) 0 [15]
# Generating local Explanations for 0    204514_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.07369578 0.9263042 ]
# Explanation for class deviant
# ('agg__Resource_11049.0 <= 0.00', -0.27691511394767987)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.18848207579662327)
# ('agg__Resource_11200.0 <= 0.00', 0.12663399671416414)
# ('agg__Activity_W_Valideren aanvraag-SCHEDULE <= 0.00', -0.10694717123816315)
# ('static__AMOUNT_REQ <= 7000.00', -0.1056436347540276)
# ('agg__mean_weekday > 3.00', 0.05906300913390342)
# (1, 122) 1 [15]
# Generating local Explanations for 0    204523_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.24240041 0.7575996 ]
# Explanation for class deviant
# ('agg__Resource_11049.0 <= 0.00', -0.20738557816458625)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.16463020171787163)
# ('agg__mean_timesincelastevent > 642.84', -0.111162452504953)
# ('static__AMOUNT_REQ <= 7000.00', -0.08529102687200649)
# ('agg__mean_weekday > 3.00', 0.06007204054312006)
# ('agg__mean_timesincemidnight > 1056.43', 0.05996958098470664)
# (1, 122) 1 [15]
# Generating local Explanations for 0    204541_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.4790628 0.5209372]
# Explanation for class deviant
# ('agg__Resource_11049.0 <= 0.00', -0.22166848532612718)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.15120582627105905)
# ('agg__Resource_11200.0 <= 0.00', 0.12312576587603283)
# ('agg__Resource_10932.0 <= 0.00', -0.107097629967852)
# ('agg__Resource_11119.0 <= 0.00', 0.09067899486901715)
# ('702.75 < agg__mean_timesincecasestart <= 1414.07', 0.05285010299110624)
# Bucket 16
# number events 14992
# Training model iteration  0
# (14992, 18)
# Bucket 17
# number events 15908
# Training model iteration  0
# (15572, 18)
# Bucket 18
# number events 16823
# Training model iteration  0
# (16470, 18)
# Bucket 19
# number events 17720
# Training model iteration  0
# (17043, 18)
# Bucket 20
# number events 18615
# Training model iteration  0
# The number of testing instances is  3419
# The total number of columns is 133
# The total accuracy is  1.0
# (17900, 18)
# (1, 133) 0 [20]
# Generating local Explanations for 0    204466_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.3057186 0.6942814]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.35384588533939004)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.29338592609598035)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.2857916297925688)
# ('agg__Resource_11049.0 <= 0.00', -0.24518350035033895)
# ('agg__Resource_10899.0 <= 0.00', -0.116248787145212)
# ('2.66 < agg__std_hour <= 3.67', 0.061639345829815125)
# (1, 133) 0 [20]
# Generating local Explanations for 0    204469_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.95861006 0.04138994]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.34532208173745244)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.27202540840334943)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.2673731061711816)
# ('agg__Resource_11049.0 <= 0.00', -0.2583028097804211)
# ('agg__Resource_10932.0 <= 0.00', -0.14193645912819172)
# ('static__AMOUNT_REQ <= 7000.00', -0.0739058129835528)
# (1, 133) 0 [20]
# Generating local Explanations for 0    204472_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.33257502 0.667425  ]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.3273139249939613)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.28546058812342456)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.27503499613389026)
# ('agg__Resource_11049.0 <= 0.00', -0.23670841040849958)
# ('agg__mean_timesincelastevent > 732.14', -0.08516438813323716)
# ('static__AMOUNT_REQ <= 7000.00', -0.07897972106616925)
# (1, 133) 1 [20]
# Generating local Explanations for 0    204475_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.82886463 0.17113537]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.3386037446927085)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.28677637319245636)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.25544666618206563)
# ('agg__Resource_11049.0 <= 0.00', -0.2208609337110726)
# ('agg__Resource_10932.0 <= 0.00', -0.1287861788093353)
# ('agg__mean_timesincelastevent <= 128.89', 0.06883689831474141)
# (1, 133) 0 [20]
# Generating local Explanations for 0    204481_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.02729005 0.97270995]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.32769941086823307)
# ('0.00 < agg__Activity_O_SENT_BACK-COMPLETE <= 1.00', 0.27015422678304535)
# ('agg__Activity_A_DECLINED-COMPLETE > 0.00', -0.2584087083237192)
# ('agg__Resource_11049.0 <= 0.00', -0.2498386068315568)
# ('agg__mean_timesincelastevent > 732.14', -0.09772441219424848)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.07620401994896808)
# (1, 133) 0 [20]
# Generating local Explanations for 0    204484_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.4119351 0.5880649]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.3314127825089252)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.3010092664762251)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.2817436877508784)
# ('agg__Resource_11049.0 <= 0.00', -0.2261487685178612)
# ('agg__Resource_10932.0 <= 0.00', -0.14281432502359342)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.0894828783112731)
# (1, 133) 0 [20]
# Generating local Explanations for 0    204499_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.07525885 0.92474115]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE > 0.00', -0.3239669388905165)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.2816402681639857)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.2759389503337133)
# ('agg__Resource_11049.0 <= 0.00', -0.22362336573304595)
# ('agg__mean_timesincelastevent > 732.14', -0.08869354231532847)
# ('agg__Activity_W_Valideren aanvraag-SCHEDULE <= 0.00', -0.07282440177352593)
# (1, 133) 0 [20]
# Generating local Explanations for 0    204514_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.6667311  0.33326885]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.3351404133325475)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.294595180050011)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.2932693133932859)
# ('agg__Resource_11049.0 <= 0.00', -0.25938320198766635)
# ('agg__mean_timesincelastevent > 732.14', -0.09353102217503437)
# ('agg__Activity_W_Valideren aanvraag-SCHEDULE <= 0.00', -0.08380509730970635)
# (1, 133) 1 [20]
# Generating local Explanations for 0    204523_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.01523745 0.98476255]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.3414928322251571)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.3047043754676824)
# ('0.00 < agg__Activity_O_SENT_BACK-COMPLETE <= 1.00', 0.27575777183521843)
# ('agg__Resource_11049.0 <= 0.00', -0.2420207547942017)
# ('static__AMOUNT_REQ <= 7000.00', -0.08504856592068834)
# ('agg__mean_timesincelastevent > 732.14', -0.08127702213393165)
# (1, 133) 1 [20]
# Generating local Explanations for 0    204541_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.6920788  0.30792117]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.33163924667781736)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.28572212620598875)
# ('0.00 < agg__Activity_O_SENT_BACK-COMPLETE <= 1.00', 0.2768114861703301)
# ('agg__Resource_11049.0 <= 0.00', -0.24254467016269138)
# ('agg__Resource_11200.0 <= 0.00', 0.11822196413892816)
# ('agg__Activity_W_Valideren aanvraag-SCHEDULE > 0.00', 0.06980621834103416)
# Bucket 21
# number events 19487
# Training model iteration  0
# (18312, 18)
# Bucket 22
# number events 20351
# Training model iteration  0
# (19008, 18)
# Bucket 23
# number events 21181
# Training model iteration  0
# (19090, 18)
# Bucket 24
# number events 21995
# Training model iteration  0
# (19536, 18)
# Bucket 25
# number events 22765
# Training model iteration  0
# The number of testing instances is  2847
# The total number of columns is 134
# The total accuracy is  1.0
# (19250, 18)
# (1, 134) 0 [25]
# Generating local Explanations for 0    204466_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.98683596 0.01316404]
# Explanation for class deviant
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.3192809851654347)
# ('agg__Activity_A_CANCELLED-COMPLETE > 0.00', -0.23105538704642903)
# ('agg__Resource_11049.0 <= 0.00', -0.12769256433545662)
# ('agg__std_timesincelastevent > 2476.94', 0.10279579636966668)
# ('agg__mean_timesincelastevent > 807.14', -0.08850579332239888)
# ('agg__max_timesincecasestart > 20179.89', -0.0808263327635672)
# (1, 134) 0 [25]
# Generating local Explanations for 0    204469_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.02186149 0.9781385 ]
# Explanation for class deviant
# ('0.00 < agg__Activity_O_SENT_BACK-COMPLETE <= 1.00', 0.3109165266905581)
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.2446533834164615)
# ('agg__Resource_11049.0 <= 0.00', -0.1658363485357243)
# ('agg__std_timesincelastevent > 2476.94', 0.08845874790228996)
# ('agg__std_timesincemidnight > 226.28', -0.07969306317475269)
# ('0.00 < agg__Activity_W_Valideren aanvraag-SCHEDULE <= 1.00', 0.07564605838232483)
# (1, 134) 0 [25]
# Generating local Explanations for 0    204472_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.6551533 0.3448467]
# Explanation for class deviant
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.3173975549461694)
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.27505957810722725)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.267005372624189)
# ('agg__Resource_11049.0 <= 0.00', -0.15069331967832572)
# ('agg__std_timesincelastevent > 2476.94', 0.09675906235666541)
# ('agg__Activity_W_Valideren aanvraag-SCHEDULE <= 0.00', -0.07219164945303201)
# (1, 134) 1 [25]
# Generating local Explanations for 0    204475_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.63255465 0.36744535]
# Explanation for class deviant
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.3006333423655164)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.27782036092493795)
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.253080226875432)
# ('agg__Resource_11049.0 <= 0.00', -0.137149358695258)
# ('agg__Resource_10609.0 <= 0.00', 0.11891540500818394)
# ('agg__std_timesincelastevent > 2476.94', 0.08968028717369152)
# (1, 134) 0 [25]
# Generating local Explanations for 0    204484_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.98639435 0.01360565]
# Explanation for class deviant
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.3115393247344007)
# ('agg__Activity_A_CANCELLED-COMPLETE > 0.00', -0.2856769987973093)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.25138292952721114)
# ('agg__Resource_11049.0 <= 0.00', -0.14935818565621975)
# ('agg__Activity_W_Completeren aanvraag-COMPLETE > 3.00', -0.07683602445153319)
# ('agg__Activity_W_Valideren aanvraag-SCHEDULE <= 0.00', -0.0626691620393462)
# (1, 134) 0 [25]
# Generating local Explanations for 0    204514_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.99425197 0.00574804]
# Explanation for class deviant
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.325807965744019)
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.2437196258343556)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.2356192167094641)
# ('agg__Resource_11049.0 <= 0.00', -0.1517355634293746)
# ('agg__std_timesincelastevent > 2476.94', 0.07516344898859076)
# ('agg__Activity_W_Valideren aanvraag-SCHEDULE <= 0.00', -0.06744281224294597)
# (1, 134) 1 [25]
# Generating local Explanations for 0    204523_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.00166839 0.9983316 ]
# Explanation for class deviant
# ('0.00 < agg__Activity_O_SENT_BACK-COMPLETE <= 1.00', 0.3250816236717309)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.2498731894449706)
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.22654203369199408)
# ('agg__Resource_11049.0 <= 0.00', -0.148297855667681)
# ('agg__std_timesincelastevent > 2476.94', 0.10193124176909078)
# ('0.00 < agg__Activity_W_Valideren aanvraag-SCHEDULE <= 1.00', 0.06604690508024538)
# (1, 134) 1 [25]
# Generating local Explanations for 0    204541_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.09319758 0.9068024 ]
# Explanation for class deviant
# ('0.00 < agg__Activity_O_SENT_BACK-COMPLETE <= 1.00', 0.3087417448013109)
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.25880625669213264)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.22655511581579926)
# ('agg__Resource_11049.0 <= 0.00', -0.13586199440275165)
# ('agg__Resource_10932.0 <= 0.00', -0.09945107487851271)
# ('0.00 < agg__Activity_W_Valideren aanvraag-SCHEDULE <= 1.00', 0.05587750726653894)
# Bucket 26
# number events 23517
# Training model iteration  0
# (19552, 18)
# Bucket 27
# number events 24223
# Training model iteration  0
# (19062, 18)
# Bucket 28
# number events 24909
# Training model iteration  0
# (19208, 18)
# Bucket 29
# number events 25551
# Training model iteration  0
# (18618, 18)
# Bucket 30
# number events 26169
# Training model iteration  0
# (18540, 18)
# Bucket 31
# number events 26751
# Training model iteration  0
# (18042, 18)
# Bucket 32
# number events 27298
# Training model iteration  0
# (17504, 18)
# Bucket 33
# number events 27807
# Training model iteration  0
# (16797, 18)
# Bucket 34
# number events 28290
# Training model iteration  0
# (16422, 18)
# Bucket 35
# number events 28742
# Training model iteration  0
# (15820, 18)
# Bucket 36
# number events 29166
# Training model iteration  0
# (15264, 18)
# Bucket 37
# number events 29565
# Training model iteration  0
# (14763, 18)
# Bucket 38
# number events 29947
# Training model iteration  0
# (14516, 18)
# Bucket 39
# number events 30300
# Training model iteration  0
# (13767, 18)
# Bucket 40
# number events 30637
# Training model iteration  0
# (13480, 18)
# bpic2012_accepted prefix_agg xgboost 1 auc 0.5522114814645935
# bpic2012_accepted prefix_agg xgboost 2 auc 0.5342209657562355
# bpic2012_accepted prefix_agg xgboost 3 auc 0.5218001915097351
# bpic2012_accepted prefix_agg xgboost 4 auc 0.5458984998404086
# bpic2012_accepted prefix_agg xgboost 5 auc 0.5622725821895946
# bpic2012_accepted prefix_agg xgboost 6 auc 0.5414709771556245
# bpic2012_accepted prefix_agg xgboost 7 auc 0.5560439560439561
# bpic2012_accepted prefix_agg xgboost 8 auc 0.5757785782682048
# bpic2012_accepted prefix_agg xgboost 9 auc 0.564661894122475
# bpic2012_accepted prefix_agg xgboost 10 auc 0.571708996397793
# bpic2012_accepted prefix_agg xgboost 11 auc 0.5586521362454973
# bpic2012_accepted prefix_agg xgboost 12 auc 0.5737677260498837
# bpic2012_accepted prefix_agg xgboost 13 auc 0.5684556107792623
# bpic2012_accepted prefix_agg xgboost 14 auc 0.5823172677944461
# bpic2012_accepted prefix_agg xgboost 15 auc 0.5982399343395193
# bpic2012_accepted prefix_agg xgboost 16 auc 0.6227850987187087
# bpic2012_accepted prefix_agg xgboost 17 auc 0.639453505937243
# bpic2012_accepted prefix_agg xgboost 18 auc 0.65540521115828
# bpic2012_accepted prefix_agg xgboost 19 auc 0.6373044043393491
# bpic2012_accepted prefix_agg xgboost 20 auc 0.6843057076547476
# bpic2012_accepted prefix_agg xgboost 21 auc 0.6986381529949994
# bpic2012_accepted prefix_agg xgboost 22 auc 0.7330711911537877
# bpic2012_accepted prefix_agg xgboost 23 auc 0.7316127734116088
# bpic2012_accepted prefix_agg xgboost 24 auc 0.7692846169095054
# bpic2012_accepted prefix_agg xgboost 25 auc 0.7348867761452031
# bpic2012_accepted prefix_agg xgboost 26 auc 0.7492132867132867
# bpic2012_accepted prefix_agg xgboost 27 auc 0.757084183821038
# bpic2012_accepted prefix_agg xgboost 28 auc 0.7719100032658682
# bpic2012_accepted prefix_agg xgboost 29 auc 0.7897923088584567
# bpic2012_accepted prefix_agg xgboost 30 auc 0.7963276742305946
# bpic2012_accepted prefix_agg xgboost 31 auc 0.8012822906940553
# bpic2012_accepted prefix_agg xgboost 32 auc 0.800530922657483
# bpic2012_accepted prefix_agg xgboost 33 auc 0.7807574688308634
# bpic2012_accepted prefix_agg xgboost 34 auc 0.784297052154195
# bpic2012_accepted prefix_agg xgboost 35 auc 0.7701778087684128
# bpic2012_accepted prefix_agg xgboost 36 auc 0.7813175501801338
# bpic2012_accepted prefix_agg xgboost 37 auc 0.7598697598697599
# bpic2012_accepted prefix_agg xgboost 38 auc 0.773756372502454
# bpic2012_accepted prefix_agg xgboost 39 auc 0.7766439909297053
# bpic2012_accepted prefix_agg xgboost 40 auc 0.7825975578515925
# bpic2012_accepted prefix_agg xgboost -1 -1 auc 0.6688296784858923

# %%
rc={'axes.labelsize': 12, 'xtick.labelsize': 13, 'ytick.labelsize': 13 , 'axes.titlesize': 10}
sns.set(rc)
sns.set_style("whitegrid")
# %matplotlib inline
for pre, exp in exp_ddict.items():
    #print('Explanations for prefix length ', pre)
    fig = exp.as_pyplot_figure()

# %%
rc={'axes.labelsize': 12, 'xtick.labelsize': 13, 'ytick.labelsize': 13 , 'axes.titlesize': 10}
sns.set(rc)
sns.set_style("whitegrid")
for pre, importance in importance_dict.items():
    if(pre==10):
        print('printing global feature importance of the XGBoost classifier', pre, importance.head(10)) 
        title = 'Prefix length {} bucket: prefix, encoding: aggregation, classifier: xgboost'.format(pre)
        var_imp_plot(importance, title, 10)
# Out:
# printing global feature importance of the XGBoost classifier 10                                          feature  feature_importance
# 0  agg__Activity_W_Completeren aanvraag-SCHEDULE            0.064664
# 1                          agg__Resource_10629.0            0.045234
# 2                          agg__Resource_10862.0            0.031930
# 3           agg__Activity_A_PREACCEPTED-COMPLETE            0.027726
# 4                          agg__Resource_10931.0            0.023714
# 5                          agg__Resource_11003.0            0.022464
# 6                          agg__Resource_11009.0            0.021187
# 7                          agg__Resource_10982.0            0.017179
# 8                          agg__Resource_10932.0            0.015918
# 9                          agg__Resource_11002.0            0.015315
