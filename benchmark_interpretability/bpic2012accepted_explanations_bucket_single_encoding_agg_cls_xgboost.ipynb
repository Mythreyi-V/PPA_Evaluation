# %% [markdown]
# ### BPIC2012
# Bucket: Single
#
# Encoding: Aggregation
#
# Classifier: XGBoost
#
# The notebook has all the code for running the benchmark and deriving explanations

# %%
import EncoderFactory
from DatasetManager import DatasetManager
import BucketFactory

import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import StandardScaler

import time
import os
import sys
from sys import argv
import pickle
from collections import defaultdict

from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import lime
import lime.lime_tabular
from lime import submodular_pick;
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

def imp_df(column_names, importances):
        df = pd.DataFrame({'feature': column_names,
                       'feature_importance': importances}) \
           .sort_values('feature_importance', ascending = False) \
           .reset_index(drop = True)
        return df

# plotting a feature importance dataframe (horizontal barchart)
def var_imp_plot(imp_df, title, num_feat):
        imp_df.columns = ['feature', 'feature_importance']
        b= sns.barplot(x = 'feature_importance', y = 'feature', data = imp_df.head(num_feat), orient = 'h', palette="Blues_r") \
           .set_title(title, fontsize = 14)

# %%
def generate_global_explanations(train_X,train_Y, cls, feature_combiner):
    
    print("The number of testing instances is ",len(train_Y))
    print("The total number of columns is",train_X.shape[1]);
    print("The total accuracy is ",cls.score(train_X,train_Y));
       
    sns.set(rc={'figure.figsize':(10,10), "font.size":18,"axes.titlesize":18,"axes.labelsize":18})
    sns.set
    feat_names = feature_combiner.get_feature_names()
    base_imp = imp_df(feat_names, cls.feature_importances_)
    base_imp.head(15)
    var_imp_plot(base_imp, 'Feature importance using XGBoost', 15)
    return base_imp

# %%
from lime import submodular_pick
def generate_local_explanations(explainer,test_xi, cls,test_y, submod=False, test_all_data=None):
    
    print("Actual value ", test_y)
    num_features=6;# maximum is 6 ,if it is larger than 6, the features displayed are different.
    exp = explainer.explain_instance(test_xi, 
                                 cls.predict_proba, num_features=num_features, labels=[0,1])
    
    #exp.show_in_notebook(show_table=True, show_all=False);
    probability_result=cls.predict_proba([test_xi])[0];
    print(probability_result);
    print ('Explanation for class %s' % class_names[1])
    print ('\n'.join(map(str, exp.as_list(label=1))))
    return exp
    #%matplotlib inline
    #fig = exp.as_pyplot_figure()
        
    if submod==True:
        sp_obj=submodular_pick.SubmodularPick(explainer, test_all_data, cls.predict_proba, 
                                      sample_size=20, num_features=num_features,num_exps_desired=4)
        [exp.as_pyplot_figure(label=exp.available_labels()[0]) for exp in sp_obj.sp_explanations];

# %%
dataset_ref = "bpic2012"
params_dir = "params"
results_dir = "results"
bucket_method = "single"
cls_encoding = "agg"
cls_method = "xgboost"
gap = 1
n_iter = 1

if bucket_method == "state":
    bucket_encoding = "last"
else:
    bucket_encoding = "agg"

method_name = "%s_%s"%(bucket_method, cls_encoding)

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"]
    #"insurance": ["insurance_activity", "insurance_followup"],
    #"sepsis_cases": ["sepsis_cases_1", "sepsis_cases_2", "sepsis_cases_4"]
}

encoding_dict = {
    "laststate": ["static", "last"],
    "agg": ["static", "agg"],
    "index": ["static", "index"],
    "combined": ["static", "last", "agg"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]
methods = encoding_dict[cls_encoding]
    
train_ratio = 0.8
random_state = 22

# create results directory
if not os.path.exists(os.path.join(params_dir)):
    os.makedirs(os.path.join(params_dir))
    
print(datasets)
# Out:
# ['bpic2012_accepted']

# %%
for dataset_name in datasets:
    
    # load optimal params
    optimal_params_filename = os.path.join(params_dir, "optimal_params_%s_%s_%s.pickle" % (cls_method, dataset_name, method_name))
    if not os.path.isfile(optimal_params_filename) or os.path.getsize(optimal_params_filename) <= 0:
        continue
        
    with open(optimal_params_filename, "rb") as fin:
        args = pickle.load(fin)
        
    print(args)
    
    # read the data
    dataset_manager = DatasetManager(dataset_name)
    data = dataset_manager.read_dataset()
    cls_encoder_args = {'case_id_col': dataset_manager.case_id_col, 
                        'static_cat_cols': dataset_manager.static_cat_cols,
                        'static_num_cols': dataset_manager.static_num_cols, 
                        'dynamic_cat_cols': dataset_manager.dynamic_cat_cols,
                        'dynamic_num_cols': dataset_manager.dynamic_num_cols, 
                        'fillna': True}

    # determine min and max (truncated) prefix lengths
    min_prefix_length = 1
    if "traffic_fines" in dataset_name:
        max_prefix_length = 10
    elif "bpic2017" in dataset_name:
        max_prefix_length = min(20, dataset_manager.get_pos_case_length_quantile(data, 0.90))
    else:
        max_prefix_length = min(40, dataset_manager.get_pos_case_length_quantile(data, 0.90))

    # split into training and test
    train, test = dataset_manager.split_data_strict(data, train_ratio, split="temporal")
    
    if gap > 1:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s_gap%s.csv" % (cls_method, dataset_name, method_name, gap))
    else:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s.csv" % (cls_method, dataset_name, method_name))
        
    start_test_prefix_generation = time.time()
    dt_test_prefixes = dataset_manager.generate_prefix_data(test, min_prefix_length, max_prefix_length)
    test_prefix_generation_time = time.time() - start_test_prefix_generation
            
    offline_total_times = []
    online_event_times = []
    train_prefix_generation_times = []

    impotance=None
    #storing local explanations
    exp_dlist=[]
    exp_rlist=[]
    for ii in range(n_iter):
        # create prefix logs
        start_train_prefix_generation = time.time()
        dt_train_prefixes = dataset_manager.generate_prefix_data(train, min_prefix_length, max_prefix_length, gap)
        train_prefix_generation_time = time.time() - start_train_prefix_generation
        train_prefix_generation_times.append(train_prefix_generation_time)
            
        # Bucketing prefixes based on control flow
        bucketer_args = {'encoding_method':bucket_encoding, 
                         'case_id_col':dataset_manager.case_id_col, 
                         'cat_cols':[dataset_manager.activity_col], 
                         'num_cols':[], 
                         'random_state':random_state}
        if bucket_method == "cluster":
            bucketer_args["n_clusters"] = int(args["n_clusters"])
        bucketer = BucketFactory.get_bucketer(bucket_method, **bucketer_args)

        start_offline_time_bucket = time.time()
        bucket_assignments_train = bucketer.fit_predict(dt_train_prefixes)
        offline_time_bucket = time.time() - start_offline_time_bucket

        bucket_assignments_test = bucketer.predict(dt_test_prefixes)

        preds_all = []
        test_y_all = []
        nr_events_all = []
        offline_time_fit = 0
        current_online_event_times = []
        
        for bucket in set(bucket_assignments_test):
            print("Bucket" , bucket )
            if bucket_method == "prefix":
                current_args = args[bucket]
            else:
                current_args = args
            relevant_train_cases_bucket = dataset_manager.get_indexes(dt_train_prefixes)[bucket_assignments_train == bucket]
            relevant_test_cases_bucket = dataset_manager.get_indexes(dt_test_prefixes)[bucket_assignments_test == bucket]
            dt_test_bucket = dataset_manager.get_relevant_data_by_indexes(dt_test_prefixes, relevant_test_cases_bucket)
            
            nr_events_all.extend(list(dataset_manager.get_prefix_lengths(dt_test_bucket)))
            print('number events', len(nr_events_all))
            
            if len(relevant_train_cases_bucket) == 0:
                preds = [dataset_manager.get_class_ratio(train)] * len(relevant_test_cases_bucket)
                current_online_event_times.extend([0] * len(preds))
            else:
                dt_train_bucket = dataset_manager.get_relevant_data_by_indexes(dt_train_prefixes, relevant_train_cases_bucket) # one row per event
                train_y = dataset_manager.get_label_numeric(dt_train_bucket)

                if len(set(train_y)) < 2:
                    preds = [train_y[0]] * len(relevant_test_cases_bucket)
                    current_online_event_times.extend([0] * len(preds))
                    test_y_all.extend(dataset_manager.get_label_numeric(dt_test_bucket))
                else:
                    start_offline_time_fit = time.time()
                    feature_combiner = FeatureUnion([(method, EncoderFactory.get_encoder(method, **cls_encoder_args)) for method in methods])

                    if cls_method == "rf":
                        cls = RandomForestClassifier(n_estimators=500,
                                                     max_features=current_args['max_features'],
                                                     random_state=random_state)

                    elif cls_method == "xgboost":
                        cls = xgb.XGBClassifier(objective='binary:logistic',
                                                n_estimators=500,
                                                learning_rate= current_args['learning_rate'],
                                                subsample=current_args['subsample'],
                                                max_depth=int(current_args['max_depth']),
                                                colsample_bytree=current_args['colsample_bytree'],
                                                min_child_weight=int(current_args['min_child_weight']),
                                                seed=random_state)

                    elif cls_method == "logit":
                        cls = LogisticRegression(C=2**current_args['C'],
                                                 random_state=random_state)

                    elif cls_method == "svm":
                        cls = SVC(C=2**current_args['C'],
                                  gamma=2**current_args['gamma'],
                                  random_state=random_state)

                    if cls_method == "svm" or cls_method == "logit":
                        pipeline = Pipeline([('encoder', feature_combiner), ('scaler', StandardScaler()), ('cls', cls)])
                    else:
                        pipeline = Pipeline([('encoder', feature_combiner), ('cls', cls)])

                    pipeline.fit(dt_train_bucket, train_y)
                    #get the explainations for the model now
        
                    print("Training model iteration ", ii )
                    
                    #get the training data as a matrix
                    trainingdata=feature_combiner.fit_transform(dt_train_bucket);
                    importance = generate_global_explanations(trainingdata,train_y, cls, feature_combiner)
                    #create an explainer now that can be passed later
                    class_names=['regular','deviant']# regular is 0, deviant is 1, 0 is left, 1 is right
                    explainer = lime.lime_tabular.LimeTabularExplainer(trainingdata,
                                                    feature_names = feature_combiner.get_feature_names(),
                                                   class_names=class_names, discretize_continuous=True)
                    
                    
                    offline_time_fit += time.time() - start_offline_time_fit

                    # predict separately for each prefix case
                    preds = []
                    
                    test_all_grouped = dt_test_bucket.groupby(dataset_manager.case_id_col)
                    print(dt_test_bucket.shape)
                    count_d=0 # count for deviant
                    count_r=0 #count for regular
                    for _, group in test_all_grouped:
                        
                        test_y_group = dataset_manager.get_label_numeric(group)
                        test_y_all.extend(test_y_group)
                            
                        start = time.time()
                        _ = bucketer.predict(group)
                        
                        if cls_method == "svm":
                            pred = pipeline.decision_function(group)
                        else:
                            preds_pos_label_idx = np.where(cls.classes_ == 1)[0][0]
                            pred = pipeline.predict_proba(group)[:,preds_pos_label_idx]
                            #print(test_y_group)
                            if group.shape[0] in [5,10,25] and (count_d<9 or count_r<9):
                                print(group.shape,test_y_group[0], pred)
                                test_x_group= feature_combiner.fit_transform(group) 
                                test_x=np.transpose(test_x_group[0])
                                print('Generating local Explanations for', dataset_manager.get_case_ids(group))
                                exp=generate_local_explanations(explainer, test_x, cls, test_y_group )
                                if(test_y_group[0]==1):
                                    count_d=count_d+1
                                    exp_dlist.append(exp)
                                else:
                                    count_r=count_r+1
                                    exp_rlist.append(exp)
                        pipeline_pred_time = time.time() - start
                        current_online_event_times.append(pipeline_pred_time / len(group))
                        preds.extend(pred)
                        

            preds_all.extend(preds)

      
   
        dt_results = pd.DataFrame({"actual": test_y_all, "predicted": preds_all, "nr_events": nr_events_all})
        for nr_events, group in dt_results.groupby("nr_events"):
            if len(set(group.actual)) < 2:
                print(dataset_name, method_name, cls_method, nr_events, "auc", np.nan)
            else:
                print(dataset_name, method_name, cls_method, nr_events, "auc", roc_auc_score(group.actual, group.predicted))
        print(dataset_name, method_name, cls_method, -1, -1, "auc", roc_auc_score(dt_results.actual, dt_results.predicted))
# Out:
# {'colsample_bytree': 0.5353160434296517, 'learning_rate': 0.05959997729599409, 'max_depth': 22, 'min_child_weight': 3, 'subsample': 0.8342285287391545}
# single
# Bucket 1
# number events 30637
# Training model iteration  0
# The number of testing instances is  117965
# The total number of columns is 134
# The total accuracy is  0.9999915229093375
# (540968, 18)
# (10, 18) 0 [0.20918429]
# Generating local Explanations for 0    204466_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.7908157  0.20918429]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.4815164234082299)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.3108796967256483)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.2664972897222735)
# ('agg__Resource_10972.0 <= 0.00', -0.2442642588021908)
# ('agg__Resource_10138.0 <= 0.00', -0.23223822614661005)
# ('agg__Resource_11049.0 <= 0.00', -0.17398340047748154)
# (25, 18) 0 [0.0005827]
# Generating local Explanations for 0    204466_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [9.994173e-01 5.826967e-04]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE > 0.00', -0.5105217110961091)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.46253053506297404)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.30338450238326237)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2556316491679348)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.24277153893522316)
# ('agg__Resource_10138.0 <= 0.00', -0.2145076022826602)
# (5, 18) 0 [0.347944]
# Generating local Explanations for 0    204466_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.652056 0.347944]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5224449214973184)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.4032426899408447)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.2982281203357443)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2623467331502607)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.2422572601845411)
# ('agg__Resource_10138.0 <= 0.00', -0.21200770510191108)
# (10, 18) 0 [0.09415958]
# Generating local Explanations for 0    204469_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9058404  0.09415958]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5065134372657177)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.4200187981716709)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.2902147096187673)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2657212568929542)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.25022053432127905)
# ('agg__Resource_11049.0 <= 0.00', -0.16826307129538398)
# (25, 18) 0 [0.8893798]
# Generating local Explanations for 0    204469_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.1106202 0.8893798]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.48737064516525724)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.4025352473327644)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.3391998965869836)
# ('agg__Activity_O_SENT_BACK-COMPLETE > 0.00', 0.26780903722098626)
# ('agg__Resource_10138.0 <= 0.00', -0.24175625424516112)
# ('agg__Resource_11049.0 <= 0.00', -0.1557029541746688)
# (5, 18) 0 [0.16209967]
# Generating local Explanations for 0    204469_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.83790034 0.16209967]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.4978567556462765)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.314828544082359)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2761074383867796)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.2592068560676639)
# ('agg__Resource_10138.0 <= 0.00', -0.22500555830944832)
# ('agg__Resource_10972.0 <= 0.00', -0.22128148884010085)
# (10, 18) 0 [0.860464]
# Generating local Explanations for 0    204472_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.13953602 0.860464  ]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5020748436530943)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.3256559592262879)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.30041561901698643)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.250598495244942)
# ('agg__Resource_10972.0 <= 0.00', -0.2347718454368666)
# ('agg__Resource_10138.0 <= 0.00', -0.21811714750113473)
# (25, 18) 0 [0.09009112]
# Generating local Explanations for 0    204472_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9099089  0.09009112]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.502412447729754)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.3160336062248187)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2775486163084229)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.2505153886623818)
# ('agg__Resource_10972.0 <= 0.00', -0.24873300182965255)
# ('agg__Resource_10138.0 <= 0.00', -0.21617138322225002)
# (5, 18) 0 [0.8282904]
# Generating local Explanations for 0    204472_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.1717096 0.8282904]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.499840862237362)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.32035213820032155)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2729785039986119)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.25379866973691406)
# ('agg__Resource_10138.0 <= 0.00', -0.2368862382851535)
# ('agg__Resource_10972.0 <= 0.00', -0.22620557582706377)
# (10, 18) 1 [0.13926849]
# Generating local Explanations for 0    204475_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.8607315  0.13926849]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5010731302515565)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.3129599192654766)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.29395903357632586)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.25058133006313954)
# ('agg__Resource_10138.0 <= 0.00', -0.23736240901103647)
# ('agg__Resource_10972.0 <= 0.00', -0.21251589204718332)
# (25, 18) 1 [0.54169214]
# Generating local Explanations for 0    204475_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.45830786 0.54169214]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5105701235700475)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.41524999606892865)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.3081666213790101)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.30492525979020374)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.255740277705155)
# ('agg__Resource_10138.0 <= 0.00', -0.232097527206341)
# (5, 18) 1 [0.37251577]
# Generating local Explanations for 0    204475_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.6274842  0.37251577]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.49307135298174154)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.2839925057760748)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2761341359202763)
# ('agg__Resource_10972.0 <= 0.00', -0.2523500657114109)
# ('agg__Resource_10138.0 <= 0.00', -0.246451910598436)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.24522267415466606)
# (10, 18) 0 [0.582255]
# Generating local Explanations for 0    204481_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.417745 0.582255]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5283491170626309)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.3159612077721149)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.28669689254576364)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.25486032544564186)
# ('agg__Resource_10972.0 <= 0.00', -0.23154818067969893)
# ('agg__Resource_10138.0 <= 0.00', -0.2184653275443378)
# (5, 18) 0 [0.49416623]
# Generating local Explanations for 0    204481_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.50583375 0.49416623]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.49927995765761446)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.2933993845058647)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.26999644822700164)
# ('agg__Resource_10972.0 <= 0.00', -0.2552806129582704)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.25074603394599054)
# ('agg__Resource_10138.0 <= 0.00', -0.22666949010765755)
# (10, 18) 0 [0.04036644]
# Generating local Explanations for 0    204484_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9596336  0.04036644]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5015878369997353)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.28764051766958465)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.25801460658025654)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2554097322624047)
# ('agg__Resource_10138.0 <= 0.00', -0.22744814462975282)
# ('agg__Resource_11049.0 <= 0.00', -0.15589682619645562)
# (25, 18) 0 [0.00144222]
# Generating local Explanations for 0    204484_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9985578  0.00144222]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE > 0.00', -0.4921262194908582)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.328859641077175)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2689611593850681)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.2555137620955263)
# ('agg__Resource_10138.0 <= 0.00', -0.24347714218680458)
# ('agg__Resource_11049.0 <= 0.00', -0.15989673328909096)
# (5, 18) 0 [0.23496717]
# Generating local Explanations for 0    204484_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.7650328  0.23496717]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5086524234133606)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.3154357123812543)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.3046330951015799)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.2607751619802759)
# ('agg__Resource_10138.0 <= 0.00', -0.24801949684529231)
# ('agg__Resource_10972.0 <= 0.00', -0.24535501334622348)
# (10, 18) 0 [0.20665]
# Generating local Explanations for 0    204499_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.79335 0.20665]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5051216220284822)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.44051276808141027)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.3034237815461732)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2745479491892224)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.2518490241366729)
# ('agg__Resource_10138.0 <= 0.00', -0.20683447647382064)
# (5, 18) 0 [0.44278923]
# Generating local Explanations for 0    204499_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.5572108  0.44278923]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5108591993241576)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.4087581277725835)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.29569628186985575)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.26789796521340214)
# ('agg__Resource_10138.0 <= 0.00', -0.26335252190301306)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.24645142326846536)
# (10, 18) 0 [0.907414]
# Generating local Explanations for 0    204514_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.09258598 0.907414  ]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5062391876096863)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.42897439585680053)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.31905267835721685)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2774148749118789)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.25756360224925917)
# ('agg__Resource_10138.0 <= 0.00', -0.23944438334749016)
# (25, 18) 0 [0.18229997]
# Generating local Explanations for 0    204514_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.8177     0.18229997]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5415514331251678)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.3061257533061819)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.24578732425935398)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2426333537079836)
# ('agg__Resource_10138.0 <= 0.00', -0.22216804621292754)
# ('agg__Resource_11049.0 <= 0.00', -0.1547273100692934)
# (5, 18) 0 [0.9561707]
# Generating local Explanations for 0    204514_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.04382932 0.9561707 ]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5330526736628863)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.31940602123846074)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2990752835898769)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.2518549968278309)
# ('agg__Resource_10972.0 <= 0.00', -0.22189838374341633)
# ('agg__Resource_10138.0 <= 0.00', -0.21179954165168424)
# (10, 18) 1 [0.69463474]
# Generating local Explanations for 0    204523_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.30536526 0.69463474]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5018276125466509)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.4221862525739457)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.3331008186615758)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.27448780782356885)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.24776687960532012)
# ('agg__Resource_10138.0 <= 0.00', -0.2316462307005759)
# (25, 18) 1 [0.99986553]
# Generating local Explanations for 0    204523_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [1.3446808e-04 9.9986553e-01]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5294406721272743)
# ('agg__Activity_A_DECLINED-COMPLETE <= 0.00', 0.40873589204185656)
# ('agg__Activity_A_APPROVED-COMPLETE > 0.00', 0.3258981547194996)
# ('agg__Activity_A_ACTIVATED-COMPLETE > 0.00', 0.2848209030975145)
# ('agg__Activity_O_SENT_BACK-COMPLETE > 0.00', 0.2563650740217312)
# ('agg__Resource_10138.0 <= 0.00', -0.23687609157276573)
# (5, 18) 1 [0.9342185]
# Generating local Explanations for 0    204523_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.06578147 0.9342185 ]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5264122605898888)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.30964546322321984)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.2647852130395067)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.26084892628692674)
# ('agg__Resource_10972.0 <= 0.00', -0.2334718824579204)
# ('agg__Resource_10138.0 <= 0.00', -0.2050775946375037)
# (10, 18) 1 [0.52675116]
# Generating local Explanations for 0    204541_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.47324884 0.52675116]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.4975047214673428)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.3246149498291056)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.275529970401638)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.23817653547246392)
# ('agg__Resource_10138.0 <= 0.00', -0.23486194103986485)
# ('agg__Resource_10972.0 <= 0.00', -0.21693477287010116)
# (25, 18) 1 [0.9333943]
# Generating local Explanations for 0    204541_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.06660569 0.9333943 ]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.5103912417252873)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.299354027797658)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.28310311350733436)
# ('agg__Activity_O_SENT_BACK-COMPLETE > 0.00', 0.25917644968407244)
# ('agg__Resource_10972.0 <= 0.00', -0.24276791813156617)
# ('agg__Resource_10138.0 <= 0.00', -0.21704163035820903)
# (5, 18) 1 [0.38319194]
# Generating local Explanations for 0    204541_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.61680806 0.38319194]
# Explanation for class deviant
# ('agg__Activity_A_CANCELLED-COMPLETE <= 0.00', 0.4992149413894451)
# ('agg__Activity_A_APPROVED-COMPLETE <= 0.00', -0.34131218423002607)
# ('agg__Activity_A_ACTIVATED-COMPLETE <= 0.00', -0.28149289957755014)
# ('agg__Activity_O_SENT_BACK-COMPLETE <= 0.00', -0.25100225906097573)
# ('agg__Resource_10972.0 <= 0.00', -0.22673311498437212)
# ('agg__Resource_10138.0 <= 0.00', -0.21018039562286964)
# bpic2012_accepted single_agg xgboost 1 auc 0.5708038849117687
# bpic2012_accepted single_agg xgboost 2 auc 0.5720076603894031
# bpic2012_accepted single_agg xgboost 3 auc 0.5715881628744699
# bpic2012_accepted single_agg xgboost 4 auc 0.5701176416944052
# bpic2012_accepted single_agg xgboost 5 auc 0.5731795175778578
# bpic2012_accepted single_agg xgboost 6 auc 0.5657015183986139
# bpic2012_accepted single_agg xgboost 7 auc 0.5630295016187132
# bpic2012_accepted single_agg xgboost 8 auc 0.5638639368929825
# bpic2012_accepted single_agg xgboost 9 auc 0.5606584287082212
# bpic2012_accepted single_agg xgboost 10 auc 0.5648214855683735
# bpic2012_accepted single_agg xgboost 11 auc 0.5666271487848251
# bpic2012_accepted single_agg xgboost 12 auc 0.5693949204322648
# bpic2012_accepted single_agg xgboost 13 auc 0.5814281154530117
# bpic2012_accepted single_agg xgboost 14 auc 0.601413524235101
# bpic2012_accepted single_agg xgboost 15 auc 0.6238429620172359
# bpic2012_accepted single_agg xgboost 16 auc 0.6507819980849026
# bpic2012_accepted single_agg xgboost 17 auc 0.6536942845669924
# bpic2012_accepted single_agg xgboost 18 auc 0.6839621285444597
# bpic2012_accepted single_agg xgboost 19 auc 0.6883717442383642
# bpic2012_accepted single_agg xgboost 20 auc 0.7247947916771322
# bpic2012_accepted single_agg xgboost 21 auc 0.7428503032237472
# bpic2012_accepted single_agg xgboost 22 auc 0.7714529338923768
# bpic2012_accepted single_agg xgboost 23 auc 0.770115282643689
# bpic2012_accepted single_agg xgboost 24 auc 0.7805778570720587
# bpic2012_accepted single_agg xgboost 25 auc 0.7739671564390666
# bpic2012_accepted single_agg xgboost 26 auc 0.7925844988344988
# bpic2012_accepted single_agg xgboost 27 auc 0.7968167656951137
# bpic2012_accepted single_agg xgboost 28 auc 0.8161404499836706
# bpic2012_accepted single_agg xgboost 29 auc 0.8166557178230329
# bpic2012_accepted single_agg xgboost 30 auc 0.8305037819639634
# bpic2012_accepted single_agg xgboost 31 auc 0.8386803610333022
# bpic2012_accepted single_agg xgboost 32 auc 0.8389008466063997
# bpic2012_accepted single_agg xgboost 33 auc 0.8395839634371743
# bpic2012_accepted single_agg xgboost 34 auc 0.8398337112622827
# bpic2012_accepted single_agg xgboost 35 auc 0.8266800313780179
# bpic2012_accepted single_agg xgboost 36 auc 0.8274060730828616
# bpic2012_accepted single_agg xgboost 37 auc 0.8264143264143263
# bpic2012_accepted single_agg xgboost 38 auc 0.8282194990658941
# bpic2012_accepted single_agg xgboost 39 auc 0.8147014361300075
# bpic2012_accepted single_agg xgboost 40 auc 0.8197421227905388
# bpic2012_accepted single_agg xgboost -1 -1 auc 0.6990136702667769

# %%
rc={'axes.labelsize': 12, 'xtick.labelsize': 13, 'ytick.labelsize': 13 , 'axes.titlesize': 10}
sns.set(rc)
sns.set_style("whitegrid")
# %matplotlib inline
for exp in exp_dlist:
    fig = exp.as_pyplot_figure()

# %%
print('printing global feature importance of the random forest classifier') 
rc={'axes.labelsize': 14, 'xtick.labelsize': 14, 'ytick.labelsize': 14 ,'axes.titlesize': 15}
sns.set(rc)
sns.set_style("whitegrid")
var_imp_plot(importance, 'bucket:single, encoding:aggregation, classifier:xgboost', 10)
# Out:
# printing global feature importance of the random forest classifier
