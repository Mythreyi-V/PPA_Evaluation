# %% [markdown]
# # BPIC 2012  - Accepted
# #### Bucket - Prefix
# ####  Encoding - Index
# ####  Classifier - XGBoost

# %%
import EncoderFactory
from DatasetManager import DatasetManager
import BucketFactory

import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import StandardScaler

import time
import os
import sys
from sys import argv
import pickle
from collections import defaultdict

from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import lime
import lime.lime_tabular
from lime import submodular_pick;
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

def imp_df(column_names, importances):
        df = pd.DataFrame({'feature': column_names,
                       'feature_importance': importances}) \
           .sort_values('feature_importance', ascending = False) \
           .reset_index(drop = True)
        return df

# plotting a feature importance dataframe (horizontal barchart)
def var_imp_plot(imp_df, title, num_feat):
        imp_df.columns = ['feature', 'feature_importance']
        b= sns.barplot(x = 'feature_importance', y = 'feature', data = imp_df.head(num_feat), orient = 'h', palette="Blues_r") 
        b.set_title(title, fontsize = 14) 
    
        for item in b.get_yticklabels():
            item.set_fontsize(13)

# %%
def generate_global_explanations(train_X,train_Y, cls, feature_combiner):
    
    print("The number of testing instances is ",len(train_Y))
    print("The total number of columns is",train_X.shape[1]);
    print("The total accuracy is ",cls.score(train_X,train_Y));
       
    sns.set(style="darkgrid")
    sns.set(rc={'figure.figsize':(10,10), "font.size":18,"axes.titlesize":18,"axes.labelsize":18})
    sns.set
    feat_names = feature_combiner.get_feature_names()
    base_imp = imp_df(feat_names, cls.feature_importances_)
    base_imp.head(15)
    #var_imp_plot(base_imp, 'Feature importance using Random forest', 15)
    return base_imp

# %%
from lime import submodular_pick
def generate_local_explanations(explainer,test_xi, cls,test_y, submod=False, test_all_data=None):
    
    print("Actual value ", test_y)
    num_features=6;# maximum is 6 ,if it is larger than 6, the features displayed are different.
    exp = explainer.explain_instance(test_xi, 
                                 cls.predict_proba, num_features=num_features, labels=[0,1])
    
    #exp.show_in_notebook(show_table=True, show_all=False);
    probability_result=cls.predict_proba([test_xi])[0];
    print(probability_result);
    print ('Explanation for class %s' % class_names[1])
    print ('\n'.join(map(str, exp.as_list(label=1))))
    return exp
    #%matplotlib inline
    #fig = exp.as_pyplot_figure()
        
    if submod==True:
        sp_obj=submodular_pick.SubmodularPick(explainer, test_all_data, cls.predict_proba, 
                                      sample_size=20, num_features=num_features,num_exps_desired=4)
        [exp.as_pyplot_figure(label=exp.available_labels()[0]) for exp in sp_obj.sp_explanations];

# %%
dataset_ref = "bpic2012"
params_dir = "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "index"
cls_method = "xgboost"
gap = 1
n_iter = 1

if bucket_method == "state":
    bucket_encoding = "last"
else:
    bucket_encoding = "agg"

method_name = "%s_%s"%(bucket_method, cls_encoding)

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"]
    #"insurance": ["insurance_activity", "insurance_followup"],
    #"sepsis_cases": ["sepsis_cases_1", "sepsis_cases_2", "sepsis_cases_4"]
}

encoding_dict = {
    "laststate": ["static", "last"],
    "agg": ["static", "agg"],
    "index": ["static", "index"],
    "combined": ["static", "last", "agg"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]
methods = encoding_dict[cls_encoding]
    
train_ratio = 0.8
random_state = 22

# create results directory
if not os.path.exists(os.path.join(params_dir)):
    os.makedirs(os.path.join(params_dir))
    
print(datasets)
# Out:
# ['bpic2012_accepted']

# %%
from sklearn.metrics import precision_recall_fscore_support
for dataset_name in datasets:
    
    # load optimal params
    optimal_params_filename = os.path.join(params_dir, "optimal_params_%s_%s_%s.pickle" % (cls_method, dataset_name, method_name))
    print(optimal_params_filename)
    if not os.path.isfile(optimal_params_filename) or os.path.getsize(optimal_params_filename) <= 0:
        continue
        
    with open(optimal_params_filename, "rb") as fin:
        args = pickle.load(fin)
        
    print(args)
    bucket_list=[5,10,15,20,25] #:)
    # read the data
    dataset_manager = DatasetManager(dataset_name)
    data = dataset_manager.read_dataset()
    cls_encoder_args = {'case_id_col': dataset_manager.case_id_col, 
                        'static_cat_cols': dataset_manager.static_cat_cols,
                        'static_num_cols': dataset_manager.static_num_cols, 
                        'dynamic_cat_cols': dataset_manager.dynamic_cat_cols,
                        'dynamic_num_cols': dataset_manager.dynamic_num_cols, 
                        'fillna': True}

    # determine min and max (truncated) prefix lengths
    min_prefix_length = 1
    if "traffic_fines" in dataset_name:
        max_prefix_length = 10
    elif "bpic2017" in dataset_name:
        max_prefix_length = min(20, dataset_manager.get_pos_case_length_quantile(data, 0.90))
    else:
        max_prefix_length = min(40, dataset_manager.get_pos_case_length_quantile(data, 0.90))

    # split into training and test
    train, test = dataset_manager.split_data_strict(data, train_ratio, split="temporal")
    
    if gap > 1:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s_gap%s.csv" % (cls_method, dataset_name, method_name, gap))
    else:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s.csv" % (cls_method, dataset_name, method_name))
        
    start_test_prefix_generation = time.time()
    dt_test_prefixes = dataset_manager.generate_prefix_data(test, min_prefix_length, max_prefix_length)
    test_prefix_generation_time = time.time() - start_test_prefix_generation
            
    offline_total_times = []
    online_event_times = []
    train_prefix_generation_times = []
    explained=False
    impotance=None
    exp_ddict=dict()
    exp_rdict=dict()
    model_dict=dict()
    importance_dict=dict()
    for ii in range(n_iter):
        # create prefix logs
        start_train_prefix_generation = time.time()
        dt_train_prefixes = dataset_manager.generate_prefix_data(train, min_prefix_length, max_prefix_length, gap)
        train_prefix_generation_time = time.time() - start_train_prefix_generation
        train_prefix_generation_times.append(train_prefix_generation_time)
            
        # Bucketing prefixes based on control flow
        bucketer_args = {'encoding_method':bucket_encoding, 
                         'case_id_col':dataset_manager.case_id_col, 
                         'cat_cols':[dataset_manager.activity_col], 
                         'num_cols':[], 
                         'random_state':random_state}
        if bucket_method == "cluster":
            bucketer_args["n_clusters"] = int(args["n_clusters"])
        bucketer = BucketFactory.get_bucketer(bucket_method, **bucketer_args)

        start_offline_time_bucket = time.time()
        bucket_assignments_train = bucketer.fit_predict(dt_train_prefixes)
        offline_time_bucket = time.time() - start_offline_time_bucket

        bucket_assignments_test = bucketer.predict(dt_test_prefixes)

        preds_all = []
        test_y_all = []
        nr_events_all = []
        offline_time_fit = 0
        current_online_event_times = []
        
        for bucket in set(bucket_assignments_test):
            print("Bucket" , bucket )
            #args has only one value - some error and so just using it
            #if bucket_method == "prefix":
            #    current_args = args[bucket]
            #else:
            current_args = args
            relevant_train_cases_bucket = dataset_manager.get_indexes(dt_train_prefixes)[bucket_assignments_train == bucket]
            relevant_test_cases_bucket = dataset_manager.get_indexes(dt_test_prefixes)[bucket_assignments_test == bucket]
            dt_test_bucket = dataset_manager.get_relevant_data_by_indexes(dt_test_prefixes, relevant_test_cases_bucket)
            
            nr_events_all.extend(list(dataset_manager.get_prefix_lengths(dt_test_bucket)))
            print('number events', len(nr_events_all))
            
            if len(relevant_train_cases_bucket) == 0:
                preds = [dataset_manager.get_class_ratio(train)] * len(relevant_test_cases_bucket)
                current_online_event_times.extend([0] * len(preds))
            else:
                dt_train_bucket = dataset_manager.get_relevant_data_by_indexes(dt_train_prefixes, relevant_train_cases_bucket) # one row per event
                train_y = dataset_manager.get_label_numeric(dt_train_bucket)

                if len(set(train_y)) < 2:
                    preds = [train_y[0]] * len(relevant_test_cases_bucket)
                    current_online_event_times.extend([0] * len(preds))
                    test_y_all.extend(dataset_manager.get_label_numeric(dt_test_bucket))
                else:
                    start_offline_time_fit = time.time()
                    feature_combiner = FeatureUnion([(method, EncoderFactory.get_encoder(method, **cls_encoder_args)) for method in methods])

                    if cls_method == "rf":
                        cls = RandomForestClassifier(n_estimators=500,
                                                     max_features=current_args['max_features'],
                                                     random_state=random_state)

                    elif cls_method == "xgboost":
                        cls = xgb.XGBClassifier(objective='binary:logistic',
                                                n_estimators=500,
                                                learning_rate= current_args['learning_rate'],
                                                subsample=current_args['subsample'],
                                                max_depth=int(current_args['max_depth']),
                                                colsample_bytree=current_args['colsample_bytree'],
                                                min_child_weight=int(current_args['min_child_weight']),
                                                seed=random_state)

                    elif cls_method == "logit":
                        cls = LogisticRegression(C=2**current_args['C'],
                                                 random_state=random_state)

                    elif cls_method == "svm":
                        cls = SVC(C=2**current_args['C'],
                                  gamma=2**current_args['gamma'],
                                  random_state=random_state)

                    if cls_method == "svm" or cls_method == "logit":
                        pipeline = Pipeline([('encoder', feature_combiner), ('scaler', StandardScaler()), ('cls', cls)])
                    else:
                        pipeline = Pipeline([('encoder', feature_combiner), ('cls', cls)])

                    pipeline.fit(dt_train_bucket, train_y)
                    #get the explainations for the model now
        
                    print("Training model iteration ", ii )
                    
                    #get the training data as a matrix
                    trainingdata=feature_combiner.fit_transform(dt_train_bucket);
                    if bucket in bucket_list:
                        importance = generate_global_explanations(trainingdata,train_y, cls, feature_combiner) 
                        #create an explainer now that can be passed later
                        class_names=['regular','deviant']# regular is 0, deviant is 1, 0 is left, 1 is right
                        explainer = lime.lime_tabular.LimeTabularExplainer(trainingdata,
                                                    feature_names = feature_combiner.get_feature_names(),
                                                   class_names=class_names, discretize_continuous=True)
                        importance_dict[bucket]=importance
                       
                        #exp_dict[bucket]=explainer
                        model_dict[bucket]=cls
                    
                    
                    offline_time_fit += time.time() - start_offline_time_fit

                    # predict separately for each prefix case
                    preds = []
                    
                    test_all_grouped = dt_test_bucket.groupby(dataset_manager.case_id_col)
                    print(dt_test_bucket.shape)
                    count_d=0
                    count_r=0
                    for _, group in test_all_grouped:
                        
                        test_y_group = dataset_manager.get_label_numeric(group)
                        test_y_all.extend(test_y_group)
                            
                        start = time.time()
                        _ = bucketer.predict(group)
                        
                        if cls_method == "svm":
                            pred = pipeline.decision_function(group)
                        else:
                            preds_pos_label_idx = np.where(cls.classes_ == 1)[0][0]
                            pred = pipeline.predict_proba(group)[:,preds_pos_label_idx]
                            #print(test_y_group)
                            if bucket in bucket_list and (count_d<3 or count_r<3):
                                test_x_group= feature_combiner.fit_transform(group)
                                print(test_x_group.shape,test_y_group[0], _)
                                test_x=np.transpose(test_x_group[0])
                                print('Generating local Explanations for', dataset_manager.get_case_ids(group))
                                exp=generate_local_explanations(explainer, test_x, cls, test_y_group )
                                if(test_y_group[0]==1):
                                    count_d=count_d+1
                                    exp_ddict[bucket+count_d]=exp
                                else:
                                    count_r=count_r+1
                                    exp_rdict[bucket+count_r]=exp
                                    
                        pipeline_pred_time = time.time() - start
                        current_online_event_times.append(pipeline_pred_time / len(group))
                        preds.extend(pred)
                        

            preds_all.extend(preds)

      
   
        dt_results = pd.DataFrame({"actual": test_y_all, "predicted": preds_all, "nr_events": nr_events_all})
        for nr_events, group in dt_results.groupby("nr_events"):
            if len(set(group.actual)) < 2:
                print(dataset_name, method_name, cls_method, nr_events, "auc", np.nan)
            else:
                #if nr_events in [5, 10, 25] and explained=False:
                #    generate_local_explanations(explainer,group[j],cls )
                #    explained=True
                print(dataset_name, method_name, cls_method, nr_events, "auc", roc_auc_score(group.actual, group.predicted))
        print(dataset_name, method_name, cls_method, -1, -1, "auc", roc_auc_score(dt_results.actual, dt_results.predicted))
                                 #precision_recall_fscore_support(group.actual, group.predicted))
# Out:
# params\optimal_params_xgboost_bpic2012_accepted_prefix_index.pickle
# {'colsample_bytree': 0.7047348347942339, 'learning_rate': 0.08635792869395631, 'max_depth': 9, 'min_child_weight': 1, 'subsample': 0.5627056016547434}
# prefix
# Bucket 1
# number events 937
# Training model iteration  0
# (937, 18)
# Bucket 2
# number events 1874
# Training model iteration  0
# (1874, 18)
# Bucket 3
# number events 2811
# Training model iteration  0
# (2811, 18)
# Bucket 4
# number events 3748
# Training model iteration  0
# (3748, 18)
# Bucket 5
# number events 4685
# Training model iteration  0
# The number of testing instances is  3747
# The total number of columns is 149
# The total accuracy is  1.0
# (4685, 18)
# (1, 149) 0 [5]
# Generating local Explanations for 0    204466_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.88082474 0.11917524]
# Explanation for class deviant
# ('index__Resource_4_10629.0 <= 0.00', -0.25691046423066943)
# ('index__Resource_4_10932.0 <= 0.00', -0.17496154060186708)
# ('index__Resource_4_10909.0 <= 0.00', 0.11288993186491274)
# ('index__Resource_4_10913.0 <= 0.00', 0.10669471742927676)
# ('64.97 < index__timesincecasestart_4 <= 671.70', -0.0441051243021769)
# ('index__open_cases_2 > 749.00', 0.03648376616608944)
# (1, 149) 0 [5]
# Generating local Explanations for 0    204469_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.7552641  0.24473588]
# Explanation for class deviant
# ('index__Resource_4_10932.0 <= 0.00', -0.1767657062655917)
# ('index__Resource_4_10629.0 <= 0.00', -0.1596059461540726)
# ('index__Resource_4_10909.0 <= 0.00', 0.0813113445265658)
# ('index__timesincecasestart_2 > 0.73', 0.07261924777379558)
# ('0.00 < index__timesincelastevent_1 <= 0.01', 0.05139782647620267)
# ('64.97 < index__timesincecasestart_4 <= 671.70', -0.03648387440646949)
# (1, 149) 0 [5]
# Generating local Explanations for 0    204472_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.5307552  0.46924478]
# Explanation for class deviant
# ('index__Resource_4_10629.0 <= 0.00', -0.2597419749935807)
# ('index__Resource_4_10932.0 <= 0.00', -0.1706138119957625)
# ('index__Resource_4_11180.0 <= 0.00', 0.09654649291751762)
# ('index__timesincelastevent_2 <= 0.56', 0.04562701495909562)
# ('64.97 < index__timesincecasestart_4 <= 671.70', -0.03988616396514128)
# ('index__timesincelastevent_3 > 0.41', -0.0362143554813928)
# (1, 149) 1 [5]
# Generating local Explanations for 0    204475_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.88492525 0.11507477]
# Explanation for class deviant
# ('index__Resource_4_10932.0 <= 0.00', -0.20767072286074828)
# ('index__Resource_4_10629.0 <= 0.00', -0.2021996589501977)
# ('index__Resource_4_10931.0 <= 0.00', -0.1587771351405547)
# ('index__Resource_4_11180.0 <= 0.00', 0.1337934844711377)
# ('index__Resource_4_10909.0 <= 0.00', 0.11368932907196741)
# ('0.56 < index__timesincecasestart_2 <= 0.65', -0.038502396732065035)
# (1, 149) 0 [5]
# Generating local Explanations for 0    204481_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.13637054 0.86362946]
# Explanation for class deviant
# ('index__Resource_4_10629.0 <= 0.00', -0.19021200701306376)
# ('index__Resource_4_10932.0 <= 0.00', -0.1664107039059969)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.061869479784468454)
# ('index__timesincecasestart_4 > 671.70', -0.05602140331088468)
# ('index__timesincelastevent_4 > 232.67', 0.043266965211874994)
# ('943.00 < index__timesincemidnight_3 <= 1178.00', 0.0420635274247483)
# (1, 149) 0 [5]
# Generating local Explanations for 0    204484_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.81804025 0.18195976]
# Explanation for class deviant
# ('index__Resource_4_10629.0 <= 0.00', -0.23567877840136864)
# ('index__Resource_4_10932.0 <= 0.00', -0.14084331442186834)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.07716859032730801)
# ('index__timesincecasestart_2 > 0.73', 0.068333857556968)
# ('index__timesincecasestart_4 > 671.70', -0.05742365968911457)
# ('943.00 < index__timesincemidnight_3 <= 1178.00', 0.04682274125689451)
# (1, 149) 0 [5]
# Generating local Explanations for 0    204499_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.68697894 0.31302103]
# Explanation for class deviant
# ('index__Resource_4_10629.0 <= 0.00', -0.23881102618290606)
# ('index__Resource_4_10932.0 <= 0.00', -0.18990185835431816)
# ('index__timesincecasestart_4 <= 6.98', 0.11760841222040447)
# ('0.56 < index__timesincelastevent_2 <= 0.64', -0.047130314785519274)
# ('index__open_cases_2 > 749.00', 0.04023260490647427)
# ('1.48 < index__timesincelastevent_4 <= 17.80', -0.03503970068901775)
# (1, 149) 0 [5]
# Generating local Explanations for 0    204514_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.7883506  0.21164945]
# Explanation for class deviant
# ('index__Resource_4_10629.0 <= 0.00', -0.22546517551565845)
# ('index__Resource_4_10932.0 <= 0.00', -0.1694388700174033)
# ('index__Resource_4_11180.0 <= 0.00', 0.10996825258873488)
# ('index__timesincecasestart_4 > 671.70', -0.06468775963785972)
# ('index__timesincelastevent_2 <= 0.56', 0.04906398472098871)
# ('index__month_0 <= 10.00', 0.039093534360943843)
# (1, 149) 1 [5]
# Generating local Explanations for 0    204523_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.02964997 0.97035   ]
# Explanation for class deviant
# ('index__Resource_4_10629.0 <= 0.00', -0.19362554734921314)
# ('index__Resource_4_10932.0 <= 0.00', -0.14915496627468522)
# ('index__timesincecasestart_4 <= 6.98', 0.11718082146473774)
# ('index__Resource_4_10913.0 <= 0.00', 0.09910707177400942)
# ('static__AMOUNT_REQ <= 7000.00', -0.03440656391517744)
# ('index__month_0 <= 10.00', 0.029381372468022696)
# (1, 149) 1 [5]
# Generating local Explanations for 0    204541_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.16866541 0.8313346 ]
# Explanation for class deviant
# ('index__Resource_4_10629.0 <= 0.00', -0.3081870844124877)
# ('index__Resource_4_10932.0 <= 0.00', -0.17754198973120203)
# ('index__timesincecasestart_4 > 671.70', -0.06645566983882116)
# ('index__timesincelastevent_4 > 232.67', 0.05241816424290301)
# ('0.56 < index__timesincecasestart_2 <= 0.65', -0.04457201702259552)
# ('index__month_0 <= 10.00', 0.0413533302644752)
# Bucket 6
# number events 5622
# Training model iteration  0
# (5622, 18)
# Bucket 7
# number events 6559
# Training model iteration  0
# (6559, 18)
# Bucket 8
# number events 7496
# Training model iteration  0
# (7496, 18)
# Bucket 9
# number events 8433
# Training model iteration  0
# (8433, 18)
# Bucket 10
# number events 9370
# Training model iteration  0
# The number of testing instances is  3742
# The total number of columns is 478
# The total accuracy is  1.0
# (9370, 18)
# (1, 478) 0 [10]
# Generating local Explanations for 0    204466_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9205236  0.07947642]
# Explanation for class deviant
# ('index__Activity_9_A_FINALIZED-COMPLETE <= 0.00', -0.07073948201226402)
# ('0.02 < index__timesincelastevent_8 <= 0.80', 0.056933569021425774)
# ('3.30 < index__timesincelastevent_5 <= 7.10', 0.05567582144899986)
# ('0.00 < index__timesincelastevent_1 <= 0.00', 0.04298881221989617)
# ('index__timesincemidnight_7 > 1102.00', 0.039990336458443305)
# ('0.65 < index__timesincecasestart_2 <= 0.73', -0.035680488901165326)
# (1, 478) 0 [10]
# Generating local Explanations for 0    204469_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.7888206  0.21117935]
# Explanation for class deviant
# ('index__Resource_4_10932.0 <= 0.00', -0.0769440829912444)
# ('static__AMOUNT_REQ <= 7000.00', -0.05443642584550038)
# ('index__Resource_9_11189.0 <= 0.00', 0.049843568749742516)
# ('index__timesincelastevent_2 > 0.72', 0.047621451683742565)
# ('0.00 < index__timesincelastevent_1 <= 0.01', 0.0430514497830393)
# ('index__timesincemidnight_7 > 1102.00', 0.030263998341855725)
# (1, 478) 0 [10]
# Generating local Explanations for 0    204472_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.7846774  0.21532263]
# Explanation for class deviant
# ('index__timesincelastevent_1 <= 0.00', -0.06672752122497912)
# ('static__AMOUNT_REQ <= 7000.00', -0.05454006558835872)
# ('index__Activity_9_A_FINALIZED-COMPLETE > 0.00', 0.04469340781371714)
# ('index__timesincelastevent_7 > 7.54', -0.036589877872826464)
# ('index__timesincelastevent_5 <= 0.12', -0.03518129243571198)
# ('index__month_0 <= 10.00', 0.028419757581674625)
# (1, 478) 1 [10]
# Generating local Explanations for 0    204475_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9774236  0.02257637]
# Explanation for class deviant
# ('index__Resource_9_10889.0 <= 0.00', -0.08459704740668066)
# ('index__Resource_8_11181.0 <= 0.00', 0.07425480350794851)
# ('index__Activity_6_O_SELECTED-COMPLETE <= 0.00', -0.06228941438973949)
# ('index__timesincelastevent_1 <= 0.00', -0.05853041337719383)
# ('index__Activity_9_A_FINALIZED-COMPLETE <= 0.00', -0.05489719351077743)
# ('index__timesincecasestart_9 > 1045.62', -0.03639118942665926)
# (1, 478) 0 [10]
# Generating local Explanations for 0    204481_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.01315999 0.98684   ]
# Explanation for class deviant
# ('0.80 < index__timesincelastevent_8 <= 6.40', -0.08531526775551612)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.05065635079488589)
# ('index__timesincecasestart_9 > 1045.62', -0.044656047580385286)
# ('index__timesincemidnight_6 <= 739.00', -0.04256517046795028)
# ('index__timesincelastevent_1 > 0.01', -0.03787099719234286)
# ('index__timesincemidnight_4 <= 704.00', 0.03442889481105959)
# (1, 478) 0 [10]
# Generating local Explanations for 0    204484_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.81454694 0.18545307]
# Explanation for class deviant
# ('index__Resource_4_10932.0 <= 0.00', -0.0913479298693749)
# ('index__timesincelastevent_1 <= 0.00', -0.07070145460154774)
# ('index__Activity_9_A_FINALIZED-COMPLETE <= 0.00', -0.05688285126878066)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.05626076864263231)
# ('index__timesincecasestart_2 > 0.73', 0.04294582903810776)
# ('index__timesincelastevent_2 > 0.72', 0.03824862860603232)
# (1, 478) 0 [10]
# Generating local Explanations for 0    204499_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.5124213 0.4875787]
# Explanation for class deviant
# ('index__timesincecasestart_9 <= 32.33', 0.06603397942957481)
# ('index__timesincelastevent_8 <= 0.02', 0.062089934996075666)
# ('index__timesincelastevent_1 <= 0.00', -0.05740453627895046)
# ('0.56 < index__timesincelastevent_2 <= 0.64', -0.05234774261177186)
# ('index__timesincemidnight_7 > 1102.00', 0.04499091488880288)
# ('index__month_0 <= 10.00', 0.02899190177433221)
# (1, 478) 0 [10]
# Generating local Explanations for 0    204514_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.90121067 0.09878933]
# Explanation for class deviant
# ('0.80 < index__timesincelastevent_8 <= 6.40', -0.07261960177341226)
# ('static__AMOUNT_REQ <= 7000.00', -0.060494923536354286)
# ('index__Activity_9_A_FINALIZED-COMPLETE > 0.00', 0.056670291839133205)
# ('0.00 < index__timesincelastevent_1 <= 0.00', 0.05054066196295126)
# ('index__open_cases_5 > 748.75', -0.04401663812461671)
# ('index__timesincelastevent_7 > 7.54', -0.033001250360626525)
# (1, 478) 1 [10]
# Generating local Explanations for 0    204523_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.3535632 0.6464368]
# Explanation for class deviant
# ('static__AMOUNT_REQ <= 7000.00', -0.06313399079082917)
# ('3.30 < index__timesincelastevent_5 <= 7.10', 0.0618717676371269)
# ('index__timesincecasestart_9 <= 32.33', 0.04646068122767965)
# ('0.02 < index__timesincelastevent_8 <= 0.80', 0.04113260592343154)
# ('0.00 < index__timesincelastevent_1 <= 0.01', 0.040765718472398224)
# ('0.65 < index__timesincecasestart_2 <= 0.73', -0.03260283229036656)
# (1, 478) 1 [10]
# Generating local Explanations for 0    204541_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9109856  0.08901442]
# Explanation for class deviant
# ('index__Resource_4_10932.0 <= 0.00', -0.09592814002363391)
# ('index__Resource_9_10889.0 <= 0.00', -0.0936220379403808)
# ('0.80 < index__timesincelastevent_8 <= 6.40', -0.08314335295405874)
# ('index__Activity_9_A_FINALIZED-COMPLETE <= 0.00', -0.05821389083295508)
# ('0.00 < index__timesincelastevent_1 <= 0.00', 0.040701744846674465)
# ('index__open_cases_4 > 748.00', 0.03256287262790881)
# Bucket 11
# number events 10307
# Training model iteration  0
# (10307, 18)
# Bucket 12
# number events 11244
# Training model iteration  0
# (11244, 18)
# Bucket 13
# number events 12181
# Training model iteration  0
# (12181, 18)
# Bucket 14
# number events 13118
# Training model iteration  0
# (13118, 18)
# Bucket 15
# number events 14055
# Training model iteration  0
# The number of testing instances is  3654
# The total number of columns is 850
# The total accuracy is  1.0
# (14055, 18)
# (1, 850) 0 [15]
# Generating local Explanations for 0    204466_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.77919495 0.22080505]
# Explanation for class deviant
# ('index__Resource_14_11049.0 <= 0.00', -0.18210738832222423)
# ('index__Activity_13_O_SENT_BACK-COMPLETE <= 0.00', -0.10151190959456406)
# ('0.02 < index__timesincelastevent_11 <= 0.68', 0.06507555412226752)
# ('index__timesincemidnight_14 > 1148.75', -0.06033509775663744)
# ('3.25 < index__timesincelastevent_5 <= 7.08', 0.0517154477943554)
# ('index__timesincelastevent_14 <= 0.01', 0.04828067172142742)
# (1, 850) 0 [15]
# Generating local Explanations for 0    204469_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.34520274 0.65479726]
# Explanation for class deviant
# ('index__Resource_14_11049.0 <= 0.00', -0.15178646749944225)
# ('0.02 < index__timesincelastevent_11 <= 0.68', 0.0693952318834585)
# ('static__AMOUNT_REQ <= 7000.00', -0.06084274930539589)
# ('index__timesincelastevent_10 > 2.53', -0.05078194920043899)
# ('index__timesincemidnight_4 > 1061.00', -0.04914502308940773)
# ('index__timesincelastevent_14 <= 0.01', 0.04440456856948947)
# (1, 850) 0 [15]
# Generating local Explanations for 0    204472_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.27992135 0.72007865]
# Explanation for class deviant
# ('index__Resource_14_11049.0 <= 0.00', -0.18815267463036378)
# ('static__AMOUNT_REQ <= 7000.00', -0.06146326349097622)
# ('index__timesincelastevent_10 > 2.53', -0.060975582817264944)
# ('index__timesincelastevent_2 <= 0.56', 0.04918498777845774)
# ('index__timesincelastevent_12 <= 0.00', 0.043816159179793514)
# ('index__timesincemidnight_4 > 1061.00', -0.04202547830250859)
# (1, 850) 1 [15]
# Generating local Explanations for 0    204475_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.84450024 0.15549977]
# Explanation for class deviant
# ('index__Activity_13_A_CANCELLED-COMPLETE <= 0.00', 0.15805686561989876)
# ('index__Resource_14_11049.0 <= 0.00', -0.128439413118993)
# ('index__timesincelastevent_10 > 2.53', -0.058704311748636086)
# ('index__timesincemidnight_7 <= 759.00', -0.05422318586680905)
# ('949.50 < index__timesincemidnight_14 <= 1148.75', -0.04273820623313031)
# ('index__timesincemidnight_4 > 1061.00', -0.03598089911484808)
# (1, 850) 0 [15]
# Generating local Explanations for 0    204481_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.05515242 0.9448476 ]
# Explanation for class deviant
# ('index__Resource_14_11049.0 <= 0.00', -0.19231042204354099)
# ('index__timesincemidnight_14 <= 764.00', 0.10767166310326705)
# ('11806.00 < static__AMOUNT_REQ <= 20000.00', 0.08350510191957518)
# ('0.02 < index__timesincelastevent_11 <= 0.68', 0.05977952665378098)
# ('index__timesincecasestart_14 > 9642.63', -0.05221339252208545)
# ('index__timesincemidnight_7 <= 759.00', -0.05099838216199339)
# (1, 850) 0 [15]
# Generating local Explanations for 0    204484_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.95916617 0.04083385]
# Explanation for class deviant
# ('index__Resource_14_11049.0 <= 0.00', -0.1476092792270132)
# ('11806.00 < static__AMOUNT_REQ <= 20000.00', 0.07276803194991345)
# ('index__timesincelastevent_14 <= 0.01', 0.057982646878419815)
# ('0.02 < index__timesincelastevent_11 <= 0.68', 0.055387885470524346)
# ('949.50 < index__timesincemidnight_14 <= 1148.75', -0.05061081927839174)
# ('index__timesincelastevent_10 > 2.53', -0.04765839556052139)
# (1, 850) 0 [15]
# Generating local Explanations for 0    204499_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.4920017 0.5079983]
# Explanation for class deviant
# ('index__Activity_13_A_CANCELLED-COMPLETE <= 0.00', 0.19530491421019164)
# ('index__Resource_14_11049.0 <= 0.00', -0.16682375424004267)
# ('index__timesincemidnight_14 <= 764.00', 0.10422865528044589)
# ('index__timesincelastevent_14 > 2001.66', -0.06557303668515993)
# ('index__timesincecasestart_14 > 9642.63', -0.049694500325285426)
# ('index__weekday_14 <= 1.00', -0.041569009928737376)
# (1, 850) 0 [15]
# Generating local Explanations for 0    204514_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.75543886 0.24456115]
# Explanation for class deviant
# ('index__Resource_14_11049.0 <= 0.00', -0.11952154764385864)
# ('index__Activity_13_O_SENT_BACK-COMPLETE <= 0.00', -0.08430039445140294)
# ('static__AMOUNT_REQ <= 7000.00', -0.06723362934152541)
# ('index__timesincelastevent_12 <= 0.00', 0.06440573551556734)
# ('0.80 < index__timesincelastevent_8 <= 6.61', -0.05033634673280341)
# ('0.02 < index__timesincelastevent_10 <= 2.53', 0.0453431416975399)
# (1, 850) 1 [15]
# Generating local Explanations for 0    204523_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.68011475 0.31988522]
# Explanation for class deviant
# ('index__Resource_14_11049.0 <= 0.00', -0.14095019951683083)
# ('index__timesincemidnight_14 <= 764.00', 0.11836639590538532)
# ('static__AMOUNT_REQ <= 7000.00', -0.07626087078849995)
# ('index__timesincelastevent_14 > 2001.66', -0.0660390379949164)
# ('index__timesincecasestart_14 > 9642.63', -0.05351022797154285)
# ('index__timesincemidnight_7 > 1101.75', 0.05084709304527846)
# (1, 850) 1 [15]
# Generating local Explanations for 0    204541_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.8495436  0.15045646]
# Explanation for class deviant
# ('index__Resource_14_11049.0 <= 0.00', -0.17563099547003178)
# ('index__Activity_13_A_CANCELLED-COMPLETE <= 0.00', 0.16961689091156643)
# ('index__Activity_13_O_SENT_BACK-COMPLETE <= 0.00', -0.08780581633319548)
# ('index__timesincelastevent_14 > 2001.66', -0.06985313266405403)
# ('0.80 < index__timesincelastevent_8 <= 6.61', -0.0482028991159305)
# ('0.02 < index__timesincelastevent_10 <= 2.53', 0.04642373973682036)
# Bucket 16
# number events 14992
# Training model iteration  0
# (14992, 18)
# Bucket 17
# number events 15908
# Training model iteration  0
# (15572, 18)
# Bucket 18
# number events 16823
# Training model iteration  0
# (16470, 18)
# Bucket 19
# number events 17720
# Training model iteration  0
# (17043, 18)
# Bucket 20
# number events 18615
# Training model iteration  0
# The number of testing instances is  3419
# The total number of columns is 1260
# The total accuracy is  1.0
# (17900, 18)
# (1, 1260) 0 [20]
# Generating local Explanations for 0    204466_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.85462403 0.14537597]
# Explanation for class deviant
# ('index__Activity_19_A_DECLINED-COMPLETE <= 0.00', 0.3045809402752859)
# ('index__Activity_17_A_CANCELLED-COMPLETE <= 0.00', 0.29331255429788794)
# ('index__Activity_19_A_CANCELLED-COMPLETE <= 0.00', 0.27541206733982454)
# ('index__Activity_13_O_SENT_BACK-COMPLETE <= 0.00', -0.10244922390113975)
# ('index__timesincemidnight_19 <= 742.00', 0.07062204512302979)
# ('index__timesincelastevent_15 <= 0.02', 0.05807649390476317)
# (1, 1260) 0 [20]
# Generating local Explanations for 0    204469_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.25630158 0.7436984 ]
# Explanation for class deviant
# ('index__Activity_17_A_CANCELLED-COMPLETE <= 0.00', 0.31303601116912705)
# ('index__Activity_19_A_DECLINED-COMPLETE <= 0.00', 0.29012414740685516)
# ('index__Activity_19_A_CANCELLED-COMPLETE <= 0.00', 0.27067393820411456)
# ('0.02 < index__timesincelastevent_11 <= 0.88', 0.06938269554905714)
# ('index__timesincelastevent_10 > 2.69', -0.06261802233000327)
# ('index__timesincelastevent_13 > 2.22', -0.061262448595968674)
# (1, 1260) 0 [20]
# Generating local Explanations for 0    204472_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.91492814 0.08507184]
# Explanation for class deviant
# ('index__Activity_17_A_CANCELLED-COMPLETE <= 0.00', 0.31566131952097937)
# ('index__Activity_19_A_DECLINED-COMPLETE <= 0.00', 0.31097276110608085)
# ('index__Activity_19_A_CANCELLED-COMPLETE <= 0.00', 0.22945974824956852)
# ('index__timesincecasestart_19 > 14649.55', -0.07986175449027426)
# ('index__timesincelastevent_17 > 3.56', -0.07194891824837621)
# ('index__timesincelastevent_10 > 2.69', -0.064675487442717)
# (1, 1260) 1 [20]
# Generating local Explanations for 0    204475_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.6972202 0.3027798]
# Explanation for class deviant
# ('index__Activity_19_A_DECLINED-COMPLETE <= 0.00', 0.3227424028257264)
# ('index__Activity_17_A_CANCELLED-COMPLETE <= 0.00', 0.30073027118517365)
# ('index__Activity_19_A_CANCELLED-COMPLETE <= 0.00', 0.2828350468381652)
# ('index__Resource_19_11049.0 <= 0.00', -0.12873197167008366)
# ('index__timesincelastevent_10 > 2.69', -0.06547055478197913)
# ('index__timesincelastevent_15 > 2.75', -0.06287158132312928)
# (1, 1260) 0 [20]
# Generating local Explanations for 0    204481_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.43619478 0.5638052 ]
# Explanation for class deviant
# ('index__Activity_19_A_DECLINED-COMPLETE > 0.00', -0.2922532794319019)
# ('index__Activity_17_A_CANCELLED-COMPLETE <= 0.00', 0.2900332492075691)
# ('index__Activity_19_A_CANCELLED-COMPLETE <= 0.00', 0.2513314284458551)
# ('index__Resource_19_11049.0 <= 0.00', -0.12267105569204448)
# ('index__timesincecasestart_19 > 14649.55', -0.07703562350963125)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.06038453116162922)
# (1, 1260) 0 [20]
# Generating local Explanations for 0    204484_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.8932064 0.1067936]
# Explanation for class deviant
# ('index__Activity_17_A_CANCELLED-COMPLETE <= 0.00', 0.3002775485700724)
# ('index__Activity_19_A_DECLINED-COMPLETE <= 0.00', 0.299618712925082)
# ('index__Activity_19_A_CANCELLED-COMPLETE <= 0.00', 0.2903224643326004)
# ('12000.00 < static__AMOUNT_REQ <= 20000.00', 0.07782763218455466)
# ('index__timesincelastevent_15 > 2.75', -0.07571539579679483)
# ('index__timesincelastevent_10 > 2.69', -0.06476840796430544)
# (1, 1260) 0 [20]
# Generating local Explanations for 0    204499_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.8881     0.11189994]
# Explanation for class deviant
# ('index__Activity_19_A_DECLINED-COMPLETE <= 0.00', 0.30216306885203176)
# ('index__Activity_17_A_CANCELLED-COMPLETE <= 0.00', 0.2902391810369932)
# ('index__Activity_19_A_CANCELLED-COMPLETE > 0.00', -0.2787516096926926)
# ('index__Activity_18_W_Valideren aanvraag-START <= 0.00', -0.09458350823095486)
# ('index__timesincecasestart_19 > 14649.55', -0.059773737021807334)
# ('index__timesincemidnight_14 <= 762.00', 0.05587001067186684)
# (1, 1260) 0 [20]
# Generating local Explanations for 0    204514_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9282345  0.07176546]
# Explanation for class deviant
# ('index__Activity_19_A_DECLINED-COMPLETE <= 0.00', 0.30772287906708645)
# ('index__Activity_17_A_CANCELLED-COMPLETE <= 0.00', 0.30339514297929987)
# ('index__Activity_19_A_CANCELLED-COMPLETE <= 0.00', 0.2901961108906907)
# ('index__timesincecasestart_19 > 14649.55', -0.07092080109006817)
# ('index__timesincelastevent_15 > 2.75', -0.06981826666926542)
# ('index__timesincelastevent_17 > 3.56', -0.06846252268751812)
# (1, 1260) 1 [20]
# Generating local Explanations for 0    204523_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.02196705 0.97803295]
# Explanation for class deviant
# ('index__Activity_19_A_DECLINED-COMPLETE <= 0.00', 0.30866998841165694)
# ('index__Activity_17_A_CANCELLED-COMPLETE <= 0.00', 0.2970985167321091)
# ('index__Activity_19_A_CANCELLED-COMPLETE <= 0.00', 0.257281197847823)
# ('index__Resource_19_11049.0 <= 0.00', -0.1225397278654173)
# ('index__timesincecasestart_19 > 14649.55', -0.07219373299030014)
# ('0.02 < index__timesincelastevent_17 <= 0.52', 0.056762232861482645)
# (1, 1260) 1 [20]
# Generating local Explanations for 0    204541_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.29570597 0.704294  ]
# Explanation for class deviant
# ('index__Activity_19_A_DECLINED-COMPLETE <= 0.00', 0.3103848092089502)
# ('index__Activity_17_A_CANCELLED-COMPLETE <= 0.00', 0.2898304123509306)
# ('index__Activity_19_A_CANCELLED-COMPLETE <= 0.00', 0.2719669888922136)
# ('index__Activity_13_O_SENT_BACK-COMPLETE <= 0.00', -0.09679196689177814)
# ('index__timesincelastevent_12 <= 0.00', 0.06165341058097803)
# ('index__timesincelastevent_15 > 2.75', -0.059186261656038124)
# Bucket 21
# number events 19487
# Training model iteration  0
# (18312, 18)
# Bucket 22
# number events 20351
# Training model iteration  0
# (19008, 18)
# Bucket 23
# number events 21181
# Training model iteration  0
# (19090, 18)
# Bucket 24
# number events 21995
# Training model iteration  0
# (19536, 18)
# Bucket 25
# number events 22765
# Training model iteration  0
# The number of testing instances is  2847
# The total number of columns is 1654
# The total accuracy is  1.0
# (19250, 18)
# (1, 1654) 0 [25]
# Generating local Explanations for 0    204466_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.85063136 0.14936861]
# Explanation for class deviant
# ('index__Resource_23_10138.0 <= 0.00', -0.12591336031497077)
# ('index__timesincelastevent_24 <= 0.03', 0.08411505778583053)
# ('index__timesincecasestart_24 > 20179.89', -0.07885742198361413)
# ('index__timesincecasestart_23 > 19308.68', -0.07141372774206904)
# ('index__timesincemidnight_24 <= 734.00', 0.06923515971339639)
# ('index__timesincelastevent_21 > 32.36', -0.06631544114025338)
# (1, 1654) 0 [25]
# Generating local Explanations for 0    204469_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.22073615 0.77926385]
# Explanation for class deviant
# ('index__Activity_23_A_DECLINED-COMPLETE <= 0.00', 0.3260501498224955)
# ('index__Resource_23_10138.0 <= 0.00', -0.12444580019517647)
# ('index__timesincelastevent_24 <= 0.03', 0.08828255037683128)
# ('index__Activity_24_W_Nabellen offertes-START <= 0.00', 0.07765857734256715)
# ('index__timesincelastevent_15 > 2.91', -0.06597777452482463)
# ('index__timesincemidnight_20 <= 736.00', 0.0619303307597956)
# (1, 1654) 0 [25]
# Generating local Explanations for 0    204472_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9614699 0.0385301]
# Explanation for class deviant
# ('index__Activity_23_A_DECLINED-COMPLETE <= 0.00', 0.3408203669679827)
# ('index__Resource_24_11049.0 <= 0.00', -0.14409282094396741)
# ('index__Resource_23_10138.0 <= 0.00', -0.13586175381837756)
# ('index__Activity_24_W_Nabellen offertes-COMPLETE > 0.00', -0.07414539112798321)
# ('index__timesincecasestart_24 > 20179.89', -0.07267685588744897)
# ('index__Activity_22_W_Nabellen offertes-START <= 0.00', 0.06549686583546256)
# (1, 1654) 1 [25]
# Generating local Explanations for 0    204475_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9553991  0.04460092]
# Explanation for class deviant
# ('index__Resource_23_10138.0 <= 0.00', -0.13060011917619307)
# ('index__timesincelastevent_21 <= 0.03', 0.1139026016710933)
# ('index__timesincelastevent_15 > 2.91', -0.08336552526104925)
# ('index__timesincelastevent_22 > 93.39', -0.07287655011520963)
# ('index__Activity_22_W_Nabellen offertes-START > 0.00', -0.07146274416525741)
# ('index__Activity_24_W_Nabellen offertes-COMPLETE <= 0.00', 0.07062944601640228)
# (1, 1654) 0 [25]
# Generating local Explanations for 0    204484_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.8973253  0.10267472]
# Explanation for class deviant
# ('index__Resource_23_10138.0 <= 0.00', -0.14305074561786343)
# ('index__Activity_20_W_Valideren aanvraag-START <= 0.00', -0.09640276893339517)
# ('index__timesincelastevent_15 > 2.91', -0.0804358109987003)
# ('index__Activity_24_W_Nabellen offertes-START <= 0.00', 0.07496546649260263)
# ('index__timesincelastevent_22 > 93.39', -0.07184044000964124)
# ('index__timesincelastevent_13 > 2.32', -0.06331679520971455)
# (1, 1654) 0 [25]
# Generating local Explanations for 0    204514_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.8990599  0.10094009]
# Explanation for class deviant
# ('index__Activity_23_A_DECLINED-COMPLETE <= 0.00', 0.3210672970450826)
# ('index__Activity_24_W_Nabellen offertes-COMPLETE <= 0.00', 0.08601239646299583)
# ('index__timesincecasestart_24 > 20179.89', -0.07866154783340397)
# ('index__timesincelastevent_15 > 2.91', -0.07692925393610592)
# ('index__Activity_22_W_Nabellen offertes-START > 0.00', -0.07503881046449307)
# ('index__timesincecasestart_23 > 19308.68', -0.07237881878072333)
# (1, 1654) 1 [25]
# Generating local Explanations for 0    204523_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.11552256 0.88447744]
# Explanation for class deviant
# ('index__Activity_23_A_DECLINED-COMPLETE <= 0.00', 0.30531807502710967)
# ('index__timesincelastevent_21 <= 0.03', 0.11010618229535739)
# ('index__timesincecasestart_24 > 20179.89', -0.08702637874920291)
# ('index__timesincemidnight_24 <= 734.00', 0.08228646688942036)
# ('index__Activity_24_W_Nabellen offertes-START <= 0.00', 0.07901161246722853)
# ('index__timesincelastevent_13 > 2.32', -0.07196697341728686)
# (1, 1654) 1 [25]
# Generating local Explanations for 0    204541_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.13852906 0.86147094]
# Explanation for class deviant
# ('index__Activity_23_A_DECLINED-COMPLETE <= 0.00', 0.295656803071887)
# ('index__Resource_24_11049.0 <= 0.00', -0.14717517544020964)
# ('index__Resource_23_10138.0 <= 0.00', -0.10235573731949132)
# ('index__timesincelastevent_15 > 2.91', -0.07237048636487857)
# ('index__Activity_22_W_Nabellen offertes-START <= 0.00', 0.07103367720688977)
# ('0.00 < index__timesincelastevent_1 <= 0.00', 0.053396909562817244)
# Bucket 26
# number events 23517
# Training model iteration  0
# (19552, 18)
# Bucket 27
# number events 24223
# Training model iteration  0
# (19062, 18)
# Bucket 28
# number events 24909
# Training model iteration  0
# (19208, 18)
# Bucket 29
# number events 25551
# Training model iteration  0
# (18618, 18)
# Bucket 30
# number events 26169
# Training model iteration  0
# (18540, 18)
# Bucket 31
# number events 26751
# Training model iteration  0
# (18042, 18)
# Bucket 32
# number events 27298
# Training model iteration  0
# (17504, 18)
# Bucket 33
# number events 27807
# Training model iteration  0
# (16797, 18)
# Bucket 34
# number events 28290
# Training model iteration  0
# (16422, 18)
# Bucket 35
# number events 28742
# Training model iteration  0
# (15820, 18)
# Bucket 36
# number events 29166
# Training model iteration  0
# (15264, 18)
# Bucket 37
# number events 29565
# Training model iteration  0
# (14763, 18)
# Bucket 38
# number events 29947
# Training model iteration  0
# (14516, 18)
# Bucket 39
# number events 30300
# Training model iteration  0
# (13767, 18)
# Bucket 40
# number events 30637
# Training model iteration  0
# (13480, 18)
# bpic2012_accepted prefix_index xgboost 1 auc 0.5622976608453787
# bpic2012_accepted prefix_index xgboost 2 auc 0.5481738178833615
# bpic2012_accepted prefix_index xgboost 3 auc 0.5258036569239889
# bpic2012_accepted prefix_index xgboost 4 auc 0.5383794628607907
# bpic2012_accepted prefix_index xgboost 5 auc 0.5608818567324791
# bpic2012_accepted prefix_index xgboost 6 auc 0.554306689161461
# bpic2012_accepted prefix_index xgboost 7 auc 0.5624458529022844
# bpic2012_accepted prefix_index xgboost 8 auc 0.5683644156673202
# bpic2012_accepted prefix_index xgboost 9 auc 0.5698189777027951
# bpic2012_accepted prefix_index xgboost 10 auc 0.541402580821668
# bpic2012_accepted prefix_index xgboost 11 auc 0.5423510099858647
# bpic2012_accepted prefix_index xgboost 12 auc 0.5480187861930601
# bpic2012_accepted prefix_index xgboost 13 auc 0.5534266563312207
# bpic2012_accepted prefix_index xgboost 14 auc 0.5706306141990789
# bpic2012_accepted prefix_index xgboost 15 auc 0.6136245497241348
# bpic2012_accepted prefix_index xgboost 16 auc 0.6419406319821257
# bpic2012_accepted prefix_index xgboost 17 auc 0.6462655601659751
# bpic2012_accepted prefix_index xgboost 18 auc 0.6749686161394498
# bpic2012_accepted prefix_index xgboost 19 auc 0.6767134929760535
# bpic2012_accepted prefix_index xgboost 20 auc 0.7182894115519477
# bpic2012_accepted prefix_index xgboost 21 auc 0.7263113097137992
# bpic2012_accepted prefix_index xgboost 22 auc 0.7534324694227804
# bpic2012_accepted prefix_index xgboost 23 auc 0.7502544740081432
# bpic2012_accepted prefix_index xgboost 24 auc 0.7854779958370502
# bpic2012_accepted prefix_index xgboost 25 auc 0.7671702679343129
# bpic2012_accepted prefix_index xgboost 26 auc 0.7710992132867133
# bpic2012_accepted prefix_index xgboost 27 auc 0.7624184977976844
# bpic2012_accepted prefix_index xgboost 28 auc 0.7830404349783306
# bpic2012_accepted prefix_index xgboost 29 auc 0.793400373945121
# bpic2012_accepted prefix_index xgboost 30 auc 0.7876452152341717
# bpic2012_accepted prefix_index xgboost 31 auc 0.8052910052910053
# bpic2012_accepted prefix_index xgboost 32 auc 0.7883627493184101
# bpic2012_accepted prefix_index xgboost 33 auc 0.8074234633867661
# bpic2012_accepted prefix_index xgboost 34 auc 0.7940854119425549
# bpic2012_accepted prefix_index xgboost 35 auc 0.7774339754205527
# bpic2012_accepted prefix_index xgboost 36 auc 0.7845856922285126
# bpic2012_accepted prefix_index xgboost 37 auc 0.7643467643467643
# bpic2012_accepted prefix_index xgboost 38 auc 0.7609005414648048
# bpic2012_accepted prefix_index xgboost 39 auc 0.7628873771730915
# bpic2012_accepted prefix_index xgboost 40 auc 0.7456237725215609
# bpic2012_accepted prefix_index xgboost -1 -1 auc 0.6751406094795382

# %%
rc={'axes.labelsize': 12, 'xtick.labelsize': 13, 'ytick.labelsize': 13 , 'axes.titlesize': 10}
sns.set(rc)
sns.set_style("whitegrid")
# %matplotlib inline
for pre, exp in exp_ddict.items():
    #print('Explanations for prefix length ', pre)
    fig = exp.as_pyplot_figure()

# %%
rc={'axes.labelsize': 12, 'xtick.labelsize': 13, 'ytick.labelsize': 13 , 'axes.titlesize': 10}
sns.set(rc)
sns.set_style("whitegrid")

for pre, importance in importance_dict.items():
    if(pre==25):
        print('printing global feature importance of the xgboost classifier', pre, importance.head(10)) 
        var_imp_plot(importance, 'bucket:prefix, ecoding:index, classifier: random forest, length:{}'.format(pre), 10)
# Out:
# printing global feature importance of the xgboost classifier 25                                              feature  feature_importance
# 0            index__Activity_18_O_SENT_BACK-COMPLETE            0.021525
# 1      index__Activity_20_W_Valideren aanvraag-START            0.012155
# 2  index__Activity_21_W_Nabellen incomplete dossi...            0.010582
# 3            index__Activity_23_O_SENT_BACK-COMPLETE            0.009712
# 4   index__Activity_16_W_Valideren aanvraag-SCHEDULE            0.008823
# 5       index__Activity_24_W_Nabellen offertes-START            0.007097
# 6    index__Activity_17_W_Completeren aanvraag-START            0.006709
# 7    index__Activity_19_W_Completeren aanvraag-START            0.006335
# 8                         index__Resource_12_11179.0            0.006254
# 9                         index__Resource_18_10881.0            0.006172
