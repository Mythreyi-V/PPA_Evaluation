# %% [markdown]
# ### BPIC2015
# Bucket: Prefix
#
# Encoding: Aggregation
#
# Classifier: XGBoost
#
# The notebook has all the code for running the benchmark and deriving explanations

# %%
import EncoderFactory
from DatasetManager import DatasetManager
import BucketFactory

import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import StandardScaler

import time
import os
import sys
from sys import argv
import pickle
from collections import defaultdict

from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import lime
import lime.lime_tabular
from lime import submodular_pick;
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

def imp_df(column_names, importances):
        df = pd.DataFrame({'feature': column_names,
                       'feature_importance': importances}) \
           .sort_values('feature_importance', ascending = False) \
           .reset_index(drop = True)
        return df

# plotting a feature importance dataframe (horizontal barchart)
def var_imp_plot(imp_df, title, num_feat):
        imp_df.columns = ['feature', 'feature_importance']
        b= sns.barplot(x = 'feature_importance', y = 'feature', data = imp_df.head(num_feat), orient = 'h', palette="Blues_r") 
        b.set_title(title, fontsize = 14) 
    
        for item in b.get_yticklabels():
            item.set_fontsize(13)

# %%
def generate_global_explanations(train_X,train_Y, cls, feature_combiner):
    
    print("The number of testing instances is ",len(train_Y))
    print("The total number of columns is",train_X.shape[1]);
    print("The total accuracy is ",cls.score(train_X,train_Y));
       
    sns.set(rc={'figure.figsize':(10,10), "font.size":18,"axes.titlesize":18,"axes.labelsize":18})
    sns.set
    feat_names = feature_combiner.get_feature_names()
    base_imp = imp_df(feat_names, cls.feature_importances_)
    base_imp.head(15)
    var_imp_plot(base_imp, 'Feature importance using XGBoost', 15)
    return base_imp

# %%
from lime import submodular_pick
def generate_local_explanations(explainer,test_xi, cls,test_y, submod=False, test_all_data=None):
    
    print("Actual value ", test_y)
    num_features=6;# maximum is 6 ,if it is larger than 6, the features displayed are different.
    exp = explainer.explain_instance(test_xi, 
                                 cls.predict_proba, num_features=num_features, labels=[0,1])
    
    #exp.show_in_notebook(show_table=True, show_all=False);
    probability_result=cls.predict_proba([test_xi])[0];
    print(probability_result);
    print ('Explanation for class %s' % class_names[1])
    print ('\n'.join(map(str, exp.as_list(label=1))))
    return exp
    #%matplotlib inline
    #fig = exp.as_pyplot_figure()
        
    if submod==True:
        sp_obj=submodular_pick.SubmodularPick(explainer, test_all_data, cls.predict_proba, 
                                      sample_size=20, num_features=num_features,num_exps_desired=4)
        [exp.as_pyplot_figure(label=exp.available_labels()[0]) for exp in sp_obj.sp_explanations];

# %%
dataset_ref = "bpic2015"
params_dir = "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "agg"
cls_method = "xgboost"
gap = 1
n_iter = 1

if bucket_method == "state":
    bucket_encoding = "last"
else:
    bucket_encoding = "agg"

method_name = "%s_%s"%(bucket_method, cls_encoding)

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
     "bpic2011": ["bpic2011_f%s"%formula for formula in range(4,5)],
    "bpic2012" : ["bpic2012_accepted"]
    #"insurance": ["insurance_activity", "insurance_followup"],
    #"sepsis_cases": ["sepsis_cases_1", "sepsis_cases_2", "sepsis_cases_4"]
}

encoding_dict = {
    "laststate": ["static", "last"],
    "agg": ["static", "agg"],
    "index": ["static", "index"],
    "combined": ["static", "last", "agg"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]
methods = encoding_dict[cls_encoding]
    
train_ratio = 0.8
random_state = 22

# create results directory
if not os.path.exists(os.path.join(params_dir)):
    os.makedirs(os.path.join(params_dir))
    
print(datasets)
# Out:
# ['bpic2015_5_f2']

# %%
for dataset_name in datasets:
    
    # load optimal params
    optimal_params_filename = os.path.join(params_dir, "optimal_params_%s_%s_%s.pickle" % (cls_method, dataset_name, method_name))
    print(optimal_params_filename)
    if not os.path.isfile(optimal_params_filename) or os.path.getsize(optimal_params_filename) <= 0:
        continue
        
    with open(optimal_params_filename, "rb") as fin:
        args = pickle.load(fin)
        
    print(args)
    bucket_list=[5,10,15,20,25] #:)
    # read the data
    dataset_manager = DatasetManager(dataset_name)
    data = dataset_manager.read_dataset()
    cls_encoder_args = {'case_id_col': dataset_manager.case_id_col, 
                        'static_cat_cols': dataset_manager.static_cat_cols,
                        'static_num_cols': dataset_manager.static_num_cols, 
                        'dynamic_cat_cols': dataset_manager.dynamic_cat_cols,
                        'dynamic_num_cols': dataset_manager.dynamic_num_cols, 
                        'fillna': True}

    # determine min and max (truncated) prefix lengths
    min_prefix_length = 1
    if "traffic_fines" in dataset_name:
        max_prefix_length = 10
    elif "bpic2017" in dataset_name:
        max_prefix_length = min(20, dataset_manager.get_pos_case_length_quantile(data, 0.90))
    else:
        max_prefix_length = min(40, dataset_manager.get_pos_case_length_quantile(data, 0.90))

    # split into training and test
    train, test = dataset_manager.split_data_strict(data, train_ratio, split="temporal")
    
    if gap > 1:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s_gap%s.csv" % (cls_method, dataset_name, method_name, gap))
    else:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s.csv" % (cls_method, dataset_name, method_name))
        
    start_test_prefix_generation = time.time()
    dt_test_prefixes = dataset_manager.generate_prefix_data(test, min_prefix_length, max_prefix_length)
    test_prefix_generation_time = time.time() - start_test_prefix_generation
            
    offline_total_times = []
    online_event_times = []
    train_prefix_generation_times = []
    explained=False
    impotance=None
    exp_ddict=dict()
    exp_rdict=dict()
    model_dict=dict()
    importance_dict=dict()
    for ii in range(n_iter):
        # create prefix logs
        start_train_prefix_generation = time.time()
        dt_train_prefixes = dataset_manager.generate_prefix_data(train, min_prefix_length, max_prefix_length, gap)
        train_prefix_generation_time = time.time() - start_train_prefix_generation
        train_prefix_generation_times.append(train_prefix_generation_time)
            
        # Bucketing prefixes based on control flow
        bucketer_args = {'encoding_method':bucket_encoding, 
                         'case_id_col':dataset_manager.case_id_col, 
                         'cat_cols':[dataset_manager.activity_col], 
                         'num_cols':[], 
                         'random_state':random_state}
        if bucket_method == "cluster":
            bucketer_args["n_clusters"] = int(args["n_clusters"])
        bucketer = BucketFactory.get_bucketer(bucket_method, **bucketer_args)

        start_offline_time_bucket = time.time()
        bucket_assignments_train = bucketer.fit_predict(dt_train_prefixes)
        offline_time_bucket = time.time() - start_offline_time_bucket

        bucket_assignments_test = bucketer.predict(dt_test_prefixes)

        preds_all = []
        test_y_all = []
        nr_events_all = []
        offline_time_fit = 0
        current_online_event_times = []
        
        for bucket in set(bucket_assignments_test):
            print("Bucket" , bucket )
            #args has only one value - some error and so just using it
            #if bucket_method == "prefix":
            #    current_args = args[bucket]
            #else:
            current_args = args
            relevant_train_cases_bucket = dataset_manager.get_indexes(dt_train_prefixes)[bucket_assignments_train == bucket]
            relevant_test_cases_bucket = dataset_manager.get_indexes(dt_test_prefixes)[bucket_assignments_test == bucket]
            dt_test_bucket = dataset_manager.get_relevant_data_by_indexes(dt_test_prefixes, relevant_test_cases_bucket)
            
            nr_events_all.extend(list(dataset_manager.get_prefix_lengths(dt_test_bucket)))
            print('number events', len(nr_events_all))
            
            if len(relevant_train_cases_bucket) == 0:
                preds = [dataset_manager.get_class_ratio(train)] * len(relevant_test_cases_bucket)
                current_online_event_times.extend([0] * len(preds))
            else:
                dt_train_bucket = dataset_manager.get_relevant_data_by_indexes(dt_train_prefixes, relevant_train_cases_bucket) # one row per event
                train_y = dataset_manager.get_label_numeric(dt_train_bucket)

                if len(set(train_y)) < 2:
                    preds = [train_y[0]] * len(relevant_test_cases_bucket)
                    current_online_event_times.extend([0] * len(preds))
                    test_y_all.extend(dataset_manager.get_label_numeric(dt_test_bucket))
                else:
                    start_offline_time_fit = time.time()
                    feature_combiner = FeatureUnion([(method, EncoderFactory.get_encoder(method, **cls_encoder_args)) for method in methods])

                    if cls_method == "rf":
                        cls = RandomForestClassifier(n_estimators=500,
                                                     max_features=current_args['max_features'],
                                                     random_state=random_state)

                    elif cls_method == "xgboost":
                        cls = xgb.XGBClassifier(objective='binary:logistic',
                                                n_estimators=500,
                                                learning_rate= current_args['learning_rate'],
                                                subsample=current_args['subsample'],
                                                max_depth=int(current_args['max_depth']),
                                                colsample_bytree=current_args['colsample_bytree'],
                                                min_child_weight=int(current_args['min_child_weight']),
                                                seed=random_state)

                    elif cls_method == "logit":
                        cls = LogisticRegression(C=2**current_args['C'],
                                                 random_state=random_state)

                    elif cls_method == "svm":
                        cls = SVC(C=2**current_args['C'],
                                  gamma=2**current_args['gamma'],
                                  random_state=random_state)

                    if cls_method == "svm" or cls_method == "logit":
                        pipeline = Pipeline([('encoder', feature_combiner), ('scaler', StandardScaler()), ('cls', cls)])
                    else:
                        pipeline = Pipeline([('encoder', feature_combiner), ('cls', cls)])

                    pipeline.fit(dt_train_bucket, train_y)
                    #get the explainations for the model now
        
                    print("Training model iteration ", ii )
                    
                    #get the training data as a matrix
                    trainingdata=feature_combiner.fit_transform(dt_train_bucket);
                    if bucket in bucket_list:
                        importance = generate_global_explanations(trainingdata,train_y, cls, feature_combiner)
                        #create an explainer now that can be passed later
                        class_names=['regular','deviant']# regular is 0, deviant is 1, 0 is left, 1 is right
                        explainer = lime.lime_tabular.LimeTabularExplainer(trainingdata,
                                                    feature_names = feature_combiner.get_feature_names(),
                                                   class_names=class_names, discretize_continuous=True)
                        importance_dict[bucket]=importance
                        #exp_dict[bucket]=explainer
                        model_dict[bucket]=cls
                    
                    
                    offline_time_fit += time.time() - start_offline_time_fit

                    # predict separately for each prefix case
                    preds = []
                    
                    test_all_grouped = dt_test_bucket.groupby(dataset_manager.case_id_col)
                    print(dt_test_bucket.shape)
                    count_d=0
                    count_r=0
                    for _, group in test_all_grouped:
                        
                        test_y_group = dataset_manager.get_label_numeric(group)
                        test_y_all.extend(test_y_group)
                            
                        start = time.time()
                        _ = bucketer.predict(group)
                        
                        if cls_method == "svm":
                            pred = pipeline.decision_function(group)
                        else:
                            preds_pos_label_idx = np.where(cls.classes_ == 1)[0][0]
                            pred = pipeline.predict_proba(group)[:,preds_pos_label_idx]
                            #print(test_y_group)
                            if bucket in bucket_list and (count_d<3 or count_r<3):
                                test_x_group= feature_combiner.fit_transform(group)
                                print(test_x_group.shape,test_y_group[0], _)
                                test_x=np.transpose(test_x_group[0])
                                print('Generating local Explanations for', dataset_manager.get_case_ids(group))
                                exp=generate_local_explanations(explainer, test_x, cls, test_y_group )
                                if(test_y_group[0]==1):
                                    count_d=count_d+1
                                    exp_ddict[bucket+count_d]=exp
                                else:
                                    count_r=count_r+1
                                    exp_rdict[bucket+count_r]=exp
                                
                        pipeline_pred_time = time.time() - start
                        current_online_event_times.append(pipeline_pred_time / len(group))
                        preds.extend(pred)
                        

            preds_all.extend(preds)

      
   
        dt_results = pd.DataFrame({"actual": test_y_all, "predicted": preds_all, "nr_events": nr_events_all})
        for nr_events, group in dt_results.groupby("nr_events"):
            if len(set(group.actual)) < 2:
                print(dataset_name, method_name, cls_method, nr_events, "auc", np.nan)
            else:
                #if nr_events in [5, 10, 25] and explained=False:
                #    generate_local_explanations(explainer,group[j],cls )
                #    explained=True
                print(dataset_name, method_name, cls_method, nr_events, "auc", roc_auc_score(group.actual, group.predicted))
        print(dataset_name, method_name, cls_method, -1, -1, "auc", roc_auc_score(dt_results.actual, dt_results.predicted))
# Out:
# params\optimal_params_xgboost_bpic2015_5_f2_prefix_agg.pickle
# {'colsample_bytree': 0.9340059126816801, 'learning_rate': 0.28762509788553114, 'max_depth': 22, 'min_child_weight': 6, 'subsample': 0.579507991418005}
# prefix
# Bucket 1
# number events 211
# Training model iteration  0
# (211, 37)
# Bucket 2
# number events 422
# Training model iteration  0
# (422, 37)
# Bucket 3
# number events 633
# Training model iteration  0
# (633, 37)
# Bucket 4
# number events 844
# Training model iteration  0
# (844, 37)
# Bucket 5
# number events 1055
# Training model iteration  0
# The number of testing instances is  839
# The total number of columns is 130
# The total accuracy is  0.9976162097735399
# (1055, 37)
# (1, 130) 0 [5]
# Generating local Explanations for 0    10061280_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.97745687 0.02254315]
# Explanation for class deviant
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.10169205017361739)
# ('agg__std_month <= 0.00', -0.08446066882600684)
# ('agg__mean_timesincemidnight > 1144.80', 0.08032761413783532)
# ('static__Handelen in strijd met regels RO <= 0.00', -0.07877557635730914)
# ('0.00 < static__Bouw <= 1.00', 0.07390113060630343)
# ('0.00 < agg__Activity_01_HOOFD_030_1 <= 1.00', -0.06375390397934355)
# (1, 130) 1 [5]
# Generating local Explanations for 0    10063988_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9649543  0.03504568]
# Explanation for class deviant
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.09454598962494233)
# ('agg__mean_timesincelastevent <= 576.00', 0.08766473428403106)
# ('0.00 < static__Bouw <= 1.00', 0.07352587648434299)
# ('agg__max_timesincelastevent <= 2880.00', -0.06495976469116328)
# ('0.00 < agg__Activity_01_HOOFD_030_1 <= 1.00', -0.06333673711335493)
# ('agg__monitoringResource_560604 <= 0.00', 0.061891450513509146)
# (1, 130) 0 [5]
# Generating local Explanations for 0    10065022_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.8535601  0.14643988]
# Explanation for class deviant
# ('static__SUMleges <= 51.94', -0.12599859963814222)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.10773308322245212)
# ('agg__mean_timesincelastevent <= 576.00', 0.0948243191081457)
# ('0.00 < static__Bouw <= 1.00', 0.08765695106812461)
# ('static__Responsible_actor_560604 <= 0.00', 0.08474603387762174)
# ('agg__min_timesincemidnight > 877.00', -0.07155559888608495)
# (1, 130) 0 [5]
# Generating local Explanations for 0    10085342_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9905068  0.00949318]
# Explanation for class deviant
# ('51.94 < static__SUMleges <= 185.76', -0.1477532630782753)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.09893969922317747)
# ('agg__mean_timesincelastevent <= 576.00', 0.09352592909124148)
# ('agg__std_month <= 0.00', -0.07955483957143787)
# ('agg__max_timesincelastevent <= 2880.00', -0.07661096787572703)
# ('0.00 < static__Bouw <= 1.00', 0.0736764739840755)
# (1, 130) 0 [5]
# Generating local Explanations for 0    10089807_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.97684544 0.02315453]
# Explanation for class deviant
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.09330484762341291)
# ('0.00 < static__Bouw <= 1.00', 0.08377012642684672)
# ('agg__mean_event_nr > 3.40', 0.08185969302121354)
# ('agg__std_month <= 0.00', -0.0778003861563208)
# ('52.10 < agg__mean_open_cases <= 83.80', -0.06550017219836803)
# ('static__Responsible_actor_560604 <= 0.00', 0.06193659722277262)
# (1, 130) 1 [5]
# Generating local Explanations for 0    10103656_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.930626   0.06937401]
# Explanation for class deviant
# ('static__SUMleges > 844.28', 0.27950367417530597)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.12121538479938389)
# ('agg__mean_timesincelastevent <= 576.00', 0.09866499697196643)
# ('agg__std_month <= 0.00', -0.08122409454067846)
# ('agg__max_timesincelastevent <= 2880.00', -0.07579628422609677)
# ('static__Responsible_actor_560604 <= 0.00', 0.0728247289634419)
# (1, 130) 0 [5]
# Generating local Explanations for 0    10128082_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9935119  0.00648808]
# Explanation for class deviant
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.11005848110603245)
# ('agg__mean_timesincelastevent <= 576.00', 0.10765900595893688)
# ('agg__max_timesincelastevent <= 2880.00', -0.07929508287778056)
# ('agg__mean_timesincemidnight > 1144.80', 0.07476057729667947)
# ('0.00 < static__Bouw <= 1.00', 0.07306156421686046)
# ('static__Responsible_actor_560604 <= 0.00', 0.07042445571006421)
# (1, 130) 0 [5]
# Generating local Explanations for 0    10180026_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9488462  0.05115376]
# Explanation for class deviant
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.11171408302700483)
# ('static__Bouw <= 0.00', -0.08611998264603224)
# ('agg__mean_timesincemidnight > 1144.80', 0.07151013755901466)
# ('agg__std_month <= 0.00', -0.07064767029823636)
# ('52.10 < agg__mean_open_cases <= 83.80', -0.05473491656265749)
# ('0.00 < agg__Activity_01_HOOFD_030_1 <= 1.00', -0.054402697063066545)
# (1, 130) 1 [5]
# Generating local Explanations for 0    10190750_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9954112  0.00458877]
# Explanation for class deviant
# ('51.94 < static__SUMleges <= 185.76', -0.14953860559276563)
# ('static__Handelen in strijd met regels RO <= 0.00', -0.0973819480429127)
# ('agg__mean_timesincelastevent <= 576.00', 0.09585650512925528)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.09427535249496984)
# ('agg__max_timesincelastevent <= 2880.00', -0.07921292051008053)
# ('0.00 < static__Bouw <= 1.00', 0.07579008111491302)
# Bucket 6
# number events 1266
# Training model iteration  0
# (1266, 37)
# Bucket 7
# number events 1477
# Training model iteration  0
# (1477, 37)
# Bucket 8
# number events 1688
# Training model iteration  0
# (1688, 37)
# Bucket 9
# number events 1899
# Training model iteration  0
# (1899, 37)
# Bucket 10
# number events 2109
# Training model iteration  0
# The number of testing instances is  833
# The total number of columns is 166
# The total accuracy is  0.9975990396158463
# (2100, 37)
# (1, 166) 0 [10]
# Generating local Explanations for 0    10061280_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.46889585 0.53110415]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.3423916062004619)
# ('55.92 < static__SUMleges <= 195.16', -0.1405945372699608)
# ('agg__Activity_16_LGSV_010 <= 0.00', -0.1287650589217941)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.09981600451546528)
# ('4939.50 < agg__max_timesincecasestart <= 9176.70', 0.09354669743579554)
# ('4260.00 < agg__max_timesincelastevent <= 7837.13', -0.09254025248502949)
# (1, 166) 1 [10]
# Generating local Explanations for 0    10063988_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9952879  0.00471213]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.371434555148895)
# ('agg__Activity_16_LGSV_010 <= 0.00', -0.10470724868394966)
# ('agg__std_timesincecasestart <= 1559.28', 0.09206202396893694)
# ('agg__monitoringResource_560604 <= 0.00', 0.08324644913771181)
# ('4260.00 < agg__max_timesincelastevent <= 7837.13', -0.08221604940074435)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.0732704586259825)
# (1, 166) 0 [10]
# Generating local Explanations for 0    10065022_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.65062225 0.34937772]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.33463253237501966)
# ('static__SUMleges <= 55.92', -0.12470174882920405)
# ('agg__std_timesincecasestart <= 1559.28', 0.11531223505306151)
# ('agg__Activity_16_LGSV_010 <= 0.00', -0.09981267690280993)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.07662497619119278)
# ('agg__monitoringResource_560604 <= 0.00', 0.07341931610620049)
# (1, 166) 0 [10]
# Generating local Explanations for 0    10085342_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.99439996 0.00560001]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.38431264142560884)
# ('55.92 < static__SUMleges <= 195.16', -0.15939976053375568)
# ('agg__Activity_16_LGSV_010 <= 0.00', -0.10239667508115383)
# ('4939.50 < agg__max_timesincecasestart <= 9176.70', 0.0976911645718519)
# ('4168.61 < agg__mean_timesincecasestart <= 7084.11', 0.08906289570014782)
# ('4260.00 < agg__max_timesincelastevent <= 7837.13', -0.08669084548611117)
# (1, 166) 0 [10]
# Generating local Explanations for 0    10089807_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.8832969  0.11670308]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.3554557258849394)
# ('4939.50 < agg__max_timesincecasestart <= 9176.70', 0.09914641980288687)
# ('agg__Activity_16_LGSV_010 <= 0.00', -0.09843504460753379)
# ('agg__monitoringResource_560604 <= 0.00', 0.09152649961029333)
# ('4168.61 < agg__mean_timesincecasestart <= 7084.11', 0.083397974930287)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.07347817063712332)
# (1, 166) 1 [10]
# Generating local Explanations for 0    10103656_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.96880305 0.03119697]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.3744043551920967)
# ('static__SUMleges > 844.88', 0.29386476361531055)
# ('0.00 < agg__Activity_16_LGSV_010 <= 1.00', 0.11008620923195661)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.08041853295271817)
# ('agg__monitoringResource_560604 <= 0.00', 0.07930283581680467)
# ('agg__mean_timesincelastevent <= 480.36', -0.07531501068638448)
# (1, 166) 0 [10]
# Generating local Explanations for 0    10128082_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.98777026 0.01222977]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.37664936929656606)
# ('agg__std_timesincecasestart <= 1559.28', 0.12061885334017525)
# ('agg__Activity_16_LGSV_010 <= 0.00', -0.12031131768229983)
# ('agg__Activity_01_HOOFD_061 > 0.00', -0.09210969472616654)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.09003495100218742)
# ('agg__monitoringResource_560604 <= 0.00', 0.07284751074121874)
# (1, 166) 0 [10]
# Generating local Explanations for 0    10180026_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9959795  0.00402052]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.3681152368306683)
# ('agg__Activity_01_HOOFD_061 > 0.00', -0.11861282988790714)
# ('agg__Activity_16_LGSV_010 <= 0.00', -0.1060323146896594)
# ('4260.00 < agg__max_timesincelastevent <= 7837.13', -0.09658991117281635)
# ('agg__std_timesincecasestart <= 1559.28', 0.09074416678512283)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.07893201195537762)
# (1, 166) 1 [10]
# Generating local Explanations for 0    10190750_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.7002622  0.29973784]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.3411279956943499)
# ('55.92 < static__SUMleges <= 195.16', -0.14185633246009174)
# ('agg__Activity_16_LGSV_010 <= 0.00', -0.12269445355742394)
# ('4939.50 < agg__max_timesincecasestart <= 9176.70', 0.08922246677460204)
# ('0.00 < agg__Activity_01_HOOFD_011 <= 1.00', 0.08178438145815144)
# ('agg__monitoringResource_560604 <= 0.00', 0.07619184849019436)
# Bucket 11
# number events 2318
# Training model iteration  0
# (2299, 37)
# Bucket 12
# number events 2526
# Training model iteration  0
# (2496, 37)
# Bucket 13
# number events 2732
# Training model iteration  0
# (2678, 37)
# Bucket 14
# number events 2938
# Training model iteration  0
# (2884, 37)
# Bucket 15
# number events 3141
# Training model iteration  0
# The number of testing instances is  816
# The total number of columns is 212
# The total accuracy is  1.0
# (3045, 37)
# (1, 212) 0 [15]
# Generating local Explanations for 0    10061280_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.95590675 0.04409326]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.4814722997504244)
# ('63.23 < static__SUMleges <= 197.88', -0.12057945768013786)
# ('0.00 < agg__Activity_02_DRZ_010 <= 1.00', 0.10675286049390527)
# ('agg__mean_event_nr > 8.13', -0.07678413375559559)
# ('agg__org:resource_560600 <= 0.00', 0.07085054711235912)
# ('agg__monitoringResource_560600 <= 0.00', -0.06895573342269312)
# (1, 212) 1 [15]
# Generating local Explanations for 0    10063988_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.6367268 0.3632732]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.49645422866978395)
# ('0.00 < agg__Activity_02_DRZ_010 <= 1.00', 0.11375315446861325)
# ('agg__min_timesincemidnight > 669.00', 0.10294419844458455)
# ('agg__std_timesincemidnight <= 188.75', -0.0850608217876897)
# ('agg__org:resource_560600 <= 0.00', 0.08240331366513617)
# ('agg__std_timesincecasestart <= 4202.26', 0.07906299129427781)
# (1, 212) 0 [15]
# Generating local Explanations for 0    10085342_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.86276037 0.13723965]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.4714955277275119)
# ('63.23 < static__SUMleges <= 197.88', -0.12456592475517013)
# ('0.00 < agg__Activity_02_DRZ_010 <= 1.00', 0.11474422087253332)
# ('agg__std_timesincecasestart <= 4202.26', 0.09831305166698846)
# ('agg__monitoringResource_560600 <= 0.00', -0.08081055263129026)
# ('agg__std_timesincelastevent <= 2225.70', 0.07842847585556936)
# (1, 212) 0 [15]
# Generating local Explanations for 0    10089807_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9462688  0.05373117]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.49033684719618165)
# ('0.00 < agg__Activity_02_DRZ_010 <= 1.00', 0.1128647410992632)
# ('agg__std_timesincelastevent <= 2225.70', 0.0990488901269011)
# ('agg__mean_event_nr > 8.13', -0.07655246052402212)
# ('agg__Activity_01_HOOFD_110_1 <= 0.00', -0.07426207121483126)
# ('agg__org:resource_560604 <= 0.00', -0.06068370055827269)
# (1, 212) 1 [15]
# Generating local Explanations for 0    10103656_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.24939609 0.7506039 ]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.45800123591508063)
# ('static__SUMleges > 844.21', 0.2389351416401381)
# ('0.00 < agg__Activity_02_DRZ_010 <= 1.00', 0.11908140176604246)
# ('agg__std_timesincecasestart <= 4202.26', 0.10383253259236763)
# ('agg__std_timesincelastevent <= 2225.70', 0.09248978944809388)
# ('agg__Activity_01_HOOFD_110_1 > 0.00', 0.06560745056939356)
# (1, 212) 0 [15]
# Generating local Explanations for 0    10128082_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.49730617 0.50269383]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.4703833679299367)
# ('0.00 < agg__Activity_02_DRZ_010 <= 1.00', 0.11493940864447356)
# ('agg__std_timesincemidnight <= 188.75', -0.08252702486062377)
# ('agg__mean_event_nr > 8.13', -0.07517995116597627)
# ('agg__min_timesincemidnight > 669.00', 0.0723519652563615)
# ('agg__std_timesincelastevent <= 2225.70', 0.0715197559891303)
# (1, 212) 0 [15]
# Generating local Explanations for 0    10180026_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.99418473 0.00581527]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.4712511757394557)
# ('0.00 < agg__Activity_02_DRZ_010 <= 1.00', 0.12264906656597688)
# ('agg__org:resource_560600 <= 0.00', 0.09048723192134914)
# ('agg__monitoringResource_560600 <= 0.00', -0.0793858915318745)
# ('agg__mean_event_nr > 8.13', -0.07284669827974545)
# ('static__Responsible_actor_560600 <= 0.00', -0.06764265627155733)
# (1, 212) 1 [15]
# Generating local Explanations for 0    10190750_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.7827826  0.21721737]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.4521110746100706)
# ('63.23 < static__SUMleges <= 197.88', -0.11892876294509219)
# ('0.00 < agg__Activity_02_DRZ_010 <= 1.00', 0.11589706868124165)
# ('agg__std_timesincecasestart <= 4202.26', 0.09359919703556217)
# ('agg__mean_event_nr > 8.13', -0.08289592249429169)
# ('agg__std_timesincemidnight <= 188.75', -0.07683708903818562)
# Bucket 16
# number events 3344
# Training model iteration  0
# (3248, 37)
# Bucket 17
# number events 3546
# Training model iteration  0
# (3434, 37)
# Bucket 18
# number events 3747
# Training model iteration  0
# (3618, 37)
# Bucket 19
# number events 3948
# Training model iteration  0
# (3819, 37)
# Bucket 20
# number events 4148
# Training model iteration  0
# The number of testing instances is  808
# The total number of columns is 243
# The total accuracy is  0.9987623762376238
# (4000, 37)
# (1, 243) 0 [20]
# Generating local Explanations for 0    10061280_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9984706  0.00152937]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.5229288682941038)
# ('agg__Activity_08_AWB45_010 <= 0.00', -0.4513209013397448)
# ('0.00 < agg__Activity_01_HOOFD_195 <= 1.00', -0.16450468954545508)
# ('3.00 < agg__question_True <= 4.00', -0.08106582463355567)
# ('168.54 < agg__std_timesincemidnight <= 204.55', -0.07394253024317028)
# ('8.00 < agg__question_EMPTY <= 9.00', -0.07187025582384324)
# (1, 243) 1 [20]
# Generating local Explanations for 0    10063988_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.05429167 0.94570833]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.5300748127841755)
# ('agg__Activity_08_AWB45_010 > 0.00', 0.4579753833779493)
# ('agg__Activity_01_HOOFD_195 <= 0.00', 0.16681119433476652)
# ('agg__std_hour <= 2.91', 0.1559542272982493)
# ('agg__question_EMPTY <= 8.00', 0.14743715063450422)
# ('agg__std_timesincemidnight <= 168.54', -0.092873757249285)
# (1, 243) 0 [20]
# Generating local Explanations for 0    10085342_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9956492  0.00435077]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.5321411900910975)
# ('agg__Activity_08_AWB45_010 <= 0.00', -0.4409151607198001)
# ('0.00 < agg__Activity_01_HOOFD_195 <= 1.00', -0.16882861029735252)
# ('3.00 < agg__question_True <= 4.00', -0.09357933039343966)
# ('168.54 < agg__std_timesincemidnight <= 204.55', -0.07185873087143217)
# ('2.91 < agg__std_hour <= 3.55', 0.06560005089859518)
# (1, 243) 0 [20]
# Generating local Explanations for 0    10089807_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9766031  0.02339691]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.5204226853198441)
# ('agg__Activity_08_AWB45_010 <= 0.00', -0.4389140863125811)
# ('0.00 < agg__Activity_01_HOOFD_195 <= 1.00', -0.166852928264754)
# ('agg__question_EMPTY <= 8.00', 0.13509957795516214)
# ('3.00 < agg__question_True <= 4.00', -0.08141797378986258)
# ('agg__Activity_01_HOOFD_120 <= 0.00', -0.05904625179870664)
# (1, 243) 1 [20]
# Generating local Explanations for 0    10103656_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.03112197 0.96887803]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.5276383485420377)
# ('agg__Activity_08_AWB45_010 > 0.00', 0.4512377242472743)
# ('agg__Activity_01_HOOFD_195 <= 0.00', 0.1757430371885051)
# ('agg__question_EMPTY <= 8.00', 0.13509177945682024)
# ('3.55 < agg__std_hour <= 4.76', -0.10286531577240866)
# ('static__SUMleges > 845.69', 0.0935987146175712)
# (1, 243) 0 [20]
# Generating local Explanations for 0    10128082_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.8729339  0.12706608]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.5246805730323315)
# ('agg__Activity_08_AWB45_010 <= 0.00', -0.44374262061190456)
# ('0.00 < agg__Activity_01_HOOFD_195 <= 1.00', -0.17388058848732538)
# ('agg__question_EMPTY <= 8.00', 0.14431284777809167)
# ('agg__std_hour <= 2.91', 0.13627232387347726)
# ('agg__question_True <= 3.00', 0.09262154415470593)
# (1, 243) 0 [20]
# Generating local Explanations for 0    10180026_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9983222  0.00167782]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.5329303853647346)
# ('agg__Activity_08_AWB45_010 <= 0.00', -0.4492782522906912)
# ('0.00 < agg__Activity_01_HOOFD_195 <= 1.00', -0.1678903347583532)
# ('agg__max_timesincelastevent > 48145.92', -0.10335070794336984)
# ('3.00 < agg__question_True <= 4.00', -0.09584087392847007)
# ('agg__Activity_01_HOOFD_120 <= 0.00', -0.06815325583543348)
# (1, 243) 1 [20]
# Generating local Explanations for 0    10190750_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.15762234 0.84237766]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.5128138198165064)
# ('agg__Activity_08_AWB45_010 <= 0.00', -0.4382458333891699)
# ('agg__Activity_01_HOOFD_195 <= 0.00', 0.17088506908919424)
# ('agg__std_hour <= 2.91', 0.1413457937064018)
# ('agg__question_EMPTY <= 8.00', 0.13644814229472954)
# ('agg__question_True <= 3.00', 0.10732965251805326)
# Bucket 21
# number events 4345
# Training model iteration  0
# (4137, 37)
# Bucket 22
# number events 4541
# Training model iteration  0
# (4312, 37)
# Bucket 23
# number events 4737
# Training model iteration  0
# (4508, 37)
# Bucket 24
# number events 4933
# Training model iteration  0
# (4704, 37)
# Bucket 25
# number events 5127
# Training model iteration  0
# The number of testing instances is  784
# The total number of columns is 267
# The total accuracy is  0.9987244897959183
# (4850, 37)
# (1, 267) 0 [25]
# Generating local Explanations for 0    10061280_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.96627015 0.03372987]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.6276353176703251)
# ('agg__Activity_08_AWB45_010 <= 0.00', -0.19772735771285085)
# ('0.00 < agg__Activity_01_HOOFD_200 <= 1.00', -0.13055703959024412)
# ('0.00 < agg__Activity_01_HOOFD_195 <= 1.00', -0.07817728013146326)
# ('agg__Activity_01_HOOFD_250 <= 0.00', 0.05046572495454061)
# ('agg__mean_month <= 3.52', 0.04845418558109861)
# (1, 267) 1 [25]
# Generating local Explanations for 0    10063988_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.00509268 0.9949073 ]
# Explanation for class deviant
# ('0.00 < agg__Activity_08_AWB45_020_2 <= 1.00', 0.6280539923022753)
# ('0.00 < agg__Activity_08_AWB45_010 <= 1.00', 0.19646083361616068)
# ('agg__Activity_01_HOOFD_200 <= 0.00', 0.12829535348667148)
# ('agg__Activity_01_HOOFD_195 <= 0.00', 0.0758247921925972)
# ('agg__max_timesincecasestart > 77009.26', 0.06943034085847007)
# ('agg__Activity_01_HOOFD_250 <= 0.00', 0.05018047926703996)
# (1, 267) 0 [25]
# Generating local Explanations for 0    10085342_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.97165823 0.02834178]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.6272509461345757)
# ('agg__Activity_08_AWB45_010 <= 0.00', -0.20773877973812271)
# ('0.00 < agg__Activity_01_HOOFD_200 <= 1.00', -0.13499870146042348)
# ('0.00 < agg__Activity_01_HOOFD_195 <= 1.00', -0.07889952044020071)
# ('agg__Activity_01_HOOFD_250 <= 0.00', 0.056326528054169635)
# ('agg__max_timesincecasestart <= 22217.48', -0.05290043456768315)
# (1, 267) 0 [25]
# Generating local Explanations for 0    10089807_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9583116  0.04168841]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.6238062348954837)
# ('agg__Activity_08_AWB45_010 <= 0.00', -0.20124724402480446)
# ('0.00 < agg__Activity_01_HOOFD_200 <= 1.00', -0.1365327131630778)
# ('0.00 < agg__Activity_01_HOOFD_195 <= 1.00', -0.07560364324577135)
# ('agg__Activity_01_HOOFD_250 <= 0.00', 0.05330794838856146)
# ('22217.48 < agg__max_timesincecasestart <= 51192.34', -0.052663246293486475)
# (1, 267) 1 [25]
# Generating local Explanations for 0    10103656_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.0057649 0.9942351]
# Explanation for class deviant
# ('0.00 < agg__Activity_08_AWB45_020_2 <= 1.00', 0.6208076538824678)
# ('0.00 < agg__Activity_08_AWB45_010 <= 1.00', 0.1934620871026194)
# ('agg__Activity_01_HOOFD_200 <= 0.00', 0.12841225707667922)
# ('agg__Activity_01_HOOFD_195 <= 0.00', 0.07758418243417808)
# ('agg__Activity_01_HOOFD_250 <= 0.00', 0.049178349768783526)
# ('agg__mean_open_cases <= 61.53', 0.045684894291112874)
# (1, 267) 0 [25]
# Generating local Explanations for 0    10128082_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.944581   0.05541902]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.6266804628641968)
# ('agg__Activity_08_AWB45_010 <= 0.00', -0.19693831253020463)
# ('0.00 < agg__Activity_01_HOOFD_200 <= 1.00', -0.12998149658167196)
# ('0.00 < agg__Activity_01_HOOFD_195 <= 1.00', -0.07529401592496708)
# ('22217.48 < agg__max_timesincecasestart <= 51192.34', -0.05247550070467431)
# ('agg__Activity_01_HOOFD_250 <= 0.00', 0.04731577493070335)
# (1, 267) 0 [25]
# Generating local Explanations for 0    10180026_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9686699  0.03133008]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.6238719277132202)
# ('agg__Activity_08_AWB45_010 <= 0.00', -0.2039254707930923)
# ('0.00 < agg__Activity_01_HOOFD_200 <= 1.00', -0.1322491258957742)
# ('0.00 < agg__Activity_01_HOOFD_195 <= 1.00', -0.08022345963973575)
# ('agg__Activity_01_HOOFD_250 <= 0.00', 0.054002281718232154)
# ('agg__mean_month <= 3.52', 0.048834793760433176)
# (1, 267) 1 [25]
# Generating local Explanations for 0    10190750_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.1844427 0.8155573]
# Explanation for class deviant
# ('agg__Activity_08_AWB45_020_2 <= 0.00', -0.6273928395284663)
# ('0.00 < agg__Activity_08_AWB45_010 <= 1.00', 0.2002980154748188)
# ('agg__Activity_01_HOOFD_200 <= 0.00', 0.12881171070159342)
# ('agg__Activity_01_HOOFD_195 <= 0.00', 0.07733195482431476)
# ('agg__max_timesincecasestart <= 22217.48', -0.05139117947115482)
# ('agg__Activity_01_HOOFD_250 <= 0.00', 0.04852694896956939)
# Bucket 26
# number events 5321
# Training model iteration  0
# (5044, 37)
# Bucket 27
# number events 5514
# Training model iteration  0
# (5211, 37)
# Bucket 28
# number events 5707
# Training model iteration  0
# (5404, 37)
# Bucket 29
# number events 5900
# Training model iteration  0
# (5597, 37)
# Bucket 30
# number events 6093
# Training model iteration  0
# (5790, 37)
# Bucket 31
# number events 6286
# Training model iteration  0
# (5983, 37)
# Bucket 32
# number events 6478
# Training model iteration  0
# (6144, 37)
# Bucket 33
# number events 6670
# Training model iteration  0
# (6336, 37)
# Bucket 34
# number events 6862
# Training model iteration  0
# (6528, 37)
# Bucket 35
# number events 7051
# Training model iteration  0
# (6615, 37)
# Bucket 36
# number events 7240
# Training model iteration  0
# (6804, 37)
# Bucket 37
# number events 7428
# Training model iteration  0
# (6956, 37)
# Bucket 38
# number events 7616
# Training model iteration  0
# (7144, 37)
# Bucket 39
# number events 7804
# Training model iteration  0
# (7332, 37)
# Bucket 40
# number events 7989
# Training model iteration  0
# (7400, 37)
# bpic2015_5_f2 prefix_agg xgboost 1 auc 0.6680652680652681
# bpic2015_5_f2 prefix_agg xgboost 2 auc 0.642890442890443
# bpic2015_5_f2 prefix_agg xgboost 3 auc 0.6660839160839161
# bpic2015_5_f2 prefix_agg xgboost 4 auc 0.6525641025641026
# bpic2015_5_f2 prefix_agg xgboost 5 auc 0.6888111888111887
# bpic2015_5_f2 prefix_agg xgboost 6 auc 0.7001165501165502
# bpic2015_5_f2 prefix_agg xgboost 7 auc 0.6977855477855478
# bpic2015_5_f2 prefix_agg xgboost 8 auc 0.6446386946386946
# bpic2015_5_f2 prefix_agg xgboost 9 auc 0.6559440559440559
# bpic2015_5_f2 prefix_agg xgboost 10 auc 0.6130205278592376
# bpic2015_5_f2 prefix_agg xgboost 11 auc 0.6584415584415585
# bpic2015_5_f2 prefix_agg xgboost 12 auc 0.7257278669043374
# bpic2015_5_f2 prefix_agg xgboost 13 auc 0.6809151113786875
# bpic2015_5_f2 prefix_agg xgboost 14 auc 0.7098133654425045
# bpic2015_5_f2 prefix_agg xgboost 15 auc 0.8227272727272728
# bpic2015_5_f2 prefix_agg xgboost 16 auc 0.8738329238329239
# bpic2015_5_f2 prefix_agg xgboost 17 auc 0.8298082869511442
# bpic2015_5_f2 prefix_agg xgboost 18 auc 0.9657534246575343
# bpic2015_5_f2 prefix_agg xgboost 19 auc 0.9840597758405978
# bpic2015_5_f2 prefix_agg xgboost 20 auc 0.9909717868338558
# bpic2015_5_f2 prefix_agg xgboost 21 auc 0.995134443021767
# bpic2015_5_f2 prefix_agg xgboost 22 auc 0.9993552546744036
# bpic2015_5_f2 prefix_agg xgboost 23 auc 0.998581560283688
# bpic2015_5_f2 prefix_agg xgboost 24 auc 0.9993552546744036
# bpic2015_5_f2 prefix_agg xgboost 25 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 26 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 27 auc 0.9998652291105121
# bpic2015_5_f2 prefix_agg xgboost 28 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 29 auc 0.9998652291105121
# bpic2015_5_f2 prefix_agg xgboost 30 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 31 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 32 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 33 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 34 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 35 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 36 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 37 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 38 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 39 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost 40 auc 1.0
# bpic2015_5_f2 prefix_agg xgboost -1 -1 auc 0.8996995070019417

# %%
rc={'axes.labelsize': 12, 'xtick.labelsize': 13, 'ytick.labelsize': 13 , 'axes.titlesize': 10}
sns.set(rc)
sns.set_style("whitegrid")
# %matplotlib inline
for pre, exp in exp_ddict.items():
    #print('Explanations for prefix length ', pre)
    fig = exp.as_pyplot_figure()

# %%
rc={'axes.labelsize': 12, 'xtick.labelsize': 13, 'ytick.labelsize': 13 , 'axes.titlesize': 10}
sns.set(rc)
sns.set_style("whitegrid")
for pre, importance in importance_dict.items():
    if(pre==10):
        print('printing global feature importance of the XGBoost classifier', pre, importance.head(10)) 
        title = 'Prefix length {} bucket: prefix, encoding: aggregation, classifier: xgboost'.format(pre)
        var_imp_plot(importance, title, 10)
# Out:
# printing global feature importance of the XGBoost classifier 10                           feature  feature_importance
# 0    agg__Activity_08_AWB45_020_2            0.223512
# 1     static__Milieu (vergunning)            0.046107
# 2      agg__Activity_01_HOOFD_011            0.037904
# 3        agg__Activity_02_DRZ_010            0.037827
# 4        agg__org:resource_560604            0.025403
# 5        agg__org:resource_560600            0.025375
# 6        agg__org:resource_560429            0.021497
# 7       agg__Activity_16_LGSV_010            0.018419
# 8  agg__monitoringResource_560429            0.017816
# 9        agg__Activity_04_BPT_005            0.017477
