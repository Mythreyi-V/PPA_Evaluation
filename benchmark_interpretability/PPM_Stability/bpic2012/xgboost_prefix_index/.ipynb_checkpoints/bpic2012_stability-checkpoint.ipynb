# %%
#from google.colab import drive
#drive.mount('/content/drive')
import sys
#PATH = '/content/drive/My Drive/PPM_Stability/'
PATH = "C:/Users/velmurug/Documents/Stability Experiments/benchmark_interpretability/PPM_Stability/"
sys.path.append(PATH)

# %%
#!pip install lime
#!pip install shap
#!pip install pandas==0.19.2
# !pip install xgboost==1.0.0
# Out:
# Requirement already satisfied: xgboost==1.0.0 in c:\programdata\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost==1.0.0) (1.18.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost==1.0.0) (1.4.1)

# %%
import EncoderFactory
from DatasetManager import DatasetManager
import BucketFactory
import stability as st #Nogueira, Sechidis, Brown.

import pandas as pd
import numpy as np
from scipy import stats

from sklearn.metrics import roc_auc_score
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import StandardScaler

import time
import os
import sys
from sys import argv
import pickle
from collections import defaultdict
import random
import joblib

from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import lime
import lime.lime_tabular
from lime import submodular_pick;

import shap

import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

def imp_df(column_names, importances):
        df = pd.DataFrame({'feature': column_names,
                       'feature_importance': importances}) \
           .sort_values('feature_importance', ascending = False) \
           .reset_index(drop = True)
        return df

# plotting a feature importance dataframe (horizontal barchart)
def var_imp_plot(imp_df, title, num_feat):
        imp_df.columns = ['feature', 'feature_importance']
        b= sns.barplot(x = 'feature_importance', y = 'feature', data = imp_df.head(num_feat), orient = 'h', palette="Blues_r")

# %%
def generate_global_explanations(train_X,train_Y, cls, feature_combiner):
    
    print("The number of testing instances is ",len(train_Y))
    print("The total number of columns is",train_X.shape[1]);
    print("The total accuracy is ",cls.score(train_X,train_Y));
       
    sns.set(rc={'figure.figsize':(10,10), "font.size":18,"axes.titlesize":18,"axes.labelsize":18})
    sns.set
    feat_names = feature_combiner.get_feature_names()
    base_imp = imp_df(feat_names, cls.feature_importances_)
    base_imp.head(15)
    var_imp_plot(base_imp, 'Feature importance using XGBoost', 15)
    return base_imp

# %%
from lime import submodular_pick
def generate_lime_explanations(explainer,test_xi, cls,test_y, submod=False, test_all_data=None, max_feat = 10):
    
    #print("Actual value ", test_y)
    exp = explainer.explain_instance(test_xi, 
                                 cls.predict_proba, num_features=max_feat, labels=[0,1])
    
    return exp
        
    if submod==True:
        sp_obj=submodular_pick.SubmodularPick(explainer, test_all_data, cls.predict_proba, 
                                      sample_size=20, num_features=num_features,num_exps_desired=4)
        [exp.as_pyplot_figure(label=exp.available_labels()[0]) for exp in sp_obj.sp_explanations];

# %%
def create_samples(shap_explainer, iterations, row, features, top = None):
    length = len(features)
    
    exp = []
    rel_exp = []
    
    for j in range(iterations):
        
        #if shap_type == "kernel":
        #    shap_explainer = shap.KernelExplainer(cls.predict, trainingsample)
        #elif shap_type == "tree":
        #    shap_explainer = shap.TreeExplainer(cls)
        #elif shap_type == "deep":
        #    shap_explainer = shap.DeepExplainer(cls, background)
        
        #print(X_test_frame.loc[row])
        shap_values = shap_explainer.shap_values(row)
        #print(shap_values)

        importances = []
        
        if type(shap_explainer) == shap.explainers.kernel.KernelExplainer:
            for i in range(length):
                feat = features[i]
                shap_val = shap_values[0][i]
                abs_val = abs(shap_values[0][i])
                entry = (feat, shap_val, abs_val)
                importances.append(entry)
                
        elif type(shap_explainer) == shap.explainers.tree.TreeExplainer:
            for i in range(length):
                feat = features[i]
                shap_val = shap_values[0][i]
                abs_val = abs(shap_values[0][i])
                entry = (feat, shap_val, abs_val)
                importances.append(entry)
        
        elif type(shap_explainer) == shap.explainers.deep.DeepExplainer:
            for i in range(length):
                feat = features[i]
                shap_val = shap_values[0][0][i]
                abs_val = abs(shap_values[0][0][i])
                entry = (feat, shap_val, abs_val)
                importances.append(entry)
        
        importances.sort(key=lambda tup: tup[2], reverse = True)
        
        exp.append(importances)

        rel_feat = []

        if top != None:
            for i in range(top):
                feat = importances[i]
                if feat[2] > 0:
                    rel_feat.append(feat)

            rel_exp.append(rel_feat)
        else:
            rel_exp = exp
        
    return exp, rel_exp

# %%
def dispersal(weights, features):
    feat_len = len(features)
    #print(feat_len)
    weights_by_feat = []
       
    for i in list(range(feat_len)):
        feat_weight = []
        for iteration in weights:
            feat_weight.append(iteration[i])
        weights_by_feat.append(feat_weight)
        
    #for iteration in weights:
     #   for val in iteration:
      #      idx = iteration.index(val)
       #     print(idx)
        #    weights_by_feat[idx].append(val)
    
    dispersal = []
    dispersal_no_outlier = []
    
    for each in weights_by_feat:
        #print("Feature", weights_by_feat.index(each)+1)
        mean = np.mean(each)
        std_dev = np.std(each)
        var = std_dev**2
        
        if mean == 0:
            dispersal.append(0)
            dispersal_no_outlier.append(0)
        #print(each)
        else:
            #dispersal with outliers
            rel_var = var/abs(mean)
            dispersal.append(rel_var)
            
            #dispersal without outliers - remove anything with a z-score higher
            #than 3 (more than 3 standard deviations away from the mean)
            rem_outlier = []
            z_scores = stats.zscore(each)
            #print(z_scores)
            #print("New list:")
            for i in range(len(z_scores)):
                #print(each[i],":",z_scores[i])
                if -3 < z_scores[i] < 3:
                    rem_outlier.append(each[i])
                #print(rem_outlier)
            if rem_outlier != []:
                new_mean = np.mean(rem_outlier)
                if new_mean == 0:
                    dispersal_no_outlier.append(0)
                else:
                    new_std = np.std(rem_outlier)
                    new_var = new_std**2
                    new_rel_var = new_var/abs(new_mean)
                    dispersal_no_outlier.append(new_rel_var)
            else:
                dispersal_no_outlier.append(rel_var)
    #print(dispersal_no_outlier)
    return dispersal, dispersal_no_outlier

# %%
dataset_ref = "bpic2012"
params_dir = PATH + "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "index"
cls_method = "xgboost"

gap = 1
n_iter = 1

method_name = "%s_%s"%(bucket_method, cls_encoding)

generate_samples = False
generate_lime = True
generate_kernel_shap = False
generate_model_shap = True

sample_size = 2
exp_iter = 10
max_feat = 10

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"]
    #"insurance": ["insurance_activity", "insurance_followup"],
    #"sepsis_cases": ["sepsis_cases_1", "sepsis_cases_2", "sepsis_cases_4"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]

datasets
# Out:
# ['bpic2012_accepted']

# %%
if generate_samples:

    for dataset_name in datasets:
        
        dataset_manager = DatasetManager(dataset_name)
        
        for ii in range(n_iter):
            num_buckets = range(len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))]))
            
            for bucket in list(num_buckets):
                bucketID = bucket+1
                print ('Bucket', bucketID)

                #import everything needed to sort and predict
                pipeline_path = os.path.join(PATH, "%s/%s_%s/pipelines/pipeline_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                bucketer_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/bucketer_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))

                predictor = joblib.load(pipeline_path)
                cls = joblib.load(cls_path)
                feature_combiner = joblib.load(feat_comb_path)
                bucketer = joblib.load(bucketer_path)

                #import data for bucket
                X_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                Y_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                X_test_path = os.path.join(PATH, "%s/%s_%s/test_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                Y_test_path = os.path.join(PATH, "%s/%s_%s/test_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucketID))

                with open (X_train_path, 'rb') as f:
                    dt_train_bucket = pickle.load(f)
                with open (Y_train_path, 'rb') as f:
                    train_y = pickle.load(f)
                with open (X_test_path, 'rb') as f:
                    dt_test_bucket = pickle.load(f)
                with open (Y_test_path, 'rb') as f:
                    test_y = pickle.load(f)

                #import previous results from predictions
                tn_path = os.path.join(PATH, "%s/%s_%s/instances/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                tp_path = os.path.join(PATH, "%s/%s_%s/instances/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fn_path = os.path.join(PATH, "%s/%s_%s/instances/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fp_path = os.path.join(PATH, "%s/%s_%s/instances/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

                instances = []

                with open (tn_path, 'rb') as f:
                    tn_list = pickle.load(f)
                with open (tp_path, 'rb') as f:
                    tp_list = pickle.load(f)
                with open (fn_path, 'rb') as f:
                    fn_list = pickle.load(f)
                with open (fp_path, 'rb') as f:
                    fp_list = pickle.load(f)

                #save results to a list
                instances.append(tn_list)
                instances.append(tp_list)
                instances.append(fn_list)
                instances.append(fp_list)

                #choose instances from the event log to explain, based on different prefix lengths
                sample_instances = []
                
                for each in instances:
                    sample = []
                    #Find instances of different prediction probabilities
                    prs = [0.5, 0.6, 0.7, 0.8, 0.9, 1.1]
                    for i in list(range(len(prs)-1)):
                        low = prs[i]
                        high = prs[i+1]
                        ins = [d for d in each if (d['proba'] >= low) & (d['proba'] < high)]
                        if len(ins) >= sample_size:
                            sample.extend(random.sample(ins, k=sample_size))
                        else:
                            sample.extend(ins)
                    sample = sorted(sample, key = lambda i: (i['proba'], i['nr_events']))
                    sample_instances.append(sample)

                tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

                with open(tn_path, 'wb') as f:
                    pickle.dump(sample_instances[0], f)
                with open(tp_path, 'wb') as f:
                    pickle.dump(sample_instances[1], f)
                with open(fn_path, 'wb') as f:
                    pickle.dump(sample_instances[2], f)
                with open(fp_path, 'wb') as f:
                    pickle.dump(sample_instances[3], f)

# %%
if generate_model_shap:

    for dataset_name in datasets:
        
        dataset_manager = DatasetManager(dataset_name)
        
        for ii in range(n_iter):
            num_buckets = range(len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))]))
            
            for bucket in list(num_buckets):
                bucketID = bucket+1
                print ('Bucket', bucketID)

                #import everything needed to sort and predict
                feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                cls = joblib.load(cls_path)
                feature_combiner = joblib.load(feat_comb_path)
                
                #import data for bucket
                #X_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                #Y_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                
                #with open (X_train_path, 'rb') as f:
                #    dt_train_bucket = pickle.load(f)
                #with open (Y_train_path, 'rb') as f:
                #    train_y = pickle.load(f)
                #with open (X_test_path, 'rb') as f:
                #    dt_test_bucket = pickle.load(f)
                #with open (Y_test_path, 'rb') as f:
                #    test_y = pickle.load(f)

                #import previously identified samples
                tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

                sample_instances = []

                with open (tn_path, 'rb') as f:
                    tn_list = pickle.load(f)
                with open (tp_path, 'rb') as f:
                    tp_list = pickle.load(f)
                #with open (fn_path, 'rb') as f:
                #    fn_list = pickle.load(f)
                #with open (fp_path, 'rb') as f:
                #    fp_list = pickle.load(f)

                #save results to a list
                sample_instances.append(tn_list)
                sample_instances.append(tp_list)
                #sample_instances.append(fn_list)
                #sample_instances.append(fp_list)

                #create explainers now that can be passed later
                tree_explainer = shap.TreeExplainer(cls)

                #explain the chosen instances and find the stability score
                cat_no = 0
                for category in sample_instances:
                    cat_no += 1
                    instance_no = 0
                    
                    for instance in category:
                        instance_no += 1    
                        print("Category", cat_no, "of", len(sample_instances), ". Testing", instance_no, "of", len(category), ".")
                
                        group = instance['input']

                        print(group.shape,instance['actual'], instance['predicted'])
                        test_x_group= feature_combiner.fit_transform(group) 
                        test_x=np.transpose(test_x_group[0])

                        print('Generating local Explanations for', instance['caseID'])

                        feat_list = feature_combiner.get_feature_names()

                        #Get Tree SHAP explanations for instance
                        exp, rel_exp = create_samples(tree_explainer, exp_iter, test_x.reshape(-1, len(test_x)), feat_list, top = max_feat)

                        feat_pres = []
                        feat_weights = []

                        for iteration in rel_exp:
                            print("Computing feature presence for iteration", rel_exp.index(iteration))
                            #print(iteration)

                            #Stability by index
                            presence_list = [0]*len(feat_list)
                            #stability by weight
                            #weights = [0]*len(feat_list)

                            for each in feat_list:
                                list_idx = feat_list.index(each)
                                #print ("Feature", list_idx)
                                for explanation in iteration:
                                    if each in explanation[0]:
                                        presence_list[list_idx] = 1
                                        #weights[list_idx] = explanation[1]

                            feat_pres.append(presence_list)
                            
                        for iteration in exp:
                            print("Compiling feature weights for iteration", exp.index(iteration))
                            #print(iteration)

                            #Stability by index
                            #presence_list = [0]*len(feat_list)
                            #stability by weight
                            weights = [0]*len(feat_list)

                            for each in feat_list:
                                list_idx = feat_list.index(each)
                                #print ("Feature", list_idx)
                                for explanation in iteration:
                                    if each in explanation[0]:
                                        #presence_list[list_idx] = 1
                                        weights[list_idx] = explanation[1]
                            feat_weights.append(weights)

                        stability = st.getStability(feat_pres)
                        print ("Stability:", round(stability,2))
                        instance['tree_shap_stability'] = stability
                        
                        norm_var = dispersal(feat_weights, feat_list)
                        avg_dispersal = np.mean(norm_var)
                        print ("Dispersal of feature importance:", round(avg_dispersal, 2))
                        instance['shap_weights_dispersal'] = norm_var
                        instance['shap_importance_stability'] = avg_dispersal

                with open(tn_path, 'wb') as f:
                    pickle.dump(sample_instances[0], f)
                with open(tp_path, 'wb') as f:
                    pickle.dump(sample_instances[1], f)
                #with open(fn_path, 'wb') as f:
                #    pickle.dump(sample_instances[2], f)
                #with open(fp_path, 'wb') as f:
                #    pickle.dump(sample_instances[3], f)
# Out:
# Bucket 1
# Category 1 of 4 . Testing 1 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 208283
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 2 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 205969
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 3 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 205433
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 4 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 205319
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 5 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 206165
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 6 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 209200
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 209087
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 8 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 210719
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 9 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 205474
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 10 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 208358
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 1 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 207894
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 2 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 207050
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 3 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 207284
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 4 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 207413
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 5 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 213906
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 6 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 206483
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 7 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 213144
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 8 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 211901
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 9 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 208172
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 10 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 209084
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 1 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 204628
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 2 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 211002
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 3 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 208103
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 4 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 211269
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 5 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 212725
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 6 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 209105
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 206793
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 8 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 210969
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 9 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 206456
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 10 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 206519
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 1 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 211817
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 2 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 207702
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 3 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 210344
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 4 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 205256
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 5 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 212776
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 6 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 211564
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 209790
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 211360
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 9 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 207873
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 10 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 204847
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Bucket 2
# Category 1 of 4 . Testing 1 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 210755_2
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 2 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 205182_2
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 3 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 207674_2
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 4 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 209559_2
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 5 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 210599_2
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 6 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 205247_2
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 213705_2
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 8 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 206528_2
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 9 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 204915_2
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# ...
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 4 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 213432_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 5 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 206615_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 6 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 204859_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 205661_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 8 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 209084_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 9 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 208103_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 1 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 206856_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 2 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 206222_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 3 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 210629_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 4 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 211883_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 5 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 206249_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 6 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 206567_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 210890_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 206441_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 9 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 208064_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 10 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 206838_40
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Computing feature presence for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Compiling feature weights for iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0

# %%
if generate_lime:

    for dataset_name in datasets:
        
        dataset_manager = DatasetManager(dataset_name)
        
        for ii in range(n_iter):
            num_buckets = range(len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))]))
            
            for bucket in list(num_buckets):
                bucketID = bucket+1
                print ('Bucket', bucketID)

                #import everything needed to sort and predict
                feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                cls = joblib.load(cls_path)
                feature_combiner = joblib.load(feat_comb_path)
                
                #import data for bucket
                X_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                Y_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                
                with open (X_train_path, 'rb') as f:
                    dt_train_bucket = pickle.load(f)
                with open (Y_train_path, 'rb') as f:
                    train_y = pickle.load(f)
                #with open (X_test_path, 'rb') as f:
                #    dt_test_bucket = pickle.load(f)
                #with open (Y_test_path, 'rb') as f:
                #    test_y = pickle.load(f)

                #import previously identified samples
                tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                #fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                #fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

                sample_instances = []

                with open (tn_path, 'rb') as f:
                    tn_list = pickle.load(f)
                with open (tp_path, 'rb') as f:
                    tp_list = pickle.load(f)
                #with open (fn_path, 'rb') as f:
                #    fn_list = pickle.load(f)
                #with open (fp_path, 'rb') as f:
                #    fp_list = pickle.load(f)

                #save results to a list
                sample_instances.append(tn_list)
                sample_instances.append(tp_list)
                #sample_instances.append(fn_list)
                #sample_instances.append(fp_list)

                #get the training data as a matrix
                trainingdata = feature_combiner.fit_transform(dt_train_bucket);
                #importance = generate_global_explanations(trainingdata,train_y, cls, feature_combiner)

                #explain the chosen instances and find the stability score
                cat_no = 0
                for category in sample_instances:
                    cat_no += 1
                    instance_no = 0
                    for instance in category:
                        instance_no += 1
                        
                        print("Category", cat_no, "of", len(sample_instances), ". Testing", instance_no, "of", len(category), ".")
                        
                        group = instance['input']
                        
                        #create explainer now that can be passed later
                        class_names=['regular','deviant']# regular is 0, deviant is 1, 0 is left, 1 is right
                        lime_explainer = lime.lime_tabular.LimeTabularExplainer(trainingdata,
                                          feature_names = feature_combiner.get_feature_names(),
                                          class_names=class_names, discretize_continuous=True)

                        #print(group.shape,instance['actual'], instance['predicted'])
                        test_x_group= feature_combiner.fit_transform(group) 
                        test_x=np.transpose(test_x_group[0])

                        print('Generating local Explanations for', instance['caseID'])

                        feat_list = feature_combiner.get_feature_names()

                        #Get lime explanations for instance
                        feat_pres = []
                        feat_weights = []

                        for iteration in list(range(exp_iter)):
                            print("Run", iteration)
                            
                            lime_exp = generate_lime_explanations(lime_explainer, test_x, cls, instance['actual'], max_feat = 300)

                            presence_list = [0]*len(feat_list)
                            weights = [0]*len(feat_list)

                            for each in feat_list:
                                list_idx = feat_list.index(each)
                                #print ("Feature", list_idx)
                                for explanation in lime_exp.as_list():
                                    if each in explanation[0]:
                                        if lime_exp.as_list().index(explanation) < max_feat:
                                            presence_list[list_idx] = 1
                                        weights[list_idx] = explanation[1]

                            feat_pres.append(presence_list)
                            feat_weights.append(weights)

                        stability = st.getStability(feat_pres)
                        print ("Stability:", round(stability,2))
                        instance['lime_stability'] = stability
                        
                        rel_var, second_var = dispersal(feat_weights, feat_list)
                        avg_dispersal = np.mean(rel_var)
                        print ("Dispersal of feature importance:", round(avg_dispersal, 2))
                        instance['lime_weights_dispersal'] = rel_var
                        adj_dispersal = np.mean(second_var)
                        print ("Dispersal with no outliers:", round(adj_dispersal, 2))
                        instance['adjusted_lime_weights_dispersal'] = second_var
                        
                #Save dictionaries updated with stability scores
                with open(tn_path, 'wb') as f:
                    pickle.dump(sample_instances[0], f)
                with open(tp_path, 'wb') as f:
                    pickle.dump(sample_instances[1], f)
                #with open(fn_path, 'wb') as f:
                #    pickle.dump(sample_instances[2], f)
                #with open(fp_path, 'wb') as f:
                #    pickle.dump(sample_instances[3], f)
# Out:
# Bucket 1
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 208283
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205969
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 205433
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205319
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.02
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206165
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.14
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 209200
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 209087
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.44
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 210719
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 205474
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.44
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 208358
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 207894
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 207050
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.14
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 207284
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 207413
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 213906
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 206483
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.41
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 213144
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 211901
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 208172
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.41
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 209084
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 204628
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.39
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 211002
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 208103
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 211269
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.49
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 212725
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 209105
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.14
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 206793
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.14
# Dispersal of feature importance: 0.18
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 210969
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 206456
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 206519
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.23
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 211817
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.02
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 207702
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.12
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 210344
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.44
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205256
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 212776
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.14
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 211564
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 209790
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 211360
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 207873
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.58
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 204847
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.01
# Bucket 2
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 210755_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205182_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.68
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 207674_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 209559_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.58
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 210599_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.7
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205247_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.59
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 213705_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.73
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 206528_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.74
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 204915_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205238_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.03
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 204841_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.63
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 212091_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 208679_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.62
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 206546_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.11
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 205409_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.68
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 210587_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.68
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 206910_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.03
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 212043_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.58
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 211134_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.68
# Dispersal of feature importance: 0.02
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205229_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 204742_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.02
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206811_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.65
# Dispersal of feature importance: 0.09
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 207278_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.61
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 211850_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 212455_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.6
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 209302_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.63
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 207780_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.63
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 211164_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.78
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 208754_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.63
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205779_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.6
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 205256_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.71
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 211859_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.63
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 204466_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.02
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 212608_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.62
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 204544_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.62
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205143_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.7
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 205514_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.65
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 212776_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 212184_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.71
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 206150_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.01
# Bucket 3
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 207735_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.6
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205797_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.61
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 206706_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.77
# Dispersal of feature importance: 0.2
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 207593_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.55
# Dispersal of feature importance: 0.02
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206561_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.61
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 214061_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.73
# Dispersal of feature importance: 0.02
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 207969_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 208550_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 207467_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 207380_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.65
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206279_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 211850_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.71
# Dispersal of feature importance: 0.02
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 209206_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 210722_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 212851_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.61
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 207128_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.73
# Dispersal of feature importance: 0.02
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 207275_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.04
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 213417_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.19
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 206733_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.7
# Dispersal of feature importance: 0.04
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 206444_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.14
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 212109_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.73
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 207611_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.63
# Dispersal of feature importance: 0.03
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 212383_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.73
# Dispersal of feature importance: 0.04
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 207825_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.75
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 211763_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.82
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 207026_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.57
# Dispersal of feature importance: 0.03
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 206047_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.02
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 205005_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.65
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 210119_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.74
# Dispersal of feature importance: 0.02
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 212803_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 207116_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.71
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205388_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.7
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 212698_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.7
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 208403_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.74
# Dispersal of feature importance: 0.08
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206255_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.8
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 209910_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.75
# Dispersal of feature importance: 0.1
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 209401_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.82
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 212346_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.59
# Dispersal of feature importance: 0.02
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 211399_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.73
# Dispersal of feature importance: 0.04
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 206423_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.01
# Bucket 4
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206315_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.12
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206417_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.24
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 209799_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.26
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205843_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.18
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 204993_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.18
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 206201_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.35
# Dispersal of feature importance: 0.22
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 206219_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.2
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 213954_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.11
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 211155_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.35
# Dispersal of feature importance: 0.09
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 206862_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.07
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 210206_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.16
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206420_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.42
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 208229_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.16
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205262_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.51
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 207275_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.11
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 209592_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.25
# Dispersal of feature importance: 0.07
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 212289_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 2.42
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 209260_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.14
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 210830_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.23
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 206114_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.16
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206901_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.23
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 208967_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 7.13
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 213234_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 1.14
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205316_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.13
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 213720_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.13
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 207843_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.42
# Dispersal of feature importance: 0.66
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 209120_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.39
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 208754_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.2
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 211847_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.35
# Dispersal of feature importance: 0.18
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 210119_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.23
# Dispersal of feature importance: 0.23
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 204999_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 0.83
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 214361_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.4
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 209859_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.22
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205349_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.09
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 207266_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.14
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205388_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.18
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 209269_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.22
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 210344_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.07
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 209057_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.13
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 204838_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.41
# Dispersal of feature importance: 0.12
# Bucket 5
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 211721_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.4
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 211928_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.12
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 212983_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.05
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 213792_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.1
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 209910_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.2
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 211338_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.38
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 206934_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.12
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 211059_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.13
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 209009_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.4
# Dispersal of feature importance: 0.07
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 208241_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.18
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 211035_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.08
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 213513_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.39
# Dispersal of feature importance: 0.18
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 206519_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.07
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 212196_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.11
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 205385_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.16
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205978_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.28
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 208118_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.4
# Dispersal of feature importance: 0.17
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 208067_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.07
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 206910_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.31
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205882_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.11
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 207275_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.62
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205532_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.06
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 208229_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.4
# Dispersal of feature importance: 0.42
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 204766_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.36
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 208124_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.4
# Dispersal of feature importance: 0.07
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 206660_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.13
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 208172_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.08
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 207780_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.39
# Dispersal of feature importance: 0.12
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 210987_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.13
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 209323_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.16
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 204685_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.07
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206366_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.11
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 213159_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.5
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 206342_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.09
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206180_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.34
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205400_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.12
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 205143_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.23
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 210416_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.04
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 207870_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.35
# Dispersal of feature importance: 0.11
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205960_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 1.21
# Bucket 6
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 211564_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.25
# Dispersal of feature importance: 0.27
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 209781_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.2
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 212346_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.06
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 208961_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.19
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206880_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.09
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 208397_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.53
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 209078_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.21
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 206709_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.17
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 212845_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.19
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 211907_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 1.44
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206047_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.19
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 204607_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.11
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 204691_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.24
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 213234_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.07
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 214277_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.19
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 207605_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 1.44
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 207047_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.2
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 204742_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.12
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 209260_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.05
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 212692_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.14
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206270_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.17
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206471_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.13
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 207392_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 0.63
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 210248_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.18
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206489_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.12
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 212455_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.09
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 213609_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.18
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 205837_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 0.09
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 204583_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.25
# Dispersal of feature importance: 0.56
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 208601_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.07
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206384_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.04
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 211122_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.06
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 207708_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.1
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 207212_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 0.11
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 209090_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.07
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205885_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.11
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 205517_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.12
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 206099_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.1
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 210572_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 0.1
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 212175_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.27
# Bucket 7
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 209278_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.06
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205724_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.2
# Dispersal of feature importance: 0.15
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 213726_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.23
# Dispersal of feature importance: 0.09
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205568_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.05
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 205757_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.06
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 206934_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.21
# Dispersal of feature importance: 0.24
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 206952_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.08
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 212983_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.23
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 207539_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.2
# Dispersal of feature importance: 0.19
# ...
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205912_38
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 206222_38
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 204712_38
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.07
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 208310_38
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 214025_38
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Bucket 39
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206180_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206567_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 210866_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.03
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205459_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206147_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 206372_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 207792_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 207966_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 212524_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205349_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206615_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.02
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 204592_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 205532_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.06
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 206898_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 211074_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.02
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205782_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 209000_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.03
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 204691_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 206456_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 206285_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 1 of 8 .
# Generating local Explanations for 205170_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 2 of 8 .
# Generating local Explanations for 206928_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 3 of 8 .
# Generating local Explanations for 205535_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 4 of 8 .
# Generating local Explanations for 205661_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 5 of 8 .
# Generating local Explanations for 213432_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.1
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 6 of 8 .
# Generating local Explanations for 204859_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 8 .
# Generating local Explanations for 207026_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 8 of 8 .
# Generating local Explanations for 208103_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 208844_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205340_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 205601_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 208025_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.05
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 205912_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 208310_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 205984_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 207254_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 204586_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 207795_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.01
# Bucket 40
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206357_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 204730_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 208055_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 207359_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.02
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 205849_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.02
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 207831_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 205340_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.07
# Dispersal of feature importance: 0.24
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 206333_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.03
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 208136_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205062_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206564_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 210704_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 206071_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 210689_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 205364_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 209592_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 207026_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 208730_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 205167_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 212043_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 1 of 9 .
# Generating local Explanations for 205553_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 2 of 9 .
# Generating local Explanations for 211847_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 3 of 9 .
# Generating local Explanations for 208997_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 4 of 9 .
# Generating local Explanations for 213432_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 5 of 9 .
# Generating local Explanations for 206615_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 6 of 9 .
# Generating local Explanations for 204859_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 7 of 9 .
# Generating local Explanations for 205661_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 8 of 9 .
# Generating local Explanations for 209084_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 9 of 9 .
# Generating local Explanations for 208103_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206856_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206222_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 210629_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 211883_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206249_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 206567_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 210890_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 206441_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 208064_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.08
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 206838_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
