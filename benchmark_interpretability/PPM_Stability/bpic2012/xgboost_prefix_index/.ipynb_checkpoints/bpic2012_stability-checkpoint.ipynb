# %%
#from google.colab import drive
#drive.mount('/content/drive')
import sys
#PATH = '/content/drive/My Drive/PPM_Stability/'
PATH = "C:/Users/velmurug/Documents/Stability Experiments/benchmark_interpretability/PPM_Stability/"
sys.path.append(PATH)

# %%
#!pip install lime
#!pip install shap
#!pip install pandas==0.19.2
# !pip install xgboost==1.0.0
# Out:
# Requirement already satisfied: xgboost==1.0.0 in c:\programdata\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost==1.0.0) (1.4.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost==1.0.0) (1.18.5)

# %%
import EncoderFactory
from DatasetManager import DatasetManager
import BucketFactory
import stability as st #Nogueira, Sechidis, Brown.

import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import StandardScaler

import time
import os
import sys
from sys import argv
import pickle
from collections import defaultdict
import random
import joblib

from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import lime
import lime.lime_tabular
from lime import submodular_pick;

import shap

import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

def imp_df(column_names, importances):
        df = pd.DataFrame({'feature': column_names,
                       'feature_importance': importances}) \
           .sort_values('feature_importance', ascending = False) \
           .reset_index(drop = True)
        return df

# plotting a feature importance dataframe (horizontal barchart)
def var_imp_plot(imp_df, title, num_feat):
        imp_df.columns = ['feature', 'feature_importance']
        b= sns.barplot(x = 'feature_importance', y = 'feature', data = imp_df.head(num_feat), orient = 'h', palette="Blues_r")

# %%
def generate_global_explanations(train_X,train_Y, cls, feature_combiner):
    
    print("The number of testing instances is ",len(train_Y))
    print("The total number of columns is",train_X.shape[1]);
    print("The total accuracy is ",cls.score(train_X,train_Y));
       
    sns.set(rc={'figure.figsize':(10,10), "font.size":18,"axes.titlesize":18,"axes.labelsize":18})
    sns.set
    feat_names = feature_combiner.get_feature_names()
    base_imp = imp_df(feat_names, cls.feature_importances_)
    base_imp.head(15)
    var_imp_plot(base_imp, 'Feature importance using XGBoost', 15)
    return base_imp

# %%
from lime import submodular_pick
def generate_lime_explanations(explainer,test_xi, cls,test_y, submod=False, test_all_data=None, max_feat = 10):
    
    #print("Actual value ", test_y)
    exp = explainer.explain_instance(test_xi, 
                                 cls.predict_proba, num_features=max_feat, labels=[0,1])
    
    return exp
        
    if submod==True:
        sp_obj=submodular_pick.SubmodularPick(explainer, test_all_data, cls.predict_proba, 
                                      sample_size=20, num_features=num_features,num_exps_desired=4)
        [exp.as_pyplot_figure(label=exp.available_labels()[0]) for exp in sp_obj.sp_explanations];

# %%
def create_samples(shap_explainer, iterations, row, features, top = 10):
    length = len(features)
    
    exp = []
    rel_exp = []
    
    for j in range(iterations):
        
        #if shap_type == "kernel":
        #    shap_explainer = shap.KernelExplainer(cls.predict, trainingsample)
        #elif shap_type == "tree":
        #    shap_explainer = shap.TreeExplainer(cls)
        #elif shap_type == "deep":
        #    shap_explainer = shap.DeepExplainer(cls, background)
        
        #print(X_test_frame.loc[row])
        shap_values = shap_explainer.shap_values(row)
        #print(shap_values)

        importances = []
        
        if type(shap_explainer) == shap.explainers.kernel.KernelExplainer:
            for i in range(length):
                feat = features[i]
                shap_val = shap_values[0][i]
                abs_val = abs(shap_values[0][i])
                entry = (feat, shap_val, abs_val)
                importances.append(entry)
                
        elif type(shap_explainer) == shap.explainers.tree.TreeExplainer:
            for i in range(length):
                feat = features[i]
                shap_val = shap_values[0][i]
                abs_val = abs(shap_values[0][i])
                entry = (feat, shap_val, abs_val)
                importances.append(entry)
        
        elif type(shap_explainer) == shap.explainers.deep.DeepExplainer:
            for i in range(length):
                feat = features[i]
                shap_val = shap_values[0][0][i]
                abs_val = abs(shap_values[0][0][i])
                entry = (feat, shap_val, abs_val)
                importances.append(entry)
        
        importances.sort(key=lambda tup: tup[2], reverse = True)
        
        exp.append(importances)

        rel_feat = []

        for i in range(top):
            feat = importances[i]
            if feat[2] > 0:
                rel_feat.append(feat)
                
        rel_exp.append(rel_feat)
        
    return exp, rel_exp

# %%
def dispersal(weights, features):
    feat_len = len(features)
    #print(feat_len)
    weights_by_feat = []
       
    for i in list(range(feat_len)):
        feat_weight = []
        for iteration in weights:
            feat_weight.append(iteration[i])
        weights_by_feat.append(feat_weight)
        
    #for iteration in weights:
     #   for val in iteration:
      #      idx = iteration.index(val)
       #     print(idx)
        #    weights_by_feat[idx].append(val)
    
    dispersal = []
    
    for each in weights_by_feat:
        if np.mean(each) == 0:
            dispersal.append(0)
        #print(each)
        else:
            var = (np.std(each))**2/abs(np.mean(each))
            dispersal.append(var)
    
    return dispersal

# %%
dataset_ref = "bpic2012"
params_dir = PATH + "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "index"
cls_method = "xgboost"

gap = 1
n_iter = 1

method_name = "%s_%s"%(bucket_method, cls_encoding)

generate_samples = True
generate_lime = True
generate_kernel_shap = False
generate_model_shap = True

sample_size = 2
exp_iter = 10
max_feat = 10

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"]
    #"insurance": ["insurance_activity", "insurance_followup"],
    #"sepsis_cases": ["sepsis_cases_1", "sepsis_cases_2", "sepsis_cases_4"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]

datasets
# Out:
# ['bpic2012_accepted']

# %%
if generate_samples:

    for dataset_name in datasets:
        
        dataset_manager = DatasetManager(dataset_name)
        
        for ii in range(n_iter):
            num_buckets = range(len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))]))
            
            for bucket in list(num_buckets):
                bucketID = bucket+1
                print ('Bucket', bucketID)

                #import everything needed to sort and predict
                pipeline_path = os.path.join(PATH, "%s/%s_%s/pipelines/pipeline_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                bucketer_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/bucketer_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))

                predictor = joblib.load(pipeline_path)
                cls = joblib.load(cls_path)
                feature_combiner = joblib.load(feat_comb_path)
                bucketer = joblib.load(bucketer_path)

                #import data for bucket
                X_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                Y_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                X_test_path = os.path.join(PATH, "%s/%s_%s/test_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                Y_test_path = os.path.join(PATH, "%s/%s_%s/test_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucketID))

                with open (X_train_path, 'rb') as f:
                    dt_train_bucket = pickle.load(f)
                with open (Y_train_path, 'rb') as f:
                    train_y = pickle.load(f)
                with open (X_test_path, 'rb') as f:
                    dt_test_bucket = pickle.load(f)
                with open (Y_test_path, 'rb') as f:
                    test_y = pickle.load(f)

                #import previous results from predictions
                tn_path = os.path.join(PATH, "%s/%s_%s/instances/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                tp_path = os.path.join(PATH, "%s/%s_%s/instances/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fn_path = os.path.join(PATH, "%s/%s_%s/instances/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fp_path = os.path.join(PATH, "%s/%s_%s/instances/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

                instances = []

                with open (tn_path, 'rb') as f:
                    tn_list = pickle.load(f)
                with open (tp_path, 'rb') as f:
                    tp_list = pickle.load(f)
                with open (fn_path, 'rb') as f:
                    fn_list = pickle.load(f)
                with open (fp_path, 'rb') as f:
                    fp_list = pickle.load(f)

                #save results to a list
                instances.append(tn_list)
                instances.append(tp_list)
                instances.append(fn_list)
                instances.append(fp_list)

                #choose instances from the event log to explain, based on different prefix lengths
                sample_instances = []
                
                for each in instances:
                    sample = []
                    #Find instances of different prediction probabilities
                    prs = [0.5, 0.6, 0.7, 0.8, 0.9, 1.1]
                    for i in list(range(len(prs)-1)):
                        low = prs[i]
                        high = prs[i+1]
                        ins = [d for d in each if (d['proba'] >= low) & (d['proba'] < high)]
                        if len(ins) >= sample_size:
                            sample.extend(random.sample(ins, k=sample_size))
                        else:
                            sample.extend(ins)
                    sample = sorted(sample, key = lambda i: (i['proba'], i['nr_events']))
                    sample_instances.append(sample)

                tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

                with open(tn_path, 'wb') as f:
                    pickle.dump(sample_instances[0], f)
                with open(tp_path, 'wb') as f:
                    pickle.dump(sample_instances[1], f)
                with open(fn_path, 'wb') as f:
                    pickle.dump(sample_instances[2], f)
                with open(fp_path, 'wb') as f:
                    pickle.dump(sample_instances[3], f)
# Out:
# Bucket 1
# Bucket 2
# Bucket 3
# Bucket 4
# Bucket 5
# Bucket 6
# Bucket 7
# Bucket 8
# Bucket 9
# Bucket 10
# Bucket 11
# Bucket 12
# Bucket 13
# Bucket 14
# Bucket 15
# Bucket 16
# Bucket 17
# Bucket 18
# Bucket 19
# Bucket 20
# Bucket 21
# Bucket 22
# Bucket 23
# Bucket 24
# Bucket 25
# Bucket 26
# Bucket 27
# Bucket 28
# Bucket 29
# Bucket 30
# Bucket 31
# Bucket 32
# Bucket 33
# Bucket 34
# Bucket 35
# Bucket 36
# Bucket 37
# Bucket 38
# Bucket 39
# Bucket 40

# %%
if generate_model_shap:

    for dataset_name in datasets:
        
        dataset_manager = DatasetManager(dataset_name)
        
        for ii in range(n_iter):
            num_buckets = range(len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))]))
            
            for bucket in list(num_buckets):
                bucketID = bucket+1
                print ('Bucket', bucketID, 'of', num_buckets)

                #import everything needed to sort and predict
                feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                cls = joblib.load(cls_path)
                feature_combiner = joblib.load(feat_comb_path)
                
                #import data for bucket
                #X_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                #Y_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                
                #with open (X_train_path, 'rb') as f:
                #    dt_train_bucket = pickle.load(f)
                #with open (Y_train_path, 'rb') as f:
                #    train_y = pickle.load(f)
                #with open (X_test_path, 'rb') as f:
                #    dt_test_bucket = pickle.load(f)
                #with open (Y_test_path, 'rb') as f:
                #    test_y = pickle.load(f)

                #import previously identified samples
                tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

                sample_instances = []

                with open (tn_path, 'rb') as f:
                    tn_list = pickle.load(f)
                with open (tp_path, 'rb') as f:
                    tp_list = pickle.load(f)
                with open (fn_path, 'rb') as f:
                    fn_list = pickle.load(f)
                with open (fp_path, 'rb') as f:
                    fp_list = pickle.load(f)

                #save results to a list
                sample_instances.append(tn_list)
                sample_instances.append(tp_list)
                sample_instances.append(fn_list)
                sample_instances.append(fp_list)

                #create explainers now that can be passed later
                tree_explainer = shap.TreeExplainer(cls)

                #explain the chosen instances and find the stability score
                cat_no = 0
                for category in sample_instances:
                    cat_no += 1
                    instance_no = 0
                    
                    for instance in category:
                        instance_no += 1    
                        print("Category", cat_no, "of", len(sample_instances), ". Testing", instance_no, "of", len(category), ".")
                
                        group = instance['input']

                        print(group.shape,instance['actual'], instance['predicted'])
                        test_x_group= feature_combiner.fit_transform(group) 
                        test_x=np.transpose(test_x_group[0])

                        print('Generating local Explanations for', instance['caseID'])

                        feat_list = feature_combiner.get_feature_names()

                        #Get Tree SHAP explanations for instance
                        exp, rel_exp = create_samples(tree_explainer, exp_iter, test_x.reshape(-1, len(test_x)), feat_list, top = max_feat)

                        feat_pres = []
                        feat_weights = []

                        for iteration in rel_exp:
                            print("Tree SHAP Iteration", rel_exp.index(iteration))
                            #print(iteration)

                            #Stability by index
                            presence_list = [0]*len(feat_list)
                            #stability by weight
                            weights = [0]*len(feat_list)

                            for each in feat_list:
                                list_idx = feat_list.index(each)
                                #print ("Feature", list_idx)
                                for explanation in iteration:
                                    if each in explanation[0]:
                                        presence_list[list_idx] = 1
                                        weights[list_idx] = explanation[1]

                            feat_pres.append(presence_list)
                            feat_weights.append(weights)

                        stability = st.getStability(feat_pres)
                        print ("Stability:", round(stability,2))
                        instance['tree_shap_stability'] = stability
                        
                        norm_var = dispersal(feat_weights, feat_list)
                        avg_dispersal = np.mean(norm_var)
                        print ("Dispersal of feature importance:", round(avg_dispersal, 2))
                        instance['shap_weights_dispersal'] = norm_var
                        instance['shap_importance_stability'] = avg_dispersal

                with open(tn_path, 'wb') as f:
                    pickle.dump(sample_instances[0], f)
                with open(tp_path, 'wb') as f:
                    pickle.dump(sample_instances[1], f)
                with open(fn_path, 'wb') as f:
                    pickle.dump(sample_instances[2], f)
                with open(fp_path, 'wb') as f:
                    pickle.dump(sample_instances[3], f)
# Out:
# Bucket 1 of 1
# Category 1 of 4 . Testing 1 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 208430
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 2 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 206372
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 3 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 213705
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 4 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 204613
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 5 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 207717
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 6 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 207041
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 209087
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 8 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 207593
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 9 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 205340
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 10 of 10 .
# (1, 18) 0 0
# Generating local Explanations for 210866
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 1 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 211281
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 2 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 213417
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 3 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 214139
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 4 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 205220
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 5 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 213201
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 6 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 210206
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 7 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 212398
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 8 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 205837
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 9 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 211254
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 10 of 10 .
# (1, 18) 1 1
# Generating local Explanations for 204523
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 1 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 212929
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 2 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 213465
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 3 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 204742
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 4 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 207281
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 5 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 209721
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 6 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 205080
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 210914
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 8 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 207482
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 9 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 209206
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 10 of 10 .
# (1, 18) 1 0
# Generating local Explanations for 210134
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 1 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 205921
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 2 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 213792
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 3 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 212773
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 4 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 212235
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 5 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 205757
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 6 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 206105
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 210494
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 207503
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 9 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 207969
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 10 of 10 .
# (1, 18) 0 1
# Generating local Explanations for 205370
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Bucket 2 of 1
# Category 1 of 4 . Testing 1 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 207792_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 2 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 205182_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 3 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 206567_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 4 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 210563_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 5 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 210857_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 6 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 213726_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 205601_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 8 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 205379_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 9 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 211086_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 10 of 10 .
# (2, 18) 0 0
# Generating local Explanations for 212563_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 1 of 10 .
# (2, 18) 1 1
# Generating local Explanations for 213091_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 2 of 10 .
# (2, 18) 1 1
# Generating local Explanations for 210833_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 3 of 10 .
# (2, 18) 1 1
# Generating local Explanations for 206300_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 4 of 10 .
# (2, 18) 1 1
# Generating local Explanations for 207020_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 5 of 10 .
# (2, 18) 1 1
# Generating local Explanations for 208832_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 6 of 10 .
# (2, 18) 1 1
# Generating local Explanations for 212626_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 7 of 10 .
# (2, 18) 1 1
# Generating local Explanations for 213825_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 8 of 10 .
# (2, 18) 1 1
# Generating local Explanations for 212632_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 9 of 10 .
# (2, 18) 1 1
# Generating local Explanations for 208601_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 10 of 10 .
# (2, 18) 1 1
# Generating local Explanations for 210197_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 1 of 10 .
# (2, 18) 1 0
# Generating local Explanations for 209742_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 2 of 10 .
# (2, 18) 1 0
# Generating local Explanations for 206811_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 3 of 10 .
# (2, 18) 1 0
# Generating local Explanations for 206408_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 4 of 10 .
# (2, 18) 1 0
# Generating local Explanations for 209257_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 5 of 10 .
# (2, 18) 1 0
# Generating local Explanations for 211113_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 6 of 10 .
# (2, 18) 1 0
# Generating local Explanations for 209721_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 10 .
# (2, 18) 1 0
# Generating local Explanations for 209646_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 8 of 10 .
# (2, 18) 1 0
# Generating local Explanations for 212803_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 9 of 10 .
# (2, 18) 1 0
# Generating local Explanations for 206053_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 10 of 10 .
# (2, 18) 1 0
# Generating local Explanations for 214052_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 1 of 10 .
# (2, 18) 0 1
# Generating local Explanations for 205256_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 2 of 10 .
# (2, 18) 0 1
# Generating local Explanations for 206606_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 3 of 10 .
# (2, 18) 0 1
# Generating local Explanations for 209404_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 4 of 10 .
# (2, 18) 0 1
# Generating local Explanations for 211360_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 5 of 10 .
# (2, 18) 0 1
# Generating local Explanations for 208418_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 6 of 10 .
# (2, 18) 0 1
# Generating local Explanations for 204514_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# (2, 18) 0 1
# Generating local Explanations for 207864_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# (2, 18) 0 1
# Generating local Explanations for 209401_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 9 of 10 .
# (2, 18) 0 1
# Generating local Explanations for 206105_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 10 of 10 .
# (2, 18) 0 1
# Generating local Explanations for 212413_2
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Bucket 3 of 1
# Category 1 of 4 . Testing 1 of 10 .
# (3, 18) 0 0
# Generating local Explanations for 209661_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 2 of 10 .
# (3, 18) 0 0
# Generating local Explanations for 206141_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 3 of 10 .
# (3, 18) 0 0
# Generating local Explanations for 204679_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 4 of 10 .
# (3, 18) 0 0
# Generating local Explanations for 206706_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 5 of 10 .
# (3, 18) 0 0
# Generating local Explanations for 210182_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 6 of 10 .
# (3, 18) 0 0
# Generating local Explanations for 208949_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# (3, 18) 0 0
# Generating local Explanations for 210266_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 8 of 10 .
# (3, 18) 0 0
# Generating local Explanations for 205754_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 9 of 10 .
# (3, 18) 0 0
# Generating local Explanations for 206528_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 10 of 10 .
# (3, 18) 0 0
# Generating local Explanations for 208667_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 1 of 10 .
# (3, 18) 1 1
# Generating local Explanations for 204963_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 2 of 10 .
# (3, 18) 1 1
# Generating local Explanations for 211224_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 3 of 10 .
# (3, 18) 1 1
# Generating local Explanations for 213930_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 4 of 10 .
# (3, 18) 1 1
# Generating local Explanations for 209434_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 5 of 10 .
# (3, 18) 1 1
# Generating local Explanations for 210969_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 6 of 10 .
# (3, 18) 1 1
# Generating local Explanations for 212274_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 7 of 10 .
# (3, 18) 1 1
# Generating local Explanations for 208457_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 8 of 10 .
# (3, 18) 1 1
# Generating local Explanations for 206645_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 9 of 10 .
# (3, 18) 1 1
# Generating local Explanations for 206910_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 10 of 10 .
# (3, 18) 1 1
# Generating local Explanations for 212764_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 1 of 10 .
# (3, 18) 1 0
# Generating local Explanations for 213010_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 2 of 10 .
# (3, 18) 1 0
# Generating local Explanations for 208793_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 3 of 10 .
# (3, 18) 1 0
# Generating local Explanations for 211113_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 4 of 10 .
# (3, 18) 1 0
# Generating local Explanations for 213600_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 5 of 10 .
# (3, 18) 1 0
# Generating local Explanations for 212103_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 6 of 10 .
# (3, 18) 1 0
# Generating local Explanations for 211763_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 10 .
# (3, 18) 1 0
# Generating local Explanations for 206660_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 8 of 10 .
# (3, 18) 1 0
# Generating local Explanations for 207215_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 9 of 10 .
# (3, 18) 1 0
# Generating local Explanations for 207614_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 10 of 10 .
# (3, 18) 1 0
# Generating local Explanations for 213609_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 1 of 10 .
# (3, 18) 0 1
# Generating local Explanations for 207768_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 2 of 10 .
# (3, 18) 0 1
# Generating local Explanations for 211227_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 3 of 10 .
# (3, 18) 0 1
# Generating local Explanations for 205803_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 4 of 10 .
# (3, 18) 0 1
# Generating local Explanations for 210890_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 5 of 10 .
# (3, 18) 0 1
# Generating local Explanations for 206745_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 6 of 10 .
# (3, 18) 0 1
# Generating local Explanations for 209910_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# (3, 18) 0 1
# Generating local Explanations for 205349_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# (3, 18) 0 1
# Generating local Explanations for 204838_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 9 of 10 .
# (3, 18) 0 1
# Generating local Explanations for 207831_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 10 of 10 .
# (3, 18) 0 1
# Generating local Explanations for 213900_3
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Bucket 4 of 1
# Category 1 of 4 . Testing 1 of 10 .
# (4, 18) 0 0
# Generating local Explanations for 205205_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 2 of 10 .
# (4, 18) 0 0
# Generating local Explanations for 207242_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 3 of 10 .
# (4, 18) 0 0
# Generating local Explanations for 205727_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 4 of 10 .
# (4, 18) 0 0
# Generating local Explanations for 206336_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 5 of 10 .
# (4, 18) 0 0
# Generating local Explanations for 205791_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 6 of 10 .
# (4, 18) 0 0
# Generating local Explanations for 211907_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# (4, 18) 0 0
# Generating local Explanations for 205649_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 8 of 10 .
# (4, 18) 0 0
# Generating local Explanations for 213954_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 9 of 10 .
# (4, 18) 0 0
# Generating local Explanations for 207726_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 10 of 10 .
# (4, 18) 0 0
# Generating local Explanations for 208025_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 1 of 10 .
# (4, 18) 1 1
# Generating local Explanations for 211549_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 2 of 10 .
# (4, 18) 1 1
# Generating local Explanations for 205313_4
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 3 of 10 .
# (4, 18) 1 1
# Generating local Explanations for 204670_4
# ...
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# (39, 18) 0 1
# Generating local Explanations for 204730_39
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# (39, 18) 0 1
# Generating local Explanations for 205583_39
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 9 of 10 .
# (39, 18) 0 1
# Generating local Explanations for 206441_39
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 10 of 10 .
# (39, 18) 0 1
# Generating local Explanations for 206132_39
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Bucket 40 of 1
# Category 1 of 4 . Testing 1 of 10 .
# (40, 18) 0 0
# Generating local Explanations for 206952_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 2 of 10 .
# (40, 18) 0 0
# Generating local Explanations for 204730_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 3 of 10 .
# (40, 18) 0 0
# Generating local Explanations for 208055_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 4 of 10 .
# (40, 18) 0 0
# Generating local Explanations for 207359_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 5 of 10 .
# (40, 18) 0 0
# Generating local Explanations for 204915_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 6 of 10 .
# (40, 18) 0 0
# Generating local Explanations for 205797_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# (40, 18) 0 0
# Generating local Explanations for 205794_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 8 of 10 .
# (40, 18) 0 0
# Generating local Explanations for 206606_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 9 of 10 .
# (40, 18) 0 0
# Generating local Explanations for 206147_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 10 of 10 .
# (40, 18) 0 0
# Generating local Explanations for 205062_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 1 of 10 .
# (40, 18) 1 1
# Generating local Explanations for 206564_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 2 of 10 .
# (40, 18) 1 1
# Generating local Explanations for 208619_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 3 of 10 .
# (40, 18) 1 1
# Generating local Explanations for 206071_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 4 of 10 .
# (40, 18) 1 1
# Generating local Explanations for 208898_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 5 of 10 .
# (40, 18) 1 1
# Generating local Explanations for 204718_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 6 of 10 .
# (40, 18) 1 1
# Generating local Explanations for 209532_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 7 of 10 .
# (40, 18) 1 1
# Generating local Explanations for 209913_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 8 of 10 .
# (40, 18) 1 1
# Generating local Explanations for 209105_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 9 of 10 .
# (40, 18) 1 1
# Generating local Explanations for 206543_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 10 of 10 .
# (40, 18) 1 1
# Generating local Explanations for 213010_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 1 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 205553_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 2 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 211847_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 3 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 208139_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 4 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 213432_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 5 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 206615_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 6 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 204859_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 205661_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 8 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 209084_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 9 of 9 .
# (40, 18) 1 0
# Generating local Explanations for 208103_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 1 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 206856_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 2 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 206222_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 3 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 205029_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 4 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 205864_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 5 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 206249_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 6 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 205846_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 208514_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 204586_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 9 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 205583_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 10 of 10 .
# (40, 18) 0 1
# Generating local Explanations for 205310_40
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Tree SHAP Iteration 0
# Stability: 1.0
# Dispersal of feature importance: 0.0

# %%
if generate_lime:

    for dataset_name in datasets:
        
        dataset_manager = DatasetManager(dataset_name)
        
        for ii in range(n_iter):
            num_buckets = range(len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))]))
            
            for bucket in list(num_buckets):
                bucketID = bucket+1
                print ('Bucket', bucketID, 'of', num_buckets)
                
                #import everything needed to sort and predict
                feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
                cls = joblib.load(cls_path)
                feature_combiner = joblib.load(feat_comb_path)
                
                #import data for bucket
                X_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                Y_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                
                with open (X_train_path, 'rb') as f:
                    dt_train_bucket = pickle.load(f)
                with open (Y_train_path, 'rb') as f:
                    train_y = pickle.load(f)
                #with open (X_test_path, 'rb') as f:
                #    dt_test_bucket = pickle.load(f)
                #with open (Y_test_path, 'rb') as f:
                #    test_y = pickle.load(f)

                #import previously identified samples
                tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
                fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

                sample_instances = []

                with open (tn_path, 'rb') as f:
                    tn_list = pickle.load(f)
                with open (tp_path, 'rb') as f:
                    tp_list = pickle.load(f)
                with open (fn_path, 'rb') as f:
                    fn_list = pickle.load(f)
                with open (fp_path, 'rb') as f:
                    fp_list = pickle.load(f)

                #save results to a list
                sample_instances.append(tn_list)
                sample_instances.append(tp_list)
                sample_instances.append(fn_list)
                sample_instances.append(fp_list)

                #get the training data as a matrix
                trainingdata = feature_combiner.fit_transform(dt_train_bucket);
                #importance = generate_global_explanations(trainingdata,train_y, cls, feature_combiner)

                #explain the chosen instances and find the stability score
                cat_no = 0
                for category in sample_instances:
                    cat_no += 1
                    instance_no = 0
                    for instance in category:
                        instance_no += 1
                        
                        print("Category", cat_no, "of", len(sample_instances), ". Testing", instance_no, "of", len(category), ".")
                        
                        group = instance['input']
                        
                        #create explainer now that can be passed later
                        class_names=['regular','deviant']# regular is 0, deviant is 1, 0 is left, 1 is right
                        lime_explainer = lime.lime_tabular.LimeTabularExplainer(trainingdata,
                                          feature_names = feature_combiner.get_feature_names(),
                                          class_names=class_names, discretize_continuous=True)

                        #print(group.shape,instance['actual'], instance['predicted'])
                        test_x_group= feature_combiner.fit_transform(group) 
                        test_x=np.transpose(test_x_group[0])

                        print('Generating local Explanations for', instance['caseID'])

                        feat_list = feature_combiner.get_feature_names()

                        #Get lime explanations for instance
                        feat_pres = []
                        feat_weights = []

                        for iteration in list(range(exp_iter)):
                            print("Run", iteration)
                            
                            lime_exp = generate_lime_explanations(lime_explainer, test_x, cls, instance['actual'], max_feat = max_feat)

                            presence_list = [0]*len(feat_list)
                            weights = [0]*len(feat_list)

                            for each in feat_list:
                                list_idx = feat_list.index(each)
                                #print ("Feature", list_idx)
                                for explanation in lime_exp.as_list():
                                    if each in explanation[0]:
                                        #if lime_exp.as_list().index(explanation) < max_feat:
                                            presence_list[list_idx] = 1
                                            weights[list_idx] = explanation[1]

                            feat_pres.append(presence_list)
                            feat_weights.append(weights)

                        stability = st.getStability(feat_pres)
                        print ("Stability:", round(stability,2))
                        instance['lime_stability'] = stability
                        
                        norm_var = dispersal(feat_weights, feat_list)
                        avg_dispersal = np.mean(norm_var)
                        print ("Dispersal of feature importance:", round(avg_dispersal, 2))
                        instance['lime_weights_dispersal'] = norm_var
                        instance['lime_importance_stability'] = avg_dispersal
                        
                #Save dictionaries updated with stability scores
                with open(tn_path, 'wb') as f:
                    pickle.dump(sample_instances[0], f)
                with open(tp_path, 'wb') as f:
                    pickle.dump(sample_instances[1], f)
                with open(fn_path, 'wb') as f:
                    pickle.dump(sample_instances[2], f)
                with open(fp_path, 'wb') as f:
                    pickle.dump(sample_instances[3], f)
# Out:
# Bucket 1 of 1
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 208430
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206372
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.41
# Dispersal of feature importance: 0.02
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 213705
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 204613
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 207717
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 207041
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 209087
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.03
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 207593
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.44
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 205340
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 210866
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 211281
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 213417
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.02
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 214139
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205220
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 213201
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 210206
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 212398
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 205837
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.02
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 211254
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.14
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 204523
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 212929
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 213465
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 204742
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.61
# Dispersal of feature importance: 0.08
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 207281
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.44
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 209721
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205080
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.12
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 210914
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 207482
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.03
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 209206
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 210134
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 205921
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.41
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 213792
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.03
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 212773
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 212235
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 205757
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.44
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 206105
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.44
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 210494
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.19
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 207503
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.14
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 207969
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.14
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205370
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.44
# Dispersal of feature importance: 0.0
# Bucket 2 of 1
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 207792_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205182_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 206567_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 210563_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.63
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 210857_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 213726_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.61
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 205601_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.63
# Dispersal of feature importance: 0.73
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 205379_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 211086_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 212563_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 213091_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.63
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 210833_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 206300_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 207020_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 208832_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 212626_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 213825_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.65
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 212632_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.61
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 208601_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 210197_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 209742_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.68
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206811_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.72
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 206408_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.74
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 209257_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.6
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 211113_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.63
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 209721_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 209646_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 212803_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 206053_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.63
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 214052_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 205256_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.68
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206606_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 209404_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.68
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 211360_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.62
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 208418_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.68
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 204514_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 207864_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.68
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 209401_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 206105_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 212413_2
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.0
# Bucket 3 of 1
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 209661_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.03
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206141_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.7
# Dispersal of feature importance: 59.7
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 204679_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.78
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 206706_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.71
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 210182_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.74
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 208949_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.7
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 210266_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.75
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 205754_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.81
# Dispersal of feature importance: 0.06
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 206528_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.22
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 208667_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.69
# Dispersal of feature importance: 0.02
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 204963_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.75
# Dispersal of feature importance: 0.07
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 211224_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.72
# Dispersal of feature importance: 0.16
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 213930_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.7
# Dispersal of feature importance: 0.09
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 209434_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 210969_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.72
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 212274_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.72
# Dispersal of feature importance: 0.02
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 208457_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.55
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 206645_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.6
# Dispersal of feature importance: 0.07
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 206910_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.75
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 212764_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.7
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 213010_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.68
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 208793_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.68
# Dispersal of feature importance: 0.02
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 211113_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.73
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 213600_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.49
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 212103_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.46
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 211763_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.79
# Dispersal of feature importance: 0.02
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 206660_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 207215_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.02
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 207614_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.02
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 213609_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.46
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 207768_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.72
# Dispersal of feature importance: 0.14
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 211227_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.62
# Dispersal of feature importance: 0.31
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 205803_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.71
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 210890_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.74
# Dispersal of feature importance: 0.13
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206745_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.79
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 209910_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.67
# Dispersal of feature importance: 0.02
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 205349_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.64
# Dispersal of feature importance: 0.03
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 204838_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.72
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 207831_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.6
# Dispersal of feature importance: 0.02
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 213900_3
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.66
# Dispersal of feature importance: 0.01
# Bucket 4 of 1
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 205205_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.17
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 207242_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.18
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 205727_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.85
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 206336_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.25
# Dispersal of feature importance: 0.16
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 205791_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.13
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 211907_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.21
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 205649_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.76
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 213954_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.13
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 207726_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.15
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 208025_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.1
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 211549_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.07
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205313_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.08
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 204670_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 0.2
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205421_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.14
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206270_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.35
# Dispersal of feature importance: 0.16
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 213693_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.11
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 208532_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.15
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 213417_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.06
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 212764_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.28
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 206444_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 1.76
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 214220_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.56
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205532_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.39
# Dispersal of feature importance: 0.16
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 210467_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 0.17
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 206907_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.16
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206793_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.1
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 207843_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.58
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 214085_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.18
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 204885_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 2.88
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 209000_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.08
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 213423_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.14
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 210071_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.12
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 214361_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.23
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 204724_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.26
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 207735_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.12
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206099_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.58
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 206255_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.16
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 210966_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.22
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 206745_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.2
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 210719_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.15
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 209057_4
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.08
# Bucket 5 of 1
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 209138_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.64
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 207380_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.09
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 207077_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.12
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 206621_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.12
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 212118_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.39
# Dispersal of feature importance: 0.18
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 208002_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.14
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 204484_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.35
# Dispersal of feature importance: 0.17
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 211573_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.17
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 211176_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.39
# Dispersal of feature importance: 0.1
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 207542_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.1
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 210833_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.06
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 208169_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.79
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 208277_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.4
# Dispersal of feature importance: 0.22
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 209823_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.39
# Dispersal of feature importance: 0.07
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206108_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.12
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205409_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.53
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 206471_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.35
# Dispersal of feature importance: 0.28
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 211083_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.42
# Dispersal of feature importance: 0.18
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 209260_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.27
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 208655_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.11
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 207852_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.39
# Dispersal of feature importance: 0.26
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 211435_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.26
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 206480_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.4
# Dispersal of feature importance: 0.35
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 206453_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.1
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 212815_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.39
# Dispersal of feature importance: 0.21
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 212425_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.08
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 209577_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.35
# Dispersal of feature importance: 0.08
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 211269_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.19
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 209814_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.09
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 204595_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.42
# Dispersal of feature importance: 0.12
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 208403_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.31
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205182_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.37
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 209278_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.41
# Dispersal of feature importance: 0.1
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205514_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.09
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206255_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.09
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 206856_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.49
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 206642_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.33
# Dispersal of feature importance: 0.13
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 212175_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.38
# Dispersal of feature importance: 0.34
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 213900_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.34
# Dispersal of feature importance: 0.14
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 207768_5
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.35
# Dispersal of feature importance: 0.13
# Bucket 6 of 1
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 208592_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.08
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205465_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.17
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 208598_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.08
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 206294_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 0.08
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 208382_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.06
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205418_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.06
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 210725_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.35
# Dispersal of feature importance: 0.42
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 208049_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.56
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 211059_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.11
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 209341_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.1
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 207843_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.05
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 205322_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.13
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 206198_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.13
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 209287_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.12
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206958_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 0.13
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 212043_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.32
# Dispersal of feature importance: 0.13
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 211997_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.2
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 211402_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.44
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 214268_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.05
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 210008_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.13
# Category 3 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206270_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.16
# Category 3 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206546_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.08
# Category 3 of 4 . Testing 3 of 10 .
# Generating local Explanations for 208577_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.05
# Category 3 of 4 . Testing 4 of 10 .
# Generating local Explanations for 204766_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.29
# Dispersal of feature importance: 0.04
# Category 3 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206210_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.37
# Dispersal of feature importance: 0.08
# Category 3 of 4 . Testing 6 of 10 .
# Generating local Explanations for 207894_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 0.1
# Category 3 of 4 . Testing 7 of 10 .
# Generating local Explanations for 212593_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 11.13
# Category 3 of 4 . Testing 8 of 10 .
# Generating local Explanations for 209206_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.27
# Dispersal of feature importance: 1.55
# Category 3 of 4 . Testing 9 of 10 .
# Generating local Explanations for 212383_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.13
# Category 3 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205170_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.08
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 204484_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.12
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 210416_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.42
# Dispersal of feature importance: 0.19
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 212413_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.07
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 206642_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.09
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 208499_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.28
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 209371_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.1
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 205514_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.28
# Dispersal of feature importance: 0.25
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 208379_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.36
# Dispersal of feature importance: 0.08
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 210572_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.3
# Dispersal of feature importance: 0.06
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205256_6
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.31
# Dispersal of feature importance: 0.06
# Bucket 7 of 1
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 207334_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.23
# Dispersal of feature importance: 0.2
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206528_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.26
# Dispersal of feature importance: 0.08
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 207245_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.23
# Dispersal of feature importance: 0.05
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205568_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.21
# Dispersal of feature importance: 0.09
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 207266_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# Dispersal of feature importance: 0.04
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 208418_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.24
# Dispersal of feature importance: 0.11
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 205379_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.23
# Dispersal of feature importance: 0.08
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 204936_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.23
# Dispersal of feature importance: 0.05
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 208002_7
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.22
# ...
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 204730_38
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 208064_38
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 211360_38
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 211543_38
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 208667_38
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Bucket 39 of 1
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 210416_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206180_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 205029_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 207708_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 211158_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 206147_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 207245_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.07
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 207966_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 204915_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205349_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206615_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.07
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206351_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.08
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 208997_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 206898_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 205782_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 211098_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 207611_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 209751_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 214139_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 211555_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 1 of 8 .
# Generating local Explanations for 205170_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.08
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 2 of 8 .
# Generating local Explanations for 208577_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 3 of 8 .
# Generating local Explanations for 205535_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.08
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 4 of 8 .
# Generating local Explanations for 205661_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 5 of 8 .
# Generating local Explanations for 205553_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 6 of 8 .
# Generating local Explanations for 213432_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.09
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 7 of 8 .
# Generating local Explanations for 207026_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 8 of 8 .
# Generating local Explanations for 208103_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 208844_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 207116_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 206952_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205367_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.02
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 209652_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205912_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 204730_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 205583_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 206441_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.07
# Dispersal of feature importance: 0.02
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 206132_39
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Bucket 40 of 1
# Category 1 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206952_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.1
# Category 1 of 4 . Testing 2 of 10 .
# Generating local Explanations for 204730_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 3 of 10 .
# Generating local Explanations for 208055_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 4 of 10 .
# Generating local Explanations for 207359_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.06
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 5 of 10 .
# Generating local Explanations for 204915_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205797_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.0
# Category 1 of 4 . Testing 7 of 10 .
# Generating local Explanations for 205794_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 8 of 10 .
# Generating local Explanations for 206606_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 9 of 10 .
# Generating local Explanations for 206147_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.08
# Dispersal of feature importance: 0.01
# Category 1 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205062_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206564_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 2 of 10 .
# Generating local Explanations for 208619_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 3 of 10 .
# Generating local Explanations for 206071_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.07
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 4 of 10 .
# Generating local Explanations for 208898_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 5 of 10 .
# Generating local Explanations for 204718_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 6 of 10 .
# Generating local Explanations for 209532_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.03
# Dispersal of feature importance: 0.04
# Category 2 of 4 . Testing 7 of 10 .
# Generating local Explanations for 209913_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 2 of 4 . Testing 8 of 10 .
# Generating local Explanations for 209105_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 9 of 10 .
# Generating local Explanations for 206543_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 2 of 4 . Testing 10 of 10 .
# Generating local Explanations for 213010_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 1 of 9 .
# Generating local Explanations for 205553_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 2 of 9 .
# Generating local Explanations for 211847_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 3 of 9 .
# Generating local Explanations for 208139_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 4 of 9 .
# Generating local Explanations for 213432_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 5 of 9 .
# Generating local Explanations for 206615_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 3 of 4 . Testing 6 of 9 .
# Generating local Explanations for 204859_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 7 of 9 .
# Generating local Explanations for 205661_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 8 of 9 .
# Generating local Explanations for 209084_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 3 of 4 . Testing 9 of 9 .
# Generating local Explanations for 208103_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 1 of 10 .
# Generating local Explanations for 206856_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 2 of 10 .
# Generating local Explanations for 206222_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 3 of 10 .
# Generating local Explanations for 205029_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 4 of 10 .
# Generating local Explanations for 205864_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 5 of 10 .
# Generating local Explanations for 206249_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 6 of 10 .
# Generating local Explanations for 205846_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.05
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 7 of 10 .
# Generating local Explanations for 208514_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
# Category 4 of 4 . Testing 8 of 10 .
# Generating local Explanations for 204586_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.03
# Category 4 of 4 . Testing 9 of 10 .
# Generating local Explanations for 205583_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.0
# Category 4 of 4 . Testing 10 of 10 .
# Generating local Explanations for 205310_40
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Stability: 0.04
# Dispersal of feature importance: 0.01
