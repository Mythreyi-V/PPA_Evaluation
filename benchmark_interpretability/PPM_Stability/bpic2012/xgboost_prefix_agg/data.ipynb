# %%
#from google.colab import drive
#drive.mount('/content/drive')
import sys
#PATH = '/content/drive/My Drive/PPM_Stability/'
#PATH = "C:/Users/velmurug/Documents/Stability Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/Mythreyi/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/mythr/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
PATH = "C:/Users/n9455647/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
sys.path.append(PATH)

# %%
from DatasetManager import DatasetManager

import pandas as pd
import numpy as np

import os
import sys
from sys import argv
import pickle
import random
import joblib

import statistics
import math

import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

lime_pal = sns.diverging_palette(100, 200, s=150)#, as_cmap=True)
shap_pal = sns.diverging_palette(0, 240, s=150)#, as_cmap=True)

sns.set_style('darkgrid')

# %%
dataset_ref = "bpic2012"
params_dir = PATH + "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "agg"
cls_method = "xgboost"

gap = 1
n_iter = 1

method_name = "%s_%s"%(bucket_method, cls_encoding)

generate_samples = False
generate_lime = True
generate_kernel_shap = False
generate_model_shap = True

sample_size = 2
exp_iter = 10
max_feat = 10
max_prefix = 25

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"]
    #"insurance": ["insurance_activity", "insurance_followup"],
    #"sepsis_cases": ["sepsis_cases_1", "sepsis_cases_2", "sepsis_cases_4"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]

datasets
# Out:
# ['bpic2012_accepted']

# %%
for dataset_name in datasets:
    sep_timing_path = os.path.join(PATH, "%s/%s_%s/sep_timing.csv" % (dataset_ref, cls_method, method_name))
    all_timing_path = os.path.join(PATH, "%s/%s_%s/all_timing.csv" % (dataset_ref, cls_method, method_name))
    
    sep_data = pd.read_csv(sep_timing_path)
    all_data = pd.read_csv(all_timing_path)
    
    time_plot = sns.scatterplot(x = all_data['Prefix Length'], y = all_data['Running Time'], hue = all_data['Explainer'], size = all_data['Feature Vector Length'])
    plt.xlabel("Prefix Length")
    plt.ylabel("Running Time (Seconds)")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,1.1, 0.1))
    #plt.ylim(0,1.1)
    plt.title("BPIC2012: Running Time (LIME) \nPrefix-Length Buckets with Aggregate Encoding")
    plot = time_plot.get_figure()
    plot.savefig("figures/timing.png", bbox_inches = "tight")
    plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []
all_lime_stab = []
all_shap_stab = []

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                data = pd.DataFrame.from_records(sample_instances[i])
                
                case_id = pd.Series(data['caseID'])
                nr_events = pd.Series(data['nr_events'])
                proba = pd.Series(data['proba'])
                lime_stability = pd.Series(data['lime_stability'])
                tree_shap_stability = pd.Series(data['tree_shap_stability'])
                
                all_caseID.extend(case_id)
                all_lengths.extend(nr_events)
                all_proba.extend(proba)
                all_lime_stab.extend(lime_stability)
                all_shap_stab.extend(tree_shap_stability)
                
                print("Average LIME Stability:", statistics.mean(lime_stability))
                print("Average SHAP Stability:", statistics.mean(tree_shap_stability))
                
                #fig, ax = plt.subplots()
                #ax.plot(nr_events, lime_stability, 'bo', label = "LIME")
                #ax.plot(nr_events, tree_shap_stability, 'ro', label = "Tree SHAP")
                #ax.set_xlabel("Prefix Length")
                #ax.set_ylabel("Stability")
                #ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,1, 0.1))
                #plt.title("Prefix length and stability by index - "+type_list[i])
                #plt.show()
                
                #fig2, ax2 = plt.subplots()
                #ax2.plot(proba, lime_stability, 'bo', label = "LIME")
                #ax2.plot(proba, tree_shap_stability, 'ro', label = "Tree SHAP")
                #ax2.set_xlabel("Prediction Probability")
                #ax2.set_ylabel("Stability")
                #ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,1, 0.1))
                #plt.title("Prediction probability and stability by index - "+type_list[i])
                #plt.show()
# Out:
# Bucket 1
# True Negatives
# Average LIME Stability: 0.46720538720538723
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4611245791245791
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.49674074074074076
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4446195286195286
# Average SHAP Stability: 1.0
# Bucket 2
# True Negatives
# Average LIME Stability: 0.5464836601307189
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.49270588235294116
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5697777777777777
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.540156862745098
# Average SHAP Stability: 1.0
# Bucket 3
# True Negatives
# Average LIME Stability: 0.6728348348348349
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6923123123123123
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6869489489489489
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6852552552552552
# Average SHAP Stability: 1.0
# Bucket 4
# True Negatives
# Average LIME Stability: 0.28724999999999995
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.3067499999999999
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.2989999999999999
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.30999999999999994
# Average SHAP Stability: 1.0
# Bucket 5
# True Negatives
# Average LIME Stability: 0.5252387706855791
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5318770685579196
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.53851536643026
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5144208037825059
# Average SHAP Stability: 1.0
# Bucket 6
# True Negatives
# Average LIME Stability: 0.5416481481481481
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5306064814814815
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.547537037037037
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.554162037037037
# Average SHAP Stability: 1.0
# Bucket 7
# True Negatives
# Average LIME Stability: 0.474938775510204
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5072653061224489
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5248979591836734
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4906122448979591
# Average SHAP Stability: 1.0
# Bucket 8
# True Negatives
# Average LIME Stability: 0.5226938775510204
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5111836734693876
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5116734693877552
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5001632653061224
# Average SHAP Stability: 1.0
# Bucket 9
# True Negatives
# Average LIME Stability: 0.4688237934904601
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4859506172839506
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.4903546576879911
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4490056116722783
# Average SHAP Stability: 1.0
# Bucket 10
# True Negatives
# Average LIME Stability: 0.4446222222222222
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4974222222222222
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.45439999999999997
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4678444444444444
# Average SHAP Stability: 1.0
# Bucket 11
# True Negatives
# Average LIME Stability: 0.47052145214521446
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.46343894389438944
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.4937227722772277
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.49005940594059405
# Average SHAP Stability: 1.0
# Bucket 12
# True Negatives
# Average LIME Stability: 0.45928712871287125
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.483953795379538
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.45366996699669965
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.44878547854785483
# Average SHAP Stability: 1.0
# Bucket 13
# True Negatives
# Average LIME Stability: 0.46771428571428575
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4713650793650794
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.458952380952381
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.46990476190476194
# Average SHAP Stability: 1.0
# Bucket 14
# True Negatives
# Average LIME Stability: 0.517090909090909
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5313939393939393
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5105454545454544
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5107878787878787
# Average SHAP Stability: 1.0
# Bucket 15
# True Negatives
# Average LIME Stability: 0.5461309523809523
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5446785714285715
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5412896825396826
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5533928571428571
# Average SHAP Stability: 1.0
# Bucket 16
# True Negatives
# Average LIME Stability: 0.6707936507936507
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6470714285714285
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6490079365079364
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6470714285714285
# Average SHAP Stability: 1.0
# Bucket 17
# True Negatives
# Average LIME Stability: 0.6806939571150097
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6782768031189084
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6748927875243664
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6765847953216374
# Average SHAP Stability: 1.0
# Bucket 18
# True Negatives
# Average LIME Stability: 0.6381666666666667
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6396111111111111
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6379259259259259
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6434629629629629
# Average SHAP Stability: 1.0
# Bucket 19
# True Negatives
# Average LIME Stability: 0.6395996326905418
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.635269054178145
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6381561065197429
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6203526170798898
# Average SHAP Stability: 1.0
# Bucket 20
# True Negatives
# Average LIME Stability: 0.6316368563685637
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6525420054200541
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6299548328816621
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6270713640469738
# Average SHAP Stability: 1.0
# Bucket 21
# True Negatives
# Average LIME Stability: 0.6498709677419354
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6589964157706093
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6544336917562724
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6762867383512544
# Average SHAP Stability: 1.0
# Bucket 22
# True Negatives
# Average LIME Stability: 0.7060645161290322
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.707505376344086
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.7305591397849462
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.7082258064516129
# Average SHAP Stability: 1.0
# Bucket 23
# True Negatives
# Average LIME Stability: 0.709426523297491
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7027025089605734
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.7125483870967741
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.7120681003584228
# Average SHAP Stability: 1.0
# Bucket 24
# True Negatives
# Average LIME Stability: 0.7504910394265233
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7276774193548387
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.7365627240143369
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.7317598566308243
# Average SHAP Stability: 1.0
# Bucket 25
# True Negatives
# Average LIME Stability: 0.6352222222222221
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.648189964157706
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6448279569892473
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6597168458781362
# Average SHAP Stability: 1.0

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens), key=lambda x: x[3])
all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1, 0.1))
plt.ylim(0,1.1)
plt.title("BPIC2012: Stability by Subset (LIME) \nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_subset_stability.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("BPIC2012: Stability by Subset (SHAP) \nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_subset_stability.png", bbox_inches = "tight")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Prefix length and stability by index \n Single Bucket with Aggregate Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Prediction probability and stability by index \n Single Bucket with Aggregate Encoding")
plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []
all_lime_stab = []
all_shap_stab = []

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                data = pd.DataFrame.from_records(sample_instances[i])
                
                dispersal_lime = []
                dispersal_shap = []
                adj_dispersal_lime = []
                adj_dispersal_shap = []
                
                case_id = pd.Series(data['caseID'])
                nr_events = pd.Series(data['nr_events'])
                proba = pd.Series(data['proba'])
                lime_stability = pd.Series(data['adjusted_lime_importance_stability'])
                tree_shap_stability = pd.Series(data['adjusted_shap_importance_stability'])
                
                all_caseID.extend(case_id)
                all_lengths.extend(nr_events)
                all_proba.extend(proba)
                all_lime_stab.extend(lime_stability)
                all_shap_stab.extend(tree_shap_stability)
                
                print("Average LIME Weights Stability:", statistics.mean(lime_stability))
                print("Average SHAP Weights Stability:", statistics.mean(tree_shap_stability))
                
                shap_dispersion = [disp for disp in tree_shap_stability if disp > 0]
                
                print (len(shap_dispersion))
                
                #fig, ax = plt.subplots()
                #ax.plot(nr_events, lime_stability, 'bo', label = "LIME")
                #ax.plot(nr_events, tree_shap_stability, 'ro', label = "Tree SHAP")
                #ax.set_xlabel("Prefix Length")
                #ax.set_ylabel("Stability")
                #ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.title("Prefix length and stability by weight - "+type_list[i])
                #plt.show()
                
                #fig2, ax2 = plt.subplots()
                #ax2.plot(proba, lime_stability, 'bo', label = "LIME")
                #ax2.plot(proba, tree_shap_stability, 'ro', label = "Tree SHAP")
                #ax2.set_xlabel("Prediction Probability")
                #ax2.set_ylabel("Stability")
                #ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.title("Prediction probability and stability by weight - "+type_list[i])
                #plt.show()
# Out:
# Bucket 1
# True Negatives
# Average LIME Weights Stability: 0.904258297110617
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.971574772984472
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.977878064370667
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.9592525985974276
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 2
# True Negatives
# Average LIME Weights Stability: 0.8837914164000027
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.6562839385074485
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Negatives
# Average LIME Weights Stability: 0.8815458235581566
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.8320062329440069
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# Bucket 3
# True Negatives
# Average LIME Weights Stability: 0.9021342472263247
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.9271840971811814
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Negatives
# Average LIME Weights Stability: 0.9416745095190687
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Positives
# Average LIME Weights Stability: 0.9516726645553953
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# Bucket 4
# True Negatives
# Average LIME Weights Stability: 0.5853142184708805
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.6391142445588496
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.2756030157654195
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.4961843826383581
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 5
# True Negatives
# Average LIME Weights Stability: 0.8073865967203607
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.6779918300836318
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.5445291082434353
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.6732311635562042
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 6
# True Negatives
# Average LIME Weights Stability: 0.7854065477319695
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.802299240157539
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.6616686800290776
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.3989231963304774
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 7
# True Negatives
# Average LIME Weights Stability: 0.7522061843361657
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.12124816950170039
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Negatives
# Average LIME Weights Stability: 0.7083336084071277
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.7521719100771262
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# Bucket 8
# True Negatives
# Average LIME Weights Stability: 0.8234166984805938
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.847717312844776
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.5017170783089399
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.8562376217966581
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 9
# True Negatives
# Average LIME Weights Stability: 0.8290539886010135
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.6759093972163357
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.7326527831026898
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Positives
# Average LIME Weights Stability: 0.7346456527107013
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 10
# True Negatives
# Average LIME Weights Stability: 0.8283705304195078
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.7012832584067678
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.8144307160839878
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.8381182388593347
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 11
# True Negatives
# Average LIME Weights Stability: 0.5434071772334848
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.8400790022025765
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.7634138802954442
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.8306727613177491
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 12
# True Negatives
# Average LIME Weights Stability: 0.7505434638835429
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.8249996147319647
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.7343600972013875
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Positives
# Average LIME Weights Stability: 0.6925945945573728
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 13
# True Negatives
# Average LIME Weights Stability: 0.8325049045694879
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.7533834260953419
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.8183113755629442
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Positives
# Average LIME Weights Stability: 0.7385448096514713
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 14
# True Negatives
# Average LIME Weights Stability: 0.8330802632252604
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.8158308530121019
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.8165223589291287
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Positives
# Average LIME Weights Stability: 0.6864336505376545
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 15
# True Negatives
# Average LIME Weights Stability: 0.7676468729130115
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.8264247280401259
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.8209153748939527
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.7613744549632944
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 16
# True Negatives
# Average LIME Weights Stability: 0.705986143293852
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.44619979037179874
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.8471400975110924
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.7817092062119764
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 17
# True Negatives
# Average LIME Weights Stability: 0.8279882542173602
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.8623707177092844
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.7910695161999661
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.8276452344723622
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 18
# True Negatives
# Average LIME Weights Stability: 0.854989740194565
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.5473290208298293
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.8087631484759031
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.8235927722713955
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# Bucket 19
# True Negatives
# Average LIME Weights Stability: 0.8191228699896415
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.8394300078324732
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.8668212594093009
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.8588139171782808
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# Bucket 20
# True Negatives
# Average LIME Weights Stability: 0.00639617771444514
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.8108534453245182
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Negatives
# Average LIME Weights Stability: 0.5959257293051765
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Positives
# Average LIME Weights Stability: 0.8330594303538332
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 21
# True Negatives
# Average LIME Weights Stability: 0.8529856647157155
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.8670382280248805
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Negatives
# Average LIME Weights Stability: 0.8445384064658424
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Positives
# Average LIME Weights Stability: 0.40451224097283667
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# Bucket 22
# True Negatives
# Average LIME Weights Stability: 0.8773196814685204
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.9200170794459365
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Negatives
# Average LIME Weights Stability: 0.639440479133808
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Positives
# Average LIME Weights Stability: 0.8896782860875144
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# Bucket 23
# True Negatives
# Average LIME Weights Stability: 0.5747774713310284
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.8147585841128363
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Negatives
# Average LIME Weights Stability: 0.6326901655513982
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Positives
# Average LIME Weights Stability: -7.356709244014614
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# Bucket 24
# True Negatives
# Average LIME Weights Stability: 0.8843131749857971
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.8964749208390671
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Negatives
# Average LIME Weights Stability: 0.7724691661519023
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: -0.2738251580318017
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# Bucket 25
# True Negatives
# Average LIME Weights Stability: 0.8969474074952687
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.873998356750963
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Negatives
# Average LIME Weights Stability: 0.9137691748830338
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.8775163420606521
# Average SHAP Weights Stability: 0.9999999999999998
# 10

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.ylim(-18, 2)
plt.title("BPIC 2012: Stability by Weight (LIME) \nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_weight_stability.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.ylim(-18, 2)
plt.title("BPIC 2012: Stability by Weight (SHAP) \nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_weight_stability.png", bbox_inches = "tight")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(lime_lower, 1.1)
plt.title("Prefix length and stability by weight \n Single Bucket with Aggregate Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(lime_lower,1)
plt.title("Prefix length and stability by weight \n Single Bucket with Aggregate Encoding")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0aa62e77f8b5> in <module>
#      28 ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#      29 #plt.yticks(np.arange(0,15,1))
# ---> 30 plt.ylim(lime_lower, 1.1)
#      31 plt.title("Prefix length and stability by weight \n Single Bucket with Aggregate Encoding")
#      32 plt.show()
#
# NameError: name 'lime_lower' is not defined

# %%
lime_mean = np.mean(all_lime_stab)
lime_std = np.std(all_lime_stab)
lime_upper = lime_mean + (3*lime_std)
lime_lower = lime_mean - (3*lime_std)

shap_mean = np.mean(all_shap_stab)
shap_std = np.std(all_shap_stab)
shap_upper = shap_mean + (3*shap_std)
shap_lower = shap_mean - (3*shap_std)

lime_outliers = [i for i in all_lime_stab if i > lime_upper or i < lime_lower]
shap_outliers = [i for i in all_shap_stab if i > shap_upper or i < shap_lower]

print (lime_mean)
print (shap_mean)
print(len(lime_outliers))
print(len(shap_outliers))
print(str(len(lime_outliers)/len(all_lime_stab)*100)+"%")
print(str(len(shap_outliers)/len(all_shap_stab)*100)+"%")

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens), key=lambda x: x[3])
all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.ylim(lime_lower, 1.1)
plt.title("BPIC 2012: Stability by Weight (LIME) \nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
#plot.savefig("figures/lime_weight_stability.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.ylim(lime_lower, 1.1)
plt.title("BPIC 2012: Stability by Weight (SHAP) \nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
#plot.savefig("figures/shap_weight_stability.png", bbox_inches = "tight")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(lime_lower, 1.1)
plt.title("Prefix length and stability by weight \n Single Bucket with Aggregate Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(lime_lower,1)
plt.title("Prefix length and stability by weight \n Single Bucket with Aggregate Encoding")
plt.show()

# %%
# bins = np.arange(0, shap_upper+1e-17, 1e-17)
# yticks = np.arange(0, 80, 10)
# #sns.set_style("white")
# plt.subplots(figsize=(20, 15))
# plt.hist(all_shap_stab, bins = bins)
# #plt.figsize([50, 50])
# plt.xticks(bins, fontsize = 8)
# plt.yticks(yticks, fontsize = 12)
# plt.title("Distribution of SHAP Stability by Weight", fontsize = 16)
# plt.xlabel("Stability Range", fontsize = 14)
# plt.ylabel("Frequency", fontsize = 14)
# plt.show()

# %%
# bins = np.arange(0, lime_upper+0.1, 0.2)
# yticks = np.arange(0, 720, 20)
# #sns.set_style("white")
# plt.subplots(figsize=(20, 10))
# plt.hist(all_lime_stab, bins = bins)
# #plt.figsize([50, 50])
# plt.xticks(bins, fontsize = 12)
# plt.yticks(yticks, fontsize = 12)
# plt.title("Distribution of LIME Stability by Weight", fontsize = 16)
# plt.xlabel("Stability Range", fontsize = 14)
# plt.ylabel("Frequency", fontsize = 14)
# plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []

sep_caseID = [[],[],[],[]]
sep_lengths = [[],[],[],[]]
sep_proba = [[],[],[],[]]

all_lime_diffs = []
all_shap_diffs = []

sep_lime_diffs = [[],[],[],[]]
sep_shap_diffs = [[],[],[],[]]

all_lime_MSE = []
all_lime_RMSE = []
all_lime_MAE = []
all_lime_MAPE = []

sep_lime_MSE = [[],[],[],[]]
sep_lime_RMSE = [[],[],[],[]]
sep_lime_MAE = [[],[],[],[]]
sep_lime_MAPE = [[],[],[],[]]

all_shap_MSE = []
all_shap_RMSE = []
all_shap_MAE = []
all_shap_MAPE = []

sep_shap_MSE = [[],[],[],[]]
sep_shap_RMSE = [[],[],[],[]]
sep_shap_MAE = [[],[],[],[]]
sep_shap_MAPE = [[],[],[],[]]

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                data = pd.DataFrame.from_records(sample_instances[i])
                
                lime_MSE = []
                lime_RMSE = []
                lime_MAE = []
                lime_MAPE = []
                
                shap_MSE = []
                shap_RMSE = []
                shap_MAE = []
                shap_MAPE = []
                
                case_id = pd.Series(data['caseID'])
                nr_events = pd.Series(data['nr_events'])
                proba = pd.Series(data['proba'])
                lime_diffs = pd.Series(data['lime_fid_change'])
                shap_diffs = pd.Series(data['shap_fid_change'])
                
                for j in range(len(lime_diffs)):
                    p1 = proba[j]
                    
                    lime_diff = lime_diffs[j]
                    shap_diff = shap_diffs[j]
                    
                    all_lime_diffs.append(lime_diff)
                    all_shap_diffs.append(shap_diff)
                    
                    lime_sq_changes = []
                    lime_abs_changes = []
                    lime_rel_changes = []
                    
                    shap_sq_changes = []
                    shap_abs_changes = []
                    shap_rel_changes = []
                    
                    for each in lime_diff:
                        lime_sq_changes.append(each**2)
                        lime_abs_changes.append(abs(each))
                        lime_rel_changes.append(abs(each)/p1)
                        
                    for each in shap_diff:
                        shap_sq_changes.append(each**2)
                        shap_abs_changes.append(abs(each))
                        shap_rel_changes.append(abs(each)/p1)
                    
                    lime_MSE.append(sum(lime_sq_changes)/len(lime_sq_changes))
                    lime_RMSE.append(math.sqrt(sum(lime_sq_changes)/len(lime_sq_changes)))
                    lime_MAE.append(sum(lime_abs_changes)/len(lime_abs_changes))
                    lime_MAPE.append(sum(lime_rel_changes)/len(lime_rel_changes))
                    
                    shap_MSE.append(sum(shap_sq_changes)/len(shap_sq_changes))
                    shap_RMSE.append(math.sqrt(sum(shap_sq_changes)/len(shap_sq_changes)))
                    shap_MAE.append(sum(shap_abs_changes)/len(shap_abs_changes))
                    shap_MAPE.append(sum(shap_rel_changes)/len(shap_rel_changes))
                
                all_caseID.extend(case_id)
                all_lengths.extend(nr_events)
                all_proba.extend(proba)
                
                all_lime_MSE.extend(lime_MSE)
                all_lime_RMSE.extend(lime_RMSE)
                all_lime_MAE.extend(lime_MAE)
                all_lime_MAPE.extend(lime_MAPE)
                
                all_shap_MSE.extend(shap_MSE)
                all_shap_RMSE.extend(shap_RMSE)
                all_shap_MAE.extend(shap_MAE)
                all_shap_MAPE.extend(shap_MAPE)
                
                sep_caseID[i].extend(case_id)
                sep_lengths[i].extend(nr_events)
                sep_proba[i].extend(proba)
                
                sep_lime_MSE[i].extend(lime_MSE)
                sep_lime_RMSE[i].extend(lime_RMSE)
                sep_lime_MAE[i].extend(lime_MAE)
                sep_lime_MAPE[i].extend(lime_MAPE)
                
                sep_shap_MSE[i].extend(shap_MSE)
                sep_shap_RMSE[i].extend(shap_RMSE)
                sep_shap_MAE[i].extend(shap_MAE)
                sep_shap_MAPE[i].extend(shap_MAPE)
                
                print("Average LIME MSE:", statistics.mean(lime_MSE))
                print("Average SHAP MSE:", statistics.mean(shap_MSE))
                print("\n")
                
                #plt.plot(nr_events, lime_MSE, 'bo', label = "LIME")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prefix length and MSE \n"+type_list[i])
                #plt.show()

                #plt.plot(nr_events, shap_MSE, 'ro', label = "Tree SHAP")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                ##plt.yticks(np.arange(0,15,1))
                #plt.title("Prefix length and MSE \n"+type_list[i])
                #plt.show()

                #plt.plot(proba, lime_MSE, 'bo', label = "LIME")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prediction probability and MSE \n"+type_list[i])
                #plt.show()

                #plt.plot(proba, shap_MSE, 'ro', label = "Tree SHAP")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prediction probability and MSE \n"+type_list[i])
                #plt.show()
                
                print("Average LIME RMSE:", statistics.mean(lime_RMSE))
                print("Average SHAP RMSE:", statistics.mean(shap_RMSE))
                print("\n")
                
                #plt.plot(nr_events, lime_RMSE, 'bo', label = "LIME")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prefix length and RMSE \n"+type_list[i])
                #plt.show()

                #plt.plot(nr_events, shap_RMSE, 'ro', label = "Tree SHAP")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prefix length and RMSE \n"+type_list[i])
                #plt.show()

                #plt.plot(proba, lime_RMSE, 'bo', label = "LIME")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prediction probability and RMSE \n"+type_list[i])
                #plt.show()

                #plt.plot(proba, shap_RMSE, 'ro', label = "Tree SHAP")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prediction probability and RMSE \n"+type_list[i])
                #plt.show()
                
                print("Average LIME MAE:", statistics.mean(lime_MAE))
                print("Average SHAP MAE:", statistics.mean(shap_MAE))
                print("\n")
                
                #plt.plot(nr_events, lime_MAE, 'bo', label = "LIME")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prefix length and MAE \n"+type_list[i])
                #plt.show()

                #plt.plot(nr_events, shap_MAE, 'ro', label = "Tree SHAP")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prefix length and MAE \n"+type_list[i])
                #plt.show()

                #plt.plot(proba, lime_MAE, 'bo', label = "LIME")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prediction probability and MAE \n"+type_list[i])
                #plt.show()

                #plt.plot(proba, shap_MAE, 'ro', label = "Tree SHAP")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prediction probability and MAE \n"+type_list[i])
                #plt.show()
                
                print("Average LIME MAPE:", statistics.mean(lime_MAPE))
                print("Average SHAP MAPE:", statistics.mean(shap_MAPE))
                print("\n")
                
                #plt.plot(nr_events, lime_MAPE, 'bo', label = "LIME")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prefix length and MAPE \n"+type_list[i])
                #plt.show()

                #plt.plot(nr_events, shap_MAPE, 'ro', label = "Tree SHAP")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prefix length and MAPE \n"+type_list[i])
                #plt.show()

                #plt.plot(proba, lime_MAPE, 'bo', label = "LIME")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prediction probability and MAPE \n"+type_list[i])
                #plt.show()

                #plt.plot(proba, shap_MAPE, 'ro', label = "Tree SHAP")
                #plt.xlabel("Prefix Length")
                #plt.ylabel("Change in Prediction Probability")
                #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                #plt.yticks(np.arange(0,15,1))
                #plt.title("Prediction probability and MAPE \n"+type_list[i])
                #plt.show()

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_MSE, all_shap_MSE, all_lime_RMSE, all_shap_RMSE, all_lime_MAE, all_shap_MAE, 
                          all_lime_MAPE, all_shap_MAPE, all_lengths, hue_lens), key=lambda x: x[-2])
all_proba, all_lime_MSE, all_shap_MSE, all_lime_RMSE, all_shap_RMSE, all_lime_MAE, all_shap_MAE, all_lime_MAPE, all_shap_MAPE, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
sns.scatterplot(all_proba, all_lime_MSE, hue=hue_lens, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("BPIC 2012: Fidelity MSE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_MSE, hue=hue_lens, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("BPIC 2012: Fidelity MSE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

# %%
sns.scatterplot(all_proba, all_lime_RMSE, hue = hue_lens, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("BPIC 2012: Fidelity RMSE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_RMSE, hue = hue_lens, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("BPIC 2012: Fidelity RMSE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_MAE, hue = hue_lens, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("BPIC 2012: Fidelity MAE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_fidelity_mae.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_MAE, hue = hue_lens, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("BPIC 2012: Fidelity MAE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_fidelity_mae.png", bbox_inches = "tight")
plt.show()

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_MAPE, hue = hue_lens, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.yticks(np.arange(0,1.1,0.1))
plt.title("BPIC 2012: Fidelity MAPE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_fidelity_mape.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_MAPE, hue = hue_lens, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.yticks(np.arange(0,1.1,0.1))
plt.title("BPIC 2012: Fidelity MAPE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_fidelity_mape.png", bbox_inches = "tight")
plt.show()

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

sep_hues = [[],[],[],[]]

for i in range(len(sep_lengths)): 
    for length in sep_lengths[i]:
        cur_bin = 0
        while length >= bins[cur_bin+1]:
            cur_bin += 1
        sep_hues[i].append(labels[cur_bin])
#sep_hues

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MSE[i], hue = sep_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MSE[i], hue = sep_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_RMSE[i], hue = sep_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_RMSE[i], hue = sep_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAE[i], hue = sep_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAE[i], hue = sep_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAPE[i], hue = sep_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAPE[i], hue = sep_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAPE\nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[],[]]
type_proba = [[],[]]
type_hues = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_hues[0].extend(sep_hues[0])
type_hues[0].extend(sep_hues[2])
type_hues[1].extend(sep_hues[1])
type_hues[1].extend(sep_hues[3])

type_lime_MSE = [[],[]]
type_shap_MSE = [[],[]]

type_lime_MSE[0].extend(sep_lime_MSE[0])
type_lime_MSE[0].extend(sep_lime_MSE[2])
type_lime_MSE[1].extend(sep_lime_MSE[1])
type_lime_MSE[1].extend(sep_lime_MSE[3])

type_shap_MSE[0].extend(sep_shap_MSE[0])
type_shap_MSE[0].extend(sep_shap_MSE[2])
type_shap_MSE[1].extend(sep_shap_MSE[1])
type_shap_MSE[1].extend(sep_shap_MSE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MSE[i], hue = type_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MSE[i], hue = type_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_RMSE = [[],[]]
type_shap_RMSE = [[],[]]

type_lime_RMSE[0].extend(sep_lime_RMSE[0])
type_lime_RMSE[0].extend(sep_lime_RMSE[2])
type_lime_RMSE[1].extend(sep_lime_RMSE[1])
type_lime_RMSE[1].extend(sep_lime_RMSE[3])

type_shap_RMSE[0].extend(sep_shap_RMSE[0])
type_shap_RMSE[0].extend(sep_shap_RMSE[2])
type_shap_RMSE[1].extend(sep_shap_RMSE[1])
type_shap_RMSE[1].extend(sep_shap_RMSE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_RMSE[i], hue = type_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_RMSE[i], hue = type_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_MAE = [[],[]]
type_shap_MAE = [[],[]]

type_lime_MAE[0].extend(sep_lime_MAE[0])
type_lime_MAE[0].extend(sep_lime_MAE[2])
type_lime_MAE[1].extend(sep_lime_MAE[1])
type_lime_MAE[1].extend(sep_lime_MAE[3])

type_shap_MAE[0].extend(sep_shap_MAE[0])
type_shap_MAE[0].extend(sep_shap_MAE[2])
type_shap_MAE[1].extend(sep_shap_MAE[1])
type_shap_MAE[1].extend(sep_shap_MAE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MAE[i], hue = type_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MAE[i], hue = type_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_MAPE = [[],[]]
type_shap_MAPE = [[],[]]

type_lime_MAPE[0].extend(sep_lime_MAPE[0])
type_lime_MAPE[0].extend(sep_lime_MAPE[2])
type_lime_MAPE[1].extend(sep_lime_MAPE[1])
type_lime_MAPE[1].extend(sep_lime_MAPE[3])

type_shap_MAPE[0].extend(sep_shap_MAPE[0])
type_shap_MAPE[0].extend(sep_shap_MAPE[2])
type_shap_MAPE[1].extend(sep_shap_MAPE[1])
type_shap_MAPE[1].extend(sep_shap_MAPE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MAPE[i], hue = type_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MAPE[i], hue = type_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
print("Average LIME MSE:", np.mean(all_lime_MSE))
print("Average SHAP MSE:", np.mean(all_shap_MSE))
print("\n")

print("Average LIME RMSE:", np.mean(all_lime_RMSE))
print("Average SHAP RMSE:", np.mean(all_shap_RMSE))
print("\n")

print("Average LIME MAE:", np.mean(all_lime_MAE))
print("Average SHAP MAE:", np.mean(all_shap_MAE))
print("\n")

print("Average LIME MAPE:", np.mean(all_lime_MAPE))
print("Average SHAP MAPE:", np.mean(all_shap_MAPE))

# %%
print(len(all_lime_MSE))
