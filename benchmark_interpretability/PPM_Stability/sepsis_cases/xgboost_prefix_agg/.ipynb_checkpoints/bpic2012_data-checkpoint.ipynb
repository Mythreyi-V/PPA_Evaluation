# %%
#from google.colab import drive
#drive.mount('/content/drive')
import sys
#PATH = '/content/drive/My Drive/PPM_Stability/'
#PATH = "C:/Users/velmurug/Documents/Stability Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/Mythreyi/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/mythr/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
PATH = "C:/Users/n9455647/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
sys.path.append(PATH)

# %%
from DatasetManager import DatasetManager

import pandas as pd
import numpy as np

import os
import sys
from sys import argv
import pickle
import random
import joblib

import statistics
import math

import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

lime_pal = sns.diverging_palette(100, 200, s=150)#, as_cmap=True)
shap_pal = sns.diverging_palette(0, 240, s=150)#, as_cmap=True)

sns.set_style('darkgrid')

# %%
dataset_ref = "sepsis_cases"
params_dir = PATH + "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "agg"
cls_method = "xgboost"

gap = 1
n_iter = 1

method_name = "%s_%s"%(bucket_method, cls_encoding)

generate_samples = False
generate_lime = True
generate_kernel_shap = False
generate_model_shap = True

sample_size = 2
exp_iter = 10
max_feat = 10
max_prefix = 25

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"],
    #"insurance": ["insurance_activity", "insurance_followup"],
    "sepsis_cases": ["sepsis_cases_1"]#, "sepsis_cases_2", "sepsis_cases_4"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]

datasets
# Out:
# ['sepsis_cases_1']

# %%
all_caseID = []
all_lengths = []
all_proba = []
all_lime_stab = []
all_shap_stab = []

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i]!=[]:
                    data = pd.DataFrame.from_records(sample_instances[i])

                    case_id = pd.Series(data['caseID'])
                    nr_events = pd.Series(data['nr_events'])
                    proba = pd.Series(data['proba'])
                    lime_stability = pd.Series(data['lime_stability'])
                    tree_shap_stability = pd.Series(data['tree_shap_stability'])

                    all_caseID.extend(case_id)
                    all_lengths.extend(nr_events)
                    all_proba.extend(proba)
                    all_lime_stab.extend(lime_stability)
                    all_shap_stab.extend(tree_shap_stability)

                    print("Average LIME Stability:", statistics.mean(lime_stability))
                    print("Average SHAP Stability:", statistics.mean(tree_shap_stability))

                    #fig, ax = plt.subplots()
                    #ax.plot(nr_events, lime_stability, 'bo', label = "LIME")
                    #ax.plot(nr_events, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax.set_xlabel("Prefix Length")
                    #ax.set_ylabel("Stability")
                    #ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,1, 0.1))
                    #plt.title("Prefix length and stability by index - "+type_list[i])
                    #plt.show()

                    #fig2, ax2 = plt.subplots()
                    #ax2.plot(proba, lime_stability, 'bo', label = "LIME")
                    #ax2.plot(proba, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax2.set_xlabel("Prediction Probability")
                    #ax2.set_ylabel("Stability")
                    #ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,1, 0.1))
                    #plt.title("Prediction probability and stability by index - "+type_list[i])
                    #plt.show()
# Out:
# Bucket 1
# True Negatives
# Average LIME Stability: 0.34886531250163305
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.33661567182098806
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.3601318457333785
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.34844819810526706
# Average SHAP Stability: 1.0
# Bucket 2
# True Negatives
# Average LIME Stability: 0.5206423871153201
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5169158106732303
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5032614978081525
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5624679930747927
# Average SHAP Stability: 1.0
# Bucket 3
# True Negatives
# Average LIME Stability: 0.3857946196223104
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.40963782522722897
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.43549024684875143
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4292786581529326
# Average SHAP Stability: 1.0
# Bucket 4
# True Negatives
# Average LIME Stability: 0.4598691272269257
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4858386523047389
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.49251411079544394
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.48673413756641626
# Average SHAP Stability: 1.0
# Bucket 5
# True Negatives
# Average LIME Stability: 0.416319822997656
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4638956892830406
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.42691192039295467
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4514483587654096
# Average SHAP Stability: 1.0
# Bucket 6
# True Negatives
# Average LIME Stability: 0.42659001027874077
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4381537453856975
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.3818090255841294
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.42835436680043915
# Average SHAP Stability: 1.0
# Bucket 7
# True Negatives
# Average LIME Stability: 0.3590979771641354
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.37588487966991363
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.3782372041510859
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.38014081007992306
# Average SHAP Stability: 1.0
# Bucket 8
# True Negatives
# Average LIME Stability: 0.36206102796998013
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.3585933317446401
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.4279368425327076
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.340764138131585
# Average SHAP Stability: 1.0
# Bucket 9
# True Negatives
# Average LIME Stability: 0.39196781674108067
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4030944205780135
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.42658323563757405
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.40447608498204135
# Average SHAP Stability: 1.0
# Bucket 10
# True Negatives
# Average LIME Stability: 0.40153342708728146
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.38299424577124785
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.40935758273179934
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.40615103428877414
# Average SHAP Stability: 1.0
# Bucket 11
# True Negatives
# Average LIME Stability: 0.32234074392748413
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.40173477472437186
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.34235739955442984
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.3576770039234357
# Average SHAP Stability: 1.0
# Bucket 12
# True Negatives
# Average LIME Stability: 0.41481053674435464
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4074022267826346
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.37706398609497666
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4152693178033255
# Average SHAP Stability: 1.0
# Bucket 13
# True Negatives
# Average LIME Stability: 0.42562495127950284
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4684467220819255
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.41526126328746255
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4550578309193994
# Average SHAP Stability: 1.0
# Bucket 14
# True Negatives
# Average LIME Stability: 0.4257376581384045
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.44019836480347846
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.4200552191340641
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4613654401730056
# Average SHAP Stability: 1.0
# Bucket 15
# True Negatives
# Average LIME Stability: 0.5831029043334742
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5705009906534506
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5803662851458219
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6026632745784575
# Average SHAP Stability: 1.0
# Bucket 16
# True Negatives
# Average LIME Stability: 0.515198345397549
# Average SHAP Stability: 1.0
# True Positives
# False Negatives
# Average LIME Stability: 0.46453160227475043
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5252514173062711
# Average SHAP Stability: 1.0
# Bucket 17
# True Negatives
# Average LIME Stability: 0.5950705953681065
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6737433902769026
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5999320561696646
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5579924238662495
# Average SHAP Stability: 1.0
# Bucket 18
# True Negatives
# Average LIME Stability: 0.6997153684214494
# Average SHAP Stability: 1.0
# True Positives
# False Negatives
# Average LIME Stability: 0.6148767656498517
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6929367903225213
# Average SHAP Stability: 1.0
# Bucket 19
# True Negatives
# Average LIME Stability: 0.7647932140153464
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7142947795527037
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.8157844630616908
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.7285592598175209
# Average SHAP Stability: 1.0
# Bucket 20
# True Negatives
# Average LIME Stability: 0.7666829529070012
# Average SHAP Stability: 1.0
# True Positives
# False Negatives
# Average LIME Stability: 0.7359506575422473
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.7360101575201166
# Average SHAP Stability: 1.0
# Bucket 21
# True Negatives
# Average LIME Stability: 0.8680729166666666
# Average SHAP Stability: 1.0
# True Positives
# False Negatives
# Average LIME Stability: 0.7898611111111111
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.8455833333333334
# Average SHAP Stability: 1.0
# Bucket 22
# True Negatives
# Average LIME Stability: 0.7181935110953306
# Average SHAP Stability: 1.0
# True Positives
# False Negatives
# Average LIME Stability: 0.6308408532711238
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.7972851568872923
# Average SHAP Stability: 1.0
# Bucket 23
# True Negatives
# Average LIME Stability: 0.6820428201197978
# Average SHAP Stability: 1.0
# True Positives
# False Negatives
# Average LIME Stability: 0.6616195107574417
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6946633877779781
# Average SHAP Stability: 1.0
# Bucket 24
# True Negatives
# Average LIME Stability: 0.7396888086138473
# Average SHAP Stability: 1.0
# True Positives
# False Negatives
# Average LIME Stability: 0.7308501118568231
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.7876446819609376
# Average SHAP Stability: 1.0
# Bucket 25
# True Negatives
# Average LIME Stability: 0.7522610656463575
# Average SHAP Stability: 1.0
# True Positives
# False Negatives
# Average LIME Stability: 0.7518488700841641
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.7864812966769689
# Average SHAP Stability: 1.0

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens), key=lambda x: x[3])
all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1, 0.1))
plt.ylim(0,1.1)
plt.title("Sepsis Cases: Stability by Subset (LIME) \nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_subset_stability.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1, 0.1))
plt.ylim(0,1.1)
plt.title("Sepsis Cases: Stability by Subset (LIME) \nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_subset_stability.png", bbox_inches = "tight")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.yticks(np.arange(0,1, 0.1))
plt.title("Prefix length and stability by index \n Single Bucket with Aggregate Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.yticks(np.arange(0,1, 0.1))
plt.title("Prediction probability and stability by index \n Single Bucket with Aggregate Encoding")
plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []
all_lime_stab = []
all_shap_stab = []

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i]!=[]:
                    data = pd.DataFrame.from_records(sample_instances[i])

                    dispersal_lime = []
                    dispersal_shap = []
                    adj_dispersal_lime = []
                    adj_dispersal_shap = []

                    case_id = pd.Series(data['caseID'])
                    nr_events = pd.Series(data['nr_events'])
                    proba = pd.Series(data['proba'])
                    lime_stability = pd.Series(data['adjusted_lime_importance_stability'])
                    tree_shap_stability = pd.Series(data['adjusted_shap_importance_stability'])

                    all_caseID.extend(case_id)
                    all_lengths.extend(nr_events)
                    all_proba.extend(proba)
                    all_lime_stab.extend(lime_stability)
                    all_shap_stab.extend(tree_shap_stability)

                    print("Average LIME Weights Stability:", statistics.mean(lime_stability))
                    print("Average SHAP Weights Stability:", statistics.mean(tree_shap_stability))

                    shap_dispersion = [disp for disp in tree_shap_stability if disp > 0]

                    print (len(shap_dispersion))

                    #fig, ax = plt.subplots()
                    #ax.plot(nr_events, lime_stability, 'bo', label = "LIME")
                    #ax.plot(nr_events, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax.set_xlabel("Prefix Length")
                    #ax.set_ylabel("Stability")
                    #ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.title("Prefix length and stability by weight - "+type_list[i])
                    #plt.show()

                    #fig2, ax2 = plt.subplots()
                    #ax2.plot(proba, lime_stability, 'bo', label = "LIME")
                    #ax2.plot(proba, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax2.set_xlabel("Prediction Probability")
                    #ax2.set_ylabel("Stability")
                    #ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.title("Prediction probability and stability by weight - "+type_list[i])
                    #plt.show()
# Out:
# Bucket 1
# True Negatives
# Average LIME Weights Stability: 0.4025466084830277
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.6044213735541472
# Average SHAP Weights Stability: 0.9999999999999999
# 5
# False Negatives
# Average LIME Weights Stability: 0.5939659411501014
# Average SHAP Weights Stability: 0.9999999999999999
# 5
# False Positives
# Average LIME Weights Stability: 0.39544118219115487
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 2
# True Negatives
# Average LIME Weights Stability: 0.776309294341185
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.3204354910404939
# Average SHAP Weights Stability: 0.9999999999999999
# 6
# False Negatives
# Average LIME Weights Stability: 0.30297718315309297
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# False Positives
# Average LIME Weights Stability: 0.4044622545160446
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 3
# True Negatives
# Average LIME Weights Stability: 0.2506816373878033
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.6843509416083102
# Average SHAP Weights Stability: 0.9999999999999998
# 7
# False Negatives
# Average LIME Weights Stability: 0.45785094446396984
# Average SHAP Weights Stability: 0.9999999999999999
# 6
# False Positives
# Average LIME Weights Stability: 0.6377684075453909
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 4
# True Negatives
# Average LIME Weights Stability: 0.5925828801577739
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.7586247268872129
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# False Negatives
# Average LIME Weights Stability: -0.42493541006065216
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# False Positives
# Average LIME Weights Stability: 0.5056726357600446
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 5
# True Negatives
# Average LIME Weights Stability: 0.37669692149491396
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.1839659326821189
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# False Negatives
# Average LIME Weights Stability: 0.6515349429633203
# Average SHAP Weights Stability: 0.9999999999999999
# 4
# False Positives
# Average LIME Weights Stability: 0.5903296387178666
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 6
# True Negatives
# Average LIME Weights Stability: 0.7440329412878072
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: -0.7658046196205999
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# False Negatives
# Average LIME Weights Stability: 0.47649828822856655
# Average SHAP Weights Stability: 0.9999999999999999
# 5
# False Positives
# Average LIME Weights Stability: 0.629236437339478
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 7
# True Negatives
# Average LIME Weights Stability: -0.29956339955355493
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.5453841404469807
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# False Negatives
# Average LIME Weights Stability: 0.45645906663424796
# Average SHAP Weights Stability: 0.9999999999999999
# 6
# False Positives
# Average LIME Weights Stability: 0.7000785819631058
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 8
# True Negatives
# Average LIME Weights Stability: 0.2466025632085817
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.48661804949567117
# Average SHAP Weights Stability: 0.9999999999999999
# 6
# False Negatives
# Average LIME Weights Stability: 0.6284560066147313
# Average SHAP Weights Stability: 0.9999999999999999
# 4
# False Positives
# Average LIME Weights Stability: 0.4676042519355575
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 9
# True Negatives
# Average LIME Weights Stability: 0.7097225226676226
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.7547761636059681
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# False Negatives
# Average LIME Weights Stability: 0.01710420626384518
# Average SHAP Weights Stability: 0.9999999999999999
# 6
# False Positives
# Average LIME Weights Stability: 0.6683851260212115
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 10
# True Negatives
# Average LIME Weights Stability: 0.674793743387445
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.560278684290167
# Average SHAP Weights Stability: 0.9999999999999999
# 6
# False Negatives
# Average LIME Weights Stability: 0.7671679230713395
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# False Positives
# Average LIME Weights Stability: 0.7356093115024924
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 11
# True Negatives
# Average LIME Weights Stability: 0.7335121005619483
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.6413720375514314
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# False Negatives
# Average LIME Weights Stability: 0.7713378897519886
# Average SHAP Weights Stability: 0.9999999999999999
# 5
# False Positives
# Average LIME Weights Stability: 0.6570263832109433
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 12
# True Negatives
# Average LIME Weights Stability: 0.7635387264626273
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.8168046898131043
# Average SHAP Weights Stability: 0.9999999999999999
# 5
# False Negatives
# Average LIME Weights Stability: 0.7582512365216558
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# False Positives
# Average LIME Weights Stability: 0.6819348868757734
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 13
# True Negatives
# Average LIME Weights Stability: 0.741310448709475
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.7691511299570055
# Average SHAP Weights Stability: 0.9999999999999999
# 3
# False Negatives
# Average LIME Weights Stability: 0.7165376920915711
# Average SHAP Weights Stability: 0.9999999999999999
# 6
# False Positives
# Average LIME Weights Stability: 0.8042131126996901
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 14
# True Negatives
# Average LIME Weights Stability: 0.7415762615478365
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.817682918018931
# Average SHAP Weights Stability: 0.9999999999999999
# 4
# False Negatives
# Average LIME Weights Stability: 0.8034320211518373
# Average SHAP Weights Stability: 0.9999999999999999
# 4
# False Positives
# Average LIME Weights Stability: 0.7467943070930632
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 15
# True Negatives
# Average LIME Weights Stability: 0.7947311473278281
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# True Positives
# Average LIME Weights Stability: 0.49639817742638515
# Average SHAP Weights Stability: 0.9999999999999999
# 4
# False Negatives
# Average LIME Weights Stability: 0.8302586742708169
# Average SHAP Weights Stability: 0.9999999999999999
# 3
# False Positives
# Average LIME Weights Stability: 0.6852209302125373
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 16
# True Negatives
# Average LIME Weights Stability: 0.8091019333405783
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# False Negatives
# Average LIME Weights Stability: 0.8658509588109176
# Average SHAP Weights Stability: 0.9999999999999999
# 5
# False Positives
# Average LIME Weights Stability: 0.827586957742984
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 17
# True Negatives
# Average LIME Weights Stability: 0.8470498506243778
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# True Positives
# Average LIME Weights Stability: 0.721131616720349
# Average SHAP Weights Stability: 0.9999999999999998
# 1
# False Negatives
# Average LIME Weights Stability: 0.8353419374555763
# Average SHAP Weights Stability: 0.9999999999999998
# 4
# False Positives
# Average LIME Weights Stability: 0.7326410915595318
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 18
# True Negatives
# Average LIME Weights Stability: 0.8933958688529114
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# True Positives
# False Negatives
# Average LIME Weights Stability: 0.8945372082734924
# Average SHAP Weights Stability: 0.9999999999999998
# 2
# False Positives
# Average LIME Weights Stability: 0.8068571400990217
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 19
# True Negatives
# Average LIME Weights Stability: 0.8854071312562857
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# True Positives
# Average LIME Weights Stability: 0.9006622633319902
# Average SHAP Weights Stability: 0.9999999999999999
# 1
# False Negatives
# Average LIME Weights Stability: 0.9240885396218543
# Average SHAP Weights Stability: 0.9999999999999999
# 1
# False Positives
# Average LIME Weights Stability: 0.8037847549236737
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# Bucket 20
# True Negatives
# Average LIME Weights Stability: 0.8830667746802314
# Average SHAP Weights Stability: 0.9999999999999999
# 4
# True Positives
# False Negatives
# Average LIME Weights Stability: 0.784910380460131
# Average SHAP Weights Stability: 0.9999999999999999
# 2
# False Positives
# Average LIME Weights Stability: 0.7537140569561896
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 21
# True Negatives
# Average LIME Weights Stability: 0.9046886861325956
# Average SHAP Weights Stability: 0.9999999999999998
# 8
# True Positives
# False Negatives
# Average LIME Weights Stability: 0.8452906002646796
# Average SHAP Weights Stability: 0.9999999999999999
# 2
# False Positives
# Average LIME Weights Stability: 0.8890343142832066
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 22
# True Negatives
# Average LIME Weights Stability: 0.8394696533634616
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# True Positives
# False Negatives
# Average LIME Weights Stability: 0.8249627370978385
# Average SHAP Weights Stability: 0.9999999999999998
# 2
# False Positives
# Average LIME Weights Stability: 0.9202760300905818
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# Bucket 23
# True Negatives
# Average LIME Weights Stability: 0.8472056514398286
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# True Positives
# False Negatives
# Average LIME Weights Stability: 0.8504090323481834
# Average SHAP Weights Stability: 0.9999999999999999
# 2
# False Positives
# Average LIME Weights Stability: 0.7382367283478408
# Average SHAP Weights Stability: 0.9999999999999999
# 6
# Bucket 24
# True Negatives
# Average LIME Weights Stability: 0.7753774193554603
# Average SHAP Weights Stability: 0.9999999999999999
# 6
# True Positives
# False Negatives
# Average LIME Weights Stability: 0.9179243138877131
# Average SHAP Weights Stability: 0.9999999999999999
# 2
# False Positives
# Average LIME Weights Stability: 0.9040300710885733
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# Bucket 25
# True Negatives
# Average LIME Weights Stability: 0.838507915212762
# Average SHAP Weights Stability: 1.0
# 6
# True Positives
# False Negatives
# Average LIME Weights Stability: 0.9513103973397674
# Average SHAP Weights Stability: 0.9999999999999999
# 2
# False Positives
# Average LIME Weights Stability: 0.9167214351790238
# Average SHAP Weights Stability: 0.9999999999999999
# 7

# %%
sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.title("Sepsis Cases: Stability by Weight (LIME) \nPrefix-length Buckets with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.title("Sepsis Cases: Stability by Weight (SHAP) \nPrefix-length Buckets with Aggregate Encoding")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("Prefix length and stability by index \n Prefix-Length Bucket with Aggregate Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("Prediction probability and stability by index \n Prefix-Length Bucket with Aggregate Encoding")
plt.show()

# %%
lime_mean = np.mean(all_lime_stab)
lime_std = np.std(all_lime_stab)
lime_upper = lime_mean + (3*lime_std)
lime_lower = lime_mean - (3*lime_std)

shap_mean = np.mean(all_shap_stab)
shap_std = np.std(all_shap_stab)
shap_upper = shap_mean + (3*shap_std)
shap_lower = shap_mean - (3*shap_std)

lime_outliers = [i for i in all_lime_stab if i > lime_upper or i < lime_lower]
shap_outliers = [i for i in all_shap_stab if i > shap_upper or i < shap_lower]

print (lime_mean)
print (shap_mean)
print(len(lime_outliers))
print(len(shap_outliers))
print(str(len(lime_outliers)/len(all_lime_stab)*100)+"%")
print(str(len(shap_outliers)/len(all_shap_stab)*100)+"%")
# Out:
# 0.6332039517834133
# 1.0
# 7
# 0
# 1.0510510510510511%
# 0.0%

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens), key=lambda x: x[3])
all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.ylim(lime_lower, 1.1)
plt.title("Sepsis Cases: Stability by Weight (LIME) \nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_weight_stability.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.ylim(lime_lower, 1.1)
plt.title("Sesis Cases: Stability by Weight (SHAP) \nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_weight_stability.png", bbox_inches = "tight")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(lime_lower, 1)
plt.title("Prefix length and stability by weight \n Single Bucket with Aggregate Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(lime_lower,1)
plt.title("Prefix length and stability by weight \n Single Bucket with Aggregate Encoding")
plt.show()

# %%
# bins = np.arange(0, shap_upper+1e-17, 1e-17)
# yticks = np.arange(0, 80, 10)
# #sns.set_style("white")
# plt.subplots(figsize=(20, 15))
# plt.hist(all_shap_stab, bins = bins)
# #plt.figsize([50, 50])
# plt.xticks(bins, fontsize = 8)
# plt.yticks(yticks, fontsize = 12)
# plt.title("Distribution of SHAP Stability by Weight", fontsize = 16)
# plt.xlabel("Stability Range", fontsize = 14)
# plt.ylabel("Frequency", fontsize = 14)
# plt.show()

# %%
# bins = np.arange(0, lime_upper+0.1, 0.2)
# yticks = np.arange(0, 720, 20)
# #sns.set_style("white")
# plt.subplots(figsize=(20, 10))
# plt.hist(all_lime_stab, bins = bins)
# #plt.figsize([50, 50])
# plt.xticks(bins, fontsize = 12)
# plt.yticks(yticks, fontsize = 12)
# plt.title("Distribution of LIME Stability by Weight", fontsize = 16)
# plt.xlabel("Stability Range", fontsize = 14)
# plt.ylabel("Frequency", fontsize = 14)
# plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []

sep_caseID = [[],[],[],[]]
sep_lengths = [[],[],[],[]]
sep_proba = [[],[],[],[]]

all_lime_diffs = []
all_shap_diffs = []

sep_lime_diffs = [[],[],[],[]]
sep_shap_diffs = [[],[],[],[]]

all_lime_MSE = []
all_lime_RMSE = []
all_lime_MAE = []
all_lime_MAPE = []

sep_lime_MSE = [[],[],[],[]]
sep_lime_RMSE = [[],[],[],[]]
sep_lime_MAE = [[],[],[],[]]
sep_lime_MAPE = [[],[],[],[]]

all_shap_MSE = []
all_shap_RMSE = []
all_shap_MAE = []
all_shap_MAPE = []

sep_shap_MSE = [[],[],[],[]]
sep_shap_RMSE = [[],[],[],[]]
sep_shap_MAE = [[],[],[],[]]
sep_shap_MAPE = [[],[],[],[]]

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i]!=[]:
                    data = pd.DataFrame.from_records(sample_instances[i])

                    lime_MSE = []
                    lime_RMSE = []
                    lime_MAE = []
                    lime_MAPE = []

                    shap_MSE = []
                    shap_RMSE = []
                    shap_MAE = []
                    shap_MAPE = []

                    case_id = pd.Series(data['caseID'])
                    nr_events = pd.Series(data['nr_events'])
                    proba = pd.Series(data['proba'])
                    lime_diffs = pd.Series(data['lime_fid_change'])
                    shap_diffs = pd.Series(data['shap_fid_change'])

                    for j in range(len(lime_diffs)):
                        p1 = proba[j]

                        lime_diff = lime_diffs[j]
                        shap_diff = shap_diffs[j]

                        all_lime_diffs.append(lime_diff)
                        all_shap_diffs.append(shap_diff)

                        lime_sq_changes = []
                        lime_abs_changes = []
                        lime_rel_changes = []

                        shap_sq_changes = []
                        shap_abs_changes = []
                        shap_rel_changes = []

                        for each in lime_diff:
                            lime_sq_changes.append(each**2)
                            lime_abs_changes.append(abs(each))
                            lime_rel_changes.append(abs(each)/p1)

                        for each in shap_diff:
                            shap_sq_changes.append(each**2)
                            shap_abs_changes.append(abs(each))
                            shap_rel_changes.append(abs(each)/p1)

                        lime_MSE.append(sum(lime_sq_changes)/len(lime_sq_changes))
                        lime_RMSE.append(math.sqrt(sum(lime_sq_changes)/len(lime_sq_changes)))
                        lime_MAE.append(sum(lime_abs_changes)/len(lime_abs_changes))
                        lime_MAPE.append(sum(lime_rel_changes)/len(lime_rel_changes))

                        shap_MSE.append(sum(shap_sq_changes)/len(shap_sq_changes))
                        shap_RMSE.append(math.sqrt(sum(shap_sq_changes)/len(shap_sq_changes)))
                        shap_MAE.append(sum(shap_abs_changes)/len(shap_abs_changes))
                        shap_MAPE.append(sum(shap_rel_changes)/len(shap_rel_changes))

                    all_caseID.extend(case_id)
                    all_lengths.extend(nr_events)
                    all_proba.extend(proba)

                    all_lime_MSE.extend(lime_MSE)
                    all_lime_RMSE.extend(lime_RMSE)
                    all_lime_MAE.extend(lime_MAE)
                    all_lime_MAPE.extend(lime_MAPE)

                    all_shap_MSE.extend(shap_MSE)
                    all_shap_RMSE.extend(shap_RMSE)
                    all_shap_MAE.extend(shap_MAE)
                    all_shap_MAPE.extend(shap_MAPE)

                    sep_caseID[i].extend(case_id)
                    sep_lengths[i].extend(nr_events)
                    sep_proba[i].extend(proba)

                    sep_lime_MSE[i].extend(lime_MSE)
                    sep_lime_RMSE[i].extend(lime_RMSE)
                    sep_lime_MAE[i].extend(lime_MAE)
                    sep_lime_MAPE[i].extend(lime_MAPE)

                    sep_shap_MSE[i].extend(shap_MSE)
                    sep_shap_RMSE[i].extend(shap_RMSE)
                    sep_shap_MAE[i].extend(shap_MAE)
                    sep_shap_MAPE[i].extend(shap_MAPE)

                    print("Average LIME MSE:", statistics.mean(lime_MSE))
                    print("Average SHAP MSE:", statistics.mean(shap_MSE))
                    print("\n")

                    #plt.plot(nr_events, lime_MSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_MSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    ##plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_MSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_MSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MSE \n"+type_list[i])
                    #plt.show()

                    print("Average LIME RMSE:", statistics.mean(lime_RMSE))
                    print("Average SHAP RMSE:", statistics.mean(shap_RMSE))
                    print("\n")

                    #plt.plot(nr_events, lime_RMSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and RMSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_RMSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and RMSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_RMSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and RMSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_RMSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and RMSE \n"+type_list[i])
                    #plt.show()

                    print("Average LIME MAE:", statistics.mean(lime_MAE))
                    print("Average SHAP MAE:", statistics.mean(shap_MAE))
                    print("\n")

                    #plt.plot(nr_events, lime_MAE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_MAE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_MAE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_MAE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAE \n"+type_list[i])
                    #plt.show()

                    print("Average LIME MAPE:", statistics.mean(lime_MAPE))
                    print("Average SHAP MAPE:", statistics.mean(shap_MAPE))
                    print("\n")

                    #plt.plot(nr_events, lime_MAPE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAPE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_MAPE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAPE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_MAPE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAPE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_MAPE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAPE \n"+type_list[i])
                    #plt.show()
# Out:
# Bucket 1
# True Negatives
# Average LIME MSE: 0.0674923463598226
# Average SHAP MSE: 0.2839744335926579
#
#
# Average LIME RMSE: 0.2248677409611952
# Average SHAP RMSE: 0.47457310008797143
#
#
# Average LIME MAE: 0.18951675787568092
# Average SHAP MAE: 0.4663698662817478
#
#
# Average LIME MAPE: 0.2710970308456193
# Average SHAP MAPE: 0.5838253996838748
#
#
# True Positives
# Average LIME MSE: 0.11199393651149615
# Average SHAP MSE: 0.0998138622006672
#
#
# Average LIME RMSE: 0.31434858711601954
# Average SHAP RMSE: 0.27476795271713506
#
#
# Average LIME MAE: 0.3021426087617874
# Average SHAP MAE: 0.26998104035854337
#
#
# Average LIME MAPE: 0.36591976542020943
# Average SHAP MAPE: 0.3065632963093428
#
#
# False Negatives
# Average LIME MSE: 0.04368344012606832
# Average SHAP MSE: 0.34197132071303116
#
#
# Average LIME RMSE: 0.17777308565855224
# Average SHAP RMSE: 0.4787434075670891
#
#
# Average LIME MAE: 0.17107049956917764
# Average SHAP MAE: 0.4713201978802681
#
#
# Average LIME MAPE: 0.27613367152343593
# Average SHAP MAPE: 0.5585051621325683
#
#
# False Positives
# Average LIME MSE: 0.1479208061120527
# Average SHAP MSE: 0.2743111309794785
#
#
# Average LIME RMSE: 0.32444622546670104
# Average SHAP RMSE: 0.4439366627515894
#
#
# Average LIME MAE: 0.3043901482224464
# Average SHAP MAE: 0.43821267545223236
#
#
# Average LIME MAPE: 0.39650640110149915
# Average SHAP MAPE: 0.5571671362322944
#
#
# Bucket 2
# True Negatives
# Average LIME MSE: 0.10764940716357044
# Average SHAP MSE: 0.25859278167438093
#
#
# Average LIME RMSE: 0.262810340695998
# Average SHAP RMSE: 0.4419489984293687
#
#
# Average LIME MAE: 0.23648016966879368
# Average SHAP MAE: 0.4281979883462191
#
#
# Average LIME MAPE: 0.3183259366420251
# Average SHAP MAPE: 0.5403292263000866
#
#
# True Positives
# Average LIME MSE: 0.09389655308599822
# Average SHAP MSE: 0.1256031208945828
#
#
# Average LIME RMSE: 0.2622798672478629
# Average SHAP RMSE: 0.32774394322135264
#
#
# Average LIME MAE: 0.23939429273207982
# Average SHAP MAE: 0.3065591151515643
#
#
# Average LIME MAPE: 0.27876784978217645
# Average SHAP MAPE: 0.3862720306482455
#
#
# False Negatives
# Average LIME MSE: 0.12656573624085662
# Average SHAP MSE: 0.184694678092485
#
#
# Average LIME RMSE: 0.31160393407024534
# Average SHAP RMSE: 0.4023639559861069
#
#
# Average LIME MAE: 0.28213490982140815
# Average SHAP MAE: 0.3898708689425673
#
#
# Average LIME MAPE: 0.34446720448415635
# Average SHAP MAPE: 0.4883439928995875
#
#
# False Positives
# Average LIME MSE: 0.0943301485595125
# Average SHAP MSE: 0.11757052003270836
#
#
# Average LIME RMSE: 0.2788333461540478
# Average SHAP RMSE: 0.27946436721607393
#
#
# Average LIME MAE: 0.24343423187732696
# Average SHAP MAE: 0.26774496108293533
#
#
# Average LIME MAPE: 0.31330679916687265
# Average SHAP MAPE: 0.3521394162471617
#
#
# Bucket 3
# True Negatives
# Average LIME MSE: 0.05664454353874935
# Average SHAP MSE: 0.2519559535781198
#
#
# Average LIME RMSE: 0.22832195636090438
# Average SHAP RMSE: 0.42613104870414115
#
#
# Average LIME MAE: 0.20162270113825798
# Average SHAP MAE: 0.4253804223239422
#
#
# Average LIME MAPE: 0.3039410884725141
# Average SHAP MAPE: 0.5635226583210424
#
#
# True Positives
# Average LIME MSE: 0.09475862752094694
# Average SHAP MSE: 0.22596624640175955
#
#
# Average LIME RMSE: 0.259565114953857
# Average SHAP RMSE: 0.380865797193731
#
#
# Average LIME MAE: 0.22604873989309585
# Average SHAP MAE: 0.37581472183976855
#
#
# Average LIME MAPE: 0.2871195611113769
# Average SHAP MAPE: 0.4593819597662494
#
#
# False Negatives
# Average LIME MSE: 0.12515639666320696
# Average SHAP MSE: 0.22339166631232776
#
#
# Average LIME RMSE: 0.3167525866858485
# Average SHAP RMSE: 0.43786789197290443
#
#
# Average LIME MAE: 0.26145766687889893
# Average SHAP MAE: 0.42612316124141214
#
#
# Average LIME MAPE: 0.3219043006936435
# Average SHAP MAPE: 0.5195355807534742
#
#
# False Positives
# Average LIME MSE: 0.23875119719196458
# Average SHAP MSE: 0.14977155070646886
#
#
# Average LIME RMSE: 0.4493862065732347
# Average SHAP RMSE: 0.31649175629157333
#
#
# Average LIME MAE: 0.4226036101579666
# Average SHAP MAE: 0.30712914347648623
#
#
# Average LIME MAPE: 0.5540789976036442
# Average SHAP MAPE: 0.41028785647930927
#
#
# Bucket 4
# True Negatives
# Average LIME MSE: 0.04630991689189103
# Average SHAP MSE: 0.32741582396065144
#
#
# Average LIME RMSE: 0.20796856244223277
# Average SHAP RMSE: 0.538534154201934
#
#
# Average LIME MAE: 0.1901177853345871
# Average SHAP MAE: 0.5324237120151519
#
#
# Average LIME MAPE: 0.2648185473902761
# Average SHAP MAPE: 0.6899698454124313
#
#
# True Positives
# Average LIME MSE: 0.12404693333318798
# Average SHAP MSE: 0.03072672720145029
#
#
# Average LIME RMSE: 0.3211262603598148
# Average SHAP RMSE: 0.1554485023222496
#
#
# Average LIME MAE: 0.2980138663734708
# Average SHAP MAE: 0.14507422702653067
#
#
# Average LIME MAPE: 0.4379655243996785
# Average SHAP MAPE: 0.20247643157782247
#
#
# False Negatives
# Average LIME MSE: 0.04587858218671891
# Average SHAP MSE: 0.22508964899569567
#
#
# Average LIME RMSE: 0.1906733768776334
# Average SHAP RMSE: 0.44513706835146366
#
#
# Average LIME MAE: 0.16929792123181478
# Average SHAP MAE: 0.43318102178829054
#
#
# Average LIME MAPE: 0.24178927598924732
# Average SHAP MAPE: 0.5636185116265563
#
#
# False Positives
# Average LIME MSE: 0.15731653441786275
# Average SHAP MSE: 0.08881490353141111
#
#
# Average LIME RMSE: 0.37096076829888797
# Average SHAP RMSE: 0.26593145077459895
#
#
# Average LIME MAE: 0.34096125602722166
# Average SHAP MAE: 0.2572948810458183
#
#
# Average LIME MAPE: 0.44753971495179534
# Average SHAP MAPE: 0.34735386644918437
#
#
# Bucket 5
# True Negatives
# Average LIME MSE: 0.03219743019637267
# Average SHAP MSE: 0.08801176566324642
#
#
# Average LIME RMSE: 0.1640204927799037
# Average SHAP RMSE: 0.2698817014298065
#
#
# Average LIME MAE: 0.14508310958743095
# Average SHAP MAE: 0.25414572477340697
#
#
# Average LIME MAPE: 0.22577976739358763
# Average SHAP MAPE: 0.3768235829135462
#
#
# True Positives
# Average LIME MSE: 0.10693423324393632
# Average SHAP MSE: 0.29220048373699925
#
#
# Average LIME RMSE: 0.2522621465739394
# Average SHAP RMSE: 0.5098391541137236
#
#
# Average LIME MAE: 0.22329105399549007
# Average SHAP MAE: 0.49474592246115207
#
#
# Average LIME MAPE: 0.27434930329645474
# Average SHAP MAPE: 0.6217685982103922
#
#
# False Negatives
# Average LIME MSE: 0.09543429855337202
# Average SHAP MSE: 0.20176469677932932
#
#
# Average LIME RMSE: 0.2707448998419462
# Average SHAP RMSE: 0.4137160379640694
#
#
# Average LIME MAE: 0.2587247556075454
# Average SHAP MAE: 0.3872144838795066
#
#
# Average LIME MAPE: 0.2944751114293794
# Average SHAP MAPE: 0.48861941361383165
#
#
# False Positives
# Average LIME MSE: 0.061073277727439985
# Average SHAP MSE: 0.11510642053624338
#
#
# Average LIME RMSE: 0.2369852754865326
# Average SHAP RMSE: 0.30398802061460367
#
#
# Average LIME MAE: 0.20493105292320252
# Average SHAP MAE: 0.28512339532375336
#
#
# Average LIME MAPE: 0.28310377169756396
# Average SHAP MAPE: 0.38252557084196565
#
#
# Bucket 6
# True Negatives
# Average LIME MSE: 0.1416609115426217
# Average SHAP MSE: 0.2868707244673645
#
#
# Average LIME RMSE: 0.3443524623222954
# Average SHAP RMSE: 0.5136355065866355
#
#
# Average LIME MAE: 0.301232617944479
# Average SHAP MAE: 0.5003188733756542
#
#
# Average LIME MAPE: 0.393233133517066
# Average SHAP MAPE: 0.6791817825595683
#
#
# True Positives
# Average LIME MSE: 0.05757093794892561
# Average SHAP MSE: 0.07217248795868778
#
#
# Average LIME RMSE: 0.2225663237617664
# Average SHAP RMSE: 0.23083740027776506
#
#
# Average LIME MAE: 0.1815517944949014
# Average SHAP MAE: 0.22024423565183365
#
#
# Average LIME MAPE: 0.22427503361739484
# Average SHAP MAPE: 0.2753950835622973
#
#
# False Negatives
# Average LIME MSE: 0.2372053721367907
# Average SHAP MSE: 0.16797410017660278
#
#
# Average LIME RMSE: 0.4294333429620847
# Average SHAP RMSE: 0.3668981493778146
#
#
# Average LIME MAE: 0.3828341545164585
# Average SHAP MAE: 0.35816523909568787
#
#
# Average LIME MAPE: 0.4641949191810701
# Average SHAP MAPE: 0.41829946864901046
#
#
# False Positives
# Average LIME MSE: 0.10283579834424433
# Average SHAP MSE: 0.09034347124170226
#
#
# Average LIME RMSE: 0.3037915475184313
# Average SHAP RMSE: 0.2525275066764154
#
#
# Average LIME MAE: 0.2647025993466377
# Average SHAP MAE: 0.24079273879528046
#
#
# Average LIME MAPE: 0.3647630504331402
# Average SHAP MAPE: 0.32604646431772755
#
#
# Bucket 7
# True Negatives
# Average LIME MSE: 0.1370101833302267
# Average SHAP MSE: 0.33747139730956227
#
#
# Average LIME RMSE: 0.3244670149501234
# Average SHAP RMSE: 0.558204327347432
#
#
# Average LIME MAE: 0.302164361551404
# Average SHAP MAE: 0.5522505820542574
#
#
# Average LIME MAPE: 0.4040869943788774
# Average SHAP MAPE: 0.7313873677259924
#
#
# True Positives
# Average LIME MSE: 0.048806503500789016
# Average SHAP MSE: 0.07272903012090304
#
#
# Average LIME RMSE: 0.19820892876597543
# Average SHAP RMSE: 0.22152271063119167
#
#
# Average LIME MAE: 0.17594314089843205
# Average SHAP MAE: 0.21480461827346256
#
#
# Average LIME MAPE: 0.25325022731750074
# Average SHAP MAPE: 0.3223448290854967
#
#
# False Negatives
# Average LIME MSE: 0.05383911436088753
# Average SHAP MSE: 0.29437964810701267
#
#
# Average LIME RMSE: 0.21761885422393495
# Average SHAP RMSE: 0.48730377148907256
#
#
# Average LIME MAE: 0.184353943169117
# Average SHAP MAE: 0.4844421257575353
#
#
# Average LIME MAPE: 0.2747531490352642
# Average SHAP MAPE: 0.6382559002374683
#
#
# False Positives
# Average LIME MSE: 0.049205208175268716
# Average SHAP MSE: 0.03575598653130694
#
#
# Average LIME RMSE: 0.19847300026663203
# Average SHAP RMSE: 0.17801429763680066
#
#
# Average LIME MAE: 0.18116353064775467
# Average SHAP MAE: 0.17481810748577117
#
#
# Average LIME MAPE: 0.24463365298412865
# Average SHAP MAPE: 0.25370682402647543
#
#
# Bucket 8
# True Negatives
# Average LIME MSE: 0.112933203608709
# Average SHAP MSE: 0.28380271020026426
#
#
# Average LIME RMSE: 0.2726285900617187
# Average SHAP RMSE: 0.47784640548739116
#
#
# Average LIME MAE: 0.2536424794793129
# Average SHAP MAE: 0.4703773372992873
#
#
# Average LIME MAPE: 0.3573814427287468
# Average SHAP MAPE: 0.6157020541132172
#
#
# True Positives
# Average LIME MSE: 0.11495655313931795
# Average SHAP MSE: 0.04812571839794402
#
#
# Average LIME RMSE: 0.30617884353266767
# Average SHAP RMSE: 0.20089687563073175
#
#
# Average LIME MAE: 0.27360859016577405
# Average SHAP MAE: 0.17608797252178193
#
#
# Average LIME MAPE: 0.36239358525394816
# Average SHAP MAPE: 0.2411621632425673
#
#
# False Negatives
# Average LIME MSE: 0.07713892949719775
# Average SHAP MSE: 0.5938374149737362
#
#
# Average LIME RMSE: 0.24791131921572704
# Average SHAP RMSE: 0.7635000053773076
#
#
# Average LIME MAE: 0.21327321939170363
# Average SHAP MAE: 0.7615895871073007
#
#
# Average LIME MAPE: 0.2571732703323549
# Average SHAP MAPE: 0.9235994833666802
#
#
# False Positives
# Average LIME MSE: 0.05674930061298931
# Average SHAP MSE: 0.07842572683674262
#
#
# Average LIME RMSE: 0.19638009459749708
# Average SHAP RMSE: 0.22857112075442138
#
#
# Average LIME MAE: 0.1795100101828575
# Average SHAP MAE: 0.21914901673793794
#
#
# Average LIME MAPE: 0.27508997843434824
# Average SHAP MAPE: 0.29778340830952293
#
#
# Bucket 9
# True Negatives
# Average LIME MSE: 0.13633460069618214
# Average SHAP MSE: 0.5433051232113985
#
#
# Average LIME RMSE: 0.3365996124954573
# Average SHAP RMSE: 0.7212127940848878
#
#
# Average LIME MAE: 0.31913757126778364
# Average SHAP MAE: 0.7210714749619365
#
#
# Average LIME MAPE: 0.428812570740513
# Average SHAP MAPE: 0.9607173217646491
#
#
# True Positives
# Average LIME MSE: 0.07430155828427608
# Average SHAP MSE: 0.04490569872599794
#
#
# Average LIME RMSE: 0.23185298979406474
# Average SHAP RMSE: 0.16328164076565924
#
#
# Average LIME MAE: 0.2087638533777661
# Average SHAP MAE: 0.16070708632469177
#
#
# Average LIME MAPE: 0.2825646945213316
# Average SHAP MAPE: 0.2509406844567838
#
#
# False Negatives
# Average LIME MSE: 0.06588308876451578
# Average SHAP MSE: 0.545306079283652
#
#
# Average LIME RMSE: 0.23404800077597024
# Average SHAP RMSE: 0.7219249725213621
#
#
# Average LIME MAE: 0.21027521478633085
# Average SHAP MAE: 0.7217252710213263
#
#
# Average LIME MAPE: 0.27572814265052237
# Average SHAP MAPE: 0.935168907830077
#
#
# False Positives
# Average LIME MSE: 0.04425121568113042
# Average SHAP MSE: 0.057291256138029496
#
#
# Average LIME RMSE: 0.1910426109405653
# Average SHAP RMSE: 0.18573241832140427
#
#
# Average LIME MAE: 0.16101550877094267
# Average SHAP MAE: 0.1813218331336975
#
#
# Average LIME MAPE: 0.22838316759522825
# Average SHAP MAPE: 0.2835451407299774
#
#
# Bucket 10
# True Negatives
# Average LIME MSE: 0.06470674826787993
# Average SHAP MSE: 0.24982256559719357
#
#
# Average LIME RMSE: 0.22581134453065713
# Average SHAP RMSE: 0.439977483138527
#
#
# Average LIME MAE: 0.19561691090464592
# Average SHAP MAE: 0.4264946453273296
#
#
# Average LIME MAPE: 0.26745886299170124
# Average SHAP MAPE: 0.5755193776345128
#
#
# True Positives
# Average LIME MSE: 0.1498974577906502
# Average SHAP MSE: 0.11742206990990159
#
#
# Average LIME RMSE: 0.36350256484676147
# Average SHAP RMSE: 0.26215316603161753
#
#
# Average LIME MAE: 0.3355219225088755
# Average SHAP MAE: 0.24827688535054523
#
#
# Average LIME MAPE: 0.4158482783913096
# Average SHAP MAPE: 0.31557113510496465
#
#
# False Negatives
# Average LIME MSE: 0.04059552448206128
# Average SHAP MSE: 0.23348022339903732
#
#
# Average LIME RMSE: 0.1815314986686174
# Average SHAP RMSE: 0.4429642346212379
#
#
# Average LIME MAE: 0.1558383176724116
# Average SHAP MAE: 0.4337165617280536
#
#
# Average LIME MAPE: 0.23994900888644935
# Average SHAP MAPE: 0.5757119291819147
#
#
# False Positives
# Average LIME MSE: 0.11910058862636325
# Average SHAP MSE: 0.11489161726513199
#
#
# Average LIME RMSE: 0.3015519797845717
# Average SHAP RMSE: 0.28744894080044114
#
#
# Average LIME MAE: 0.26615853250026705
# Average SHAP MAE: 0.2728644132614136
#
#
# Average LIME MAPE: 0.3405630984743618
# Average SHAP MAPE: 0.3561941224147354
#
#
# Bucket 11
# True Negatives
# Average LIME MSE: 0.04474755525619542
# Average SHAP MSE: 0.4077395187794938
#
#
# Average LIME RMSE: 0.17655554038349
# Average SHAP RMSE: 0.6142149880948575
#
#
# Average LIME MAE: 0.160900991410017
# Average SHAP MAE: 0.6117116098105907
#
#
# Average LIME MAPE: 0.22200109891201072
# Average SHAP MAPE: 0.8112801917073612
#
#
# True Positives
# Average LIME MSE: 0.2280698535554465
# Average SHAP MSE: 0.024513925340025784
#
#
# Average LIME RMSE: 0.46878394472301615
# Average SHAP RMSE: 0.14777696678781038
#
#
# Average LIME MAE: 0.4345758748905999
# Average SHAP MAE: 0.13772318150315965
#
#
# Average LIME MAPE: 0.5815518321550157
# Average SHAP MAPE: 0.18575113109584998
#
#
# False Negatives
# Average LIME MSE: 0.039996849626847485
# Average SHAP MSE: 0.3239239011785916
#
#
# Average LIME RMSE: 0.16814666915431775
# Average SHAP RMSE: 0.5084226261148846
#
#
# Average LIME MAE: 0.14574324183166026
# Average SHAP MAE: 0.5015370348840952
#
#
# Average LIME MAPE: 0.21108306620751158
# Average SHAP MAPE: 0.6170352267346263
#
#
# False Positives
# Average LIME MSE: 0.18328643083120777
# Average SHAP MSE: 0.05108728302088154
#
#
# Average LIME RMSE: 0.3614800470293083
# Average SHAP RMSE: 0.20239400918659664
#
#
# Average LIME MAE: 0.33590025842189786
# Average SHAP MAE: 0.19671418517827988
#
#
# Average LIME MAPE: 0.429233209364276
# Average SHAP MAPE: 0.2748583226665591
#
#
# Bucket 12
# True Negatives
# Average LIME MSE: 0.14454883282634898
# Average SHAP MSE: 0.4407824903228675
#
#
# Average LIME RMSE: 0.3010988766235269
# Average SHAP RMSE: 0.6405621842266525
#
#
# Average LIME MAE: 0.2791413726657629
# Average SHAP MAE: 0.6386949845403432
#
#
# Average LIME MAPE: 0.3746835040531143
# Average SHAP MAPE: 0.8522745454717888
#
#
# True Positives
# Average LIME MSE: 0.13884908246310962
# Average SHAP MSE: 0.0419830467668244
#
#
# Average LIME RMSE: 0.33982971390853145
# Average SHAP RMSE: 0.1916545196243238
#
#
# Average LIME MAE: 0.32048926532268524
# Average SHAP MAE: 0.18372712850570677
#
#
# Average LIME MAPE: 0.4365948443608809
# Average SHAP MAPE: 0.2650619230452753
#
#
# False Negatives
# Average LIME MSE: 0.07851864150582895
# Average SHAP MSE: 0.38861615890965806
#
#
# Average LIME RMSE: 0.2552081546786792
# Average SHAP RMSE: 0.5906683865797042
#
#
# Average LIME MAE: 0.23370001520961523
# Average SHAP MAE: 0.5741719027981163
#
#
# Average LIME MAPE: 0.3140086931596282
# Average SHAP MAPE: 0.7500489134603238
#
#
# False Positives
# Average LIME MSE: 0.11940546841616861
# Average SHAP MSE: 0.15395612506595663
#
#
# Average LIME RMSE: 0.31766527208355794
# Average SHAP RMSE: 0.3174851849012354
#
#
# Average LIME MAE: 0.2914317148923874
# Average SHAP MAE: 0.30721099317073824
#
#
# Average LIME MAPE: 0.3847140279491243
# Average SHAP MAPE: 0.4160560119927819
#
#
# Bucket 13
# True Negatives
# Average LIME MSE: 0.03363717315622923
# Average SHAP MSE: 0.4614811332036983
#
#
# Average LIME RMSE: 0.16146381263177095
# Average SHAP RMSE: 0.6635993332368326
#
#
# Average LIME MAE: 0.14522331207990646
# Average SHAP MAE: 0.6628899894654751
#
#
# Average LIME MAPE: 0.2124243555153159
# Average SHAP MAPE: 0.8941813664279534
#
#
# True Positives
# Average LIME MSE: 0.08176547875986022
# Average SHAP MSE: 0.13565882313941435
#
#
# Average LIME RMSE: 0.2836447812134982
# Average SHAP RMSE: 0.3404713238876794
#
#
# Average LIME MAE: 0.26610157589117683
# Average SHAP MAE: 0.33172676463921863
#
#
# Average LIME MAPE: 0.43581251094622053
# Average SHAP MAPE: 0.5511506348584669
#
#
# False Negatives
# Average LIME MSE: 0.058770595480622745
# Average SHAP MSE: 0.5315213835527796
#
#
# Average LIME RMSE: 0.2191889056761032
# Average SHAP RMSE: 0.7070422245923053
#
#
# Average LIME MAE: 0.20425463703771432
# Average SHAP MAE: 0.7064964983612299
#
#
# Average LIME MAPE: 0.2715970538664407
# Average SHAP MAPE: 0.9043981124393313
#
#
# False Positives
# Average LIME MSE: 0.17411766660516806
# Average SHAP MSE: 0.07759767367622217
#
#
# Average LIME RMSE: 0.3899978316013514
# Average SHAP RMSE: 0.23432298687289976
#
#
# Average LIME MAE: 0.3706987711787224
# Average SHAP MAE: 0.22863918870687486
#
#
# Average LIME MAPE: 0.4932583133010958
# Average SHAP MAPE: 0.33526326014718194
#
#
# Bucket 14
# True Negatives
# Average LIME MSE: 0.0518923664415531
# Average SHAP MSE: 0.2992802836152265
#
#
# Average LIME RMSE: 0.20614036355980575
# Average SHAP RMSE: 0.47486642106753996
#
#
# Average LIME MAE: 0.18790263712406158
# Average SHAP MAE: 0.4697923544049263
#
#
# Average LIME MAPE: 0.27497833273934036
# Average SHAP MAPE: 0.598905801146552
#
#
# True Positives
# Average LIME MSE: 0.263055752056271
# Average SHAP MSE: 0.2543800169938812
#
#
# Average LIME RMSE: 0.48373139798468057
# Average SHAP RMSE: 0.43405011865820564
#
#
# Average LIME MAE: 0.46630820557475094
# Average SHAP MAE: 0.42724378928542134
#
#
# Average LIME MAPE: 0.6203665271188065
# Average SHAP MAPE: 0.5455772879974334
#
#
# False Negatives
# Average LIME MSE: 0.07584103453855787
# Average SHAP MSE: 0.15576984715794462
#
#
# Average LIME RMSE: 0.2556176999597964
# Average SHAP RMSE: 0.3301487418610389
#
#
# Average LIME MAE: 0.22906696200370788
# Average SHAP MAE: 0.3148710086941719
#
#
# Average LIME MAPE: 0.35102944858157714
# Average SHAP MAPE: 0.41712727626018586
#
#
# False Positives
# Average LIME MSE: 0.2548843849054995
# Average SHAP MSE: 0.1521694746502829
#
#
# Average LIME RMSE: 0.4778214685339422
# Average SHAP RMSE: 0.3197924079679067
#
#
# Average LIME MAE: 0.45845252990722657
# Average SHAP MAE: 0.3066535595059395
#
#
# Average LIME MAPE: 0.6139988292965965
# Average SHAP MAPE: 0.38261270115568313
#
#
# Bucket 15
# True Negatives
# Average LIME MSE: 0.2651206082233111
# Average SHAP MSE: 0.2717384325945669
#
#
# Average LIME RMSE: 0.47233511073371914
# Average SHAP RMSE: 0.4327709632483469
#
#
# Average LIME MAE: 0.4487860531028774
# Average SHAP MAE: 0.4286303729232815
#
#
# Average LIME MAPE: 0.5806380751181713
# Average SHAP MAPE: 0.5295899759270767
#
#
# True Positives
# Average LIME MSE: 0.05668735123325872
# Average SHAP MSE: 0.251992058344786
#
#
# Average LIME RMSE: 0.2133420803466755
# Average SHAP RMSE: 0.4728455546176366
#
#
# Average LIME MAE: 0.18297817409038544
# Average SHAP MAE: 0.46953861489892007
#
#
# Average LIME MAPE: 0.27753463244983456
# Average SHAP MAPE: 0.6291323779295828
#
#
# False Negatives
# Average LIME MSE: 0.024466720942491887
# Average SHAP MSE: 0.0717767527977716
#
#
# Average LIME RMSE: 0.15355256801655978
# Average SHAP RMSE: 0.21736180195644866
#
#
# Average LIME MAE: 0.11366056216259797
# Average SHAP MAE: 0.2061006626735131
#
#
# Average LIME MAPE: 0.14352389966842802
# Average SHAP MAPE: 0.23361356240395226
#
#
# False Positives
# Average LIME MSE: 0.06971673833351531
# Average SHAP MSE: 0.1284328464496308
#
#
# Average LIME RMSE: 0.24354232876290627
# Average SHAP RMSE: 0.29190961305758906
#
#
# Average LIME MAE: 0.2079829216003418
# Average SHAP MAE: 0.2849461105465889
#
#
# Average LIME MAPE: 0.2794357579041778
# Average SHAP MAPE: 0.3798461909644107
#
#
# Bucket 16
# True Negatives
# Average LIME MSE: 0.2972970092966938
# Average SHAP MSE: 0.14548141625136865
#
#
# Average LIME RMSE: 0.4974248038924795
# Average SHAP RMSE: 0.32352626822562797
#
#
# Average LIME MAE: 0.4745382023602724
# Average SHAP MAE: 0.31097201295197013
#
#
# Average LIME MAPE: 0.6038813736553665
# Average SHAP MAPE: 0.40759645813331136
#
#
# True Positives
# False Negatives
# Average LIME MSE: 0.12826684835318014
# Average SHAP MSE: 0.06754801345686436
#
#
# Average LIME RMSE: 0.29052240546416475
# Average SHAP RMSE: 0.2289652502171216
#
#
# Average LIME MAE: 0.257403684258461
# Average SHAP MAE: 0.2212878066301346
#
#
# Average LIME MAPE: 0.3422233054245995
# Average SHAP MAPE: 0.3181903041409085
#
#
# False Positives
# Average LIME MSE: 0.07794802007874843
# Average SHAP MSE: 0.3030232262704024
#
#
# Average LIME RMSE: 0.23970379217220583
# Average SHAP RMSE: 0.5296548098052138
#
#
# Average LIME MAE: 0.21045169860124588
# Average SHAP MAE: 0.5212285354733467
#
#
# Average LIME MAPE: 0.2831785828766324
# Average SHAP MAPE: 0.6945995323054666
#
#
# Bucket 17
# True Negatives
# Average LIME MSE: 0.052611332917833195
# Average SHAP MSE: 0.21988144828904246
#
#
# Average LIME RMSE: 0.2125672337006415
# Average SHAP RMSE: 0.4495668356373108
#
#
# Average LIME MAE: 0.1768058886130651
# Average SHAP MAE: 0.4452048210634126
#
#
# Average LIME MAPE: 0.2385969196390159
# Average SHAP MAPE: 0.5767991946498093
#
#
# True Positives
# Average LIME MSE: 0.12113711598323293
# Average SHAP MSE: 0.010749603889109328
#
#
# Average LIME RMSE: 0.34804757718339735
# Average SHAP RMSE: 0.1036802965327035
#
#
# Average LIME MAE: 0.29653857052326205
# Average SHAP MAE: 0.09957691729068756
#
#
# Average LIME MAPE: 0.48638443430328493
# Average SHAP MAPE: 0.16332668799419048
#
#
# False Negatives
# Average LIME MSE: 0.291099247660465
# Average SHAP MSE: 0.21572249923855183
#
#
# Average LIME RMSE: 0.5007480139922614
# Average SHAP RMSE: 0.45383494454780327
#
#
# Average LIME MAE: 0.4651496445760131
# Average SHAP MAE: 0.4523950396105647
#
#
# Average LIME MAPE: 0.5319498862965937
# Average SHAP MAPE: 0.5457476964637299
#
#
# False Positives
# Average LIME MSE: 0.24389525012266552
# Average SHAP MSE: 0.11159428283709241
#
#
# Average LIME RMSE: 0.44353702214061186
# Average SHAP RMSE: 0.2784558510356078
#
#
# Average LIME MAE: 0.4108149528503418
# Average SHAP MAE: 0.27298079431056976
#
#
# Average LIME MAPE: 0.5500086586054845
# Average SHAP MAPE: 0.37541913696278373
#
#
# Bucket 18
# True Negatives
# Average LIME MSE: 0.18738075757417536
# Average SHAP MSE: 0.1145083925035063
#
#
# Average LIME RMSE: 0.3963778407949955
# Average SHAP RMSE: 0.2637931131205279
#
#
# Average LIME MAE: 0.3691076723237832
# Average SHAP MAE: 0.2560735643737846
#
#
# Average LIME MAPE: 0.49720704176350544
# Average SHAP MAPE: 0.3533554895543312
#
#
# True Positives
# False Negatives
# Average LIME MSE: 0.20195156270839182
# Average SHAP MSE: 0.16100426700568607
#
#
# Average LIME RMSE: 0.39200784453871007
# Average SHAP RMSE: 0.32826710198802544
#
#
# Average LIME MAE: 0.3769918382167816
# Average SHAP MAE: 0.3190703153610229
#
#
# Average LIME MAPE: 0.4819909551714305
# Average SHAP MAPE: 0.4408546240466924
#
#
# False Positives
# Average LIME MSE: 0.10683261871891203
# Average SHAP MSE: 0.25480737286736677
#
#
# Average LIME RMSE: 0.29434154341256047
# Average SHAP RMSE: 0.45706145376229357
#
#
# Average LIME MAE: 0.2756061115860939
# Average SHAP MAE: 0.45188820183277134
#
#
# Average LIME MAPE: 0.37801799463352237
# Average SHAP MAPE: 0.5771537376153457
#
#
# Bucket 19
# True Negatives
# Average LIME MSE: 0.2660892713906043
# Average SHAP MSE: 0.35023094271845223
#
#
# Average LIME RMSE: 0.4905998021946745
# Average SHAP RMSE: 0.573260590529363
#
#
# Average LIME MAE: 0.463622136041522
# Average SHAP MAE: 0.5724084202200175
#
#
# Average LIME MAPE: 0.6201880092467307
# Average SHAP MAPE: 0.7648873613643562
#
#
# True Positives
# Average LIME MSE: 0.04889542215010616
# Average SHAP MSE: 0.020641341955503913
#
#
# Average LIME RMSE: 0.22112309275628847
# Average SHAP RMSE: 0.14367095028398716
#
#
# Average LIME MAE: 0.15764279067516326
# Average SHAP MAE: 0.12537639141082763
#
#
# Average LIME MAPE: 0.2502945931384754
# Average SHAP MAPE: 0.19906418011849783
#
#
# False Negatives
# Average LIME MSE: 0.530449051461993
# Average SHAP MSE: 0.3135475280879847
#
#
# Average LIME RMSE: 0.7283193334396616
# Average SHAP RMSE: 0.5599531481186482
#
#
# Average LIME MAE: 0.7226901441812515
# Average SHAP MAE: 0.5549189954996109
#
#
# Average LIME MAPE: 0.8564394163006954
# Average SHAP MAPE: 0.65761862732787
#
#
# False Positives
# Average LIME MSE: 0.12234739993997837
# Average SHAP MSE: 0.08632963059137909
#
#
# Average LIME RMSE: 0.29267389751382134
# Average SHAP RMSE: 0.24234889072893478
#
#
# Average LIME MAE: 0.2715818726354175
# Average SHAP MAE: 0.23117204341623518
#
#
# Average LIME MAPE: 0.37585202093496917
# Average SHAP MAPE: 0.3167688166711316
#
#
# Bucket 20
# True Negatives
# Average LIME MSE: 0.22668010081867987
# Average SHAP MSE: 0.540046439120207
#
#
# Average LIME RMSE: 0.43152345255434577
# Average SHAP RMSE: 0.7294158109226017
#
#
# Average LIME MAE: 0.40280146002769474
# Average SHAP MAE: 0.7291740477085114
#
#
# Average LIME MAPE: 0.4999876991423322
# Average SHAP MAPE: 0.9316932729406464
#
#
# True Positives
# False Negatives
# Average LIME MSE: 0.5080857986106769
# Average SHAP MSE: 0.9106450808194552
#
#
# Average LIME RMSE: 0.7126957146790112
# Average SHAP RMSE: 0.9542341248721049
#
#
# Average LIME MAE: 0.6857105663046241
# Average SHAP MAE: 0.9542295327410102
#
#
# Average LIME MAPE: 0.7103488173274228
# Average SHAP MAPE: 0.9881744021316405
#
#
# False Positives
# Average LIME MSE: 0.18982358860905008
# Average SHAP MSE: 0.06580229822511939
#
#
# Average LIME RMSE: 0.3714338802781154
# Average SHAP RMSE: 0.22961281363430674
#
#
# Average LIME MAE: 0.34732286155223846
# Average SHAP MAE: 0.2187076687812805
#
#
# Average LIME MAPE: 0.43376485313633756
# Average SHAP MAPE: 0.31820910300115657
#
#
# Bucket 21
# True Negatives
# Average LIME MSE: 0.30641149148391744
# Average SHAP MSE: 0.23670353199821006
#
#
# Average LIME RMSE: 0.5028678997024939
# Average SHAP RMSE: 0.4074887800830005
#
#
# Average LIME MAE: 0.4725079759024084
# Average SHAP MAE: 0.4017408310435712
#
#
# Average LIME MAPE: 0.5895112639503793
# Average SHAP MAPE: 0.49712894582076683
#
#
# True Positives
# False Negatives
# Average LIME MSE: 0.311501389350619
# Average SHAP MSE: 0.4291796288409585
#
#
# Average LIME RMSE: 0.464990551471762
# Average SHAP RMSE: 0.5603728977146498
#
#
# Average LIME MAE: 0.4540477376431227
# Average SHAP MAE: 0.559033228084445
#
#
# Average LIME MAPE: 0.5419842689576218
# Average SHAP MAPE: 0.5982373347045662
#
#
# False Positives
# Average LIME MSE: 0.14790839177446424
# Average SHAP MSE: 0.23906121824408097
#
#
# Average LIME RMSE: 0.3409719492078133
# Average SHAP RMSE: 0.39112999984063607
#
#
# Average LIME MAE: 0.31566132605075836
# Average SHAP MAE: 0.38813134640455244
#
#
# Average LIME MAPE: 0.4343011043899196
# Average SHAP MAPE: 0.4886307617554296
#
#
# Bucket 22
# True Negatives
# Average LIME MSE: 0.11109439302965976
# Average SHAP MSE: 0.2443423371158487
#
#
# Average LIME RMSE: 0.2803281644231575
# Average SHAP RMSE: 0.45656144634664864
#
#
# Average LIME MAE: 0.26063012671139507
# Average SHAP MAE: 0.44509560325079495
#
#
# Average LIME MAPE: 0.3283221533619415
# Average SHAP MAPE: 0.5561936807701554
#
#
# True Positives
# False Negatives
# Average LIME MSE: 0.12809707441828355
# Average SHAP MSE: 0.09160094363083476
#
#
# Average LIME RMSE: 0.35285221993036564
# Average SHAP RMSE: 0.2989219796720788
#
#
# Average LIME MAE: 0.3203014940023422
# Average SHAP MAE: 0.2680368945002556
#
#
# Average LIME MAPE: 0.4476783003117741
# Average SHAP MAPE: 0.39103079731757334
#
#
# False Positives
# Average LIME MSE: 0.12038871671208443
# Average SHAP MSE: 0.07010139507727248
#
#
# Average LIME RMSE: 0.30845415562080647
# Average SHAP RMSE: 0.24421267871638577
#
#
# Average LIME MAE: 0.2748677920550108
# Average SHAP MAE: 0.22216362096369266
#
#
# Average LIME MAPE: 0.3579103254778713
# Average SHAP MAPE: 0.2901581846770378
#
#
# Bucket 23
# True Negatives
# Average LIME MSE: 0.3001325135808413
# Average SHAP MSE: 0.12867096359361213
#
#
# Average LIME RMSE: 0.531813700339792
# Average SHAP RMSE: 0.252689648387028
#
#
# Average LIME MAE: 0.49448531232774257
# Average SHAP MAE: 0.2467154777298371
#
#
# Average LIME MAPE: 0.6221345973363425
# Average SHAP MAPE: 0.2786953461376308
#
#
# True Positives
# False Negatives
# Average LIME MSE: 0.3212388299110621
# Average SHAP MSE: 0.10388323186058987
#
#
# Average LIME RMSE: 0.5339054403622172
# Average SHAP RMSE: 0.2883295277199175
#
#
# Average LIME MAE: 0.46749390196055174
# Average SHAP MAE: 0.27970821391791106
#
#
# Average LIME MAPE: 0.4795625540585977
# Average SHAP MAPE: 0.285318227060974
#
#
# False Positives
# Average LIME MSE: 0.19398775836905086
# Average SHAP MSE: 0.32795766501707524
#
#
# Average LIME RMSE: 0.40534076272579794
# Average SHAP RMSE: 0.521600823796913
#
#
# Average LIME MAE: 0.36249430775642394
# Average SHAP MAE: 0.515489450097084
#
#
# Average LIME MAPE: 0.44410223510628277
# Average SHAP MAPE: 0.6620500562522119
#
#
# Bucket 24
# True Negatives
# Average LIME MSE: 0.11290915225429268
# Average SHAP MSE: 0.1750370878586089
#
#
# Average LIME RMSE: 0.2795459924862176
# Average SHAP RMSE: 0.4031454876364549
#
#
# Average LIME MAE: 0.2578041659047206
# Average SHAP MAE: 0.3859473006178935
#
#
# Average LIME MAPE: 0.30593479850457383
# Average SHAP MAPE: 0.4634547560733516
#
#
# True Positives
# False Negatives
# Average LIME MSE: 0.01807194749314503
# Average SHAP MSE: 0.1593187123124017
#
#
# Average LIME RMSE: 0.13299985529913533
# Average SHAP RMSE: 0.3984518562468868
#
#
# Average LIME MAE: 0.11825673580169677
# Average SHAP MAE: 0.3894115127623081
#
#
# Average LIME MAPE: 0.1498878755810473
# Average SHAP MAPE: 0.48712227382121376
#
#
# False Positives
# Average LIME MSE: 0.3734304054993465
# Average SHAP MSE: 0.23698416225930516
#
#
# Average LIME RMSE: 0.5953380396025163
# Average SHAP RMSE: 0.4475509860912736
#
#
# Average LIME MAE: 0.5873730501958302
# Average SHAP MAE: 0.4440641092402594
#
#
# Average LIME MAPE: 0.7669229773692374
# Average SHAP MAPE: 0.582269215362037
#
#
# Bucket 25
# True Negatives
# Average LIME MSE: 0.13864529486511853
# Average SHAP MSE: 0.28885514363124987
#
#
# Average LIME RMSE: 0.3388372838438244
# Average SHAP RMSE: 0.4856200741505988
#
#
# Average LIME MAE: 0.31717778506378336
# Average SHAP MAE: 0.4775000022103389
#
#
# Average LIME MAPE: 0.4257586194117289
# Average SHAP MAPE: 0.6185106362902351
#
#
# True Positives
# False Negatives
# Average LIME MSE: 0.02359587189781611
# Average SHAP MSE: 0.338266166181852
#
#
# Average LIME RMSE: 0.14492227079937497
# Average SHAP RMSE: 0.5778135082081008
#
#
# Average LIME MAE: 0.12600743621587754
# Average SHAP MAE: 0.5563292890787124
#
#
# Average LIME MAPE: 0.15093791707642873
# Average SHAP MAPE: 0.6699909672475721
#
#
# False Positives
# Average LIME MSE: 0.23395757893767477
# Average SHAP MSE: 0.14345548489092635
#
#
# Average LIME RMSE: 0.44800708371619147
# Average SHAP RMSE: 0.3042887771289265
#
#
# Average LIME MAE: 0.42415917473179954
# Average SHAP MAE: 0.29156264407294136
#
#
# Average LIME MAPE: 0.5502199539916245
# Average SHAP MAPE: 0.34465288525291415

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_MSE, all_shap_MSE, all_lime_RMSE, all_shap_RMSE, all_lime_MAE, all_shap_MAE, 
                          all_lime_MAPE, all_shap_MAPE, all_lengths, hue_lens), key=lambda x: x[-2])
all_proba, all_lime_MSE, all_shap_MSE, all_lime_RMSE, all_shap_RMSE, all_lime_MAE, all_shap_MAE, all_lime_MAPE, all_shap_MAPE, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
sns.scatterplot(all_proba, all_lime_MSE, hue=hue_lens, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1,0.1))
plt.ylim(0,1.1)
plt.title("Sepsis Cases: Fidelity MSE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_MSE, hue=hue_lens, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1,0.1))
plt.ylim(0,1.1)
plt.title("Sepsis Cases: Fidelity MSE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

# %%
sns.scatterplot(all_proba, all_lime_RMSE, hue = hue_lens, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1,0.1))
plt.ylim(0,1.1)
plt.title("Sepsis Cases: Fidelity RMSE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_RMSE, hue = hue_lens, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1,0.1))
plt.ylim(0,1.1)
plt.title("Sepsis Cases: Fidelity RMSE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_MAE, hue = hue_lens, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1,0.1))
plt.ylim(0,1.1)
plt.title("Sepsis Cases: Fidelity MAE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_fidelity_mae.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_MAE, hue = hue_lens, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1,0.1))
plt.ylim(0,1.1)
plt.title("Sepsis Cases: Fidelity MAE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_fidelity_mae.png", bbox_inches = "tight")
plt.show()

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_MAPE, hue = hue_lens, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1,0.1))
plt.ylim(0,1.1)
plt.title("Sepsis Cases: Fidelity MAPE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_fidelity_mape.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_MAPE, hue = hue_lens, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1,0.1))
plt.ylim(0,1.1)
plt.title("Sepsis Cases: Fidelity MAPE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_fidelity_mape.png", bbox_inches = "tight")
plt.show()

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

sep_hues = [[],[],[],[]]

for i in range(len(sep_lengths)): 
    for length in sep_lengths[i]:
        cur_bin = 0
        while length >= bins[cur_bin+1]:
            cur_bin += 1
        sep_hues[i].append(labels[cur_bin])
#sep_hues

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MSE[i], hue = sep_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MSE[i], hue = sep_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-32ffa474fc63> in <module>
#       2
#       3 for i in range(len(type_list)):
# ----> 4     sns.scatterplot(sep_proba[i], sep_lime_MSE[i], hue = sep_hues[i], palette = lime_pal)
#       5     plt.xlabel("Prediction Probability")
#       6     plt.ylabel("Change in Prediction Probability")
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     799     )
#     800
# --> 801     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     802     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#     803     p.map_style(markers=markers, order=style_order)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py in map(cls, plotter, *args, **kwargs)
#      51         # This method is assigned the __init__ docstring
#      52         method_name = "_{}_map".format(cls.__name__[:-7].lower())
# ---> 53         setattr(plotter, method_name, cls(plotter, *args, **kwargs))
#      54         return plotter
#      55
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py in __init__(self, plotter, palette, order, norm)
#     117                 cmap = norm = None
#     118                 levels, lookup_table = self.categorical_mapping(
# --> 119                     data, palette, order,
#     120                 )
#     121
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py in categorical_mapping(self, data, palette, order)
#     202                 if len(palette) != n_colors:
#     203                     err = "The palette list has the wrong number of colors."
# --> 204                     raise ValueError(err)
#     205                 colors = palette
#     206             else:
#
# ValueError: The palette list has the wrong number of colors.

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_RMSE[i], hue = sep_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_RMSE[i], hue = sep_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAE[i], hue = sep_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAE[i], hue = sep_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAPE[i], hue = sep_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAPE[i], hue = sep_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAPE\nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[],[]]
type_proba = [[],[]]
type_hues = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_hues[0].extend(sep_hues[0])
type_hues[0].extend(sep_hues[2])
type_hues[1].extend(sep_hues[1])
type_hues[1].extend(sep_hues[3])

type_lime_MSE = [[],[]]
type_shap_MSE = [[],[]]

type_lime_MSE[0].extend(sep_lime_MSE[0])
type_lime_MSE[0].extend(sep_lime_MSE[2])
type_lime_MSE[1].extend(sep_lime_MSE[1])
type_lime_MSE[1].extend(sep_lime_MSE[3])

type_shap_MSE[0].extend(sep_shap_MSE[0])
type_shap_MSE[0].extend(sep_shap_MSE[2])
type_shap_MSE[1].extend(sep_shap_MSE[1])
type_shap_MSE[1].extend(sep_shap_MSE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MSE[i], hue = type_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MSE[i], hue = type_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_RMSE = [[],[]]
type_shap_RMSE = [[],[]]

type_lime_RMSE[0].extend(sep_lime_RMSE[0])
type_lime_RMSE[0].extend(sep_lime_RMSE[2])
type_lime_RMSE[1].extend(sep_lime_RMSE[1])
type_lime_RMSE[1].extend(sep_lime_RMSE[3])

type_shap_RMSE[0].extend(sep_shap_RMSE[0])
type_shap_RMSE[0].extend(sep_shap_RMSE[2])
type_shap_RMSE[1].extend(sep_shap_RMSE[1])
type_shap_RMSE[1].extend(sep_shap_RMSE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_RMSE[i], hue = type_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_RMSE[i], hue = type_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_MAE = [[],[]]
type_shap_MAE = [[],[]]

type_lime_MAE[0].extend(sep_lime_MAE[0])
type_lime_MAE[0].extend(sep_lime_MAE[2])
type_lime_MAE[1].extend(sep_lime_MAE[1])
type_lime_MAE[1].extend(sep_lime_MAE[3])

type_shap_MAE[0].extend(sep_shap_MAE[0])
type_shap_MAE[0].extend(sep_shap_MAE[2])
type_shap_MAE[1].extend(sep_shap_MAE[1])
type_shap_MAE[1].extend(sep_shap_MAE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MAE[i], hue = type_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MAE[i], hue = type_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_MAPE = [[],[]]
type_shap_MAPE = [[],[]]

type_lime_MAPE[0].extend(sep_lime_MAPE[0])
type_lime_MAPE[0].extend(sep_lime_MAPE[2])
type_lime_MAPE[1].extend(sep_lime_MAPE[1])
type_lime_MAPE[1].extend(sep_lime_MAPE[3])

type_shap_MAPE[0].extend(sep_shap_MAPE[0])
type_shap_MAPE[0].extend(sep_shap_MAPE[2])
type_shap_MAPE[1].extend(sep_shap_MAPE[1])
type_shap_MAPE[1].extend(sep_shap_MAPE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MAPE[i], hue = type_hues[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MAPE[i], hue = type_hues[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
print("Average LIME MSE:", np.mean(all_lime_MSE))
print("Average SHAP MSE:", np.mean(all_shap_MSE))
print("\n")

print("Average LIME RMSE:", np.mean(all_lime_RMSE))
print("Average SHAP RMSE:", np.mean(all_shap_RMSE))
print("\n")

print("Average LIME MAE:", np.mean(all_lime_MAE))
print("Average SHAP MAE:", np.mean(all_shap_MAE))
print("\n")

print("Average LIME MAPE:", np.mean(all_lime_MAPE))
print("Average SHAP MAPE:", np.mean(all_shap_MAPE))
# Out:
# Average LIME MSE: 0.12976033001781262
# Average SHAP MSE: 0.21030127315126582
#
#
# Average LIME RMSE: 0.3087127411202885
# Average SHAP RMSE: 0.3890077811219941
#
#
# Average LIME MAE: 0.2824177154555201
# Average SHAP MAE: 0.3804438045142112
#
#
# Average LIME MAPE: 0.3744494652066537
# Average SHAP MAPE: 0.49663141885552775

# %%
print(len(all_lime_MSE))
# Out:
# 666
