# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
PATH = '/content/drive/My Drive/PPM_Stability/'
#PATH = "C:/Users/velmurug/Documents/Stability Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/Mythreyi/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/mythr/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/n9455647/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
sys.path.append(PATH)
# Out:
# Mounted at /content/drive

# %%
# !pip install xgboost==1.0.0
# Out:
# Collecting xgboost==1.0.0
#   Downloading https://files.pythonhosted.org/packages/c1/e8/88d7afd859a52092e86e0f1d9fa5ed7718c73ee5ef68a71d0123019a197e/xgboost-1.0.0-py3-none-manylinux1_x86_64.whl (109.7MB)
#      |████████████████████████████████| 109.8MB 45kB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from xgboost==1.0.0) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from xgboost==1.0.0) (1.18.5)
# Installing collected packages: xgboost
#   Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
# Successfully installed xgboost-1.0.0

# %%
from DatasetManager_for_colab import DatasetManager

import pandas as pd
import numpy as np

import os
import sys
from sys import argv
import pickle
import random
import joblib

import statistics
import math

import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

lime_pal = sns.diverging_palette(100, 200, s=150, as_cmap=True)
shap_pal = sns.diverging_palette(0, 240, s=150, as_cmap=True)

sns.set_style('whitegrid')

# %%
dataset_ref = "sepsis_cases"
params_dir = PATH + "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "index"
cls_method = "xgboost"

gap = 1
n_iter = 1

method_name = "%s_%s"%(bucket_method, cls_encoding)

generate_samples = False
generate_lime = True
generate_kernel_shap = False
generate_model_shap = True

sample_size = 2
exp_iter = 10
max_feat = 10
max_prefix = 20

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"],
    #"insurance": ["insurance_activity", "insurance_followup"],
    "sepsis_cases": ["sepsis_cases_1"]#, "sepsis_cases_2", "sepsis_cases_4"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]

datasets
# Out:
# ['sepsis_cases_1']

# %%
all_caseID = []
all_lengths = []
all_proba = []
all_lime_stab = []
all_shap_stab = []

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            #feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            #cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            #cls = joblib.load(cls_path)
            #feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i] != []:
                  data = pd.DataFrame.from_records(sample_instances[i])
                  
                  case_id = pd.Series(data['caseID'])
                  nr_events = pd.Series(data['nr_events'])
                  proba = pd.Series(data['proba'])
                  lime_stability = pd.Series(data['lime_stability'])
                  tree_shap_stability = pd.Series(data['tree_shap_stability'])
                  
                  all_caseID.extend(case_id)
                  all_lengths.extend(nr_events)
                  all_proba.extend(proba)
                  all_lime_stab.extend(lime_stability)
                  all_shap_stab.extend(tree_shap_stability)
                  
                  print("Average LIME Stability:", statistics.mean(lime_stability))
                  print("Average SHAP Stability:", statistics.mean(tree_shap_stability))
                  
                  #fig, ax = plt.subplots()
                  #ax.plot(nr_events, lime_stability, 'bo', label = "LIME")
                  #ax.plot(nr_events, tree_shap_stability, 'ro', label = "Tree SHAP")
                  #ax.set_xlabel("Prefix Length")
                  #ax.set_ylabel("Stability")
                  #ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,1, 0.1))
                  #plt.title("Prefix length and stability by index - "+type_list[i])
                  #plt.show()
                  
                  #fig2, ax2 = plt.subplots()
                  #ax2.plot(proba, lime_stability, 'bo', label = "LIME")
                  #ax2.plot(proba, tree_shap_stability, 'ro', label = "Tree SHAP")
                  #ax2.set_xlabel("Prediction Probability")
                  #ax2.set_ylabel("Stability")
                  #ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,1, 0.1))
                  #plt.title("Prediction probability and stability by index - "+type_list[i])
                  #plt.show()
                else:
                  print("No samples of this type")
# Out:
# Bucket 1
# True Negatives
# Average LIME Stability: 0.5177026782919256
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.516872010051618
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5031012411691886
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.482696025802074
# Average SHAP Stability: 1.0
# Bucket 2
# True Negatives
# Average LIME Stability: 0.462684160330005
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4790724739944274
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.4793988087756008
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.44308071347872113
# Average SHAP Stability: 1.0
# Bucket 3
# True Negatives
# Average LIME Stability: 0.509531105318017
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4623632010137975
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.46310941318260945
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.49901955181910096
# Average SHAP Stability: 1.0
# Bucket 4
# True Negatives
# Average LIME Stability: 0.4639218155272283
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.47675614456726595
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.4311714445572479
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.43723537182441014
# Average SHAP Stability: 1.0
# Bucket 5
# True Negatives
# Average LIME Stability: 0.4142206057493275
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.38851583526884026
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.3634557305534193
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.37824980467200603
# Average SHAP Stability: 1.0
# Bucket 6
# True Negatives
# Average LIME Stability: 0.4670690510708286
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.40694699197435913
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.47751230912862164
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4816566624803958
# Average SHAP Stability: 1.0
# Bucket 7
# True Negatives
# Average LIME Stability: 0.5281796827225005
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5688540596917064
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.530091834539494
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5330121632366865
# Average SHAP Stability: 1.0
# Bucket 8
# True Negatives
# Average LIME Stability: 0.22002655802109908
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.1952030642166405
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.23316721343195349
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.1933353050621761
# Average SHAP Stability: 1.0
# Bucket 9
# True Negatives
# Average LIME Stability: 0.22641123965830112
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.23228635860935565
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.24732403136839085
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.26810365651223755
# Average SHAP Stability: 1.0
# Bucket 10
# True Negatives
# Average LIME Stability: 0.1412150278886947
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.17687103298237075
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.17973170142602884
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.18156926024385914
# Average SHAP Stability: 1.0
# Bucket 11
# True Negatives
# Average LIME Stability: 0.18626638490651934
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.2161140704810736
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.21995026757157024
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.20618238262213803
# Average SHAP Stability: 1.0
# Bucket 12
# True Negatives
# Average LIME Stability: 0.2542533514600671
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.24474102045522297
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.23680366583445234
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.22703280876595971
# Average SHAP Stability: 1.0
# Bucket 13
# True Negatives
# Average LIME Stability: 0.22926907684122783
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.18087574859380684
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.3674022779691294
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.23844351591428176
# Average SHAP Stability: 1.0
# Bucket 14
# True Negatives
# Average LIME Stability: 0.32166627153486915
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.29731365800741827
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.3028361909637788
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.3615286941475246
# Average SHAP Stability: 1.0
# Bucket 15
# True Negatives
# Average LIME Stability: 0.48539174961247666
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.4865958795101927
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.4619204361300797
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.448474675983402
# Average SHAP Stability: 1.0
# Bucket 16
# True Negatives
# Average LIME Stability: 0.32776931808888066
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.35392929123075195
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.43086112997125237
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.37477224478900295
# Average SHAP Stability: 1.0
# Bucket 17
# True Negatives
# No samples of this type
# True Positives
# Average LIME Stability: 0.4319311206314236
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.43676767676767675
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.440754985365955
# Average SHAP Stability: 1.0
# Bucket 18
# True Negatives
# Average LIME Stability: 0.6066698930129302
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6732094155313186
# Average SHAP Stability: 1.0
# False Negatives
# No samples of this type
# False Positives
# Average LIME Stability: 0.5434585078481355
# Average SHAP Stability: 1.0
# Bucket 19
# True Negatives
# Average LIME Stability: 0.5003399728021756
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.48301648978826245
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5676545676545677
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4613930885529156
# Average SHAP Stability: 1.0
# Bucket 20
# True Negatives
# Average LIME Stability: 0.6388354554751494
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6164272543861553
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5816476331625471
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5221513491295333
# Average SHAP Stability: 1.0

# %%
sns.scatterplot(all_proba, all_lime_stab, hue=all_lengths, palette=lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.yticks(np.arange(0,1, 0.1))
plt.title("Prefix length and stability by index \n Prefix-Length Bucket with Index-Based Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_stab, hue=all_lengths, palette=shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.yticks(np.arange(0,1, 0.1))
plt.title("Prefix length and stability by index \n Prefix-Length Bucket with Index-Based Encoding")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.title("Prefix length and stability by index \n Single Bucket with Index-Based Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.title("Prediction probability and stability by index \n Single Bucket with Index-Based Encoding")
plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []
all_lime_stab = []
all_shap_stab = []

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i] != []:
                  data = pd.DataFrame.from_records(sample_instances[i])
                  
                  dispersal_lime = []
                  dispersal_shap = []
                  adj_dispersal_lime = []
                  adj_dispersal_shap = []
                  
                  case_id = pd.Series(data['caseID'])
                  nr_events = pd.Series(data['nr_events'])
                  proba = pd.Series(data['proba'])
                  lime_stability = pd.Series(data['adjusted_lime_importance_stability'])
                  tree_shap_stability = pd.Series(data['adjusted_shap_importance_stability'])
                  
                  all_caseID.extend(case_id)
                  all_lengths.extend(nr_events)
                  all_proba.extend(proba)
                  all_lime_stab.extend(lime_stability)
                  all_shap_stab.extend(tree_shap_stability)
                  
                  print("Average LIME Weights Stability:", statistics.mean(lime_stability))
                  print("Average SHAP Weights Stability:", statistics.mean(tree_shap_stability))
                  
                  shap_dispersion = [disp for disp in tree_shap_stability if disp > 0]
                  
                  print (len(shap_dispersion))
                  
                  #fig, ax = plt.subplots()
                  #ax.plot(nr_events, lime_stability, 'bo', label = "LIME")
                  #ax.plot(nr_events, tree_shap_stability, 'ro', label = "Tree SHAP")
                  #ax.set_xlabel("Prefix Length")
                  #ax.set_ylabel("Stability")
                  #ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.title("Prefix length and stability by weight - "+type_list[i])
                  #plt.show()
                  
                  #fig2, ax2 = plt.subplots()
                  #ax2.plot(proba, lime_stability, 'bo', label = "LIME")
                  #ax2.plot(proba, tree_shap_stability, 'ro', label = "Tree SHAP")
                  #ax2.set_xlabel("Prediction Probability")
                  #ax2.set_ylabel("Stability")
                  #ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.title("Prediction probability and stability by weight - "+type_list[i])
                  #plt.show()
                else:
                  print("No samples of this type")
# Out:
# Bucket 1
# True Negatives
# Average LIME Weights Stability: 0.16328972044782228
# Average SHAP Weights Stability: 2.37608418009667e-16
# 4
# True Positives
# Average LIME Weights Stability: 0.5349681893192513
# Average SHAP Weights Stability: 2.62350622643763e-16
# 4
# False Negatives
# Average LIME Weights Stability: 0.4478693726790739
# Average SHAP Weights Stability: 2.8051078842588457e-16
# 8
# False Positives
# Average LIME Weights Stability: 0.24087341130494008
# Average SHAP Weights Stability: 2.3980430750380372e-16
# 5
# Bucket 2
# True Negatives
# Average LIME Weights Stability: 0.286166547423299
# Average SHAP Weights Stability: 3.1555139900348947e-16
# 7
# True Positives
# Average LIME Weights Stability: 0.19839074842712787
# Average SHAP Weights Stability: 2.4067876186228807e-16
# 7
# False Negatives
# Average LIME Weights Stability: 0.5694588299941176
# Average SHAP Weights Stability: 2.4749324840624874e-16
# 4
# False Positives
# Average LIME Weights Stability: 0.25758009050490493
# Average SHAP Weights Stability: 2.371417656044693e-16
# 4
# Bucket 3
# True Negatives
# Average LIME Weights Stability: 0.2927516304025278
# Average SHAP Weights Stability: 2.878094227189707e-16
# 4
# True Positives
# Average LIME Weights Stability: 0.2288186638097759
# Average SHAP Weights Stability: 2.790573741499734e-16
# 3
# False Negatives
# Average LIME Weights Stability: 0.40795614452563106
# Average SHAP Weights Stability: 2.3810362876912865e-16
# 4
# False Positives
# Average LIME Weights Stability: 0.476812082541022
# Average SHAP Weights Stability: 2.8867485611906647e-16
# 5
# Bucket 4
# True Negatives
# Average LIME Weights Stability: 0.3418853028206512
# Average SHAP Weights Stability: 2.457150504444244e-16
# 6
# True Positives
# Average LIME Weights Stability: 0.5554772387994736
# Average SHAP Weights Stability: 2.4760243729858283e-16
# 5
# False Negatives
# Average LIME Weights Stability: 0.38548395291299187
# Average SHAP Weights Stability: 1.8608229390835292e-16
# 4
# False Positives
# Average LIME Weights Stability: 0.9511859197435543
# Average SHAP Weights Stability: 1.4714224221787958e-16
# 4
# Bucket 5
# True Negatives
# Average LIME Weights Stability: 0.36444106595195547
# Average SHAP Weights Stability: 3.0074469286307804e-16
# 4
# True Positives
# Average LIME Weights Stability: 0.369345311008887
# Average SHAP Weights Stability: 2.6838599598920124e-16
# 4
# False Negatives
# Average LIME Weights Stability: 0.42397234064444
# Average SHAP Weights Stability: 2.101405525751943e-16
# 8
# False Positives
# Average LIME Weights Stability: 0.35828465800736353
# Average SHAP Weights Stability: 2.1832581590115025e-16
# 6
# Bucket 6
# True Negatives
# Average LIME Weights Stability: 0.5219102571493265
# Average SHAP Weights Stability: 1.9176764291130038e-16
# 3
# True Positives
# Average LIME Weights Stability: 0.8624354575808171
# Average SHAP Weights Stability: 1.648736365793527e-16
# 5
# False Negatives
# Average LIME Weights Stability: 0.7381692260712938
# Average SHAP Weights Stability: 2.2073694666758788e-16
# 2
# False Positives
# Average LIME Weights Stability: 0.4474164690681164
# Average SHAP Weights Stability: 2.0135592793874385e-16
# 8
# Bucket 7
# True Negatives
# Average LIME Weights Stability: 0.3538396723657065
# Average SHAP Weights Stability: 1.9965949468597098e-16
# 5
# True Positives
# Average LIME Weights Stability: 0.3070366003480539
# Average SHAP Weights Stability: 1.8471802202322653e-16
# 4
# False Negatives
# Average LIME Weights Stability: 0.32620173304545774
# Average SHAP Weights Stability: 2.1617352977486992e-16
# 6
# False Positives
# Average LIME Weights Stability: 0.47443591169710486
# Average SHAP Weights Stability: 2.1749487074802068e-16
# 4
# Bucket 8
# True Negatives
# Average LIME Weights Stability: 0.5175576491967083
# Average SHAP Weights Stability: 2.1905076063607715e-16
# 6
# True Positives
# Average LIME Weights Stability: 0.5413617282992196
# Average SHAP Weights Stability: 1.4364667775429566e-16
# 3
# False Negatives
# Average LIME Weights Stability: 0.7155477379249281
# Average SHAP Weights Stability: 2.0566727404898698e-16
# 5
# False Positives
# Average LIME Weights Stability: 0.8998131211313072
# Average SHAP Weights Stability: 1.5964085447409546e-16
# 4
# Bucket 9
# True Negatives
# Average LIME Weights Stability: 1.0272726860644519
# Average SHAP Weights Stability: 1.5466148136010096e-16
# 4
# True Positives
# Average LIME Weights Stability: 0.37403231147738225
# Average SHAP Weights Stability: 1.078440283426447e-16
# 5
# False Negatives
# Average LIME Weights Stability: 0.5840474516799492
# Average SHAP Weights Stability: 1.5465857927123663e-16
# 4
# False Positives
# Average LIME Weights Stability: 0.6408490255099693
# Average SHAP Weights Stability: 2.1413100677873575e-16
# 6
# Bucket 10
# True Negatives
# Average LIME Weights Stability: 1.2884330822504904
# Average SHAP Weights Stability: 1.6659441001266825e-16
# 5
# True Positives
# Average LIME Weights Stability: 1.1806948205865813
# Average SHAP Weights Stability: 1.6425716403499215e-16
# 6
# False Negatives
# Average LIME Weights Stability: 0.7136571992475339
# Average SHAP Weights Stability: 1.4240688557811013e-16
# 5
# False Positives
# Average LIME Weights Stability: 0.618143591378494
# Average SHAP Weights Stability: 1.8021465605744672e-16
# 3
# Bucket 11
# True Negatives
# Average LIME Weights Stability: 2.915967451068785
# Average SHAP Weights Stability: 1.811689088764917e-16
# 5
# True Positives
# Average LIME Weights Stability: 515.2408318062143
# Average SHAP Weights Stability: 1.6938575160735924e-16
# 4
# False Negatives
# Average LIME Weights Stability: 0.47681865536118107
# Average SHAP Weights Stability: 1.156940407574838e-16
# 3
# False Positives
# Average LIME Weights Stability: 0.316930210784726
# Average SHAP Weights Stability: 1.8466329842025451e-16
# 3
# Bucket 12
# True Negatives
# Average LIME Weights Stability: 0.49647330564199066
# Average SHAP Weights Stability: 8.632595706674438e-17
# 4
# True Positives
# Average LIME Weights Stability: 0.7468059867686114
# Average SHAP Weights Stability: 1.1858255458004953e-16
# 4
# False Negatives
# Average LIME Weights Stability: 0.5132104492048338
# Average SHAP Weights Stability: 1.238907901267506e-16
# 3
# False Positives
# Average LIME Weights Stability: 0.456118769245787
# Average SHAP Weights Stability: 1.2472798137736534e-16
# 6
# Bucket 13
# True Negatives
# Average LIME Weights Stability: 0.5784433154607947
# Average SHAP Weights Stability: 1.3474737457343604e-16
# 4
# True Positives
# Average LIME Weights Stability: 0.7627816343120799
# Average SHAP Weights Stability: 1.2540860618231017e-16
# 4
# False Negatives
# Average LIME Weights Stability: 0.48403155813796517
# Average SHAP Weights Stability: 1.0625095968891167e-16
# 2
# False Positives
# Average LIME Weights Stability: 0.28078945679612444
# Average SHAP Weights Stability: 1.093259348527098e-16
# 2
# Bucket 14
# True Negatives
# Average LIME Weights Stability: 0.4018769160490197
# Average SHAP Weights Stability: 1.0396283507581721e-16
# 3
# True Positives
# Average LIME Weights Stability: 0.5271994940935134
# Average SHAP Weights Stability: 1.4208588269578804e-16
# 4
# False Negatives
# Average LIME Weights Stability: 0.41636894011966136
# Average SHAP Weights Stability: 1.2823480444873903e-16
# 2
# False Positives
# Average LIME Weights Stability: 0.4882556535437633
# Average SHAP Weights Stability: 9.184959135420261e-17
# 2
# Bucket 15
# True Negatives
# Average LIME Weights Stability: 0.3872234471368596
# Average SHAP Weights Stability: 9.523866567241953e-17
# 3
# True Positives
# Average LIME Weights Stability: 0.43106284054239846
# Average SHAP Weights Stability: 9.404875382821504e-17
# 4
# False Negatives
# Average LIME Weights Stability: 0.34804910104073516
# Average SHAP Weights Stability: 1.1389304810565122e-16
# 3
# False Positives
# Average LIME Weights Stability: 0.3249970546560141
# Average SHAP Weights Stability: 8.191093143110966e-17
# 3
# Bucket 16
# True Negatives
# Average LIME Weights Stability: 0.39376243500570546
# Average SHAP Weights Stability: 8.773493771962449e-17
# 3
# True Positives
# Average LIME Weights Stability: 0.28527584269518563
# Average SHAP Weights Stability: 1.2159462662507817e-16
# 3
# False Negatives
# Average LIME Weights Stability: 0.5267361830440633
# Average SHAP Weights Stability: 2.716960432111995e-16
# 1
# False Positives
# Average LIME Weights Stability: 0.7375371485402562
# Average SHAP Weights Stability: 8.961994875580337e-17
# 4
# Bucket 17
# True Negatives
# No samples of this type
# True Positives
# Average LIME Weights Stability: 0.23592870574515673
# Average SHAP Weights Stability: 1.2077173628544438e-16
# 2
# False Negatives
# Average LIME Weights Stability: 0.3298244935217527
# Average SHAP Weights Stability: 8.521338117513657e-17
# 2
# False Positives
# Average LIME Weights Stability: 0.25609365384610316
# Average SHAP Weights Stability: 7.052774705534023e-17
# 3
# Bucket 18
# True Negatives
# Average LIME Weights Stability: 0.3143012767208013
# Average SHAP Weights Stability: 1.142580456804006e-16
# 2
# True Positives
# Average LIME Weights Stability: 0.6333876544416692
# Average SHAP Weights Stability: 1.693534123941461e-16
# 2
# False Negatives
# No samples of this type
# False Positives
# Average LIME Weights Stability: 0.3551699409449691
# Average SHAP Weights Stability: 9.77424289169561e-17
# 1
# Bucket 19
# True Negatives
# Average LIME Weights Stability: 0.6299524182085557
# Average SHAP Weights Stability: 7.886692391279427e-17
# 2
# True Positives
# Average LIME Weights Stability: 0.30144878555630295
# Average SHAP Weights Stability: 1.5592258439093302e-16
# 2
# False Negatives
# Average LIME Weights Stability: 0.42833895014253537
# Average SHAP Weights Stability: 1.197075106133013e-16
# 1
# False Positives
# Average LIME Weights Stability: 0.2861792686166699
# Average SHAP Weights Stability: 9.88754136338836e-17
# 2
# Bucket 20
# True Negatives
# Average LIME Weights Stability: 0.44765689369045775
# Average SHAP Weights Stability: 9.574545993083587e-17
# 1
# True Positives
# Average LIME Weights Stability: 0.23396904688363018
# Average SHAP Weights Stability: 4.005453894505511e-17
# 1
# False Negatives
# Average LIME Weights Stability: 0.3223154249788224
# Average SHAP Weights Stability: 1.448136346782546e-16
# 2
# False Positives
# Average LIME Weights Stability: 0.3159931677686243
# Average SHAP Weights Stability: 7.911756644057161e-17
# 2

# %%
sns.scatterplot(all_proba, all_lime_stab, hue=all_lengths, palette=lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.title("Prefix length and stability by index \n Prefix-Length Bucket with Index-Based Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_stab, hue=all_lengths, palette=shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.title("Prefix length and stability by index \n Prefix-Length Bucket with Index-Based Encoding")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("Prefix length and stability by index \n Prefix-Length Bucket with Index-Based Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("Prediction probability and stability by index \n Prefix-Length Bucket with Index-Based Encoding")
plt.show()

# %%
lime_mean = np.mean(all_lime_stab)
lime_std = np.std(all_lime_stab)
lime_upper = lime_mean + (3*lime_std)
lime_lower = lime_mean - (3*lime_std)

shap_mean = np.mean(all_shap_stab)
shap_std = np.std(all_shap_stab)
shap_upper = shap_mean + (3*shap_std)
shap_lower = shap_mean - (3*shap_std)

lime_outliers = [i for i in all_lime_stab if i > lime_upper or i < lime_lower]
shap_outliers = [i for i in all_shap_stab if i > shap_upper or i < shap_lower]

print (lime_mean)
print (shap_mean)
print(len(lime_outliers))
print(len(shap_outliers))
print(str(len(lime_outliers)/len(all_lime_stab)*100)+"%")
print(str(len(shap_outliers)/len(all_shap_stab)*100)+"%")
# Out:
# 7.468656175848497
# 1.8267987160974445e-16
# 1
# 2
# 0.33670033670033667%
# 0.6734006734006733%

# %%
print(lime_upper)
# Out:
# 365.13973292122597

# %%
sns.scatterplot(all_proba, all_lime_stab, hue=all_lengths, palette=lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.ylim(0, 2)
plt.title("Prefix length and stability by index \n Prefix-Length Bucket with Index-Based Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_stab, hue=all_lengths, palette=shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.ylim(0, shap_upper)
plt.title("Prefix length and stability by index \n Prefix-Length Bucket with Index-Based Encoding")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(0, 2)
plt.title("Prefix length and stability by weight \n Single Bucket with Index-Based Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(0, 2)
plt.title("Prefix length and stability by weight \n Single Bucket with Index-Based Encoding")
plt.show()

# %%
bins = np.arange(0, shap_upper+1e-17, 1e-17)
yticks = np.arange(0, 35, 5)
#sns.set_style("white")
plt.subplots(figsize=(20, 15))
plt.hist(all_shap_stab, bins = bins)
#plt.figsize([50, 50])
plt.xticks(bins, fontsize = 8)
plt.yticks(yticks, fontsize = 12)
plt.title("Distribution of SHAP Stability by Weight", fontsize = 16)
plt.xlabel("Stability Range", fontsize = 14)
plt.ylabel("Frequency", fontsize = 14)
plt.show()

# %%
bins = np.arange(0, 2, 0.1)
yticks = np.arange(0, 80, 5)
#sns.set_style("white")
plt.subplots(figsize=(10, 10))
plt.hist(all_lime_stab, bins = bins)
#plt.figsize([50, 50])
plt.xticks(bins, fontsize = 12)
plt.yticks(yticks, fontsize = 12)
plt.title("Distribution of LIME Stability by Weight", fontsize = 16)
plt.xlabel("Stability Range", fontsize = 14)
plt.ylabel("Frequency", fontsize = 14)
plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []

sep_caseID = [[],[],[],[]]
sep_lengths = [[],[],[],[]]
sep_proba = [[],[],[],[]]

all_lime_diffs = []
all_shap_diffs = []

sep_lime_diffs = [[],[],[],[]]
sep_shap_diffs = [[],[],[],[]]

all_lime_MSE = []
all_lime_RMSE = []
all_lime_MAE = []
all_lime_MAPE = []

sep_lime_MSE = [[],[],[],[]]
sep_lime_RMSE = [[],[],[],[]]
sep_lime_MAE = [[],[],[],[]]
sep_lime_MAPE = [[],[],[],[]]

all_shap_MSE = []
all_shap_RMSE = []
all_shap_MAE = []
all_shap_MAPE = []

sep_shap_MSE = [[],[],[],[]]
sep_shap_RMSE = [[],[],[],[]]
sep_shap_MAE = [[],[],[],[]]
sep_shap_MAPE = [[],[],[],[]]

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i] != []:
                  
                  data = pd.DataFrame.from_records(sample_instances[i])
                  
                  lime_MSE = []
                  lime_RMSE = []
                  lime_MAE = []
                  lime_MAPE = []
                  
                  shap_MSE = []
                  shap_RMSE = []
                  shap_MAE = []
                  shap_MAPE = []
                  
                  case_id = pd.Series(data['caseID'])
                  nr_events = pd.Series(data['nr_events'])
                  proba = pd.Series(data['proba'])
                  lime_diffs = pd.Series(data['lime_fid_change'])
                  shap_diffs = pd.Series(data['shap_fid_change'])
                  
                  for j in range(len(lime_diffs)):
                      p1 = proba[j]
                      
                      lime_diff = lime_diffs[j]
                      shap_diff = shap_diffs[j]
                      
                      all_lime_diffs.append(lime_diff)
                      all_shap_diffs.append(shap_diff)
                      
                      lime_sq_changes = []
                      lime_abs_changes = []
                      lime_rel_changes = []
                      
                      shap_sq_changes = []
                      shap_abs_changes = []
                      shap_rel_changes = []
                      
                      for each in lime_diff:
                          lime_sq_changes.append(each**2)
                          lime_abs_changes.append(abs(each))
                          lime_rel_changes.append(abs(each)/p1)
                          
                      for each in shap_diff:
                          shap_sq_changes.append(each**2)
                          shap_abs_changes.append(abs(each))
                          shap_rel_changes.append(abs(each)/p1)
                      
                      lime_MSE.append(sum(lime_sq_changes)/len(lime_sq_changes))
                      lime_RMSE.append(math.sqrt(sum(lime_sq_changes)/len(lime_sq_changes)))
                      lime_MAE.append(sum(lime_abs_changes)/len(lime_abs_changes))
                      lime_MAPE.append(sum(lime_rel_changes)/len(lime_rel_changes))
                      
                      shap_MSE.append(sum(shap_sq_changes)/len(shap_sq_changes))
                      shap_RMSE.append(math.sqrt(sum(shap_sq_changes)/len(shap_sq_changes)))
                      shap_MAE.append(sum(shap_abs_changes)/len(shap_abs_changes))
                      shap_MAPE.append(sum(shap_rel_changes)/len(shap_rel_changes))
                  
                  all_caseID.extend(case_id)
                  all_lengths.extend(nr_events)
                  all_proba.extend(proba)
                  
                  all_lime_MSE.extend(lime_MSE)
                  all_lime_RMSE.extend(lime_RMSE)
                  all_lime_MAE.extend(lime_MAE)
                  all_lime_MAPE.extend(lime_MAPE)
                  
                  all_shap_MSE.extend(shap_MSE)
                  all_shap_RMSE.extend(shap_RMSE)
                  all_shap_MAE.extend(shap_MAE)
                  all_shap_MAPE.extend(shap_MAPE)
                  
                  sep_caseID[i].extend(case_id)
                  sep_lengths[i].extend(nr_events)
                  sep_proba[i].extend(proba)
                  
                  sep_lime_MSE[i].extend(lime_MSE)
                  sep_lime_RMSE[i].extend(lime_RMSE)
                  sep_lime_MAE[i].extend(lime_MAE)
                  sep_lime_MAPE[i].extend(lime_MAPE)
                  
                  sep_shap_MSE[i].extend(shap_MSE)
                  sep_shap_RMSE[i].extend(shap_RMSE)
                  sep_shap_MAE[i].extend(shap_MAE)
                  sep_shap_MAPE[i].extend(shap_MAPE)
                  
                  print("Average LIME MSE:", statistics.mean(lime_MSE))
                  print("Average SHAP MSE:", statistics.mean(shap_MSE))
                  print("\n")
                  
                  #plt.plot(nr_events, lime_MSE, 'bo', label = "LIME")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prefix length and MSE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(nr_events, shap_MSE, 'ro', label = "Tree SHAP")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  ##plt.yticks(np.arange(0,15,1))
                  #plt.title("Prefix length and MSE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(proba, lime_MSE, 'bo', label = "LIME")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prediction probability and MSE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(proba, shap_MSE, 'ro', label = "Tree SHAP")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prediction probability and MSE \n"+type_list[i])
                  #plt.show()
                  
                  print("Average LIME RMSE:", statistics.mean(lime_RMSE))
                  print("Average SHAP RMSE:", statistics.mean(shap_RMSE))
                  print("\n")
                  
                  #plt.plot(nr_events, lime_RMSE, 'bo', label = "LIME")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prefix length and RMSE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(nr_events, shap_RMSE, 'ro', label = "Tree SHAP")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prefix length and RMSE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(proba, lime_RMSE, 'bo', label = "LIME")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prediction probability and RMSE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(proba, shap_RMSE, 'ro', label = "Tree SHAP")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prediction probability and RMSE \n"+type_list[i])
                  #plt.show()
                  
                  print("Average LIME MAE:", statistics.mean(lime_MAE))
                  print("Average SHAP MAE:", statistics.mean(shap_MAE))
                  print("\n")
                  
                  #plt.plot(nr_events, lime_MAE, 'bo', label = "LIME")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prefix length and MAE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(nr_events, shap_MAE, 'ro', label = "Tree SHAP")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prefix length and MAE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(proba, lime_MAE, 'bo', label = "LIME")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prediction probability and MAE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(proba, shap_MAE, 'ro', label = "Tree SHAP")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prediction probability and MAE \n"+type_list[i])
                  #plt.show()
                  
                  print("Average LIME MAPE:", statistics.mean(lime_MAPE))
                  print("Average SHAP MAPE:", statistics.mean(shap_MAPE))
                  print("\n")
                  
                  #plt.plot(nr_events, lime_MAPE, 'bo', label = "LIME")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prefix length and MAPE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(nr_events, shap_MAPE, 'ro', label = "Tree SHAP")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prefix length and MAPE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(proba, lime_MAPE, 'bo', label = "LIME")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prediction probability and MAPE \n"+type_list[i])
                  #plt.show()

                  #plt.plot(proba, shap_MAPE, 'ro', label = "Tree SHAP")
                  #plt.xlabel("Prefix Length")
                  #plt.ylabel("Change in Prediction Probability")
                  #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                  #plt.yticks(np.arange(0,15,1))
                  #plt.title("Prediction probability and MAPE \n"+type_list[i])
                  #plt.show()
                else:
                  print("No samples of this type")
# Out:
# Bucket 1
# True Negatives
# Average LIME MSE: 0.05257518972501378
# Average SHAP MSE: 0.20804473286740197
#
#
# Average LIME RMSE: 0.16232310125863064
# Average SHAP RMSE: 0.35714958054162116
#
#
# Average LIME MAE: 0.16194259982585207
# Average SHAP MAE: 0.3556956025193358
#
#
# Average LIME MAPE: 0.24232817823989128
# Average SHAP MAPE: 0.42612476721906467
#
#
# True Positives
# Average LIME MSE: 0.05699630865003993
# Average SHAP MSE: 0.0658172194779925
#
#
# Average LIME RMSE: 0.20142294255385748
# Average SHAP RMSE: 0.22063619797357722
#
#
# Average LIME MAE: 0.16961182057857513
# Average SHAP MAE: 0.21125541478395463
#
#
# Average LIME MAPE: 0.23986218786441485
# Average SHAP MAPE: 0.28082761696813147
#
#
# False Negatives
# Average LIME MSE: 0.05117490176901926
# Average SHAP MSE: 0.3384095683904623
#
#
# Average LIME RMSE: 0.18401307587267013
# Average SHAP RMSE: 0.4991840164323277
#
#
# Average LIME MAE: 0.1827183489687741
# Average SHAP MAE: 0.4987356890109368
#
#
# Average LIME MAPE: 0.26057326011895426
# Average SHAP MAPE: 0.6105313459845866
#
#
# False Positives
# Average LIME MSE: 0.04238408066073248
# Average SHAP MSE: 0.35020886736137224
#
#
# Average LIME RMSE: 0.17325769043861064
# Average SHAP RMSE: 0.4783885385325897
#
#
# Average LIME MAE: 0.12936706066131592
# Average SHAP MAE: 0.47828890442848204
#
#
# Average LIME MAPE: 0.1497381196426792
# Average SHAP MAPE: 0.5500342287627484
#
#
# Bucket 2
# True Negatives
# Average LIME MSE: 0.30267564861175605
# Average SHAP MSE: 0.13007719805167253
#
#
# Average LIME RMSE: 0.4783728916197484
# Average SHAP RMSE: 0.3185656474474335
#
#
# Average LIME MAE: 0.4592973465228819
# Average SHAP MAE: 0.31347240325287984
#
#
# Average LIME MAPE: 0.5824906642403099
# Average SHAP MAPE: 0.4234974845556623
#
#
# True Positives
# Average LIME MSE: 0.2459155353188677
# Average SHAP MSE: 0.14551107720425016
#
#
# Average LIME RMSE: 0.45207671953187334
# Average SHAP RMSE: 0.3036643423771851
#
#
# Average LIME MAE: 0.4475739504609789
# Average SHAP MAE: 0.29928753631455557
#
#
# Average LIME MAPE: 0.5847844626149957
# Average SHAP MAPE: 0.3889539323107703
#
#
# False Negatives
# Average LIME MSE: 0.2857703520847449
# Average SHAP MSE: 0.016792160275261887
#
#
# Average LIME RMSE: 0.45334430877628046
# Average SHAP RMSE: 0.09729519060429934
#
#
# Average LIME MAE: 0.45140022295927335
# Average SHAP MAE: 0.09628789383386901
#
#
# Average LIME MAPE: 0.4861329196674093
# Average SHAP MAPE: 0.12041222830907976
#
#
# False Positives
# Average LIME MSE: 0.3545080884078726
# Average SHAP MSE: 0.15580768721118599
#
#
# Average LIME RMSE: 0.5202799016561457
# Average SHAP RMSE: 0.34299255022180647
#
#
# Average LIME MAE: 0.5151346191763878
# Average SHAP MAE: 0.3395861893892288
#
#
# Average LIME MAPE: 0.6197295480107068
# Average SHAP MAPE: 0.44974518271630687
#
#
# Bucket 3
# True Negatives
# Average LIME MSE: 0.5476232799530598
# Average SHAP MSE: 0.055412162205683804
#
#
# Average LIME RMSE: 0.7251390975077217
# Average SHAP RMSE: 0.18765837931828325
#
#
# Average LIME MAE: 0.6922149533871561
# Average SHAP MAE: 0.18280444690026343
#
#
# Average LIME MAPE: 0.7995234090627446
# Average SHAP MAPE: 0.22145642345532285
#
#
# True Positives
# Average LIME MSE: 0.8096057757705413
# Average SHAP MSE: 0.5244323813378797
#
#
# Average LIME RMSE: 0.8968156411306522
# Average SHAP RMSE: 0.7123971676953099
#
#
# Average LIME MAE: 0.8967211544513702
# Average SHAP MAE: 0.6972346325715383
#
#
# Average LIME MAPE: 0.9607381856254041
# Average SHAP MAPE: 0.7592201713157773
#
#
# False Negatives
# Average LIME MSE: 0.06530364197340299
# Average SHAP MSE: 0.6168119327827897
#
#
# Average LIME RMSE: 0.20610835464861094
# Average SHAP RMSE: 0.7582693625852789
#
#
# Average LIME MAE: 0.15040423427708446
# Average SHAP MAE: 0.7561015472281725
#
#
# Average LIME MAPE: 0.19891951378481204
# Average SHAP MAPE: 0.893697104831779
#
#
# False Positives
# Average LIME MSE: 0.3928772074068372
# Average SHAP MSE: 0.13034900410441053
#
#
# Average LIME RMSE: 0.5932066287634045
# Average SHAP RMSE: 0.28299929685511016
#
#
# Average LIME MAE: 0.5308686006069183
# Average SHAP MAE: 0.28255060195922854
#
#
# Average LIME MAPE: 0.6644335711183943
# Average SHAP MAPE: 0.41989803396110204
#
#
# Bucket 4
# True Negatives
# Average LIME MSE: 0.42024206600698166
# Average SHAP MSE: 0.22209848912381666
#
#
# Average LIME RMSE: 0.5817362827254182
# Average SHAP RMSE: 0.39097064016579564
#
#
# Average LIME MAE: 0.5654270699519354
# Average SHAP MAE: 0.38148807047788674
#
#
# Average LIME MAPE: 0.6762977886447213
# Average SHAP MAPE: 0.4855388530784517
#
#
# True Positives
# Average LIME MSE: 0.5252971056084863
# Average SHAP MSE: 0.27340492158320123
#
#
# Average LIME RMSE: 0.6645106133810919
# Average SHAP RMSE: 0.39391733050801864
#
#
# Average LIME MAE: 0.6641054105758667
# Average SHAP MAE: 0.37820066094398497
#
#
# Average LIME MAPE: 0.7380738743565192
# Average SHAP MAPE: 0.4247546235593422
#
#
# False Negatives
# Average LIME MSE: 0.3997890392375999
# Average SHAP MSE: 0.3687741142829831
#
#
# Average LIME RMSE: 0.5867812111677848
# Average SHAP RMSE: 0.48914145518888685
#
#
# Average LIME MAE: 0.541043434466701
# Average SHAP MAE: 0.48585368114290756
#
#
# Average LIME MAPE: 0.6305157446169495
# Average SHAP MAPE: 0.5782969837747189
#
#
# False Positives
# Average LIME MSE: 0.528419218526339
# Average SHAP MSE: 0.1831753073469507
#
#
# Average LIME RMSE: 0.6525041435276634
# Average SHAP RMSE: 0.24478082654199612
#
#
# Average LIME MAE: 0.639347867667675
# Average SHAP MAE: 0.24257855117321014
#
#
# Average LIME MAPE: 0.6787741123634661
# Average SHAP MAPE: 0.27289550754736014
#
#
# Bucket 5
# True Negatives
# Average LIME MSE: 0.19327947808804216
# Average SHAP MSE: 0.12380166645410762
#
#
# Average LIME RMSE: 0.3824313167169158
# Average SHAP RMSE: 0.31611348625142227
#
#
# Average LIME MAE: 0.3319795020994207
# Average SHAP MAE: 0.311298299687769
#
#
# Average LIME MAPE: 0.42059320373809567
# Average SHAP MAPE: 0.44814669614280334
#
#
# True Positives
# Average LIME MSE: 0.17487992583636833
# Average SHAP MSE: 0.01643997954131473
#
#
# Average LIME RMSE: 0.3888703031480901
# Average SHAP RMSE: 0.09122111335526677
#
#
# Average LIME MAE: 0.2892520233988762
# Average SHAP MAE: 0.09118626862764359
#
#
# Average LIME MAPE: 0.33709605699886125
# Average SHAP MAPE: 0.11369115828182605
#
#
# False Negatives
# Average LIME MSE: 0.20989024846507756
# Average SHAP MSE: 0.07094635875898066
#
#
# Average LIME RMSE: 0.37920073823138345
# Average SHAP RMSE: 0.2178695934049744
#
#
# Average LIME MAE: 0.34542342038330387
# Average SHAP MAE: 0.21782664065685822
#
#
# Average LIME MAPE: 0.411633193296835
# Average SHAP MAPE: 0.33439977107822555
#
#
# False Positives
# Average LIME MSE: 0.20918597585513463
# Average SHAP MSE: 0.021949721328418666
#
#
# Average LIME RMSE: 0.372489080556635
# Average SHAP RMSE: 0.1253106171118721
#
#
# Average LIME MAE: 0.36285457213719685
# Average SHAP MAE: 0.12359876632690431
#
#
# Average LIME MAPE: 0.43979421785118705
# Average SHAP MAPE: 0.15427645648496982
#
#
# Bucket 6
# True Negatives
# Average LIME MSE: 0.06028025715063941
# Average SHAP MSE: 0.3557311934404143
#
#
# Average LIME RMSE: 0.23823387463294307
# Average SHAP RMSE: 0.5728952494865049
#
#
# Average LIME MAE: 0.2070904765355711
# Average SHAP MAE: 0.5554753255176669
#
#
# Average LIME MAPE: 0.22106046985059788
# Average SHAP MAPE: 0.5896999780536316
#
#
# True Positives
# Average LIME MSE: 0.32192225861954255
# Average SHAP MSE: 0.11857886431154348
#
#
# Average LIME RMSE: 0.5462880449131248
# Average SHAP RMSE: 0.27869583046263074
#
#
# Average LIME MAE: 0.4991752505302429
# Average SHAP MAE: 0.27227085709571835
#
#
# Average LIME MAPE: 0.6740795485454371
# Average SHAP MAPE: 0.42671361880568887
#
#
# False Negatives
# Average LIME MSE: 0.006734514273134896
# Average SHAP MSE: 0.538129999339356
#
#
# Average LIME RMSE: 0.05881425313742364
# Average SHAP RMSE: 0.7235493317981907
#
#
# Average LIME MAE: 0.03198368328644392
# Average SHAP MAE: 0.6433047123534834
#
#
# Average LIME MAPE: 0.03198475951812294
# Average SHAP MAPE: 0.6433143501309699
#
#
# False Positives
# Average LIME MSE: 0.293680714655628
# Average SHAP MSE: 0.28650405139675594
#
#
# Average LIME RMSE: 0.4771336974416542
# Average SHAP RMSE: 0.4347186693529107
#
#
# Average LIME MAE: 0.4588677555322647
# Average SHAP MAE: 0.43187619969248775
#
#
# Average LIME MAPE: 0.598480970292126
# Average SHAP MAPE: 0.577664271903315
#
#
# Bucket 7
# True Negatives
# Average LIME MSE: 0.233663650809949
# Average SHAP MSE: 0.173801560903194
#
#
# Average LIME RMSE: 0.40754721428354657
# Average SHAP RMSE: 0.3472182659749683
#
#
# Average LIME MAE: 0.38047779345535676
# Average SHAP MAE: 0.30288536167121494
#
#
# Average LIME MAPE: 0.4493911164907168
# Average SHAP MAPE: 0.3612362404013517
#
#
# True Positives
# Average LIME MSE: 0.3287630185930482
# Average SHAP MSE: 0.13751188085935206
#
#
# Average LIME RMSE: 0.539924748787602
# Average SHAP RMSE: 0.29292798334989245
#
#
# Average LIME MAE: 0.4975233495235443
# Average SHAP MAE: 0.27109452337026596
#
#
# Average LIME MAPE: 0.5552474024683753
# Average SHAP MAPE: 0.33794458142669803
#
#
# False Negatives
# Average LIME MSE: 0.16777238120201565
# Average SHAP MSE: 0.22827321806673076
#
#
# Average LIME RMSE: 0.36318915220251574
# Average SHAP RMSE: 0.40950133659690874
#
#
# Average LIME MAE: 0.3395476872069897
# Average SHAP MAE: 0.375184777542745
#
#
# Average LIME MAPE: 0.4466386639720801
# Average SHAP MAPE: 0.49945904715854
#
#
# False Positives
# Average LIME MSE: 0.24065461143047165
# Average SHAP MSE: 0.05900100271737454
#
#
# Average LIME RMSE: 0.44507496637165406
# Average SHAP RMSE: 0.17118810993666123
#
#
# Average LIME MAE: 0.40645482987165454
# Average SHAP MAE: 0.1696464776992798
#
#
# Average LIME MAPE: 0.4757272421213956
# Average SHAP MAPE: 0.21471108574857664
#
#
# Bucket 8
# True Negatives
# Average LIME MSE: 0.29588354199674716
# Average SHAP MSE: 0.20222323974705178
#
#
# Average LIME RMSE: 0.49254033491325955
# Average SHAP RMSE: 0.3835640018120281
#
#
# Average LIME MAE: 0.45628463218842324
# Average SHAP MAE: 0.37569650302563484
#
#
# Average LIME MAPE: 0.5705471146710562
# Average SHAP MAPE: 0.5058599051545053
#
#
# True Positives
# Average LIME MSE: 0.3701921786117672
# Average SHAP MSE: 0.16451574664531468
#
#
# Average LIME RMSE: 0.5215209937715223
# Average SHAP RMSE: 0.24282158717740546
#
#
# Average LIME MAE: 0.5194182217121124
# Average SHAP MAE: 0.24280330340067546
#
#
# Average LIME MAPE: 0.5559191005453442
# Average SHAP MAPE: 0.33560347964763604
#
#
# False Negatives
# Average LIME MSE: 0.2706606831116767
# Average SHAP MSE: 0.5522205252539085
#
#
# Average LIME RMSE: 0.4726585013867116
# Average SHAP RMSE: 0.6629635567903989
#
#
# Average LIME MAE: 0.40358561180066316
# Average SHAP MAE: 0.6618000652594492
#
#
# Average LIME MAPE: 0.46270133007455205
# Average SHAP MAPE: 0.7405286281912302
#
#
# False Positives
# Average LIME MSE: 0.3997964312241482
# Average SHAP MSE: 0.02124449574813001
#
#
# Average LIME RMSE: 0.49894084725354904
# Average SHAP RMSE: 0.12481060082774495
#
#
# Average LIME MAE: 0.490431421995163
# Average SHAP MAE: 0.10927736312150955
#
#
# Average LIME MAPE: 0.5125294160660657
# Average SHAP MAPE: 0.143345780149477
#
#
# Bucket 9
# True Negatives
# Average LIME MSE: 0.3219322268073064
# Average SHAP MSE: 0.47090989229723335
#
#
# Average LIME RMSE: 0.48129174104586653
# Average SHAP RMSE: 0.6314749291372648
#
#
# Average LIME MAE: 0.4411234670968042
# Average SHAP MAE: 0.6287133210988032
#
#
# Average LIME MAPE: 0.5357463734520171
# Average SHAP MAPE: 0.7384537336628542
#
#
# True Positives
# Average LIME MSE: 0.5495343869125667
# Average SHAP MSE: 0.25342469893883063
#
#
# Average LIME RMSE: 0.6931811486957831
# Average SHAP RMSE: 0.3984211232769587
#
#
# Average LIME MAE: 0.6814150261878967
# Average SHAP MAE: 0.3897530889511108
#
#
# Average LIME MAPE: 0.8084566374172919
# Average SHAP MAPE: 0.49831203804304025
#
#
# False Negatives
# Average LIME MSE: 0.49301539133805883
# Average SHAP MSE: 0.4775413348311115
#
#
# Average LIME RMSE: 0.6892125784095611
# Average SHAP RMSE: 0.6067167717373505
#
#
# Average LIME MAE: 0.6170819289749488
# Average SHAP MAE: 0.6031996555393562
#
#
# Average LIME MAPE: 0.7687674758073049
# Average SHAP MAPE: 0.7290758925248583
#
#
# False Positives
# Average LIME MSE: 0.38703192265112674
# Average SHAP MSE: 0.2591141606178923
#
#
# Average LIME RMSE: 0.5682684643605752
# Average SHAP RMSE: 0.37640953203355093
#
#
# Average LIME MAE: 0.5244064956903458
# Average SHAP MAE: 0.3763720413049062
#
#
# Average LIME MAPE: 0.6317565129657133
# Average SHAP MAPE: 0.5035477431544632
#
#
# Bucket 10
# True Negatives
# Average LIME MSE: 0.2362381206784016
# Average SHAP MSE: 0.4075484682520095
#
#
# Average LIME RMSE: 0.47612776144789004
# Average SHAP RMSE: 0.5449448649561534
#
#
# Average LIME MAE: 0.4032894578902051
# Average SHAP MAE: 0.537310813232325
#
#
# Average LIME MAPE: 0.5710871115047462
# Average SHAP MAPE: 0.6940576118062753
#
#
# True Positives
# Average LIME MSE: 0.3997557343178362
# Average SHAP MSE: 0.35834964007997183
#
#
# Average LIME RMSE: 0.5677194884203125
# Average SHAP RMSE: 0.5400829005992022
#
#
# Average LIME MAE: 0.5368969112634658
# Average SHAP MAE: 0.5275043328603108
#
#
# Average LIME MAPE: 0.6434205952975465
# Average SHAP MAPE: 0.6316840400118789
#
#
# False Negatives
# Average LIME MSE: 0.274873155985224
# Average SHAP MSE: 0.6214105465169125
#
#
# Average LIME RMSE: 0.46636458688449506
# Average SHAP RMSE: 0.7555907780969449
#
#
# Average LIME MAE: 0.42539438648356737
# Average SHAP MAE: 0.7512073297633105
#
#
# Average LIME MAPE: 0.4916837979592802
# Average SHAP MAPE: 0.8800535061164343
#
#
# False Positives
# Average LIME MSE: 0.18670941337684008
# Average SHAP MSE: 0.5501546697862452
#
#
# Average LIME RMSE: 0.3722079310295992
# Average SHAP RMSE: 0.6171787403262384
#
#
# Average LIME MAE: 0.32618177533149717
# Average SHAP MAE: 0.6164010683695476
#
#
# Average LIME MAPE: 0.33663271680917856
# Average SHAP MAPE: 0.670104103417005
#
#
# Bucket 11
# True Negatives
# Average LIME MSE: 0.09452281517941624
# Average SHAP MSE: 0.2526955038677409
#
#
# Average LIME RMSE: 0.2865104795766945
# Average SHAP RMSE: 0.4031719465878055
#
#
# Average LIME MAE: 0.27260432646609845
# Average SHAP MAE: 0.3984559609461576
#
#
# Average LIME MAPE: 0.3660048567543117
# Average SHAP MAPE: 0.4875567859919886
#
#
# True Positives
# Average LIME MSE: 0.4986189751228478
# Average SHAP MSE: 0.023519263998038477
#
#
# Average LIME RMSE: 0.6478970569191081
# Average SHAP RMSE: 0.10995975079590818
#
#
# Average LIME MAE: 0.5867400109767914
# Average SHAP MAE: 0.1090348094701767
#
#
# Average LIME MAPE: 0.6252794110071036
# Average SHAP MAPE: 0.13847740312393214
#
#
# False Negatives
# Average LIME MSE: 0.2943081601939559
# Average SHAP MSE: 0.32489072430216104
#
#
# Average LIME RMSE: 0.4529210013993753
# Average SHAP RMSE: 0.4820645127287311
#
#
# Average LIME MAE: 0.42514781405528385
# Average SHAP MAE: 0.436542202035586
#
#
# Average LIME MAPE: 0.4818901836375143
# Average SHAP MAPE: 0.5013941643361538
#
#
# False Positives
# Average LIME MSE: 0.391168685707983
# Average SHAP MSE: 0.011091703637591386
#
#
# Average LIME RMSE: 0.5340089530052802
# Average SHAP RMSE: 0.08789298177787729
#
#
# Average LIME MAE: 0.5064731140931448
# Average SHAP MAE: 0.08682800928751627
#
#
# Average LIME MAPE: 0.5142131692307659
# Average SHAP MAPE: 0.09401434483675206
#
#
# Bucket 12
# True Negatives
# Average LIME MSE: 0.21363149827155825
# Average SHAP MSE: 0.5182966708362816
#
#
# Average LIME RMSE: 0.3148573214034193
# Average SHAP RMSE: 0.6667703620231541
#
#
# Average LIME MAE: 0.3083780583925545
# Average SHAP MAE: 0.6663394464878365
#
#
# Average LIME MAPE: 0.3338871342039805
# Average SHAP MAPE: 0.7109653759699797
#
#
# True Positives
# Average LIME MSE: 0.2546919962587412
# Average SHAP MSE: 0.34130234340592297
#
#
# Average LIME RMSE: 0.4131512188936896
# Average SHAP RMSE: 0.4725658462851383
#
#
# Average LIME MAE: 0.402143295109272
# Average SHAP MAE: 0.4491688385605812
#
#
# Average LIME MAPE: 0.5130818895447904
# Average SHAP MAPE: 0.60290831251894
#
#
# False Negatives
# Average LIME MSE: 0.1769695601151401
# Average SHAP MSE: 0.3826282451543803
#
#
# Average LIME RMSE: 0.34131308800978155
# Average SHAP RMSE: 0.5034782574289018
#
#
# Average LIME MAE: 0.2998558792596062
# Average SHAP MAE: 0.5025389664495985
#
#
# Average LIME MAPE: 0.39294441342762865
# Average SHAP MAPE: 0.6375804931685122
#
#
# False Positives
# Average LIME MSE: 0.3360838215879011
# Average SHAP MSE: 0.017857360456079382
#
#
# Average LIME RMSE: 0.5525401451917967
# Average SHAP RMSE: 0.09455209954303948
#
#
# Average LIME MAE: 0.5038195451100668
# Average SHAP MAE: 0.0909110943476359
#
#
# Average LIME MAPE: 0.6080979869954691
# Average SHAP MAPE: 0.12547550946783648
#
#
# Bucket 13
# True Negatives
# Average LIME MSE: 0.2165061033254491
# Average SHAP MSE: 0.3935773255187758
#
#
# Average LIME RMSE: 0.3298996719064208
# Average SHAP RMSE: 0.6038286152413356
#
#
# Average LIME MAE: 0.31155135203152895
# Average SHAP MAE: 0.557536427094601
#
#
# Average LIME MAPE: 0.3924381700424384
# Average SHAP MAPE: 0.6248252649139365
#
#
# True Positives
# Average LIME MSE: 0.6767930612017743
# Average SHAP MSE: 0.4387816575051449
#
#
# Average LIME RMSE: 0.803380317651802
# Average SHAP RMSE: 0.5196923042083105
#
#
# Average LIME MAE: 0.7379091113805771
# Average SHAP MAE: 0.4938038796186447
#
#
# Average LIME MAPE: 0.7806136870904151
# Average SHAP MAPE: 0.5385462618273629
#
#
# False Negatives
# Average LIME MSE: 0.27841359143744165
# Average SHAP MSE: 0.3023829507652231
#
#
# Average LIME RMSE: 0.49851284265504836
# Average SHAP RMSE: 0.459665830571919
#
#
# Average LIME MAE: 0.4120053187012672
# Average SHAP MAE: 0.4591857746243477
#
#
# Average LIME MAPE: 0.5127902969065187
# Average SHAP MAPE: 0.5788973528046296
#
#
# False Positives
# Average LIME MSE: 0.7245882646462523
# Average SHAP MSE: 0.9783834858396818
#
#
# Average LIME RMSE: 0.8390632604351582
# Average SHAP RMSE: 0.9891192896579628
#
#
# Average LIME MAE: 0.8116950452327728
# Average SHAP MAE: 0.9891192376613618
#
#
# Average LIME MAPE: 0.8199025518632701
# Average SHAP MAPE: 0.9975669728609063
#
#
# Bucket 14
# True Negatives
# Average LIME MSE: 0.16853898115494903
# Average SHAP MSE: 0.6377490592857378
#
#
# Average LIME RMSE: 0.2482946246897059
# Average SHAP RMSE: 0.7489748561659095
#
#
# Average LIME MAE: 0.2445315901112432
# Average SHAP MAE: 0.7441116095132505
#
#
# Average LIME MAPE: 0.33981186746828945
# Average SHAP MAPE: 0.7958778983288382
#
#
# True Positives
# Average LIME MSE: 0.0903299142941715
# Average SHAP MSE: 0.18053912102855668
#
#
# Average LIME RMSE: 0.27915669911179036
# Average SHAP RMSE: 0.2727361408191261
#
#
# Average LIME MAE: 0.21306384950876237
# Average SHAP MAE: 0.2713435381650925
#
#
# Average LIME MAPE: 0.24721271709744927
# Average SHAP MAPE: 0.30445987173290967
#
#
# False Negatives
# Average LIME MSE: 0.2634626528614389
# Average SHAP MSE: 0.4418951136680159
#
#
# Average LIME RMSE: 0.3803139879935324
# Average SHAP RMSE: 0.5096290357537338
#
#
# Average LIME MAE: 0.3801887189038098
# Average SHAP MAE: 0.5031099066138267
#
#
# Average LIME MAPE: 0.3851909262924419
# Average SHAP MAPE: 0.522203671195517
#
#
# False Positives
# Average LIME MSE: 0.4304314579278254
# Average SHAP MSE: 0.46383369882092235
#
#
# Average LIME RMSE: 0.63665420512624
# Average SHAP RMSE: 0.4887608099182077
#
#
# Average LIME MAE: 0.5732264012098313
# Average SHAP MAE: 0.48874788582324985
#
#
# Average LIME MAPE: 0.5870486690244666
# Average SHAP MAPE: 0.5015084454876695
#
#
# Bucket 15
# True Negatives
# Average LIME MSE: 0.0989017882362597
# Average SHAP MSE: 0.061808315475221975
#
#
# Average LIME RMSE: 0.28153539132785427
# Average SHAP RMSE: 0.23060973668676807
#
#
# Average LIME MAE: 0.2317307951549689
# Average SHAP MAE: 0.2278797832628091
#
#
# Average LIME MAPE: 0.2620773061619254
# Average SHAP MAPE: 0.2898905897997127
#
#
# True Positives
# Average LIME MSE: 0.17569814782552032
# Average SHAP MSE: 0.01730667793565006
#
#
# Average LIME RMSE: 0.40956674070054133
# Average SHAP RMSE: 0.09662565023443594
#
#
# Average LIME MAE: 0.3616185292601585
# Average SHAP MAE: 0.07857896238565446
#
#
# Average LIME MAPE: 0.44820369248019004
# Average SHAP MAPE: 0.11237637318363684
#
#
# False Negatives
# Average LIME MSE: 0.08899190010797296
# Average SHAP MSE: 0.07521705175123296
#
#
# Average LIME RMSE: 0.26449297337851824
# Average SHAP RMSE: 0.2147126559446796
#
#
# Average LIME MAE: 0.20905818427854683
# Average SHAP MAE: 0.21404948219909178
#
#
# Average LIME MAPE: 0.3589085342893481
# Average SHAP MAPE: 0.3593547033783674
#
#
# False Positives
# Average LIME MSE: 0.23012411644207992
# Average SHAP MSE: 0.02197720787892846
#
#
# Average LIME RMSE: 0.3964710985617367
# Average SHAP RMSE: 0.11053969309759827
#
#
# Average LIME MAE: 0.3120603481928507
# Average SHAP MAE: 0.10777433514595032
#
#
# Average LIME MAPE: 0.3298381872233282
# Average SHAP MAPE: 0.11261066711893179
#
#
# Bucket 16
# True Negatives
# Average LIME MSE: 0.6721860938099592
# Average SHAP MSE: 0.2891734649682945
#
#
# Average LIME RMSE: 0.8132591773738735
# Average SHAP RMSE: 0.42065748860353863
#
#
# Average LIME MAE: 0.786146720374624
# Average SHAP MAE: 0.40905339928964773
#
#
# Average LIME MAPE: 0.8501282875984786
# Average SHAP MAPE: 0.42288375825137875
#
#
# True Positives
# Average LIME MSE: 0.654311862007813
# Average SHAP MSE: 0.6754832974450755
#
#
# Average LIME RMSE: 0.7064817575823755
# Average SHAP RMSE: 0.7910682870701273
#
#
# Average LIME MAE: 0.6999938209851583
# Average SHAP MAE: 0.7899657150109609
#
#
# Average LIME MAPE: 0.7348347643042373
# Average SHAP MAPE: 0.9156610810726041
#
#
# False Negatives
# Average LIME MSE: 0.31264482099430796
# Average SHAP MSE: 0.15919258429470934
#
#
# Average LIME RMSE: 0.5591465112064171
# Average SHAP RMSE: 0.3989894538640205
#
#
# Average LIME MAE: 0.5591425478458405
# Average SHAP MAE: 0.39891533851623534
#
#
# Average LIME MAPE: 0.9865446526661963
# Average SHAP MAPE: 0.7038416153374566
#
#
# False Positives
# Average LIME MSE: 0.8206727235096973
# Average SHAP MSE: 0.2682855408557484
#
#
# Average LIME RMSE: 0.9048600170715364
# Average SHAP RMSE: 0.46494467698958863
#
#
# Average LIME MAE: 0.89364904910326
# Average SHAP MAE: 0.38795544654130937
#
#
# Average LIME MAPE: 0.9624035892446197
# Average SHAP MAPE: 0.40406521868268547
#
#
# Bucket 17
# True Negatives
# No samples of this type
# True Positives
# Average LIME MSE: 0.6305879760103703
# Average SHAP MSE: 0.08414445306202153
#
#
# Average LIME RMSE: 0.7751848399136869
# Average SHAP RMSE: 0.26445842199972275
#
#
# Average LIME MAE: 0.6886080026626586
# Average SHAP MAE: 0.2641895294189453
#
#
# Average LIME MAPE: 0.6995733572975432
# Average SHAP MAPE: 0.26878137577088074
#
#
# False Negatives
# Average LIME MSE: 0.7422018513785866
# Average SHAP MSE: 0.478234120007662
#
#
# Average LIME RMSE: 0.8579936035782347
# Average SHAP RMSE: 0.6128467637928596
#
#
# Average LIME MAE: 0.857991199940443
# Average SHAP MAE: 0.6061402432620525
#
#
# Average LIME MAPE: 0.9917559896276771
# Average SHAP MAPE: 0.6740275052348226
#
#
# False Positives
# Average LIME MSE: 0.7502540773907288
# Average SHAP MSE: 0.20684518016607178
#
#
# Average LIME RMSE: 0.8551657105809826
# Average SHAP RMSE: 0.39569469862020273
#
#
# Average LIME MAE: 0.8533895949522654
# Average SHAP MAE: 0.3935479780038198
#
#
# Average LIME MAPE: 0.9459083860681484
# Average SHAP MAPE: 0.43903955173627673
#
#
# Bucket 18
# True Negatives
# Average LIME MSE: 0.10586409033409908
# Average SHAP MSE: 0.9793075336842845
#
#
# Average LIME RMSE: 0.3246917197890019
# Average SHAP RMSE: 0.98955700496992
#
#
# Average LIME MAE: 0.13418056087684818
# Average SHAP MAE: 0.9895567121624481
#
#
# Average LIME MAPE: 0.13474200135582223
# Average SHAP MAPE: 0.9944227537423663
#
#
# True Positives
# Average LIME MSE: 0.06270454243747174
# Average SHAP MSE: 0.8348963903821642
#
#
# Average LIME RMSE: 0.2092358738291636
# Average SHAP RMSE: 0.9137231788896958
#
#
# Average LIME MAE: 0.14125797152519226
# Average SHAP MAE: 0.8878733485937118
#
#
# Average LIME MAPE: 0.14135612450482493
# Average SHAP MAPE: 0.8885112804417894
#
#
# False Negatives
# No samples of this type
# False Positives
# Average LIME MSE: 0.5802360529798083
# Average SHAP MSE: 0.9892625784787974
#
#
# Average LIME RMSE: 0.7617322711949444
# Average SHAP RMSE: 0.9946167998172951
#
#
# Average LIME MAE: 0.7250496327877045
# Average SHAP MAE: 0.9946139335632325
#
#
# Average LIME MAPE: 0.7251416952497294
# Average SHAP MAPE: 0.9947402236864837
#
#
# Bucket 19
# True Negatives
# Average LIME MSE: 0.6533072522085086
# Average SHAP MSE: 0.2549329709628794
#
#
# Average LIME RMSE: 0.7966916483037347
# Average SHAP RMSE: 0.4980450113374163
#
#
# Average LIME MAE: 0.6855076689273119
# Average SHAP MAE: 0.36035978533327584
#
#
# Average LIME MAPE: 0.6969274175213748
# Average SHAP MAPE: 0.36615757110211666
#
#
# True Positives
# Average LIME MSE: 0.3384157587342068
# Average SHAP MSE: 0.6937967769114437
#
#
# Average LIME RMSE: 0.5282302725354701
# Average SHAP RMSE: 0.8127266159463861
#
#
# Average LIME MAE: 0.4063584476709366
# Average SHAP MAE: 0.7079598724842071
#
#
# Average LIME MAPE: 0.4068914012114655
# Average SHAP MAPE: 0.7088947719592225
#
#
# False Negatives
# Average LIME MSE: 0.6027882932278248
# Average SHAP MSE: 0.14823295066887499
#
#
# Average LIME RMSE: 0.7763944185965177
# Average SHAP RMSE: 0.38501032540553376
#
#
# Average LIME MAE: 0.650999478623271
# Average SHAP MAE: 0.18956220634281634
#
#
# Average LIME MAPE: 0.6600325360115283
# Average SHAP MAPE: 0.192192509967883
#
#
# False Positives
# Average LIME MSE: 0.377812897112984
# Average SHAP MSE: 0.19279220234693906
#
#
# Average LIME RMSE: 0.46165611268602136
# Average SHAP RMSE: 0.3276208842965575
#
#
# Average LIME MAE: 0.4389471739530563
# Average SHAP MAE: 0.21149339973926543
#
#
# Average LIME MAPE: 0.44356717675433305
# Average SHAP MAPE: 0.21393280626287206
#
#
# Bucket 20
# True Negatives
# Average LIME MSE: 0.6563838203049296
# Average SHAP MSE: 0.40817997125854155
#
#
# Average LIME RMSE: 0.8101751787761271
# Average SHAP RMSE: 0.6388896393419927
#
#
# Average LIME MAE: 0.8064284719526768
# Average SHAP MAE: 0.5172427870333195
#
#
# Average LIME MAPE: 0.8105491381245613
# Average SHAP MAPE: 0.5198857800938429
#
#
# True Positives
# Average LIME MSE: 0.8049785245703962
# Average SHAP MSE: 0.48096328053739545
#
#
# Average LIME RMSE: 0.8972059543774753
# Average SHAP RMSE: 0.6935151624423185
#
#
# Average LIME MAE: 0.861126309633255
# Average SHAP MAE: 0.5218478381633759
#
#
# Average LIME MAPE: 0.8613377779905523
# Average SHAP MAPE: 0.5219759892880844
#
#
# False Negatives
# Average LIME MSE: 0.6634836747755364
# Average SHAP MSE: 0.18337991533589335
#
#
# Average LIME RMSE: 0.7937172092245398
# Average SHAP RMSE: 0.40850802233981354
#
#
# Average LIME MAE: 0.7920434217900038
# Average SHAP MAE: 0.31962029449641705
#
#
# Average LIME MAPE: 0.9420094588756581
# Average SHAP MAPE: 0.38780335470851823
#
#
# False Positives
# Average LIME MSE: 0.5913474999298189
# Average SHAP MSE: 0.14020613417985112
#
#
# Average LIME RMSE: 0.7588939624456275
# Average SHAP RMSE: 0.2893216149654385
#
#
# Average LIME MAE: 0.6577634900808335
# Average SHAP MAE: 0.19766830205917357
#
#
# Average LIME MAPE: 0.6788727017570353
# Average SHAP MAPE: 0.20646326016461702

# %%
data
# Out:
#    caseID  ...                                    lime_fid_change
# 0  SLA_20  ...  [0.9418181, 0.9170844, 0.9237307, 0.94746315, ...
# 1   LG_20  ...  [0.021001577, 0.89764124, 0.8967927, -0.000194...
#
# [2 rows x 19 columns]

# %%
sns.scatterplot(all_proba, all_lime_MSE, hue = all_lengths, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("LIME: Prediction probability and MSE \nPrefix-length Bucket with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_MSE, hue = all_lengths, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("SHAP: Prediction probability and MSE \nPrefix-length Bucket with Aggregate Encoding")
plt.show()

# %%
sns.scatterplot(all_proba, all_lime_RMSE, hue = all_lengths, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("LIME: Prediction probability and RMSE \nPrefix-length Bucket with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_RMSE, hue = all_lengths, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("SHAP: Prediction probability and RMSE \nPrefix-length Bucket with Aggregate Encoding")
plt.show()

# %%
sns.scatterplot(all_proba, all_lime_MAE, hue = all_lengths, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("LIME: Prediction probability and MAE \nPrefix-length Bucket with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_MAE, hue = all_lengths, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("SHAP: Prediction probability and MAE \nPrefix-length Bucket with Aggregate Encoding")
plt.show()

# %%
sns.scatterplot(all_proba, all_lime_MAPE, hue = all_lengths, palette = lime_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("LIME: Prediction probability and MAPE \nPrefix-length Bucket with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_MAPE, hue = all_lengths, palette = shap_pal)
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("SHAP: Prediction probability and MAPE \nPrefix-length Bucket with Aggregate Encoding")
plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MSE[i], hue = sep_lengths[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MSE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MSE[i], hue = sep_lengths[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MSE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_RMSE[i], hue = sep_lengths[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and RMSE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_RMSE[i], hue = sep_lengths[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and RMSE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAE[i], hue = sep_lengths[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAE[i], hue = sep_lengths[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAPE[i], hue = sep_lengths[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAPE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAPE[i], hue = sep_lengths[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAPE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_MSE = [[],[]]
type_shap_MSE = [[],[]]

type_lime_MSE[0].extend(sep_lime_MSE[0])
type_lime_MSE[0].extend(sep_lime_MSE[2])
type_lime_MSE[1].extend(sep_lime_MSE[1])
type_lime_MSE[1].extend(sep_lime_MSE[3])

type_shap_MSE[0].extend(sep_shap_MSE[0])
type_shap_MSE[0].extend(sep_shap_MSE[2])
type_shap_MSE[1].extend(sep_shap_MSE[1])
type_shap_MSE[1].extend(sep_shap_MSE[3])

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MSE[i], hue = sep_lengths[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MSE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MSE[i], hue = sep_lengths[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MSE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_RMSE = [[],[]]
type_shap_RMSE = [[],[]]

type_lime_RMSE[0].extend(sep_lime_RMSE[0])
type_lime_RMSE[0].extend(sep_lime_RMSE[2])
type_lime_RMSE[1].extend(sep_lime_RMSE[1])
type_lime_RMSE[1].extend(sep_lime_RMSE[3])

type_shap_RMSE[0].extend(sep_shap_RMSE[0])
type_shap_RMSE[0].extend(sep_shap_RMSE[2])
type_shap_RMSE[1].extend(sep_shap_RMSE[1])
type_shap_RMSE[1].extend(sep_shap_RMSE[3])

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_RMSE[i], hue = sep_lengths[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and RMSE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_RMSE[i], hue = sep_lengths[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and RMSE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_MAE = [[],[]]
type_shap_MAE = [[],[]]

type_lime_MAE[0].extend(sep_lime_MAE[0])
type_lime_MAE[0].extend(sep_lime_MAE[2])
type_lime_MAE[1].extend(sep_lime_MAE[1])
type_lime_MAE[1].extend(sep_lime_MAE[3])

type_shap_MAE[0].extend(sep_shap_MAE[0])
type_shap_MAE[0].extend(sep_shap_MAE[2])
type_shap_MAE[1].extend(sep_shap_MAE[1])
type_shap_MAE[1].extend(sep_shap_MAE[3])

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAE[i], hue = sep_lengths[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAE[i], hue = sep_lengths[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_MAPE = [[],[]]
type_shap_MAPE = [[],[]]

type_lime_MAPE[0].extend(sep_lime_MAPE[0])
type_lime_MAPE[0].extend(sep_lime_MAPE[2])
type_lime_MAPE[1].extend(sep_lime_MAPE[1])
type_lime_MAPE[1].extend(sep_lime_MAPE[3])

type_shap_MAPE[0].extend(sep_shap_MAPE[0])
type_shap_MAPE[0].extend(sep_shap_MAPE[2])
type_shap_MAPE[1].extend(sep_shap_MAPE[1])
type_shap_MAPE[1].extend(sep_shap_MAPE[3])

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAPE[i], hue = sep_lengths[i], palette = lime_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAPE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAPE[i], hue = sep_lengths[i], palette = shap_pal)
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAPE \nPrefix-length Bucket with Aggregate Encoding")
    plt.show()

# %%
print("Average LIME MSE:", np.mean(all_lime_MSE))
print("Average SHAP MSE:", np.mean(all_shap_MSE))
print("\n")

print("Average LIME RMSE:", np.mean(all_lime_RMSE))
print("Average SHAP RMSE:", np.mean(all_shap_RMSE))
print("\n")

print("Average LIME MAE:", np.mean(all_lime_MAE))
print("Average SHAP MAE:", np.mean(all_shap_MAE))
print("\n")

print("Average LIME MAPE:", np.mean(all_lime_MAPE))
print("Average SHAP MAPE:", np.mean(all_shap_MAPE))
# Out:
# Average LIME MSE: 0.3212056289238599
# Average SHAP MSE: 0.26876007338974095
#
#
# Average LIME RMSE: 0.4858009811526588
# Average SHAP RMSE: 0.4069385012731512
#
#
# Average LIME MAE: 0.45101235227481934
# Average SHAP MAE: 0.39282760750581386
#
#
# Average LIME MAPE: 0.5298854978486026
# Average SHAP MAPE: 0.4712017045434181
