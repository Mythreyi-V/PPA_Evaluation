# %%
#from google.colab import drive
#drive.mount('/content/drive')
import sys
#PATH = '/content/drive/My Drive/PPM_Stability/'
#PATH = "C:/Users/velmurug/Documents/Stability Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/Mythreyi/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
PATH = "C:/Users/mythr/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/n9455647/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
sys.path.append(PATH)

# %%
from DatasetManager import DatasetManager

import pandas as pd
import numpy as np

import os
import sys
from sys import argv
import pickle
import random
import joblib

import statistics
import math

import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

lime_pal = sns.diverging_palette(100, 200, s=150)#, as_cmap=True)
shap_pal = sns.diverging_palette(0, 240, s=150)#, as_cmap=True)

sns.set_style('darkgrid')

# %%
dataset_ref = "production"
params_dir = PATH + "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "agg"
cls_method = "xgboost"

gap = 1
n_iter = 1

method_name = "%s_%s"%(bucket_method, cls_encoding)

generate_samples = False
generate_lime = True
generate_kernel_shap = False
generate_model_shap = True

sample_size = 2
exp_iter = 10
max_feat = 10
max_prefix = 20

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"],
    #"insurance": ["insurance_activity", "insurance_followup"],
    "sepsis_cases": ["sepsis_cases_1"],# "sepsis_cases_2", "sepsis_cases_4"]
    "production" : ["production"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]

datasets
# Out:
# ['production']

# %%
for dataset_name in datasets:
    sep_timing_path = os.path.join(PATH, "%s/%s_%s/sep_timing.csv" % (dataset_ref, cls_method, method_name))
    all_timing_path = os.path.join(PATH, "%s/%s_%s/all_timing.csv" % (dataset_ref, cls_method, method_name))
    
    sep_data = pd.read_csv(sep_timing_path)
    all_data = pd.read_csv(all_timing_path)
    
    time_plot = sns.scatterplot(x = all_data['Prefix Length'], y = all_data['Running Time'], hue = all_data['Explainer'], size = all_data['Feature Vector Length'])
    plt.xlabel("Prefix Length")
    plt.ylabel("Running Time (Seconds)")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,1.1, 0.1))
    #plt.ylim(0,1.1)
    plt.title("Production: Stability by Subset (LIME) \nPrefix-Length Buckets with Aggregate Encoding")
    plot = time_plot.get_figure()
    plot.savefig("figures/timing.png", bbox_inches = "tight")
    plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []
all_lime_stab = []
all_shap_stab = []

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])-1
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i]!= []:
                    data = pd.DataFrame.from_records(sample_instances[i])

                    case_id = pd.Series(data['caseID'])
                    nr_events = pd.Series(data['nr_events'])
                    proba = pd.Series(data['proba'])
                    lime_stability = pd.Series(data['lime_stability'])
                    tree_shap_stability = pd.Series(data['tree_shap_stability'])

                    all_caseID.extend(case_id)
                    all_lengths.extend(nr_events)
                    all_proba.extend(proba)
                    all_lime_stab.extend(lime_stability)
                    all_shap_stab.extend(tree_shap_stability)

                    print("Average LIME Stability:", statistics.mean(lime_stability))
                    print("Average SHAP Stability:", statistics.mean(tree_shap_stability))

                    #fig, ax = plt.subplots()
                    #ax.plot(nr_events, lime_stability, 'bo', label = "LIME")
                    #ax.plot(nr_events, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax.set_xlabel("Prefix Length")
                    #ax.set_ylabel("Stability")
                    #ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,1, 0.1))
                    #plt.title("Prefix length and stability by index - "+type_list[i])
                    #plt.show()

                    #fig2, ax2 = plt.subplots()
                    #ax2.plot(proba, lime_stability, 'bo', label = "LIME")
                    #ax2.plot(proba, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax2.set_xlabel("Prediction Probability")
                    #ax2.set_ylabel("Stability")
                    #ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,1, 0.1))
                    #plt.title("Prediction probability and stability by index - "+type_list[i])
                    #plt.show()
# Out:
# Bucket 1
# True Negatives
# Average LIME Stability: 0.8604411764705882
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.875152505446623
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.8497058823529411
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.8595465686274509
# Average SHAP Stability: 1.0
# Bucket 2
# True Negatives
# Average LIME Stability: 0.8140699300699301
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.8086013986013986
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.8177156177156177
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.8204895104895105
# Average SHAP Stability: 1.0
# Bucket 3
# True Negatives
# Average LIME Stability: 0.8705357142857143
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.9023809523809524
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.9089285714285714
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.8857142857142857
# Average SHAP Stability: 1.0
# Bucket 4
# True Negatives
# Average LIME Stability: 0.8723214285714286
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.8833333333333333
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.839047619047619
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.8775132275132275
# Average SHAP Stability: 1.0
# Bucket 5
# True Negatives
# Average LIME Stability: 0.7192355882756077
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7116421251029422
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6640153233427761
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.7000304150705073
# Average SHAP Stability: 1.0
# Bucket 6
# True Negatives
# Average LIME Stability: 0.7990639269406392
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.8066159309994926
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.7762100456621004
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.791577879249112
# Average SHAP Stability: 1.0
# Bucket 7
# True Negatives
# Average LIME Stability: 0.6900308641975308
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7388773148148148
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6577777777777777
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.7362037037037037
# Average SHAP Stability: 1.0
# Bucket 8
# True Negatives
# Average LIME Stability: 0.8480045879973689
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.8592812519129992
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.8375768321513002
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.8433280798529026
# Average SHAP Stability: 1.0
# Bucket 9
# True Negatives
# Average LIME Stability: 0.7352527103301018
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7716865845910815
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.7403224609658865
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.694020061728395
# Average SHAP Stability: 1.0
# Bucket 10
# True Negatives
# Average LIME Stability: 0.9115023850369748
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7533148148148148
# Average SHAP Stability: 1.0
# False Negatives
# False Positives
# Average LIME Stability: 0.6435892070212348
# Average SHAP Stability: 1.0
# Bucket 11
# True Negatives
# Average LIME Stability: 0.9153945249597424
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.854621578099839
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.8427053140096619
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.8623671497584542
# Average SHAP Stability: 1.0
# Bucket 12
# True Negatives
# Average LIME Stability: 0.776927536231884
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.8534299516908213
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.772629905758387
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.7992109500805153
# Average SHAP Stability: 1.0
# Bucket 13
# True Negatives
# Average LIME Stability: 0.876687104757741
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.8211910599768241
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.9213526570048309
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.8981159420289855
# Average SHAP Stability: 1.0
# Bucket 14
# True Negatives
# Average LIME Stability: 0.6554501216545012
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7909651257096513
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6860502838605028
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6749229521492296
# Average SHAP Stability: 1.0
# Bucket 15
# True Negatives
# Average LIME Stability: 0.8173141040349672
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.8202381235047719
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.7657718513147747
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.8518629908103592
# Average SHAP Stability: 1.0
# Bucket 16
# True Negatives
# Average LIME Stability: 0.8885301837270341
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.9089063867016622
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.8393875765529308
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.9089063867016622
# Average SHAP Stability: 1.0
# Bucket 17
# True Negatives
# Average LIME Stability: 0.9105045202682998
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.8819378827646545
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.9208923884514436
# Average SHAP Stability: 1.0
# False Positives
# Bucket 18
# True Negatives
# Average LIME Stability: 0.8553703703703703
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.847003367003367
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.8338552188552188
# Average SHAP Stability: 1.0
# False Positives
# Bucket 19
# True Negatives
# Average LIME Stability: 0.8772825150732128
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.9018260120585702
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.8599224806201551
# Average SHAP Stability: 1.0
# False Positives
# Bucket 20
# True Negatives
# Average LIME Stability: 0.8407665805340223
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7924777490668963
# Average SHAP Stability: 1.0
# False Negatives
# False Positives

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens), key=lambda x: x[3])
all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
pal_len = len(set(hue_lens))

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1, 0.1))
plt.ylim(0,1.1)
plt.title("Production: Stability by Subset (LIME) \nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_subset_stability.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1, 0.1))
plt.ylim(0,1.1)
plt.title("Production: Stability by Subset (SHAP) \nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_subset_stability.png", bbox_inches = "tight")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.yticks(np.arange(0,1, 0.1))
plt.title("Prefix length and stability by index \n Single Bucket with Aggregate Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.yticks(np.arange(0,1, 0.1))
plt.title("Prediction probability and stability by index \n Single Bucket with Aggregate Encoding")
plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []
all_lime_stab = []
all_shap_stab = []

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])-1
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i]!= []:
                    data = pd.DataFrame.from_records(sample_instances[i])

                    dispersal_lime = []
                    dispersal_shap = []
                    adj_dispersal_lime = []
                    adj_dispersal_shap = []

                    case_id = pd.Series(data['caseID'])
                    nr_events = pd.Series(data['nr_events'])
                    proba = pd.Series(data['proba'])
                    lime_stability = pd.Series(data['adjusted_lime_importance_stability'])
                    tree_shap_stability = pd.Series(data['adjusted_shap_importance_stability'])

                    all_caseID.extend(case_id)
                    all_lengths.extend(nr_events)
                    all_proba.extend(proba)
                    all_lime_stab.extend(lime_stability)
                    all_shap_stab.extend(tree_shap_stability)

                    print("Average LIME Weights Stability:", statistics.mean(lime_stability))
                    print("Average SHAP Weights Stability:", statistics.mean(tree_shap_stability))

                    shap_dispersion = [disp for disp in tree_shap_stability if disp > 0]

                    print (len(shap_dispersion))

                    #fig, ax = plt.subplots()
                    #ax.plot(nr_events, lime_stability, 'bo', label = "LIME")
                    #ax.plot(nr_events, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax.set_xlabel("Prefix Length")
                    #ax.set_ylabel("Stability")
                    #ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.title("Prefix length and stability by weight - "+type_list[i])
                    #plt.show()

                    #fig2, ax2 = plt.subplots()
                    #ax2.plot(proba, lime_stability, 'bo', label = "LIME")
                    #ax2.plot(proba, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax2.set_xlabel("Prediction Probability")
                    #ax2.set_ylabel("Stability")
                    #ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.title("Prediction probability and stability by weight - "+type_list[i])
                    #plt.show()
# Out:
# Bucket 1
# True Negatives
# Average LIME Weights Stability: 0.8768532155617124
# Average SHAP Weights Stability: 0.9999999999999998
# 8
# True Positives
# Average LIME Weights Stability: 0.8477915243236264
# Average SHAP Weights Stability: 0.9999999999999998
# 9
# False Negatives
# Average LIME Weights Stability: 0.9388336032848088
# Average SHAP Weights Stability: 0.9999999999999998
# 8
# False Positives
# Average LIME Weights Stability: 0.9179712443659532
# Average SHAP Weights Stability: 0.9999999999999998
# 8
# Bucket 2
# True Negatives
# Average LIME Weights Stability: 0.8767786411536256
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# True Positives
# Average LIME Weights Stability: 0.906637874776233
# Average SHAP Weights Stability: 0.9999999999999998
# 10
# False Negatives
# Average LIME Weights Stability: 0.9174739818217815
# Average SHAP Weights Stability: 0.9999999999999999
# 6
# False Positives
# Average LIME Weights Stability: 0.8508026789218276
# Average SHAP Weights Stability: 0.9999999999999998
# 6
# Bucket 3
# True Negatives
# Average LIME Weights Stability: 0.9006440718422318
# Average SHAP Weights Stability: 0.9999999999999998
# 8
# True Positives
# Average LIME Weights Stability: 0.9500328849374062
# Average SHAP Weights Stability: 0.9999999999999998
# 6
# False Negatives
# Average LIME Weights Stability: 0.8814200841041805
# Average SHAP Weights Stability: 0.9999999999999998
# 8
# False Positives
# Average LIME Weights Stability: 0.8902090089076347
# Average SHAP Weights Stability: 0.9999999999999998
# 9
# Bucket 4
# True Negatives
# Average LIME Weights Stability: 0.9013219284385526
# Average SHAP Weights Stability: 0.9999999999999998
# 8
# True Positives
# Average LIME Weights Stability: 0.8906523910488136
# Average SHAP Weights Stability: 0.9999999999999998
# 6
# False Negatives
# Average LIME Weights Stability: 0.9129616555901896
# Average SHAP Weights Stability: 0.9999999999999998
# 5
# False Positives
# Average LIME Weights Stability: 0.9341590954859177
# Average SHAP Weights Stability: 0.9999999999999998
# 9
# Bucket 5
# True Negatives
# Average LIME Weights Stability: 0.8617323642640566
# Average SHAP Weights Stability: 0.9999999999999998
# 7
# True Positives
# Average LIME Weights Stability: 0.7742082671146159
# Average SHAP Weights Stability: 0.9999999999999998
# 9
# False Negatives
# Average LIME Weights Stability: 0.90420918345381
# Average SHAP Weights Stability: 0.9999999999999998
# 7
# False Positives
# Average LIME Weights Stability: 0.8893638611413139
# Average SHAP Weights Stability: 0.9999999999999998
# 6
# Bucket 6
# True Negatives
# Average LIME Weights Stability: 0.9303083301367459
# Average SHAP Weights Stability: 0.9999999999999998
# 8
# True Positives
# Average LIME Weights Stability: 0.9078898481400522
# Average SHAP Weights Stability: 0.9999999999999998
# 9
# False Negatives
# Average LIME Weights Stability: 0.9338028661954899
# Average SHAP Weights Stability: 0.9999999999999998
# 8
# False Positives
# Average LIME Weights Stability: 0.7022836677247257
# Average SHAP Weights Stability: 0.9999999999999998
# 9
# Bucket 7
# True Negatives
# Average LIME Weights Stability: 0.9184424647091959
# Average SHAP Weights Stability: 0.9999999999999998
# 7
# True Positives
# Average LIME Weights Stability: 0.8979380513449916
# Average SHAP Weights Stability: 0.9999999999999998
# 8
# False Negatives
# Average LIME Weights Stability: 0.9279508411567259
# Average SHAP Weights Stability: 0.9999999999999998
# 3
# False Positives
# Average LIME Weights Stability: 0.9209643682948326
# Average SHAP Weights Stability: 0.9999999999999998
# 8
# Bucket 8
# True Negatives
# Average LIME Weights Stability: 0.9160608922418653
# Average SHAP Weights Stability: 0.9999999999999998
# 4
# True Positives
# Average LIME Weights Stability: 0.8481069916460039
# Average SHAP Weights Stability: 0.9999999999999998
# 5
# False Negatives
# Average LIME Weights Stability: 0.9341741291723357
# Average SHAP Weights Stability: 0.9999999999999998
# 4
# False Positives
# Average LIME Weights Stability: 0.8522180443107208
# Average SHAP Weights Stability: 0.9999999999999998
# 6
# Bucket 9
# True Negatives
# Average LIME Weights Stability: 0.9086978677952089
# Average SHAP Weights Stability: 0.9999999999999998
# 5
# True Positives
# Average LIME Weights Stability: 0.871030159855962
# Average SHAP Weights Stability: 0.9999999999999998
# 3
# False Negatives
# Average LIME Weights Stability: 0.6747611061806879
# Average SHAP Weights Stability: 0.9999999999999997
# 5
# False Positives
# Average LIME Weights Stability: 0.4156266973536954
# Average SHAP Weights Stability: 0.9999999999999998
# 4
# Bucket 10
# True Negatives
# Average LIME Weights Stability: 0.9387644785659722
# Average SHAP Weights Stability: 0.9999999999999999
# 4
# True Positives
# Average LIME Weights Stability: 0.7648442437315676
# Average SHAP Weights Stability: 0.9999999999999998
# 5
# False Negatives
# False Positives
# Average LIME Weights Stability: 0.7299509812494454
# Average SHAP Weights Stability: 0.9999999999999999
# 3
# Bucket 11
# True Negatives
# Average LIME Weights Stability: 0.9492241690779376
# Average SHAP Weights Stability: 0.9999999999999998
# 2
# True Positives
# Average LIME Weights Stability: 0.9397955479997292
# Average SHAP Weights Stability: 0.9999999999999998
# 5
# False Negatives
# Average LIME Weights Stability: 0.9232869895400654
# Average SHAP Weights Stability: 0.9999999999999998
# 3
# False Positives
# Average LIME Weights Stability: 0.9347537872911986
# Average SHAP Weights Stability: 0.9999999999999998
# 4
# Bucket 12
# True Negatives
# Average LIME Weights Stability: 0.8491065014139402
# Average SHAP Weights Stability: 0.9999999999999998
# 5
# True Positives
# Average LIME Weights Stability: 0.9279496635046929
# Average SHAP Weights Stability: 0.9999999999999998
# 4
# False Negatives
# Average LIME Weights Stability: 0.8503845161394014
# Average SHAP Weights Stability: 0.9999999999999998
# 3
# False Positives
# Average LIME Weights Stability: 0.917883670464342
# Average SHAP Weights Stability: 0.9999999999999998
# 4
# Bucket 13
# True Negatives
# Average LIME Weights Stability: 0.9509163020791891
# Average SHAP Weights Stability: 0.9999999999999998
# 6
# True Positives
# Average LIME Weights Stability: 0.9419085382260977
# Average SHAP Weights Stability: 0.9999999999999998
# 5
# False Negatives
# Average LIME Weights Stability: 0.9471181841227099
# Average SHAP Weights Stability: 0.9999999999999998
# 2
# False Positives
# Average LIME Weights Stability: 0.9397905817757981
# Average SHAP Weights Stability: 0.9999999999999998
# 4
# Bucket 14
# True Negatives
# Average LIME Weights Stability: 0.9066993526790488
# Average SHAP Weights Stability: 0.9999999999999998
# 2
# True Positives
# Average LIME Weights Stability: 0.9661849297064328
# Average SHAP Weights Stability: 0.9999999999999998
# 3
# False Negatives
# Average LIME Weights Stability: 0.8503524081442718
# Average SHAP Weights Stability: 0.9999999999999999
# 3
# False Positives
# Average LIME Weights Stability: 0.8551352880599481
# Average SHAP Weights Stability: 0.9999999999999998
# 3
# Bucket 15
# True Negatives
# Average LIME Weights Stability: 0.8956047039571349
# Average SHAP Weights Stability: 0.9999999999999998
# 4
# True Positives
# Average LIME Weights Stability: 0.8337099856638397
# Average SHAP Weights Stability: 0.9999999999999998
# 3
# False Negatives
# Average LIME Weights Stability: 0.8961385910239934
# Average SHAP Weights Stability: 0.9999999999999998
# 3
# False Positives
# Average LIME Weights Stability: 0.9117440741886215
# Average SHAP Weights Stability: 0.9999999999999999
# 1
# Bucket 16
# True Negatives
# Average LIME Weights Stability: 0.9463297673851637
# Average SHAP Weights Stability: 0.9999999999999997
# 2
# True Positives
# Average LIME Weights Stability: 0.9415280624369521
# Average SHAP Weights Stability: 0.9999999999999999
# 5
# False Negatives
# Average LIME Weights Stability: 0.917924790878765
# Average SHAP Weights Stability: 0.9999999999999997
# 1
# False Positives
# Average LIME Weights Stability: 0.9133688491947584
# Average SHAP Weights Stability: 0.9999999999999999
# 1
# Bucket 17
# True Negatives
# Average LIME Weights Stability: 0.9494200442013992
# Average SHAP Weights Stability: 0.9999999999999999
# 3
# True Positives
# Average LIME Weights Stability: 0.8965393038555489
# Average SHAP Weights Stability: 0.9999999999999998
# 4
# False Negatives
# Average LIME Weights Stability: 0.9595971653731638
# Average SHAP Weights Stability: 0.9999999999999998
# 1
# False Positives
# Bucket 18
# True Negatives
# Average LIME Weights Stability: 0.9373580860516239
# Average SHAP Weights Stability: 0.9999999999999998
# 2
# True Positives
# Average LIME Weights Stability: 0.9339337475110964
# Average SHAP Weights Stability: 0.9999999999999999
# 2
# False Negatives
# Average LIME Weights Stability: 0.9425059029635081
# Average SHAP Weights Stability: 0.9999999999999998
# 2
# False Positives
# Bucket 19
# True Negatives
# Average LIME Weights Stability: 0.9598791541940308
# Average SHAP Weights Stability: 0.9999999999999999
# 4
# True Positives
# Average LIME Weights Stability: 0.9622132505132264
# Average SHAP Weights Stability: 0.9999999999999998
# 2
# False Negatives
# Average LIME Weights Stability: 0.9297401061931391
# Average SHAP Weights Stability: 0.9999999999999999
# 2
# False Positives
# Bucket 20
# True Negatives
# Average LIME Weights Stability: 0.916524867252078
# Average SHAP Weights Stability: 0.9999999999999998
# 2
# True Positives
# Average LIME Weights Stability: 0.8956923444961267
# Average SHAP Weights Stability: 0.9999999999999998
# 3
# False Negatives
# False Positives

# %%
sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.title("Production: Stability by Weight (LIME) \nPrefix-length Buckets with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.title("Production: Stability by Weight (SHAP) \nPrefix-length Buckets with Aggregate Encoding")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("Prefix length and stability by index \n Prefix-Length Bucket with Aggregate Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("Prediction probability and stability by index \n Prefix-Length Bucket with Aggregate Encoding")
plt.show()

# %%
lime_mean = np.mean(all_lime_stab)
lime_std = np.std(all_lime_stab)
lime_upper = lime_mean + (3*lime_std)
lime_lower = lime_mean - (3*lime_std)

shap_mean = np.mean(all_shap_stab)
shap_std = np.std(all_shap_stab)
shap_upper = shap_mean + (3*shap_std)
shap_lower = shap_mean - (3*shap_std)

lime_outliers = [i for i in all_lime_stab if i > lime_upper or i < lime_lower]
shap_outliers = [i for i in all_shap_stab if i > shap_upper or i < shap_lower]

print (lime_mean)
print (shap_mean)
print(len(lime_outliers))
print(len(shap_outliers))
print(str(len(lime_outliers)/len(all_lime_stab)*100)+"%")
print(str(len(shap_outliers)/len(all_shap_stab)*100)+"%")
# Out:
# 0.886484291626052
# 0.9999999999999999
# 6
# 1
# 1.639344262295082%
# 0.273224043715847%

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens), key=lambda x: x[3])
all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.ylim(lime_lower, 1.1)
plt.title("Production: Stability by Weight (LIME) \nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_weight_stability.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.ylim(lime_lower, 1.1)
plt.title("Production: Stability by Weight (SHAP) \nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_weight_stability.png", bbox_inches = "tight")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(lime_lower, 1)
plt.title("Prefix length and stability by weight \n Single Bucket with Aggregate Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(lime_lower,1)
plt.title("Prefix length and stability by weight \n Single Bucket with Aggregate Encoding")
plt.show()

# %%
# bins = np.arange(0, shap_upper+1e-17, 1e-17)
# yticks = np.arange(0, 80, 10)
# #sns.set_style("white")
# plt.subplots(figsize=(20, 15))
# plt.hist(all_shap_stab, bins = bins)
# #plt.figsize([50, 50])
# plt.xticks(bins, fontsize = 8)
# plt.yticks(yticks, fontsize = 12)
# plt.title("Distribution of SHAP Stability by Weight", fontsize = 16)
# plt.xlabel("Stability Range", fontsize = 14)
# plt.ylabel("Frequency", fontsize = 14)
# plt.show()

# %%
# bins = np.arange(0, lime_upper+0.1, 0.2)
# yticks = np.arange(0, 720, 20)
# #sns.set_style("white")
# plt.subplots(figsize=(20, 10))
# plt.hist(all_lime_stab, bins = bins)
# #plt.figsize([50, 50])
# plt.xticks(bins, fontsize = 12)
# plt.yticks(yticks, fontsize = 12)
# plt.title("Distribution of LIME Stability by Weight", fontsize = 16)
# plt.xlabel("Stability Range", fontsize = 14)
# plt.ylabel("Frequency", fontsize = 14)
# plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []

sep_caseID = [[],[],[],[]]
sep_lengths = [[],[],[],[]]
sep_proba = [[],[],[],[]]

all_lime_diffs = []
all_shap_diffs = []

sep_lime_diffs = [[],[],[],[]]
sep_shap_diffs = [[],[],[],[]]

all_lime_MSE = []
all_lime_RMSE = []
all_lime_MAE = []
all_lime_MAPE = []

sep_lime_MSE = [[],[],[],[]]
sep_lime_RMSE = [[],[],[],[]]
sep_lime_MAE = [[],[],[],[]]
sep_lime_MAPE = [[],[],[],[]]

all_shap_MSE = []
all_shap_RMSE = []
all_shap_MAE = []
all_shap_MAPE = []

sep_shap_MSE = [[],[],[],[]]
sep_shap_RMSE = [[],[],[],[]]
sep_shap_MAE = [[],[],[],[]]
sep_shap_MAPE = [[],[],[],[]]

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])-1
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i]!=[]:
                    data = pd.DataFrame.from_records(sample_instances[i])

                    lime_MSE = []
                    lime_RMSE = []
                    lime_MAE = []
                    lime_MAPE = []

                    shap_MSE = []
                    shap_RMSE = []
                    shap_MAE = []
                    shap_MAPE = []

                    case_id = pd.Series(data['caseID'])
                    nr_events = pd.Series(data['nr_events'])
                    proba = pd.Series(data['proba'])
                    lime_diffs = pd.Series(data['lime_fid_change'])
                    shap_diffs = pd.Series(data['shap_fid_change'])

                    for j in range(len(lime_diffs)):
                        p1 = proba[j]

                        lime_diff = lime_diffs[j]
                        shap_diff = shap_diffs[j]

                        all_lime_diffs.append(lime_diff)
                        all_shap_diffs.append(shap_diff)

                        lime_sq_changes = []
                        lime_abs_changes = []
                        lime_rel_changes = []

                        shap_sq_changes = []
                        shap_abs_changes = []
                        shap_rel_changes = []

                        for each in lime_diff:
                            lime_sq_changes.append(each**2)
                            lime_abs_changes.append(abs(each))
                            lime_rel_changes.append(abs(each)/p1)

                        for each in shap_diff:
                            shap_sq_changes.append(each**2)
                            shap_abs_changes.append(abs(each))
                            shap_rel_changes.append(abs(each)/p1)

                        lime_MSE.append(sum(lime_sq_changes)/len(lime_sq_changes))
                        lime_RMSE.append(math.sqrt(sum(lime_sq_changes)/len(lime_sq_changes)))
                        lime_MAE.append(sum(lime_abs_changes)/len(lime_abs_changes))
                        lime_MAPE.append(sum(lime_rel_changes)/len(lime_rel_changes))

                        shap_MSE.append(sum(shap_sq_changes)/len(shap_sq_changes))
                        shap_RMSE.append(math.sqrt(sum(shap_sq_changes)/len(shap_sq_changes)))
                        shap_MAE.append(sum(shap_abs_changes)/len(shap_abs_changes))
                        shap_MAPE.append(sum(shap_rel_changes)/len(shap_rel_changes))

                    all_caseID.extend(case_id)
                    all_lengths.extend(nr_events)
                    all_proba.extend(proba)

                    all_lime_MSE.extend(lime_MSE)
                    all_lime_RMSE.extend(lime_RMSE)
                    all_lime_MAE.extend(lime_MAE)
                    all_lime_MAPE.extend(lime_MAPE)

                    all_shap_MSE.extend(shap_MSE)
                    all_shap_RMSE.extend(shap_RMSE)
                    all_shap_MAE.extend(shap_MAE)
                    all_shap_MAPE.extend(shap_MAPE)

                    sep_caseID[i].extend(case_id)
                    sep_lengths[i].extend(nr_events)
                    sep_proba[i].extend(proba)

                    sep_lime_MSE[i].extend(lime_MSE)
                    sep_lime_RMSE[i].extend(lime_RMSE)
                    sep_lime_MAE[i].extend(lime_MAE)
                    sep_lime_MAPE[i].extend(lime_MAPE)

                    sep_shap_MSE[i].extend(shap_MSE)
                    sep_shap_RMSE[i].extend(shap_RMSE)
                    sep_shap_MAE[i].extend(shap_MAE)
                    sep_shap_MAPE[i].extend(shap_MAPE)

                    print("Average LIME MSE:", statistics.mean(lime_MSE))
                    print("Average SHAP MSE:", statistics.mean(shap_MSE))
                    print("\n")

                    #plt.plot(nr_events, lime_MSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_MSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    ##plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_MSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_MSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MSE \n"+type_list[i])
                    #plt.show()

                    print("Average LIME RMSE:", statistics.mean(lime_RMSE))
                    print("Average SHAP RMSE:", statistics.mean(shap_RMSE))
                    print("\n")

                    #plt.plot(nr_events, lime_RMSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and RMSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_RMSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and RMSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_RMSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and RMSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_RMSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and RMSE \n"+type_list[i])
                    #plt.show()

                    print("Average LIME MAE:", statistics.mean(lime_MAE))
                    print("Average SHAP MAE:", statistics.mean(shap_MAE))
                    print("\n")

                    #plt.plot(nr_events, lime_MAE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_MAE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_MAE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_MAE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAE \n"+type_list[i])
                    #plt.show()

                    print("Average LIME MAPE:", statistics.mean(lime_MAPE))
                    print("Average SHAP MAPE:", statistics.mean(shap_MAPE))
                    print("\n")

                    #plt.plot(nr_events, lime_MAPE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAPE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_MAPE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAPE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_MAPE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAPE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_MAPE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAPE \n"+type_list[i])
                    #plt.show()
# Out:
# Bucket 1
# True Negatives
# Average LIME MSE: 0.09497072293752613
# Average SHAP MSE: 0.1160630854844053
#
#
# Average LIME RMSE: 0.2703084172799357
# Average SHAP RMSE: 0.2794252277065389
#
#
# Average LIME MAE: 0.24383202670142054
# Average SHAP MAE: 0.2724831867031753
#
#
# Average LIME MAPE: 0.29484026376941336
# Average SHAP MAPE: 0.3525250593435063
#
#
# True Positives
# Average LIME MSE: 0.13717850597947268
# Average SHAP MSE: 0.18778555202497968
#
#
# Average LIME RMSE: 0.3301610987683815
# Average SHAP RMSE: 0.35788971331964176
#
#
# Average LIME MAE: 0.30515065292517346
# Average SHAP MAE: 0.35073311759365927
#
#
# Average LIME MAPE: 0.39717733306964575
# Average SHAP MAPE: 0.4576672414038908
#
#
# False Negatives
# Average LIME MSE: 0.089509345176074
# Average SHAP MSE: 0.32510102013480024
#
#
# Average LIME RMSE: 0.24415385134540693
# Average SHAP RMSE: 0.5104395288367974
#
#
# Average LIME MAE: 0.22379520907998085
# Average SHAP MAE: 0.5006552482023835
#
#
# Average LIME MAPE: 0.28235207791588923
# Average SHAP MAPE: 0.6259908022240195
#
#
# False Positives
# Average LIME MSE: 0.20674532482603195
# Average SHAP MSE: 0.16857978737794602
#
#
# Average LIME RMSE: 0.4096782105048749
# Average SHAP RMSE: 0.37165331371228266
#
#
# Average LIME MAE: 0.3822434838861227
# Average SHAP MAE: 0.34154293723404405
#
#
# Average LIME MAPE: 0.48135128950507505
# Average SHAP MAPE: 0.4439760820447539
#
#
# Bucket 2
# True Negatives
# Average LIME MSE: 0.04331782704137378
# Average SHAP MSE: 0.11906050532467545
#
#
# Average LIME RMSE: 0.17781340774239823
# Average SHAP RMSE: 0.31371794962574906
#
#
# Average LIME MAE: 0.1549889425933361
# Average SHAP MAE: 0.3051111075282097
#
#
# Average LIME MAPE: 0.22087336666908391
# Average SHAP MAPE: 0.4365374315211731
#
#
# True Positives
# Average LIME MSE: 0.19964165764324865
# Average SHAP MSE: 0.15507389414970538
#
#
# Average LIME RMSE: 0.4217125685471731
# Average SHAP RMSE: 0.3374858137278978
#
#
# Average LIME MAE: 0.40210083454847334
# Average SHAP MAE: 0.32646665900945665
#
#
# Average LIME MAPE: 0.5428730828506498
# Average SHAP MAPE: 0.42282712414371093
#
#
# False Negatives
# Average LIME MSE: 0.04015004085707899
# Average SHAP MSE: 0.02013311849280216
#
#
# Average LIME RMSE: 0.19295765814546
# Average SHAP RMSE: 0.1293757907161619
#
#
# Average LIME MAE: 0.17163919396698474
# Average SHAP MAE: 0.1198643454660972
#
#
# Average LIME MAPE: 0.21345672714278568
# Average SHAP MAPE: 0.15096865778038132
#
#
# False Positives
# Average LIME MSE: 0.14733166936037162
# Average SHAP MSE: 0.32773333484525496
#
#
# Average LIME RMSE: 0.3187048186375978
# Average SHAP RMSE: 0.5563788016374386
#
#
# Average LIME MAE: 0.2989450459678968
# Average SHAP MAE: 0.5480034162600835
#
#
# Average LIME MAPE: 0.3629148809668107
# Average SHAP MAPE: 0.6842218950244294
#
#
# Bucket 3
# True Negatives
# Average LIME MSE: 0.25917896996027184
# Average SHAP MSE: 0.38322068346293797
#
#
# Average LIME RMSE: 0.4718977678672578
# Average SHAP RMSE: 0.5877343968042094
#
#
# Average LIME MAE: 0.44958652430796064
# Average SHAP MAE: 0.581478183955187
#
#
# Average LIME MAPE: 0.5790513713453519
# Average SHAP MAPE: 0.7772039901628559
#
#
# True Positives
# Average LIME MSE: 0.09414583133327288
# Average SHAP MSE: 0.050525216383413195
#
#
# Average LIME RMSE: 0.2880405548191979
# Average SHAP RMSE: 0.194653655232875
#
#
# Average LIME MAE: 0.24308310598134994
# Average SHAP MAE: 0.18923322061697642
#
#
# Average LIME MAPE: 0.31030213965114967
# Average SHAP MAPE: 0.2667721195055818
#
#
# False Negatives
# Average LIME MSE: 0.378251332044453
# Average SHAP MSE: 0.3669885689468152
#
#
# Average LIME RMSE: 0.5708234710121999
# Average SHAP RMSE: 0.5628901846881672
#
#
# Average LIME MAE: 0.5594149006996304
# Average SHAP MAE: 0.5611997014377267
#
#
# Average LIME MAPE: 0.7097417998689586
# Average SHAP MAPE: 0.7532854806486887
#
#
# False Positives
# Average LIME MSE: 0.06120269539617401
# Average SHAP MSE: 0.05955703775127628
#
#
# Average LIME RMSE: 0.22842792430890282
# Average SHAP RMSE: 0.1903823776998529
#
#
# Average LIME MAE: 0.1898815092113283
# Average SHAP MAE: 0.18752375510003833
#
#
# Average LIME MAPE: 0.2678493947641525
# Average SHAP MAPE: 0.2921743514146619
#
#
# Bucket 4
# True Negatives
# Average LIME MSE: 0.1318532277885496
# Average SHAP MSE: 0.11248330894746086
#
#
# Average LIME RMSE: 0.33773076226400267
# Average SHAP RMSE: 0.2833525808310978
#
#
# Average LIME MAE: 0.3124359582085162
# Average SHAP MAE: 0.2660374368075281
#
#
# Average LIME MAPE: 0.41149625275621304
# Average SHAP MAPE: 0.35979348703463426
#
#
# True Positives
# Average LIME MSE: 0.05833376103782367
# Average SHAP MSE: 0.224503100240961
#
#
# Average LIME RMSE: 0.2027092804471903
# Average SHAP RMSE: 0.3803775823690702
#
#
# Average LIME MAE: 0.1777610093355179
# Average SHAP MAE: 0.37010459999243417
#
#
# Average LIME MAPE: 0.21186456026019923
# Average SHAP MAPE: 0.42512719204827243
#
#
# False Negatives
# Average LIME MSE: 0.5029800200972124
# Average SHAP MSE: 0.12561832501428438
#
#
# Average LIME RMSE: 0.6836565214445607
# Average SHAP RMSE: 0.2598550044409706
#
#
# Average LIME MAE: 0.671922690346837
# Average SHAP MAE: 0.25028823621571067
#
#
# Average LIME MAPE: 0.7577903177065182
# Average SHAP MAPE: 0.29485448985543716
#
#
# False Positives
# Average LIME MSE: 0.07107516844700318
# Average SHAP MSE: 0.2302179050725414
#
#
# Average LIME RMSE: 0.24005713203943185
# Average SHAP RMSE: 0.438209747377349
#
#
# Average LIME MAE: 0.20573691891299353
# Average SHAP MAE: 0.42160248690181307
#
#
# Average LIME MAPE: 0.2749590135197438
# Average SHAP MAPE: 0.520427381219725
#
#
# Bucket 5
# True Negatives
# Average LIME MSE: 0.12513527050931064
# Average SHAP MSE: 0.04847948911582206
#
#
# Average LIME RMSE: 0.3069899824011302
# Average SHAP RMSE: 0.18203602557020182
#
#
# Average LIME MAE: 0.2743869113868901
# Average SHAP MAE: 0.1804800953982132
#
#
# Average LIME MAPE: 0.359227377241595
# Average SHAP MAPE: 0.2897043506696049
#
#
# True Positives
# Average LIME MSE: 0.24578150442797417
# Average SHAP MSE: 0.49752756492811373
#
#
# Average LIME RMSE: 0.4721558976318561
# Average SHAP RMSE: 0.6820033084769579
#
#
# Average LIME MAE: 0.43168080117967395
# Average SHAP MAE: 0.6811404817634159
#
#
# Average LIME MAPE: 0.5592795971450951
# Average SHAP MAPE: 0.8931660751675877
#
#
# False Negatives
# Average LIME MSE: 0.15389498822732675
# Average SHAP MSE: 0.08577147119192681
#
#
# Average LIME RMSE: 0.35727557152581446
# Average SHAP RMSE: 0.24476560545600834
#
#
# Average LIME MAE: 0.32185123810278515
# Average SHAP MAE: 0.24200765269675426
#
#
# Average LIME MAPE: 0.41937376651868213
# Average SHAP MAPE: 0.38020284113120695
#
#
# False Positives
# Average LIME MSE: 0.16995282197589875
# Average SHAP MSE: 0.6430328106109837
#
#
# Average LIME RMSE: 0.392493642010325
# Average SHAP RMSE: 0.7929970042415349
#
#
# Average LIME MAE: 0.3458010345697403
# Average SHAP MAE: 0.7929039667050044
#
#
# Average LIME MAPE: 0.4509965180912109
# Average SHAP MAPE: 0.971045066282556
#
#
# Bucket 6
# True Negatives
# Average LIME MSE: 0.042851459256493744
# Average SHAP MSE: 0.06111464455626963
#
#
# Average LIME RMSE: 0.19452927036303383
# Average SHAP RMSE: 0.20463490930896105
#
#
# Average LIME MAE: 0.18047758002066985
# Average SHAP MAE: 0.20154919176129624
#
#
# Average LIME MAPE: 0.2418130000306876
# Average SHAP MAPE: 0.27354045790044473
#
#
# True Positives
# Average LIME MSE: 0.39221102942435904
# Average SHAP MSE: 0.5476373348488789
#
#
# Average LIME RMSE: 0.6062796873336901
# Average SHAP RMSE: 0.7238798504575928
#
#
# Average LIME MAE: 0.5930985934204526
# Average SHAP MAE: 0.7237772285938263
#
#
# Average LIME MAPE: 0.7752832383681666
# Average SHAP MAPE: 0.9474875479821891
#
#
# False Negatives
# Average LIME MSE: 0.057551440786777645
# Average SHAP MSE: 0.04239252397770367
#
#
# Average LIME RMSE: 0.21759963973894136
# Average SHAP RMSE: 0.17335923330045733
#
#
# Average LIME MAE: 0.19978472208604217
# Average SHAP MAE: 0.17224494041875005
#
#
# Average LIME MAPE: 0.25385297759522557
# Average SHAP MAPE: 0.24428477454990832
#
#
# False Positives
# Average LIME MSE: 0.3935424159496361
# Average SHAP MSE: 0.5361563683155157
#
#
# Average LIME RMSE: 0.6056918942521011
# Average SHAP RMSE: 0.7198804368651575
#
#
# Average LIME MAE: 0.5949886076980166
# Average SHAP MAE: 0.7197058724032508
#
#
# Average LIME MAPE: 0.767762463963875
# Average SHAP MAPE: 0.9350387754838778
#
#
# Bucket 7
# True Negatives
# Average LIME MSE: 0.029922993255026564
# Average SHAP MSE: 0.029760867925962543
#
#
# Average LIME RMSE: 0.15278797657961807
# Average SHAP RMSE: 0.14169602164230155
#
#
# Average LIME MAE: 0.1371334649156779
# Average SHAP MAE: 0.12716236184351146
#
#
# Average LIME MAPE: 0.17420630541700294
# Average SHAP MAPE: 0.1578051682226547
#
#
# True Positives
# Average LIME MSE: 0.47869528479870715
# Average SHAP MSE: 0.49215205373275606
#
#
# Average LIME RMSE: 0.6485125335136437
# Average SHAP RMSE: 0.6910983746762316
#
#
# Average LIME MAE: 0.6388188380748033
# Average SHAP MAE: 0.6903466921299696
#
#
# Average LIME MAPE: 0.76536858590514
# Average SHAP MAPE: 0.8747069154643774
#
#
# False Negatives
# Average LIME MSE: 0.045506094491779475
# Average SHAP MSE: 0.04831206287566476
#
#
# Average LIME RMSE: 0.14910534371440629
# Average SHAP RMSE: 0.16201864540061792
#
#
# Average LIME MAE: 0.14399539629618327
# Average SHAP MAE: 0.15335143605868023
#
#
# Average LIME MAPE: 0.22345450282553952
# Average SHAP MAPE: 0.23475469738184568
#
#
# False Positives
# Average LIME MSE: 0.3992057322341189
# Average SHAP MSE: 0.38384947616922194
#
#
# Average LIME RMSE: 0.6119407652651224
# Average SHAP RMSE: 0.5820433213279684
#
#
# Average LIME MAE: 0.6094017196446657
# Average SHAP MAE: 0.579469932243228
#
#
# Average LIME MAPE: 0.8206403802609207
# Average SHAP MAPE: 0.7464818620863011
#
#
# Bucket 8
# True Negatives
# Average LIME MSE: 0.01846731101756475
# Average SHAP MSE: 0.015851031995145422
#
#
# Average LIME RMSE: 0.11986255593255736
# Average SHAP RMSE: 0.10374717424520372
#
#
# Average LIME MAE: 0.0982281282544136
# Average SHAP MAE: 0.09927425114437938
#
#
# Average LIME MAPE: 0.1128988949584966
# Average SHAP MAPE: 0.11441378527933288
#
#
# True Positives
# Average LIME MSE: 0.5232297503130917
# Average SHAP MSE: 0.6588564006456802
#
#
# Average LIME RMSE: 0.705049467165337
# Average SHAP RMSE: 0.7973687050538177
#
#
# Average LIME MAE: 0.698719072341919
# Average SHAP MAE: 0.7972573214769364
#
#
# Average LIME MAPE: 0.8157673396318994
# Average SHAP MAPE: 0.9292535427108296
#
#
# False Negatives
# Average LIME MSE: 0.08627979328002841
# Average SHAP MSE: 0.023849216005270308
#
#
# Average LIME RMSE: 0.22217031439726806
# Average SHAP RMSE: 0.11481403787397924
#
#
# Average LIME MAE: 0.21791956410743296
# Average SHAP MAE: 0.11329587050713598
#
#
# Average LIME MAPE: 0.2821820599633224
# Average SHAP MAPE: 0.15708486050802592
#
#
# False Positives
# Average LIME MSE: 0.42082455836924726
# Average SHAP MSE: 0.42297586243869256
#
#
# Average LIME RMSE: 0.635777421034519
# Average SHAP RMSE: 0.6136735598737844
#
#
# Average LIME MAE: 0.6213850741585095
# Average SHAP MAE: 0.6104805558919907
#
#
# Average LIME MAPE: 0.7734261026398743
# Average SHAP MAPE: 0.7463489476218182
#
#
# Bucket 9
# True Negatives
# Average LIME MSE: 0.18833217025920151
# Average SHAP MSE: 0.06316188147811215
#
#
# Average LIME RMSE: 0.3768702252468146
# Average SHAP RMSE: 0.21086672695129693
#
#
# Average LIME MAE: 0.3444518325466197
# Average SHAP MAE: 0.19139573968830517
#
#
# Average LIME MAPE: 0.43505850438874494
# Average SHAP MAPE: 0.246548200957431
#
#
# True Positives
# Average LIME MSE: 0.43421768609746736
# Average SHAP MSE: 0.5293657945838179
#
#
# Average LIME RMSE: 0.5600836155244229
# Average SHAP RMSE: 0.7146229660364697
#
#
# Average LIME MAE: 0.5509486774603526
# Average SHAP MAE: 0.7088901201883951
#
#
# Average LIME MAPE: 0.5570002777994806
# Average SHAP MAPE: 0.7480773377162239
#
#
# False Negatives
# Average LIME MSE: 0.18655172616322263
# Average SHAP MSE: 0.05439948273293274
#
#
# Average LIME RMSE: 0.40463744523415474
# Average SHAP RMSE: 0.1794221738602563
#
#
# Average LIME MAE: 0.3601881282031536
# Average SHAP MAE: 0.1608631904423237
#
#
# Average LIME MAPE: 0.4305201287692412
# Average SHAP MAPE: 0.19365717192723902
#
#
# False Positives
# Average LIME MSE: 0.36633318013618765
# Average SHAP MSE: 0.40832806413651096
#
#
# Average LIME RMSE: 0.48020524987463775
# Average SHAP RMSE: 0.6077188817349325
#
#
# Average LIME MAE: 0.47289392203092573
# Average SHAP MAE: 0.5965313449501991
#
#
# Average LIME MAPE: 0.4993454836022228
# Average SHAP MAPE: 0.6951346493204468
#
#
# Bucket 10
# True Negatives
# Average LIME MSE: 0.08267646541315504
# Average SHAP MSE: 0.07604440640023313
#
#
# Average LIME RMSE: 0.262621492855045
# Average SHAP RMSE: 0.21055172295249955
#
#
# Average LIME MAE: 0.22736403867602348
# Average SHAP MAE: 0.19950454235076903
#
#
# Average LIME MAPE: 0.28059521095490086
# Average SHAP MAPE: 0.26452181478703163
#
#
# True Positives
# Average LIME MSE: 0.21498157164738468
# Average SHAP MSE: 0.642562793631901
#
#
# Average LIME RMSE: 0.42658868997999555
# Average SHAP RMSE: 0.7856421588735745
#
#
# Average LIME MAE: 0.39418221592903135
# Average SHAP MAE: 0.7852605032920837
#
#
# Average LIME MAPE: 0.45155574968342815
# Average SHAP MAPE: 0.9359364192426833
#
#
# False Negatives
# False Positives
# Average LIME MSE: 0.4366232641150747
# Average SHAP MSE: 0.5358415002131791
#
#
# Average LIME RMSE: 0.6303128133509048
# Average SHAP RMSE: 0.6659012462119207
#
#
# Average LIME MAE: 0.6130046258370081
# Average SHAP MAE: 0.6629092395305634
#
#
# Average LIME MAPE: 0.6681499605882811
# Average SHAP MAPE: 0.732113559014738
#
#
# Bucket 11
# True Negatives
# Average LIME MSE: 0.17851871931838464
# Average SHAP MSE: 0.7356689264463079
#
#
# Average LIME RMSE: 0.4223097686153925
# Average SHAP RMSE: 0.8531194517061791
#
#
# Average LIME MAE: 0.39584048464894295
# Average SHAP MAE: 0.851905957609415
#
#
# Average LIME MAPE: 0.3988026471872392
# Average SHAP MAPE: 0.8583342375087738
#
#
# True Positives
# Average LIME MSE: 0.4851194295839839
# Average SHAP MSE: 0.2964411568622738
#
#
# Average LIME RMSE: 0.6824423562761561
# Average SHAP RMSE: 0.45572583860001115
#
#
# Average LIME MAE: 0.6653613662719726
# Average SHAP MAE: 0.4419770580530167
#
#
# Average LIME MAPE: 0.7740436902120883
# Average SHAP MAPE: 0.4781178756266857
#
#
# False Negatives
# Average LIME MSE: 0.06505454884012506
# Average SHAP MSE: 0.02537379748240613
#
#
# Average LIME RMSE: 0.23172750818833837
# Average SHAP RMSE: 0.15488136117137652
#
#
# Average LIME MAE: 0.21271109183629353
# Average SHAP MAE: 0.1424396514892578
#
#
# Average LIME MAPE: 0.3254130918877633
# Average SHAP MAPE: 0.2007025480064794
#
#
# False Positives
# Average LIME MSE: 0.4389501840020019
# Average SHAP MSE: 0.14607499322841958
#
#
# Average LIME RMSE: 0.6024755259195592
# Average SHAP RMSE: 0.3640269239900696
#
#
# Average LIME MAE: 0.5843203015625477
# Average SHAP MAE: 0.34876250103116035
#
#
# Average LIME MAPE: 0.6884900121556318
# Average SHAP MAPE: 0.4313068856762357
#
#
# Bucket 12
# True Negatives
# Average LIME MSE: 0.012676546533000328
# Average SHAP MSE: 0.026021285095502573
#
#
# Average LIME RMSE: 0.08846681313628162
# Average SHAP RMSE: 0.12909420994808773
#
#
# Average LIME MAE: 0.08524792455136776
# Average SHAP MAE: 0.11234064280986786
#
#
# Average LIME MAPE: 0.10345254551508107
# Average SHAP MAPE: 0.12438288383591906
#
#
# True Positives
# Average LIME MSE: 0.5799547232497625
# Average SHAP MSE: 0.5305094484933748
#
#
# Average LIME RMSE: 0.7593066961385495
# Average SHAP RMSE: 0.7170544463568869
#
#
# Average LIME MAE: 0.7516498222947121
# Average SHAP MAE: 0.7150594830513
#
#
# Average LIME MAPE: 0.8471142777438476
# Average SHAP MAPE: 0.8095477296045752
#
#
# False Negatives
# Average LIME MSE: 0.10244841090608534
# Average SHAP MSE: 0.018573331968129457
#
#
# Average LIME RMSE: 0.309532974887478
# Average SHAP RMSE: 0.12513806639432204
#
#
# Average LIME MAE: 0.30080496370792387
# Average SHAP MAE: 0.11900215645631154
#
#
# Average LIME MAPE: 0.4296250718356871
# Average SHAP MAPE: 0.1788631837917691
#
#
# False Positives
# Average LIME MSE: 0.7341493105380018
# Average SHAP MSE: 0.5348003187724982
#
#
# Average LIME RMSE: 0.8546259516238393
# Average SHAP RMSE: 0.6917146967178417
#
#
# Average LIME MAE: 0.853590176999569
# Average SHAP MAE: 0.6851967677474022
#
#
# Average LIME MAPE: 0.9688071630681053
# Average SHAP MAPE: 0.7582161408801165
#
#
# Bucket 13
# True Negatives
# Average LIME MSE: 0.05793610942964904
# Average SHAP MSE: 0.060697941104801464
#
#
# Average LIME RMSE: 0.22328174652516083
# Average SHAP RMSE: 0.2189103706345114
#
#
# Average LIME MAE: 0.21405039227878053
# Average SHAP MAE: 0.20979314493015408
#
#
# Average LIME MAPE: 0.29477957905319563
# Average SHAP MAPE: 0.29317437083046394
#
#
# True Positives
# Average LIME MSE: 0.6857251311005121
# Average SHAP MSE: 0.5587937426789074
#
#
# Average LIME RMSE: 0.8211162996744146
# Average SHAP RMSE: 0.7051631494810883
#
#
# Average LIME MAE: 0.8207351720333099
# Average SHAP MAE: 0.6965576952695847
#
#
# Average LIME MAPE: 0.9587996528784796
# Average SHAP MAPE: 0.7866051966544685
#
#
# False Negatives
# Average LIME MSE: 0.029285319900761622
# Average SHAP MSE: 0.05333063416670778
#
#
# Average LIME RMSE: 0.16589542009167557
# Average SHAP RMSE: 0.21179727203073906
#
#
# Average LIME MAE: 0.15104495584964753
# Average SHAP MAE: 0.1838504672050476
#
#
# Average LIME MAPE: 0.18651898951715157
# Average SHAP MAPE: 0.213533104300455
#
#
# False Positives
# Average LIME MSE: 0.46163906693636536
# Average SHAP MSE: 0.32846185605083783
#
#
# Average LIME RMSE: 0.6750385774386266
# Average SHAP RMSE: 0.5571800070036034
#
#
# Average LIME MAE: 0.67445008456707
# Average SHAP MAE: 0.5481946885585786
#
#
# Average LIME MAPE: 0.9523713705848205
# Average SHAP MAPE: 0.7660122378235625
#
#
# Bucket 14
# True Negatives
# Average LIME MSE: 0.04556038366175715
# Average SHAP MSE: 0.0027548886234384025
#
#
# Average LIME RMSE: 0.16194580078263682
# Average SHAP RMSE: 0.052251646007685816
#
#
# Average LIME MAE: 0.13815629016608
# Average SHAP MAE: 0.03647788036614656
#
#
# Average LIME MAPE: 0.14186374827515708
# Average SHAP MAPE: 0.03795653586239944
#
#
# True Positives
# Average LIME MSE: 0.516964695753764
# Average SHAP MSE: 0.5150799650989631
#
#
# Average LIME RMSE: 0.6572922990504904
# Average SHAP RMSE: 0.7055842647359246
#
#
# Average LIME MAE: 0.6396202623844147
# Average SHAP MAE: 0.7026317417621613
#
#
# Average LIME MAPE: 0.6937338735787725
# Average SHAP MAPE: 0.8130220219008293
#
#
# False Negatives
# Average LIME MSE: 0.24765826165542557
# Average SHAP MSE: 0.036017876093177484
#
#
# Average LIME RMSE: 0.4454778734747914
# Average SHAP RMSE: 0.16547919854171902
#
#
# Average LIME MAE: 0.43032649233937265
# Average SHAP MAE: 0.1512448161840439
#
#
# Average LIME MAPE: 0.5766983381759572
# Average SHAP MAPE: 0.2481529619294468
#
#
# False Positives
# Average LIME MSE: 0.14757593078191877
# Average SHAP MSE: 0.19916927683661317
#
#
# Average LIME RMSE: 0.3592779162285771
# Average SHAP RMSE: 0.3786826570923586
#
#
# Average LIME MAE: 0.3345742682615916
# Average SHAP MAE: 0.3670799205700556
#
#
# Average LIME MAPE: 0.6340535256131364
# Average SHAP MAPE: 0.5451323194010501
#
#
# Bucket 15
# True Negatives
# Average LIME MSE: 0.17845567811045754
# Average SHAP MSE: 0.46436287232636164
#
#
# Average LIME RMSE: 0.3791611541945088
# Average SHAP RMSE: 0.617344940660453
#
#
# Average LIME MAE: 0.350458040216472
# Average SHAP MAE: 0.6070957848220132
#
#
# Average LIME MAPE: 0.41370714092812816
# Average SHAP MAPE: 0.6973050709390463
#
#
# True Positives
# Average LIME MSE: 0.27137872769685356
# Average SHAP MSE: 0.3017733775860607
#
#
# Average LIME RMSE: 0.4645586059754008
# Average SHAP RMSE: 0.4957811189336794
#
#
# Average LIME MAE: 0.44419375956058504
# Average SHAP MAE: 0.4829103817542394
#
#
# Average LIME MAPE: 0.48167316360745593
# Average SHAP MAPE: 0.5150240564429283
#
#
# False Negatives
# Average LIME MSE: 0.09894361062342363
# Average SHAP MSE: 0.02926040983582651
#
#
# Average LIME RMSE: 0.302616738301529
# Average SHAP RMSE: 0.1675991944836739
#
#
# Average LIME MAE: 0.2778070390224457
# Average SHAP MAE: 0.13795323371887208
#
#
# Average LIME MAPE: 0.44651473621437515
# Average SHAP MAPE: 0.22314915401878452
#
#
# False Positives
# Average LIME MSE: 0.3014853304717119
# Average SHAP MSE: 0.11809724300194198
#
#
# Average LIME RMSE: 0.5490767983367281
# Average SHAP RMSE: 0.34365279425888856
#
#
# Average LIME MAE: 0.5315592557191848
# Average SHAP MAE: 0.33414825797080994
#
#
# Average LIME MAPE: 0.5428167424085045
# Average SHAP MAPE: 0.3412249282119787
#
#
# Bucket 16
# True Negatives
# Average LIME MSE: 0.30235469573072327
# Average SHAP MSE: 0.04083638923589208
#
#
# Average LIME RMSE: 0.5498272307369984
# Average SHAP RMSE: 0.17882610796533982
#
#
# Average LIME MAE: 0.5074893370270729
# Average SHAP MAE: 0.16379087120294572
#
#
# Average LIME MAPE: 0.5111007555603407
# Average SHAP MAPE: 0.1653194301791694
#
#
# True Positives
# Average LIME MSE: 0.4500032269581673
# Average SHAP MSE: 0.6771698632922803
#
#
# Average LIME RMSE: 0.6230002949960323
# Average SHAP RMSE: 0.8139630359808012
#
#
# Average LIME MAE: 0.6064958912134171
# Average SHAP MAE: 0.8136907613277435
#
#
# Average LIME MAPE: 0.6800030438565879
# Average SHAP MAPE: 0.9454052845745647
#
#
# False Negatives
# Average LIME MSE: 0.09698213281773141
# Average SHAP MSE: 0.000574090516333279
#
#
# Average LIME RMSE: 0.3114195446945028
# Average SHAP RMSE: 0.0239601860663326
#
#
# Average LIME MAE: 0.3052816901355982
# Average SHAP MAE: 0.01703965999186039
#
#
# Average LIME MAPE: 0.31225457889200714
# Average SHAP MAPE: 0.01742886005661861
#
#
# False Positives
# Average LIME MSE: 0.37187399206230437
# Average SHAP MSE: 0.8275244903803263
# Average LIME RMSE: 0.6098147194536259
# Average SHAP RMSE: 0.9096837309638588
#
#
# Average LIME MAE: 0.5566371083259583
# Average SHAP MAE: 0.9093475341796875
#
#
# Average LIME MAPE: 0.5798922617889625
# Average SHAP MAPE: 0.9473382037600018
#
#
# Bucket 17
# True Negatives
# Average LIME MSE: 0.015438914926243795
# Average SHAP MSE: 0.1009369451673935
#
#
# Average LIME RMSE: 0.11370525555713758
# Average SHAP RMSE: 0.2680618447938972
#
#
# Average LIME MAE: 0.08638636196653049
# Average SHAP MAE: 0.2355863289286693
#
#
# Average LIME MAPE: 0.09477746958805586
# Average SHAP MAPE: 0.24765551599206492
#
#
# True Positives
# Average LIME MSE: 0.16572466692863447
# Average SHAP MSE: 0.20209052038109368
#
#
# Average LIME RMSE: 0.3092611829427992
# Average SHAP RMSE: 0.4041032937145127
#
#
# Average LIME MAE: 0.29178778901696206
# Average SHAP MAE: 0.3753085672855377
#
#
# Average LIME MAPE: 0.3314038794101791
# Average SHAP MAPE: 0.4454894090057927
#
#
# False Negatives
# Average LIME MSE: 0.491932443953323
# Average SHAP MSE: 0.7296229835546142
#
#
# Average LIME RMSE: 0.7013789588755304
# Average SHAP RMSE: 0.8541797138510222
#
#
# Average LIME MAE: 0.6949653677642346
# Average SHAP MAE: 0.8505136124789715
#
#
# Average LIME MAPE: 0.7241791842057966
# Average SHAP MAPE: 0.8862661113926149
#
#
# False Positives
# Bucket 18
# True Negatives
# Average LIME MSE: 0.32951991332351577
# Average SHAP MSE: 0.10986450082241178
#
#
# Average LIME RMSE: 0.5327338409734708
# Average SHAP RMSE: 0.3195806564899334
#
#
# Average LIME MAE: 0.4923700254410506
# Average SHAP MAE: 0.2886932443827391
#
#
# Average LIME MAPE: 0.5085274872787866
# Average SHAP MAPE: 0.29960280082249274
#
#
# True Positives
# Average LIME MSE: 0.4005048439256034
# Average SHAP MSE: 0.2947178250210782
#
#
# Average LIME RMSE: 0.5094261367073409
# Average SHAP RMSE: 0.4664754140647305
#
#
# Average LIME MAE: 0.5016303285956383
# Average SHAP MAE: 0.4411929249763489
#
#
# Average LIME MAPE: 0.5773827261943125
# Average SHAP MAPE: 0.5272406942557936
#
#
# False Negatives
# Average LIME MSE: 0.049995540628150904
# Average SHAP MSE: 0.05781709630493104
#
#
# Average LIME RMSE: 0.2232391936051486
# Average SHAP RMSE: 0.2267126575374881
#
#
# Average LIME MAE: 0.16897534728050234
# Average SHAP MAE: 0.19746774658560753
#
#
# Average LIME MAPE: 0.22184157009939331
# Average SHAP MAPE: 0.2455791762357474
#
#
# False Positives
# Bucket 19
# True Negatives
# Average LIME MSE: 0.2610799186740378
# Average SHAP MSE: 0.197934891674284
#
#
# Average LIME RMSE: 0.46815514406225306
# Average SHAP RMSE: 0.38622247348577315
#
#
# Average LIME MAE: 0.44770798115059735
# Average SHAP MAE: 0.3568404438905418
#
#
# Average LIME MAPE: 0.532992997836989
# Average SHAP MAPE: 0.40329289001157465
#
#
# True Positives
# Average LIME MSE: 0.039081588197902487
# Average SHAP MSE: 0.06289506528775272
#
#
# Average LIME RMSE: 0.19643176934106374
# Average SHAP RMSE: 0.2291312453916948
#
#
# Average LIME MAE: 0.17646022140979767
# Average SHAP MAE: 0.2118386670947075
#
#
# Average LIME MAPE: 0.28117305838765017
# Average SHAP MAPE: 0.32998172289736255
#
#
# False Negatives
# Average LIME MSE: 0.22000581927087065
# Average SHAP MSE: 0.028159964517987236
#
#
# Average LIME RMSE: 0.46901640825612356
# Average SHAP RMSE: 0.1622339611416583
#
#
# Average LIME MAE: 0.4465888306498528
# Average SHAP MAE: 0.15213004797697066
#
#
# Average LIME MAPE: 0.5953796067774068
# Average SHAP MAPE: 0.20516792060756633
#
#
# False Positives
# Bucket 20
# True Negatives
# Average LIME MSE: 0.12955900117273536
# Average SHAP MSE: 0.021528948466310635
#
#
# Average LIME RMSE: 0.3345021671830522
# Average SHAP RMSE: 0.14542522662386942
#
#
# Average LIME MAE: 0.2907467645127326
# Average SHAP MAE: 0.12992904777638614
#
#
# Average LIME MAPE: 0.29203115071504326
# Average SHAP MAPE: 0.1308361923787067
#
#
# True Positives
# Average LIME MSE: 0.3716220113155657
# Average SHAP MSE: 0.24336484841495507
#
#
# Average LIME RMSE: 0.5392302774185173
# Average SHAP RMSE: 0.43287840127089544
#
#
# Average LIME MAE: 0.5067829291025797
# Average SHAP MAE: 0.4244736512502035
#
#
# Average LIME MAPE: 0.5288622358761218
# Average SHAP MAPE: 0.49922937064618855
#
#
# False Negatives
# False Positives

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_MSE, all_shap_MSE, all_lime_RMSE, all_shap_RMSE, all_lime_MAE, all_shap_MAE, 
                          all_lime_MAPE, all_shap_MAPE, all_lengths, hue_lens), key=lambda x: x[-2])
all_proba, all_lime_MSE, all_shap_MSE, all_lime_RMSE, all_shap_RMSE, all_lime_MAE, all_shap_MAE, all_lime_MAPE, all_shap_MAPE, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
sns.scatterplot(all_proba, all_lime_MSE, hue=hue_lens, palette = lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MSE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_MSE, hue=hue_lens, palette = shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MSE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

# %%
sns.scatterplot(all_proba, all_lime_RMSE, hue = hue_lens, palette = lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity RMSE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_RMSE, hue = hue_lens, palette = shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity RMSE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plt.show()

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_MAE, hue = hue_lens, palette = lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MAE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_fidelity_mae.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_MAE, hue = hue_lens, palette = shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MAE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_fidelity_mae.png", bbox_inches = "tight")
plt.show()

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_MAPE, hue = hue_lens, palette = lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MAPE (LIME)\nPrefix-length Buckets with Aggregate Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_fidelity_mape.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_MAPE, hue = hue_lens, palette = shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MAPE (SHAP)\nPrefix-length Buckets with Aggregate Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_fidelity_mape.png", bbox_inches = "tight")
plt.show()

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

sep_hues = [[],[],[],[]]

for i in range(len(sep_lengths)): 
    for length in sep_lengths[i]:
        cur_bin = 0
        while length >= bins[cur_bin+1]:
            cur_bin += 1
        sep_hues[i].append(labels[cur_bin])
#sep_hues

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MSE[i], hue = sep_hues[i], palette = lime_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MSE[i], hue = sep_hues[i], palette = shap_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_RMSE[i], hue = sep_hues[i], palette = lime_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_RMSE[i], hue = sep_hues[i], palette = shap_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAE[i], hue = sep_hues[i], palette = lime_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAE[i], hue = sep_hues[i], palette = shap_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAPE[i], hue = sep_hues[i], palette = lime_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAPE[i], hue = sep_hues[i], palette = shap_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAPE\nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[],[]]
type_proba = [[],[]]
type_hues = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_hues[0].extend(sep_hues[0])
type_hues[0].extend(sep_hues[2])
type_hues[1].extend(sep_hues[1])
type_hues[1].extend(sep_hues[3])

type_lime_MSE = [[],[]]
type_shap_MSE = [[],[]]

type_lime_MSE[0].extend(sep_lime_MSE[0])
type_lime_MSE[0].extend(sep_lime_MSE[2])
type_lime_MSE[1].extend(sep_lime_MSE[1])
type_lime_MSE[1].extend(sep_lime_MSE[3])

type_shap_MSE[0].extend(sep_shap_MSE[0])
type_shap_MSE[0].extend(sep_shap_MSE[2])
type_shap_MSE[1].extend(sep_shap_MSE[1])
type_shap_MSE[1].extend(sep_shap_MSE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MSE[i], hue = type_hues[i], palette = lime_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MSE[i], hue = type_hues[i], palette = shap_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_RMSE = [[],[]]
type_shap_RMSE = [[],[]]

type_lime_RMSE[0].extend(sep_lime_RMSE[0])
type_lime_RMSE[0].extend(sep_lime_RMSE[2])
type_lime_RMSE[1].extend(sep_lime_RMSE[1])
type_lime_RMSE[1].extend(sep_lime_RMSE[3])

type_shap_RMSE[0].extend(sep_shap_RMSE[0])
type_shap_RMSE[0].extend(sep_shap_RMSE[2])
type_shap_RMSE[1].extend(sep_shap_RMSE[1])
type_shap_RMSE[1].extend(sep_shap_RMSE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_RMSE[i], hue = type_hues[i], palette = lime_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_RMSE[i], hue = type_hues[i], palette = shap_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_MAE = [[],[]]
type_shap_MAE = [[],[]]

type_lime_MAE[0].extend(sep_lime_MAE[0])
type_lime_MAE[0].extend(sep_lime_MAE[2])
type_lime_MAE[1].extend(sep_lime_MAE[1])
type_lime_MAE[1].extend(sep_lime_MAE[3])

type_shap_MAE[0].extend(sep_shap_MAE[0])
type_shap_MAE[0].extend(sep_shap_MAE[2])
type_shap_MAE[1].extend(sep_shap_MAE[1])
type_shap_MAE[1].extend(sep_shap_MAE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MAE[i], hue = type_hues[i], palette = lime_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MAE[i], hue = type_hues[i], palette = shap_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_MAPE = [[],[]]
type_shap_MAPE = [[],[]]

type_lime_MAPE[0].extend(sep_lime_MAPE[0])
type_lime_MAPE[0].extend(sep_lime_MAPE[2])
type_lime_MAPE[1].extend(sep_lime_MAPE[1])
type_lime_MAPE[1].extend(sep_lime_MAPE[3])

type_shap_MAPE[0].extend(sep_shap_MAPE[0])
type_shap_MAPE[0].extend(sep_shap_MAPE[2])
type_shap_MAPE[1].extend(sep_shap_MAPE[1])
type_shap_MAPE[1].extend(sep_shap_MAPE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MAPE[i], hue = type_hues[i], palette = lime_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MAPE[i], hue = type_hues[i], palette = shap_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Aggregate Encoding")
    plt.show()

# %%
print("Average LIME MSE:", np.mean(all_lime_MSE))
print("Average SHAP MSE:", np.mean(all_shap_MSE))
print("\n")

print("Average LIME RMSE:", np.mean(all_lime_RMSE))
print("Average SHAP RMSE:", np.mean(all_shap_RMSE))
print("\n")

print("Average LIME MAE:", np.mean(all_lime_MAE))
print("Average SHAP MAE:", np.mean(all_shap_MAE))
print("\n")

print("Average LIME MAPE:", np.mean(all_lime_MAPE))
print("Average SHAP MAPE:", np.mean(all_shap_MAPE))
# Out:
# Average LIME MSE: 0.224201972780498
# Average SHAP MSE: 0.251369022307646
#
#
# Average LIME RMSE: 0.40323106703456957
# Average SHAP RMSE: 0.414505107313964
#
#
# Average LIME MAE: 0.38194581071241523
# Average SHAP MAE: 0.4055231353971449
#
#
# Average LIME MAPE: 0.47366466356136006
# Average SHAP MAPE: 0.5089115965891036

# %%
print(len(all_lime_MSE))
# Out:
# 366
