# %%
#from google.colab import drive
#drive.mount('/content/drive')
import sys
#PATH = '/content/drive/My Drive/PPM_Stability/'
#PATH = "C:/Users/velmurug/Documents/Stability Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/Mythreyi/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/mythr/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
PATH = "C:/Users/n9455647/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
sys.path.append(PATH)

# %%
from DatasetManager import DatasetManager

import pandas as pd
import numpy as np

import os
import sys
from sys import argv
import pickle
import random
import joblib

import statistics
import math

import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

lime_pal = sns.diverging_palette(100, 200, s=150)#, as_cmap=True)
shap_pal = sns.diverging_palette(0, 240, s=150)#, as_cmap=True)

sns.set_style('darkgrid')

# %%
dataset_ref = "production"
params_dir = PATH + "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "index"
cls_method = "xgboost"

gap = 1
n_iter = 1

method_name = "%s_%s"%(bucket_method, cls_encoding)

generate_samples = False
generate_lime = True
generate_kernel_shap = False
generate_model_shap = True

sample_size = 2
exp_iter = 10
max_feat = 10
max_prefix = 20

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"],
    #"insurance": ["insurance_activity", "insurance_followup"],
    #"sepsis_cases": ["sepsis_cases_1", "sepsis_cases_2", "sepsis_cases_4"]
    "production" : ["production"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]

datasets
# Out:
# ['production']

# %%
for dataset_name in datasets:
    sep_timing_path = os.path.join(PATH, "%s/%s_%s/sep_timing.csv" % (dataset_ref, cls_method, method_name))
    all_timing_path = os.path.join(PATH, "%s/%s_%s/all_timing.csv" % (dataset_ref, cls_method, method_name))
    
    sep_data = pd.read_csv(sep_timing_path)
    all_data = pd.read_csv(all_timing_path)
    
    time_plot = sns.scatterplot(x = all_data['Prefix Length'], y = all_data['Running Time'], hue = all_data['Explainer'], size = all_data['Feature Vector Length'])
    plt.xlabel("Prefix Length")
    plt.ylabel("Running Time (Seconds)")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,1.1, 0.1))
    #plt.ylim(0,1.1)
    plt.title("Production: Running Time \nPrefix-Length Buckets with Index-Based Encoding")
    plot = time_plot.get_figure()
    plot.savefig("figures/timing.png", bbox_inches = "tight")
    plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []
all_lime_stab = []
all_shap_stab = []

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i]!=[]:
                    data = pd.DataFrame.from_records(sample_instances[i])

                    case_id = pd.Series(data['caseID'])
                    nr_events = pd.Series(data['nr_events'])
                    proba = pd.Series(data['proba'])
                    lime_stability = pd.Series(data['lime_stability'])
                    tree_shap_stability = pd.Series(data['tree_shap_stability'])

                    all_caseID.extend(case_id)
                    all_lengths.extend(nr_events)
                    all_proba.extend(proba)
                    all_lime_stab.extend(lime_stability)
                    all_shap_stab.extend(tree_shap_stability)

                    print("Average LIME Stability:", statistics.mean(lime_stability))
                    print("Average SHAP Stability:", statistics.mean(tree_shap_stability))

                    #fig, ax = plt.subplots()
                    #ax.plot(nr_events, lime_stability, 'bo', label = "LIME")
                    #ax.plot(nr_events, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax.set_xlabel("Prefix Length")
                    #ax.set_ylabel("Stability")
                    #ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,1, 0.1))
                    #plt.title("Prefix length and stability by index - "+type_list[i])
                    #plt.show()

                    #fig2, ax2 = plt.subplots()
                    #ax2.plot(proba, lime_stability, 'bo', label = "LIME")
                    #ax2.plot(proba, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax2.set_xlabel("Prediction Probability")
                    #ax2.set_ylabel("Stability")
                    #ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,1, 0.1))
                    #plt.title("Prediction probability and stability by index - "+type_list[i])
                    #plt.show()
# Out:
# Bucket 1
# True Negatives
# Average LIME Stability: 0.6390123456790123
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6802469135802469
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6595679012345679
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6342592592592593
# Average SHAP Stability: 1.0
# Bucket 2
# True Negatives
# Average LIME Stability: 0.700920099726702
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6551533766112793
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6715523059808043
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6733267017635265
# Average SHAP Stability: 1.0
# Bucket 3
# True Negatives
# Average LIME Stability: 0.5501217007208571
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.569350038206544
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5416850402426046
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5467786692001143
# Average SHAP Stability: 1.0
# Bucket 4
# True Negatives
# Average LIME Stability: 0.5701956128767376
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6052850337306047
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6065364427125574
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5756571443472733
# Average SHAP Stability: 1.0
# Bucket 5
# True Negatives
# Average LIME Stability: 0.7421469359109324
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7134487510766581
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.7082055699109963
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.70603088070723
# Average SHAP Stability: 1.0
# Bucket 6
# True Negatives
# Average LIME Stability: 0.607846790890269
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6109439664900962
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6065649456563557
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5917301002650062
# Average SHAP Stability: 1.0
# Bucket 7
# True Negatives
# Average LIME Stability: 0.5544084487474518
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6179142855435403
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5301317940451803
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6021752340251252
# Average SHAP Stability: 1.0
# Bucket 8
# True Negatives
# Average LIME Stability: 0.43245530090869544
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.404602915690782
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5318586282108294
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4471210215361157
# Average SHAP Stability: 1.0
# Bucket 9
# True Negatives
# Average LIME Stability: 0.4986188145731375
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5581860612651802
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5410781221678448
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5501120174007612
# Average SHAP Stability: 1.0
# Bucket 10
# True Negatives
# Average LIME Stability: 0.44087141223370285
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5061127596439168
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5153786604866242
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.431240356083086
# Average SHAP Stability: 1.0
# Bucket 11
# True Negatives
# Average LIME Stability: 0.5258012545844636
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.617633557379392
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5040008746292912
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5515435921297852
# Average SHAP Stability: 1.0
# Bucket 12
# True Negatives
# Average LIME Stability: 0.42837696712798273
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.5449269257969495
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.39360980734463347
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4547127813064745
# Average SHAP Stability: 1.0
# Bucket 13
# True Negatives
# Average LIME Stability: 0.5296844635339628
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6648483753895253
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.5348307975885238
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.5796849004901379
# Average SHAP Stability: 1.0
# Bucket 14
# True Negatives
# Average LIME Stability: 0.6630309523053877
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6435250890801862
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6349585039090204
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.6662306476557285
# Average SHAP Stability: 1.0
# Bucket 15
# True Negatives
# Average LIME Stability: 0.7726272918310021
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.8126198732710666
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.7677878739571709
# Average SHAP Stability: 1.0
# False Positives
# Bucket 16
# True Negatives
# Average LIME Stability: 0.6965052113524348
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7533548105004342
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.7437285946331686
# Average SHAP Stability: 1.0
# False Positives
# Average LIME Stability: 0.4990242471948264
# Average SHAP Stability: 1.0
# Bucket 17
# True Negatives
# Average LIME Stability: 0.639646428510271
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.6298849899750001
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.661478268265714
# Average SHAP Stability: 1.0
# False Positives
# Bucket 18
# True Negatives
# Average LIME Stability: 0.7536494283270945
# Average SHAP Stability: 1.0
# True Positives
# False Negatives
# Average LIME Stability: 0.7256871629417422
# Average SHAP Stability: 1.0
# False Positives
# Bucket 19
# True Negatives
# Average LIME Stability: 0.6517225369347983
# Average SHAP Stability: 1.0
# True Positives
# Average LIME Stability: 0.7109446179460488
# Average SHAP Stability: 1.0
# False Negatives
# Average LIME Stability: 0.6938651538272133
# Average SHAP Stability: 1.0
# False Positives
# Bucket 20
# True Negatives
# Average LIME Stability: 0.7852277981331723
# Average SHAP Stability: 1.0
# True Positives
# False Negatives
# Average LIME Stability: 0.8012784943689553
# Average SHAP Stability: 1.0
# False Positives

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens), key=lambda x: x[3])
all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
pal_len = len(set(hue_lens))

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1, 0.1))
plt.ylim(0,1.1)
plt.title("Production: Stability by Subset (LIME) \nPrefix-length Buckets with Index-based Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_subset_stability.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Stability by Subset (SHAP) \nPrefix-length Buckets with Index-based Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_subset_stability.png", bbox_inches = "tight")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.yticks(np.arange(0,1, 0.1))
plt.title("Prefix length and stability by index \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.yticks(np.arange(0,1, 0.1))
plt.title("Prediction probability and stability by index \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []
all_lime_stab = []
all_shap_stab = []

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i]!=[]:
                    data = pd.DataFrame.from_records(sample_instances[i])

                    dispersal_lime = []
                    dispersal_shap = []
                    adj_dispersal_lime = []
                    adj_dispersal_shap = []

                    case_id = pd.Series(data['caseID'])
                    nr_events = pd.Series(data['nr_events'])
                    proba = pd.Series(data['proba'])
                    lime_stability = pd.Series(data['adjusted_lime_importance_stability'])
                    tree_shap_stability = pd.Series(data['adjusted_shap_importance_stability'])

                    all_caseID.extend(case_id)
                    all_lengths.extend(nr_events)
                    all_proba.extend(proba)
                    all_lime_stab.extend(lime_stability)
                    all_shap_stab.extend(tree_shap_stability)

                    print("Average LIME Weights Stability:", statistics.mean(lime_stability))
                    print("Average SHAP Weights Stability:", statistics.mean(tree_shap_stability))

                    shap_dispersion = [disp for disp in tree_shap_stability if disp > 0]

                    print (len(shap_dispersion))

                    #fig, ax = plt.subplots()
                    #ax.plot(nr_events, lime_stability, 'bo', label = "LIME")
                    #ax.plot(nr_events, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax.set_xlabel("Prefix Length")
                    #ax.set_ylabel("Stability")
                    #ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.title("Prefix length and stability by weight - "+type_list[i])
                    #plt.show()

                    #fig2, ax2 = plt.subplots()
                    #ax2.plot(proba, lime_stability, 'bo', label = "LIME")
                    #ax2.plot(proba, tree_shap_stability, 'ro', label = "Tree SHAP")
                    #ax2.set_xlabel("Prediction Probability")
                    #ax2.set_ylabel("Stability")
                    #ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.title("Prediction probability and stability by weight - "+type_list[i])
                    #plt.show()
# Out:
# Bucket 1
# True Negatives
# Average LIME Weights Stability: 0.8928844678285193
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.9030207097472479
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.9691879252837756
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# False Positives
# Average LIME Weights Stability: 0.9524831333084689
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# Bucket 2
# True Negatives
# Average LIME Weights Stability: 0.9390195044990163
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.9242161107975961
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.9494979962592679
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# False Positives
# Average LIME Weights Stability: 0.8492828327351408
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# Bucket 3
# True Negatives
# Average LIME Weights Stability: 0.7517868121637032
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# True Positives
# Average LIME Weights Stability: 0.9048479402894007
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.7790080343917464
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Positives
# Average LIME Weights Stability: 0.8445856817784915
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# Bucket 4
# True Negatives
# Average LIME Weights Stability: 0.7719374578241146
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# True Positives
# Average LIME Weights Stability: 0.8934668427643151
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.9227499107197272
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# False Positives
# Average LIME Weights Stability: 0.464107528197084
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# Bucket 5
# True Negatives
# Average LIME Weights Stability: 0.6734088047790329
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# True Positives
# Average LIME Weights Stability: 0.8641610759070265
# Average SHAP Weights Stability: 0.9999999999999999
# 10
# False Negatives
# Average LIME Weights Stability: 0.8908000946932972
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# False Positives
# Average LIME Weights Stability: 0.4303053272867325
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# Bucket 6
# True Negatives
# Average LIME Weights Stability: 0.638070963793498
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# True Positives
# Average LIME Weights Stability: 0.8283010766322741
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# False Negatives
# Average LIME Weights Stability: 0.890933646009961
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# False Positives
# Average LIME Weights Stability: 0.8213224694906459
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# Bucket 7
# True Negatives
# Average LIME Weights Stability: 0.8332825774820132
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# True Positives
# Average LIME Weights Stability: 0.8420709285115445
# Average SHAP Weights Stability: 1.0
# 8
# False Negatives
# Average LIME Weights Stability: 0.8929692142231904
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# False Positives
# Average LIME Weights Stability: 0.7900977608530841
# Average SHAP Weights Stability: 0.9999999999999999
# 7
# Bucket 8
# True Negatives
# Average LIME Weights Stability: 0.8924073838590958
# Average SHAP Weights Stability: 0.9999999999999999
# 8
# True Positives
# Average LIME Weights Stability: 0.6884932255887519
# Average SHAP Weights Stability: 0.9999999999999999
# 6
# False Negatives
# Average LIME Weights Stability: 0.7529451218323296
# Average SHAP Weights Stability: 0.9999999999999999
# 9
# False Positives
# Average LIME Weights Stability: 0.7720856554831217
# Average SHAP Weights Stability: 1.0
# 5
# Bucket 9
# True Negatives
# Average LIME Weights Stability: 0.8443916765679118
# Average SHAP Weights Stability: 1.0
# 6
# True Positives
# Average LIME Weights Stability: 0.8374813035304777
# Average SHAP Weights Stability: 1.0
# 8
# False Negatives
# Average LIME Weights Stability: 0.7339749880287764
# Average SHAP Weights Stability: 1.0
# 5
# False Positives
# Average LIME Weights Stability: 0.8591881443312412
# Average SHAP Weights Stability: 1.0
# 5
# Bucket 10
# True Negatives
# Average LIME Weights Stability: 0.739757312723267
# Average SHAP Weights Stability: 1.0
# 8
# True Positives
# Average LIME Weights Stability: 0.8435454496036632
# Average SHAP Weights Stability: 1.0
# 6
# False Negatives
# Average LIME Weights Stability: 0.706303513343146
# Average SHAP Weights Stability: 1.0
# 5
# False Positives
# Average LIME Weights Stability: 0.5605579870923316
# Average SHAP Weights Stability: 1.0
# 5
# Bucket 11
# True Negatives
# Average LIME Weights Stability: 0.9050078797731635
# Average SHAP Weights Stability: 1.0
# 6
# True Positives
# Average LIME Weights Stability: 0.8645256759236096
# Average SHAP Weights Stability: 1.0
# 7
# False Negatives
# Average LIME Weights Stability: 0.8933292335264257
# Average SHAP Weights Stability: 1.0
# 5
# False Positives
# Average LIME Weights Stability: 0.872364880314336
# Average SHAP Weights Stability: 1.0
# 4
# Bucket 12
# True Negatives
# Average LIME Weights Stability: 0.8694924934448708
# Average SHAP Weights Stability: 1.0
# 7
# True Positives
# Average LIME Weights Stability: 0.8570931228877924
# Average SHAP Weights Stability: 1.0
# 6
# False Negatives
# Average LIME Weights Stability: 0.7756118951659025
# Average SHAP Weights Stability: 1.0
# 6
# False Positives
# Average LIME Weights Stability: 0.9255851380505848
# Average SHAP Weights Stability: 1.0
# 1
# Bucket 13
# True Negatives
# Average LIME Weights Stability: 0.8421786911593588
# Average SHAP Weights Stability: 1.0
# 4
# True Positives
# Average LIME Weights Stability: 0.8992724188979002
# Average SHAP Weights Stability: 1.0
# 2
# False Negatives
# Average LIME Weights Stability: 0.7542003439940608
# Average SHAP Weights Stability: 1.0
# 5
# False Positives
# Average LIME Weights Stability: -0.329203265470569
# Average SHAP Weights Stability: 1.0
# 3
# Bucket 14
# True Negatives
# Average LIME Weights Stability: 0.766288609294854
# Average SHAP Weights Stability: 1.0
# 6
# True Positives
# Average LIME Weights Stability: 0.35786915563696897
# Average SHAP Weights Stability: 1.0
# 6
# False Negatives
# Average LIME Weights Stability: 0.9133492605748226
# Average SHAP Weights Stability: 1.0
# 3
# False Positives
# Average LIME Weights Stability: 0.8474377400964607
# Average SHAP Weights Stability: 1.0
# 2
# Bucket 15
# True Negatives
# Average LIME Weights Stability: 0.9022390446779806
# Average SHAP Weights Stability: 1.0
# 7
# True Positives
# Average LIME Weights Stability: 0.8376327954872277
# Average SHAP Weights Stability: 1.0
# 7
# False Negatives
# Average LIME Weights Stability: 0.9037451102569821
# Average SHAP Weights Stability: 1.0
# 1
# False Positives
# Bucket 16
# True Negatives
# Average LIME Weights Stability: 0.9045589615872273
# Average SHAP Weights Stability: 1.0
# 3
# True Positives
# Average LIME Weights Stability: -0.5051306198753811
# Average SHAP Weights Stability: 1.0
# 5
# False Negatives
# Average LIME Weights Stability: 0.8987041175642565
# Average SHAP Weights Stability: 1.0
# 2
# False Positives
# Average LIME Weights Stability: 0.9089614848063386
# Average SHAP Weights Stability: 1.0
# 1
# Bucket 17
# True Negatives
# Average LIME Weights Stability: 0.9190655592986238
# Average SHAP Weights Stability: 1.0
# 3
# True Positives
# Average LIME Weights Stability: 0.8209733487096667
# Average SHAP Weights Stability: 1.0
# 4
# False Negatives
# Average LIME Weights Stability: 0.9108799358559672
# Average SHAP Weights Stability: 1.0
# 1
# False Positives
# Bucket 18
# True Negatives
# Average LIME Weights Stability: 0.9055220578652181
# Average SHAP Weights Stability: 1.0
# 3
# True Positives
# False Negatives
# Average LIME Weights Stability: 0.87797310625469
# Average SHAP Weights Stability: 1.0
# 3
# False Positives
# Bucket 19
# True Negatives
# Average LIME Weights Stability: 0.9213953687053009
# Average SHAP Weights Stability: 1.0
# 3
# True Positives
# Average LIME Weights Stability: 0.8834469835533219
# Average SHAP Weights Stability: 1.0
# 1
# False Negatives
# Average LIME Weights Stability: 0.8449843180997723
# Average SHAP Weights Stability: 1.0
# 3
# False Positives
# Bucket 20
# True Negatives
# Average LIME Weights Stability: 0.9061681146281764
# Average SHAP Weights Stability: 1.0
# 2
# True Positives
# False Negatives
# Average LIME Weights Stability: 0.8266936808765443
# Average SHAP Weights Stability: 1.0
# 3
# False Positives

# %%
sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Stability by Weight (LIME) \nPrefix-length Buckets with Index-based Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Stability by Weight (SHAP) \nPrefix-length Buckets with Index-based Encoding")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("Prefix length and stability by index \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.title("Prediction probability and stability by index \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
plt.show()

# %%
lime_mean = np.mean(all_lime_stab)
lime_std = np.std(all_lime_stab)
lime_upper = lime_mean + (3*lime_std)
lime_lower = lime_mean - (3*lime_std)

shap_mean = np.mean(all_shap_stab)
shap_std = np.std(all_shap_stab)
shap_upper = shap_mean + (3*shap_std)
shap_lower = shap_mean - (3*shap_std)

lime_outliers = [i for i in all_lime_stab if i > lime_upper or i < lime_lower]
shap_outliers = [i for i in all_shap_stab if i > shap_upper or i < shap_lower]

print (lime_mean)
print (shap_mean)
print(len(lime_outliers))
print(len(shap_outliers))
print(str(len(lime_outliers)/len(all_lime_stab)*100)+"%")
print(str(len(shap_outliers)/len(all_shap_stab)*100)+"%")
# Out:
# 0.7984736886684136
# 1.0
# 8
# 0
# 1.805869074492099%
# 0.0%

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens), key=lambda x: x[3])
all_proba, all_lime_stab, all_shap_stab, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_stab, hue=hue_lens, palette=lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1.1, 0.1))
plt.ylim(-17,1.1)
plt.title("Production: Stability by Weight (LIME) \nPrefix-length Buckets with Index-based Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_weight_stability.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_stab, hue=hue_lens, palette=shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Stability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,1, 0.1))
plt.ylim(-17,1.1)
plt.title("Production: Stability by Weight (SHAP) \nPrefix-length Buckets with Index-based Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_weight_stability.png", bbox_inches = "tight")
plt.show()

fig, ax = plt.subplots()
ax.plot(all_lengths, all_lime_stab, 'bo', label = "LIME")
ax.plot(all_lengths, all_shap_stab, 'ro', label = "Tree SHAP")
ax.set_xlabel("Prefix Length")
ax.set_ylabel("Stability")
ax.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(0, lime_upper)
plt.title("Prefix length and stability by weight \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
plt.show()

fig2, ax2 = plt.subplots()
ax2.plot(all_proba, all_lime_stab, 'bo', label = "LIME")
ax2.plot(all_proba, all_shap_stab, 'ro', label = "Tree SHAP")
ax2.set_xlabel("Prediction Probability")
ax2.set_ylabel("Stability")
ax2.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
#plt.yticks(np.arange(0,15,1))
plt.ylim(0, lime_upper)
plt.title("Prefix length and stability by weight \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
plt.show()

# %%
# bins = np.arange(0, shap_upper+1e-17, 1e-17)
# yticks = np.arange(0, 120, 10)
# #sns.set_style("white")
# plt.subplots(figsize=(20, 15))
# plt.hist(all_shap_stab, bins = bins)
# #plt.figsize([50, 50])
# plt.xticks(bins, fontsize = 8)
# plt.yticks(yticks, fontsize = 12)
# plt.title("Distribution of SHAP Stability by Weight", fontsize = 16)
# plt.xlabel("Stability Range", fontsize = 14)
# plt.ylabel("Frequency", fontsize = 14)
# plt.show()

# %%
# bins = np.arange(0, lime_upper+0.1, 0.1)
# yticks = np.arange(0, 720, 20)
# #sns.set_style("white")
# plt.subplots(figsize=(10, 10))
# plt.hist(all_lime_stab, bins = bins)
# #plt.figsize([50, 50])
# plt.xticks(bins, fontsize = 12)
# plt.yticks(yticks, fontsize = 12)
# plt.title("Distribution of LIME Stability by Weight", fontsize = 16)
# plt.xlabel("Stability Range", fontsize = 14)
# plt.ylabel("Frequency", fontsize = 14)
# plt.show()

# %%
all_caseID = []
all_lengths = []
all_proba = []

sep_caseID = [[],[],[],[]]
sep_lengths = [[],[],[],[]]
sep_proba = [[],[],[],[]]

all_lime_diffs = []
all_shap_diffs = []

sep_lime_diffs = [[],[],[],[]]
sep_shap_diffs = [[],[],[],[]]

all_lime_MSE = []
all_lime_RMSE = []
all_lime_MAE = []
all_lime_MAPE = []

sep_lime_MSE = [[],[],[],[]]
sep_lime_RMSE = [[],[],[],[]]
sep_lime_MAE = [[],[],[],[]]
sep_lime_MAPE = [[],[],[],[]]

all_shap_MSE = []
all_shap_RMSE = []
all_shap_MAE = []
all_shap_MAPE = []

sep_shap_MSE = [[],[],[],[]]
sep_shap_RMSE = [[],[],[],[]]
sep_shap_MAE = [[],[],[],[]]
sep_shap_MAPE = [[],[],[],[]]

for dataset_name in datasets:

    dataset_manager = DatasetManager(dataset_name)

    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s_%s/models'% (dataset_ref, cls_method, method_name)))])
        
        if num_buckets < max_prefix:
            max_prefix = num_buckets
            
        buckets = range(0, max_prefix, gap)

        for bucket in buckets:
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucketID))
            cls = joblib.load(cls_path)
            feature_combiner = joblib.load(feat_comb_path)

            #import previously identified samples
            tn_path = os.path.join(PATH, "%s/%s_%s/samples/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            tp_path = os.path.join(PATH, "%s/%s_%s/samples/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fn_path = os.path.join(PATH, "%s/%s_%s/samples/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))
            fp_path = os.path.join(PATH, "%s/%s_%s/samples/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucketID))

            sample_instances = []

            with open (tn_path, 'rb') as f:
                tn_list = pickle.load(f)
            with open (tp_path, 'rb') as f:
                tp_list = pickle.load(f)
            with open (fn_path, 'rb') as f:
                fn_list = pickle.load(f)
            with open (fp_path, 'rb') as f:
                fp_list = pickle.load(f)

            #save results to a list
            sample_instances.append(tn_list)
            sample_instances.append(tp_list)
            sample_instances.append(fn_list)
            sample_instances.append(fp_list)
            
            type_list = ["True Negatives", "True Positives", "False Negatives", "False Positives"]
            
            for i in range(len(sample_instances)):
                print (type_list[i])
                if sample_instances[i]!=[]:
                    data = pd.DataFrame.from_records(sample_instances[i])

                    lime_MSE = []
                    lime_RMSE = []
                    lime_MAE = []
                    lime_MAPE = []

                    shap_MSE = []
                    shap_RMSE = []
                    shap_MAE = []
                    shap_MAPE = []

                    case_id = pd.Series(data['caseID'])
                    nr_events = pd.Series(data['nr_events'])
                    proba = pd.Series(data['proba'])
                    lime_diffs = pd.Series(data['lime_fid_change'])
                    shap_diffs = pd.Series(data['shap_fid_change'])

                    for j in range(len(lime_diffs)):
                        p1 = proba[j]

                        lime_diff = lime_diffs[j]
                        shap_diff = shap_diffs[j]

                        all_lime_diffs.append(lime_diff)
                        all_shap_diffs.append(shap_diff)

                        lime_sq_changes = []
                        lime_abs_changes = []
                        lime_rel_changes = []

                        shap_sq_changes = []
                        shap_abs_changes = []
                        shap_rel_changes = []

                        for each in lime_diff:
                            lime_sq_changes.append(each**2)
                            lime_abs_changes.append(abs(each))
                            lime_rel_changes.append(abs(each)/p1)

                        for each in shap_diff:
                            shap_sq_changes.append(each**2)
                            shap_abs_changes.append(abs(each))
                            shap_rel_changes.append(abs(each)/p1)

                        lime_MSE.append(sum(lime_sq_changes)/len(lime_sq_changes))
                        lime_RMSE.append(math.sqrt(sum(lime_sq_changes)/len(lime_sq_changes)))
                        lime_MAE.append(sum(lime_abs_changes)/len(lime_abs_changes))
                        lime_MAPE.append(sum(lime_rel_changes)/len(lime_rel_changes))

                        shap_MSE.append(sum(shap_sq_changes)/len(shap_sq_changes))
                        shap_RMSE.append(math.sqrt(sum(shap_sq_changes)/len(shap_sq_changes)))
                        shap_MAE.append(sum(shap_abs_changes)/len(shap_abs_changes))
                        shap_MAPE.append(sum(shap_rel_changes)/len(shap_rel_changes))

                    all_caseID.extend(case_id)
                    all_lengths.extend(nr_events)
                    all_proba.extend(proba)

                    all_lime_MSE.extend(lime_MSE)
                    all_lime_RMSE.extend(lime_RMSE)
                    all_lime_MAE.extend(lime_MAE)
                    all_lime_MAPE.extend(lime_MAPE)

                    all_shap_MSE.extend(shap_MSE)
                    all_shap_RMSE.extend(shap_RMSE)
                    all_shap_MAE.extend(shap_MAE)
                    all_shap_MAPE.extend(shap_MAPE)

                    sep_caseID[i].extend(case_id)
                    sep_lengths[i].extend(nr_events)
                    sep_proba[i].extend(proba)

                    sep_lime_MSE[i].extend(lime_MSE)
                    sep_lime_RMSE[i].extend(lime_RMSE)
                    sep_lime_MAE[i].extend(lime_MAE)
                    sep_lime_MAPE[i].extend(lime_MAPE)

                    sep_shap_MSE[i].extend(shap_MSE)
                    sep_shap_RMSE[i].extend(shap_RMSE)
                    sep_shap_MAE[i].extend(shap_MAE)
                    sep_shap_MAPE[i].extend(shap_MAPE)

                    print("Average LIME MSE:", statistics.mean(lime_MSE))
                    print("Average SHAP MSE:", statistics.mean(shap_MSE))
                    print("\n")

                    #plt.plot(nr_events, lime_MSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_MSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    ##plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_MSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_MSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MSE \n"+type_list[i])
                    #plt.show()

                    print("Average LIME RMSE:", statistics.mean(lime_RMSE))
                    print("Average SHAP RMSE:", statistics.mean(shap_RMSE))
                    print("\n")

                    #plt.plot(nr_events, lime_RMSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and RMSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_RMSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and RMSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_RMSE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and RMSE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_RMSE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and RMSE \n"+type_list[i])
                    #plt.show()

                    print("Average LIME MAE:", statistics.mean(lime_MAE))
                    print("Average SHAP MAE:", statistics.mean(shap_MAE))
                    print("\n")

                    #plt.plot(nr_events, lime_MAE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_MAE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_MAE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_MAE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAE \n"+type_list[i])
                    #plt.show()

                    print("Average LIME MAPE:", statistics.mean(lime_MAPE))
                    print("Average SHAP MAPE:", statistics.mean(shap_MAPE))
                    print("\n")

                    #plt.plot(nr_events, lime_MAPE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAPE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(nr_events, shap_MAPE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prefix length and MAPE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, lime_MAPE, 'bo', label = "LIME")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAPE \n"+type_list[i])
                    #plt.show()

                    #plt.plot(proba, shap_MAPE, 'ro', label = "Tree SHAP")
                    #plt.xlabel("Prefix Length")
                    #plt.ylabel("Change in Prediction Probability")
                    #plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
                    #plt.yticks(np.arange(0,15,1))
                    #plt.title("Prediction probability and MAPE \n"+type_list[i])
                    #plt.show()
# Out:
# Bucket 1
# True Negatives
# Average LIME MSE: 0.06178021507743809
# Average SHAP MSE: 0.04012363651495962
#
#
# Average LIME RMSE: 0.21510364975161136
# Average SHAP RMSE: 0.17870197020029113
#
#
# Average LIME MAE: 0.1951584178209305
# Average SHAP MAE: 0.16980504631996154
#
#
# Average LIME MAPE: 0.26903452812835327
# Average SHAP MAPE: 0.24294383965489036
#
#
# True Positives
# Average LIME MSE: 0.09988456142413817
# Average SHAP MSE: 0.04017957426607488
#
#
# Average LIME RMSE: 0.2797068413540592
# Average SHAP RMSE: 0.1737504594346793
#
#
# Average LIME MAE: 0.2543597161769867
# Average SHAP MAE: 0.16349650025367737
#
#
# Average LIME MAPE: 0.3247232308457111
# Average SHAP MAPE: 0.22428142145315397
#
#
# False Negatives
# Average LIME MSE: 0.05873963348242646
# Average SHAP MSE: 0.051254001239109045
#
#
# Average LIME RMSE: 0.21630847097083478
# Average SHAP RMSE: 0.20408691723244016
#
#
# Average LIME MAE: 0.1871034514158964
# Average SHAP MAE: 0.19450504370033742
#
#
# Average LIME MAPE: 0.28165965670436516
# Average SHAP MAPE: 0.2779088400860596
#
#
# False Positives
# Average LIME MSE: 0.15668699854504742
# Average SHAP MSE: 0.03315959614224582
#
#
# Average LIME RMSE: 0.32579505860207597
# Average SHAP RMSE: 0.16106395004306104
#
#
# Average LIME MAE: 0.3050301782786846
# Average SHAP MAE: 0.14851961135864258
#
#
# Average LIME MAPE: 0.4155267995752143
# Average SHAP MAPE: 0.2205335927716079
#
#
# Bucket 2
# True Negatives
# Average LIME MSE: 0.14689703907885074
# Average SHAP MSE: 0.13296902242909284
#
#
# Average LIME RMSE: 0.3287288271345623
# Average SHAP RMSE: 0.3344361211882506
#
#
# Average LIME MAE: 0.31266799733042716
# Average SHAP MAE: 0.3233067844808102
#
#
# Average LIME MAPE: 0.43055199682074075
# Average SHAP MAPE: 0.41760864429417055
#
#
# True Positives
# Average LIME MSE: 0.22062762307676298
# Average SHAP MSE: 0.10753625447185222
#
#
# Average LIME RMSE: 0.4412038787791154
# Average SHAP RMSE: 0.25306079362795914
#
#
# Average LIME MAE: 0.42512310326099395
# Average SHAP MAE: 0.24163196206092835
#
#
# Average LIME MAPE: 0.572981521852138
# Average SHAP MAPE: 0.3081732339491139
#
#
# False Negatives
# Average LIME MSE: 0.12318540179868093
# Average SHAP MSE: 0.21914307085986448
#
#
# Average LIME RMSE: 0.3391080385202366
# Average SHAP RMSE: 0.418684646002303
#
#
# Average LIME MAE: 0.3089886236935854
# Average SHAP MAE: 0.412434022501111
#
#
# Average LIME MAPE: 0.46100871516907055
# Average SHAP MAPE: 0.5736836701457576
#
#
# False Positives
# Average LIME MSE: 0.299482073445125
# Average SHAP MSE: 0.1278622703179546
#
#
# Average LIME RMSE: 0.517269496402831
# Average SHAP RMSE: 0.3161588335845356
#
#
# Average LIME MAE: 0.5025533124804497
# Average SHAP MAE: 0.3041445970535278
#
#
# Average LIME MAPE: 0.668049389996688
# Average SHAP MAPE: 0.407888856343969
#
#
# Bucket 3
# True Negatives
# Average LIME MSE: 0.08124520099857813
# Average SHAP MSE: 0.3750380043471527
#
#
# Average LIME RMSE: 0.24709755700576902
# Average SHAP RMSE: 0.5546748050710815
#
#
# Average LIME MAE: 0.22806322496384382
# Average SHAP MAE: 0.5496793418750167
#
#
# Average LIME MAPE: 0.29876437858497146
# Average SHAP MAPE: 0.7023481276701694
#
#
# True Positives
# Average LIME MSE: 0.1604189606731509
# Average SHAP MSE: 0.29710257000686113
#
#
# Average LIME RMSE: 0.34952990303756104
# Average SHAP RMSE: 0.5082871527344442
#
#
# Average LIME MAE: 0.33110410869121554
# Average SHAP MAE: 0.5028764116764068
#
#
# Average LIME MAPE: 0.4286178985159804
# Average SHAP MAPE: 0.6804357370856777
#
#
# False Negatives
# Average LIME MSE: 0.12810252329643418
# Average SHAP MSE: 0.3721892972251977
#
#
# Average LIME RMSE: 0.28917942704646893
# Average SHAP RMSE: 0.5625687791573343
#
#
# Average LIME MAE: 0.2689167956262827
# Average SHAP MAE: 0.5571929348260164
#
#
# Average LIME MAPE: 0.3341268765270266
# Average SHAP MAPE: 0.7230432756495369
#
#
# False Positives
# Average LIME MSE: 0.18332471341585063
# Average SHAP MSE: 0.36829583652519515
#
#
# Average LIME RMSE: 0.3588798974575632
# Average SHAP RMSE: 0.5875176878495264
#
#
# Average LIME MAE: 0.34406906723976133
# Average SHAP MAE: 0.584080444574356
#
#
# Average LIME MAPE: 0.43649538070821625
# Average SHAP MAPE: 0.794857115892291
#
#
# Bucket 4
# True Negatives
# Average LIME MSE: 0.09716724953478229
# Average SHAP MSE: 0.49905527949455386
#
#
# Average LIME RMSE: 0.26115147001556843
# Average SHAP RMSE: 0.6341918452179501
#
#
# Average LIME MAE: 0.24441471952013671
# Average SHAP MAE: 0.6326347026508301
#
#
# Average LIME MAPE: 0.3065648225182231
# Average SHAP MAPE: 0.7621669026199246
#
#
# True Positives
# Average LIME MSE: 0.22612421533453567
# Average SHAP MSE: 0.45197805743822506
#
#
# Average LIME RMSE: 0.4132655475518726
# Average SHAP RMSE: 0.6376764729110515
#
#
# Average LIME MAE: 0.39684978663921355
# Average SHAP MAE: 0.6353140938282013
#
#
# Average LIME MAPE: 0.5170525559931182
# Average SHAP MAPE: 0.8271996282086032
#
#
# False Negatives
# Average LIME MSE: 0.16020967950983178
# Average SHAP MSE: 0.5146731540379456
#
#
# Average LIME RMSE: 0.35888193431451065
# Average SHAP RMSE: 0.6916217009346916
#
#
# Average LIME MAE: 0.3446280932519585
# Average SHAP MAE: 0.6908295551780611
#
#
# Average LIME MAPE: 0.4399723030908454
# Average SHAP MAPE: 0.8822805922655689
#
#
# False Positives
# Average LIME MSE: 0.2988445413691146
# Average SHAP MSE: 0.43797308208909447
#
#
# Average LIME RMSE: 0.49129398865032886
# Average SHAP RMSE: 0.6518963837437967
#
#
# Average LIME MAE: 0.47822067737579343
# Average SHAP MAE: 0.6513526099068778
#
#
# Average LIME MAPE: 0.5833026234323985
# Average SHAP MAPE: 0.866782313895665
#
#
# Bucket 5
# True Negatives
# Average LIME MSE: 0.30790415817859224
# Average SHAP MSE: 0.4582256321457213
#
#
# Average LIME RMSE: 0.5332714740626155
# Average SHAP RMSE: 0.6555250341113786
#
#
# Average LIME MAE: 0.5246413844327131
# Average SHAP MAE: 0.6545668341219425
#
#
# Average LIME MAPE: 0.6929696236281799
# Average SHAP MAPE: 0.8408329613110438
#
#
# True Positives
# Average LIME MSE: 0.3551200213573614
# Average SHAP MSE: 0.36759456854296124
#
#
# Average LIME RMSE: 0.5760589533105954
# Average SHAP RMSE: 0.5905605078954603
#
#
# Average LIME MAE: 0.5708442777395248
# Average SHAP MAE: 0.5892990642786026
#
#
# Average LIME MAPE: 0.7451676129761483
# Average SHAP MAPE: 0.7813804493083393
#
#
# False Negatives
# Average LIME MSE: 0.27662681393605987
# Average SHAP MSE: 0.5833670694828197
#
#
# Average LIME RMSE: 0.49020684092391315
# Average SHAP RMSE: 0.7495664053552622
#
#
# Average LIME MAE: 0.47987222000956536
# Average SHAP MAE: 0.749059668715511
#
#
# Average LIME MAPE: 0.5854814746439797
# Average SHAP MAPE: 0.902605590050262
#
#
# False Positives
# Average LIME MSE: 0.3618284907753497
# Average SHAP MSE: 0.3150837757796423
#
#
# Average LIME RMSE: 0.5646905177857771
# Average SHAP RMSE: 0.5551280285127475
#
#
# Average LIME MAE: 0.5579623652829064
# Average SHAP MAE: 0.5533828947279188
#
#
# Average LIME MAPE: 0.7347583652083977
# Average SHAP MAPE: 0.7607979057152311
#
#
# Bucket 6
# True Negatives
# Average LIME MSE: 0.05391753587979849
# Average SHAP MSE: 0.5864880664219516
#
#
# Average LIME RMSE: 0.21231814797372486
# Average SHAP RMSE: 0.7554131077330639
#
#
# Average LIME MAE: 0.19186943833317074
# Average SHAP MAE: 0.7552334068076951
#
#
# Average LIME MAPE: 0.24303212708810684
# Average SHAP MAPE: 0.9304076413332106
#
#
# True Positives
# Average LIME MSE: 0.16014515862122275
# Average SHAP MSE: 0.3183013244150038
#
#
# Average LIME RMSE: 0.3476321595389076
# Average SHAP RMSE: 0.5312620063050371
#
#
# Average LIME MAE: 0.3233130293233054
# Average SHAP MAE: 0.5236335762909481
#
#
# Average LIME MAPE: 0.40899356933168446
# Average SHAP MAPE: 0.6837624830738039
#
#
# False Negatives
# Average LIME MSE: 0.06946785616304167
# Average SHAP MSE: 0.5206466816321953
#
#
# Average LIME RMSE: 0.235619100955437
# Average SHAP RMSE: 0.7021264579167468
#
#
# Average LIME MAE: 0.21433194877786768
# Average SHAP MAE: 0.7017112612931264
#
#
# Average LIME MAPE: 0.2769312676707124
# Average SHAP MAPE: 0.9020441455681443
#
#
# False Positives
# Average LIME MSE: 0.1382070221395399
# Average SHAP MSE: 0.3031337003254239
#
#
# Average LIME RMSE: 0.3327951362810353
# Average SHAP RMSE: 0.5403872411283565
#
#
# Average LIME MAE: 0.3145105756819248
# Average SHAP MAE: 0.5393176607787609
#
#
# Average LIME MAPE: 0.43153999186605285
# Average SHAP MAPE: 0.7656109421821438
#
#
# Bucket 7
# True Negatives
# Average LIME MSE: 0.047761815604670396
# Average SHAP MSE: 0.5566798441326726
#
#
# Average LIME RMSE: 0.20315306295882699
# Average SHAP RMSE: 0.724256188892093
#
#
# Average LIME MAE: 0.18253736691549421
# Average SHAP MAE: 0.7241892573423684
#
#
# Average LIME MAPE: 0.2508609464234932
# Average SHAP MAPE: 0.9550418167645484
#
#
# True Positives
# Average LIME MSE: 0.08151861216011305
# Average SHAP MSE: 0.3488691762048012
#
#
# Average LIME RMSE: 0.2538468478679579
# Average SHAP RMSE: 0.5838466927740213
#
#
# Average LIME MAE: 0.23120931014418603
# Average SHAP MAE: 0.5827367469668389
#
#
# Average LIME MAPE: 0.29082694418701455
# Average SHAP MAPE: 0.7833559498317675
#
#
# False Negatives
# Average LIME MSE: 0.021620477160673626
# Average SHAP MSE: 0.413062181598307
#
#
# Average LIME RMSE: 0.1339269677972593
# Average SHAP RMSE: 0.6004586922514876
#
#
# Average LIME MAE: 0.11651100087910891
# Average SHAP MAE: 0.5987069226801396
#
#
# Average LIME MAPE: 0.18202978867413275
# Average SHAP MAPE: 0.8125039598937092
#
#
# False Positives
# Average LIME MSE: 0.09546820743688327
# Average SHAP MSE: 0.49325623695344845
#
#
# Average LIME RMSE: 0.27239705879928044
# Average SHAP RMSE: 0.6840388446244702
#
#
# Average LIME MAE: 0.2549418321677617
# Average SHAP MAE: 0.6824023791721889
#
#
# Average LIME MAPE: 0.3352223626903358
# Average SHAP MAPE: 0.83828841895108
#
#
# Bucket 8
# True Negatives
# Average LIME MSE: 0.09274350825990181
# Average SHAP MSE: 0.4211547025508267
#
#
# Average LIME RMSE: 0.27054359284953644
# Average SHAP RMSE: 0.618524864093638
#
#
# Average LIME MAE: 0.2512797592906281
# Average SHAP MAE: 0.617427924904041
#
#
# Average LIME MAPE: 0.33232874056515627
# Average SHAP MAPE: 0.7955730128416197
#
#
# True Positives
# Average LIME MSE: 0.12405878361283927
# Average SHAP MSE: 0.30897671898179996
#
#
# Average LIME RMSE: 0.32418829444999536
# Average SHAP RMSE: 0.5291368985825365
#
#
# Average LIME MAE: 0.3034057065844536
# Average SHAP MAE: 0.5258543699979782
#
#
# Average LIME MAPE: 0.39472817170691615
# Average SHAP MAPE: 0.7170920873398642
#
#
# False Negatives
# Average LIME MSE: 0.024968973582972797
# Average SHAP MSE: 0.3945832573048814
#
#
# Average LIME RMSE: 0.1406029683916721
# Average SHAP RMSE: 0.6016065083657782
#
#
# Average LIME MAE: 0.11951082232925626
# Average SHAP MAE: 0.600189287132687
#
#
# Average LIME MAPE: 0.18112468529711215
# Average SHAP MAPE: 0.8066897809462362
#
#
# False Positives
# Average LIME MSE: 0.028473469395805324
# Average SHAP MSE: 0.30945397468179175
#
#
# Average LIME RMSE: 0.1644501166025698
# Average SHAP RMSE: 0.5447775099814612
#
#
# Average LIME MAE: 0.1439679217338562
# Average SHAP MAE: 0.5439337766170502
#
#
# Average LIME MAPE: 0.21551553376669735
# Average SHAP MAPE: 0.8154791802543528
#
#
# Bucket 9
# True Negatives
# Average LIME MSE: 0.06111841587978156
# Average SHAP MSE: 0.598474791438743
#
#
# Average LIME RMSE: 0.229378519944064
# Average SHAP RMSE: 0.7510069635451793
#
#
# Average LIME MAE: 0.21246596307804186
# Average SHAP MAE: 0.7509223911290367
#
#
# Average LIME MAPE: 0.2668428027403717
# Average SHAP MAPE: 0.9285670224933119
#
#
# True Positives
# Average LIME MSE: 0.10022829292609284
# Average SHAP MSE: 0.45229376046859887
#
#
# Average LIME RMSE: 0.2860007760325874
# Average SHAP RMSE: 0.6551855567204793
#
#
# Average LIME MAE: 0.2733575589954853
# Average SHAP MAE: 0.6547330476343631
#
#
# Average LIME MAPE: 0.3653054816832911
# Average SHAP MAPE: 0.8336746127698691
#
#
# False Negatives
# Average LIME MSE: 0.08544816792834957
# Average SHAP MSE: 0.4170495369103061
#
#
# Average LIME RMSE: 0.23800205915065706
# Average SHAP RMSE: 0.6244179772396344
#
#
# Average LIME MAE: 0.2234227842092514
# Average SHAP MAE: 0.6243170887231827
#
#
# Average LIME MAPE: 0.33360725585749695
# Average SHAP MAPE: 0.9019350917082732
#
#
# False Positives
# Average LIME MSE: 0.07818247125764859
# Average SHAP MSE: 0.3766321109035553
#
#
# Average LIME RMSE: 0.24387182048571843
# Average SHAP RMSE: 0.6071171264050524
#
#
# Average LIME MAE: 0.23560228347778323
# Average SHAP MAE: 0.6064725589752197
#
#
# Average LIME MAPE: 0.3689966815444963
# Average SHAP MAPE: 0.8696383474205601
#
#
# Bucket 10
# True Negatives
# Average LIME MSE: 0.022830801638315436
# Average SHAP MSE: 0.5242237248938477
#
#
# Average LIME RMSE: 0.1361874236459121
# Average SHAP RMSE: 0.7046453880490264
#
#
# Average LIME MAE: 0.125457181641832
# Average SHAP MAE: 0.7044411203358323
#
#
# Average LIME MAPE: 0.18805972864209272
# Average SHAP MAPE: 0.9214839286478963
#
#
# True Positives
# Average LIME MSE: 0.390989948463618
# Average SHAP MSE: 0.49217369423048013
#
#
# Average LIME RMSE: 0.6150756592361242
# Average SHAP RMSE: 0.6752666822463724
#
#
# Average LIME MAE: 0.6071558261911074
# Average SHAP MAE: 0.6734197308619817
#
#
# Average LIME MAPE: 0.7044933201878171
# Average SHAP MAPE: 0.7645545346437627
#
#
# False Negatives
# Average LIME MSE: 0.07910280178177706
# Average SHAP MSE: 0.46907906421056317
#
#
# Average LIME RMSE: 0.24974898214473037
# Average SHAP RMSE: 0.657200304261211
#
#
# Average LIME MAE: 0.2415596403181553
# Average SHAP MAE: 0.657023761421442
#
#
# Average LIME MAPE: 0.4005775547140832
# Average SHAP MAPE: 0.9163066434593723
#
#
# False Positives
# Average LIME MSE: 0.3451369573909252
# Average SHAP MSE: 0.5194653590071833
#
#
# Average LIME RMSE: 0.5718216580388255
# Average SHAP RMSE: 0.7175558122779355
#
#
# Average LIME MAE: 0.5584748393297195
# Average SHAP MAE: 0.7167879641056061
#
#
# Average LIME MAPE: 0.662296437934549
# Average SHAP MAPE: 0.8704828373609118
#
#
# Bucket 11
# True Negatives
# Average LIME MSE: 0.017544173873444046
# Average SHAP MSE: 0.6228686898053514
#
#
# Average LIME RMSE: 0.1096674153572369
# Average SHAP RMSE: 0.7754422376721338
#
#
# Average LIME MAE: 0.09428687989711762
# Average SHAP MAE: 0.7751720617214839
#
#
# Average LIME MAPE: 0.1269464860514531
# Average SHAP MAPE: 0.9311732687016688
#
#
# True Positives
# Average LIME MSE: 0.25020104170187357
# Average SHAP MSE: 0.3694084339564395
#
#
# Average LIME RMSE: 0.47702167923360717
# Average SHAP RMSE: 0.5941484712612731
#
#
# Average LIME MAE: 0.468086708017758
# Average SHAP MAE: 0.591816989013127
#
#
# Average LIME MAPE: 0.5825157099647702
# Average SHAP MAPE: 0.7575921003051731
#
#
# False Negatives
# Average LIME MSE: 0.016957796746620027
# Average SHAP MSE: 0.2665510293014658
#
#
# Average LIME RMSE: 0.1272747380594095
# Average SHAP RMSE: 0.49688470191745676
#
#
# Average LIME MAE: 0.1107930874824524
# Average SHAP MAE: 0.49469732999801636
#
#
# Average LIME MAPE: 0.17247301788051317
# Average SHAP MAPE: 0.7569891526502364
#
#
# False Positives
# Average LIME MSE: 0.29786374242731134
# Average SHAP MSE: 0.27230277530950914
#
#
# Average LIME RMSE: 0.5436846762450962
# Average SHAP RMSE: 0.5168438592320052
#
#
# Average LIME MAE: 0.5356968753039837
# Average SHAP MAE: 0.5099695459008217
#
#
# Average LIME MAPE: 0.6824800004496019
# Average SHAP MAPE: 0.6445156863880918
#
#
# Bucket 12
# True Negatives
# Average LIME MSE: 0.08740380005062326
# Average SHAP MSE: 0.5002524216124536
#
#
# Average LIME RMSE: 0.27222078650847514
# Average SHAP RMSE: 0.6715980645653654
#
#
# Average LIME MAE: 0.25410128885081834
# Average SHAP MAE: 0.6707637485648904
#
#
# Average LIME MAPE: 0.3147437084409491
# Average SHAP MAPE: 0.8121821142494386
#
#
# True Positives
# Average LIME MSE: 0.061052617488280496
# Average SHAP MSE: 0.19566040769262222
#
#
# Average LIME RMSE: 0.22733456607179833
# Average SHAP RMSE: 0.40886889430007933
#
#
# Average LIME MAE: 0.20744205713272096
# Average SHAP MAE: 0.4057472328344981
#
#
# Average LIME MAPE: 0.3012303196328317
# Average SHAP MAPE: 0.5857710621166239
#
#
# False Negatives
# Average LIME MSE: 0.03380287695741315
# Average SHAP MSE: 0.43483068512013623
#
#
# Average LIME RMSE: 0.1666301455970785
# Average SHAP RMSE: 0.6303194032203231
#
#
# Average LIME MAE: 0.14114573945601783
# Average SHAP MAE: 0.6297055905063947
#
#
# Average LIME MAPE: 0.18539914738114124
# Average SHAP MAPE: 0.8259627482806564
#
#
# False Positives
# Average LIME MSE: 0.029903542334760492
# Average SHAP MSE: 0.138519871066595
#
#
# Average LIME RMSE: 0.17292640727997702
# Average SHAP RMSE: 0.3721825775967959
#
#
# Average LIME MAE: 0.15047763288021088
# Average SHAP MAE: 0.3702241122722626
#
#
# Average LIME MAPE: 0.22870354332556125
# Average SHAP MAPE: 0.5626853950356228
#
#
# Bucket 13
# True Negatives
# Average LIME MSE: 0.14898869368865642
# Average SHAP MSE: 0.6752957528660173
#
#
# Average LIME RMSE: 0.3843704287565057
# Average SHAP RMSE: 0.8192350721117171
#
#
# Average LIME MAE: 0.3741242432966828
# Average SHAP MAE: 0.8189014965668321
#
#
# Average LIME MAPE: 0.42126504708319007
# Average SHAP MAPE: 0.9223279713918772
#
#
# True Positives
# Average LIME MSE: 0.09759707589906969
# Average SHAP MSE: 0.1771122781159324
#
#
# Average LIME RMSE: 0.3003253266450604
# Average SHAP RMSE: 0.4208259615984663
#
#
# Average LIME MAE: 0.28509285897016523
# Average SHAP MAE: 0.4159854412078857
#
#
# Average LIME MAPE: 0.43210433523344516
# Average SHAP MAPE: 0.6798858777034453
#
#
# False Negatives
# Average LIME MSE: 0.10282184111938523
# Average SHAP MSE: 0.422419160994028
#
#
# Average LIME RMSE: 0.27803191405203725
# Average SHAP RMSE: 0.6246708161873625
#
#
# Average LIME MAE: 0.2642094305157662
# Average SHAP MAE: 0.6243414869904518
#
#
# Average LIME MAPE: 0.35344512710398573
# Average SHAP MAPE: 0.8803059751682589
#
#
# False Positives
# Average LIME MSE: 0.09592648548820257
# Average SHAP MSE: 0.21375697487543305
#
#
# Average LIME RMSE: 0.26618515489638134
# Average SHAP RMSE: 0.4607995076378509
#
#
# Average LIME MAE: 0.25562676787376404
# Average SHAP MAE: 0.4573793053627014
#
#
# Average LIME MAPE: 0.36180281840263895
# Average SHAP MAPE: 0.7125721179282539
#
#
# Bucket 14
# True Negatives
# Average LIME MSE: 0.05156530198385538
# Average SHAP MSE: 0.30132434247286716
#
#
# Average LIME RMSE: 0.1960253708753097
# Average SHAP RMSE: 0.5368101486889154
#
#
# Average LIME MAE: 0.1792498787244161
# Average SHAP MAE: 0.5357130294044813
#
#
# Average LIME MAPE: 0.21836047208349146
# Average SHAP MAPE: 0.6803058867960542
#
#
# True Positives
# Average LIME MSE: 0.05838946880622231
# Average SHAP MSE: 0.12830235651285526
#
#
# Average LIME RMSE: 0.2060835433008048
# Average SHAP RMSE: 0.32834081492757017
#
#
# Average LIME MAE: 0.19022809167702992
# Average SHAP MAE: 0.32446282207965854
#
#
# Average LIME MAPE: 0.28442902614221155
# Average SHAP MAPE: 0.4654219081085765
#
#
# False Negatives
# Average LIME MSE: 0.017644293465969223
# Average SHAP MSE: 0.16181898683924084
#
#
# Average LIME RMSE: 0.12895865823557545
# Average SHAP RMSE: 0.3807552084525263
#
#
# Average LIME MAE: 0.11162922779719034
# Average SHAP MAE: 0.37941761811574304
#
#
# Average LIME MAPE: 0.17457018649061343
# Average SHAP MAPE: 0.5887678635302261
#
#
# False Positives
# Average LIME MSE: 0.0305393611762927
# Average SHAP MSE: 0.1723212130568596
#
#
# Average LIME RMSE: 0.17205678394518437
# Average SHAP RMSE: 0.3842755067239888
#
#
# Average LIME MAE: 0.14572203755378724
# Average SHAP MAE: 0.38189575970172884
#
#
# Average LIME MAPE: 0.22596225144909118
# Average SHAP MAPE: 0.5786236432315826
#
#
# Bucket 15
# True Negatives
# Average LIME MSE: 0.05533683189703414
# Average SHAP MSE: 0.4707106091963876
#
#
# Average LIME RMSE: 0.1858945167386431
# Average SHAP RMSE: 0.6604582109751136
#
#
# Average LIME MAE: 0.182491911309106
# Average SHAP MAE: 0.6601138581122671
#
#
# Average LIME MAPE: 0.2998425193406368
# Average SHAP MAPE: 0.8805937996717621
#
#
# True Positives
# Average LIME MSE: 0.4029271638695324
# Average SHAP MSE: 0.3099720479837937
#
#
# Average LIME RMSE: 0.6232810893519031
# Average SHAP RMSE: 0.5232166110290161
#
#
# Average LIME MAE: 0.6216659584215709
# Average SHAP MAE: 0.5211210225309645
#
#
# Average LIME MAPE: 0.8157961139123749
# Average SHAP MAPE: 0.6601588221878205
#
#
# False Negatives
# Average LIME MSE: 0.0864931445594305
# Average SHAP MSE: 0.24931969165422635
#
#
# Average LIME RMSE: 0.294097168567517
# Average SHAP RMSE: 0.4993192282039881
#
#
# Average LIME MAE: 0.29132625460624695
# Average SHAP MAE: 0.4988599240779877
#
#
# Average LIME MAPE: 0.5054273809816803
# Average SHAP MAPE: 0.8654814350469137
#
#
# False Positives
# Bucket 16
# True Negatives
# Average LIME MSE: 0.11703715586799335
# Average SHAP MSE: 0.3751841311657031
#
#
# Average LIME RMSE: 0.30864141432445436
# Average SHAP RMSE: 0.6114118961847141
#
#
# Average LIME MAE: 0.28997073570887244
# Average SHAP MAE: 0.6105832397937775
#
#
# Average LIME MAPE: 0.35888320530138873
# Average SHAP MAPE: 0.7648455817635433
#
#
# True Positives
# Average LIME MSE: 0.10158163606552331
# Average SHAP MSE: 0.06817530148309991
#
#
# Average LIME RMSE: 0.2583081596659293
# Average SHAP RMSE: 0.2146265299977348
#
#
# Average LIME MAE: 0.2508611369132996
# Average SHAP MAE: 0.19803625702857972
#
#
# Average LIME MAPE: 0.34379366340742423
# Average SHAP MAPE: 0.27144854164326604
#
#
# False Negatives
# Average LIME MSE: 0.018409256110482452
# Average SHAP MSE: 0.07797577725600106
#
#
# Average LIME RMSE: 0.13456891201152577
# Average SHAP RMSE: 0.27773933721877697
#
#
# Average LIME MAE: 0.11972355544567109
# Average SHAP MAE: 0.2680747151374817
#
#
# Average LIME MAPE: 0.2067619829413014
# Average SHAP MAPE: 0.4733329750935301
#
#
# False Positives
# Average LIME MSE: 0.0881028993679955
# Average SHAP MSE: 0.11511274449204087
#
#
# Average LIME RMSE: 0.2968213256624185
# Average SHAP RMSE: 0.3392826911176591
#
#
# Average LIME MAE: 0.2877349674701691
# Average SHAP MAE: 0.3354486048221588
#
#
# Average LIME MAPE: 0.5276159682743494
# Average SHAP MAPE: 0.6151078612225752
#
#
# Bucket 17
# True Negatives
# Average LIME MSE: 0.05381566170358226
# Average SHAP MSE: 0.33147917003855165
#
#
# Average LIME RMSE: 0.22923470988283492
# Average SHAP RMSE: 0.5752439387086097
#
#
# Average LIME MAE: 0.21576826771100363
# Average SHAP MAE: 0.5740121722221375
#
#
# Average LIME MAPE: 0.2711014152647972
# Average SHAP MAPE: 0.7187482315123551
#
#
# True Positives
# Average LIME MSE: 0.04284488958800352
# Average SHAP MSE: 0.016868158781743504
#
#
# Average LIME RMSE: 0.18119156644994944
# Average SHAP RMSE: 0.12091273966403507
#
#
# Average LIME MAE: 0.16528913304209708
# Average SHAP MAE: 0.11184138059616089
#
#
# Average LIME MAPE: 0.23956910153939145
# Average SHAP MAPE: 0.1692539832325033
#
#
# False Negatives
# Average LIME MSE: 0.10476206582493255
# Average SHAP MSE: 0.18963470481723518
#
#
# Average LIME RMSE: 0.32366968629288184
# Average SHAP RMSE: 0.4354706704443311
#
#
# Average LIME MAE: 0.3092757523059845
# Average SHAP MAE: 0.43375966548919676
#
#
# Average LIME MAPE: 0.42135173650114555
# Average SHAP MAPE: 0.5909463865670551
#
#
# False Positives
# Bucket 18
# True Negatives
# Average LIME MSE: 0.0882985805607958
# Average SHAP MSE: 0.3216277365776493
#
#
# Average LIME RMSE: 0.2747240150960084
# Average SHAP RMSE: 0.4908352145631951
#
#
# Average LIME MAE: 0.263159269404908
# Average SHAP MAE: 0.4882546010737618
#
#
# Average LIME MAPE: 0.2751063422193228
# Average SHAP MAPE: 0.502558525272314
#
#
# True Positives
# False Negatives
# Average LIME MSE: 0.10986899080174267
# Average SHAP MSE: 0.04488330496745972
#
#
# Average LIME RMSE: 0.3244429036142426
# Average SHAP RMSE: 0.20392082961157604
#
#
# Average LIME MAE: 0.3118214060862859
# Average SHAP MAE: 0.1996807744105657
#
#
# Average LIME MAPE: 0.38022812375555326
# Average SHAP MAPE: 0.2419820787560447
#
#
# False Positives
# Bucket 19
# True Negatives
# Average LIME MSE: 0.05857133061821935
# Average SHAP MSE: 0.26084384981095193
#
#
# Average LIME RMSE: 0.21835965137423477
# Average SHAP RMSE: 0.47602575661389224
#
#
# Average LIME MAE: 0.2104103859513998
# Average SHAP MAE: 0.4729643559704224
#
#
# Average LIME MAPE: 0.2184201793177636
# Average SHAP MAPE: 0.49399913003142276
#
#
# True Positives
# Average LIME MSE: 0.01985649673978864
# Average SHAP MSE: 0.0013800328839913335
#
#
# Average LIME RMSE: 0.1409130822166226
# Average SHAP RMSE: 0.03714879384302179
#
#
# Average LIME MAE: 0.11826710402965546
# Average SHAP MAE: 0.029600226879119874
#
#
# Average LIME MAPE: 0.1761261435991645
# Average SHAP MAPE: 0.04408135172205165
#
#
# False Negatives
# Average LIME MSE: 0.1332253970292459
# Average SHAP MSE: 0.13828533790875153
#
#
# Average LIME RMSE: 0.32730886203546283
# Average SHAP RMSE: 0.3220808235512485
#
#
# Average LIME MAE: 0.31827403157949447
# Average SHAP MAE: 0.3203932131330172
#
#
# Average LIME MAPE: 0.37349675159229084
# Average SHAP MAPE: 0.3731219997218471
#
#
# False Positives
# Bucket 20
# True Negatives
# Average LIME MSE: 0.022150144768314124
# Average SHAP MSE: 0.03508222992608259
#
#
# Average LIME RMSE: 0.14825304052666494
# Average SHAP RMSE: 0.16485290757716975
#
#
# Average LIME MAE: 0.13594117537140846
# Average SHAP MAE: 0.154382885992527
#
#
# Average LIME MAPE: 0.15382239816644505
# Average SHAP MAPE: 0.1743917806649098
#
#
# True Positives
# False Negatives
# Average LIME MSE: 0.06243253666646069
# Average SHAP MSE: 0.07762837509857962
#
#
# Average LIME RMSE: 0.2436937786142614
# Average SHAP RMSE: 0.27488895972874505
#
#
# Average LIME MAE: 0.23376538554827372
# Average SHAP MAE: 0.27398657202720644
#
#
# Average LIME MAPE: 0.4226965329038839
# Average SHAP MAPE: 0.4936573684081528
#
#
# False Positives

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

hue_lens = []
for length in all_lengths:
    cur_bin = 0
    while length >= bins[cur_bin+1]:
        cur_bin += 1
    hue_lens.append(labels[cur_bin])
#hue_lens

sorted_lists = sorted(zip(all_proba, all_lime_MSE, all_shap_MSE, all_lime_RMSE, all_shap_RMSE, all_lime_MAE, all_shap_MAE, 
                          all_lime_MAPE, all_shap_MAPE, all_lengths, hue_lens), key=lambda x: x[-2])
all_proba, all_lime_MSE, all_shap_MSE, all_lime_RMSE, all_shap_RMSE, all_lime_MAE, all_shap_MAE, all_lime_MAPE, all_shap_MAPE, all_lengths, hue_lens = [[x[i] for x in sorted_lists] for i in range(len(sorted_lists[0]))]

# %%
sns.scatterplot(all_proba, all_lime_MSE, hue=hue_lens, palette = lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MSE (LIME)\nPrefix-length Buckets with Index-based Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_MSE, hue=hue_lens, palette = shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MSE (SHAP)\nPrefix-length Buckets with Index-based Encoding")
plt.show()

# %%
sns.scatterplot(all_proba, all_lime_RMSE, hue = hue_lens, palette = lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity RMSE (LIME)\nPrefix-length Buckets with Index-based Encoding")
plt.show()

sns.scatterplot(all_proba, all_shap_RMSE, hue = hue_lens, palette = shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity RMSE (SHAP)\nPrefix-length Buckets with Index-based Encoding")
plt.show()

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_MAE, hue = hue_lens, palette = lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MAE (LIME)\nPrefix-length Buckets with Index-based Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_fidelity_mae.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_MAE, hue = hue_lens, palette = shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MAE (SHAP)\nPrefix-length Buckets with Index-based Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_fidelity_mae.png", bbox_inches = "tight")
plt.show()

# %%
lime_scat = sns.scatterplot(all_proba, all_lime_MAPE, hue = hue_lens, palette = lime_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MAPE (LIME)\nPrefix-length Buckets with Index-based Encoding")
plot = lime_scat.get_figure()
plot.savefig("figures/lime_fidelity_mape.png", bbox_inches = "tight")
plt.show()

shap_scat = sns.scatterplot(all_proba, all_shap_MAPE, hue = hue_lens, palette = shap_pal[:pal_len])
plt.xlabel("Prediction Probability")
plt.ylabel("Change in Prediction Probability")
plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
plt.ylim(0,1.1)
plt.title("Production: Fidelity MAPE (SHAP)\nPrefix-length Buckets with Index-based Encoding")
plot = shap_scat.get_figure()
plot.savefig("figures/shap_fidelity_mape.png", bbox_inches = "tight")
plt.show()

# %%
max_len = max(all_lengths)
bins = np.arange(0, max_len+10, 5)
labels = []
for i in range(len(bins)-1):
    start = str(int(bins[i]+1))
    end = str(int(bins[i+1]))
    label = start+"-"+end+" prefixes"
    labels.append(label)

sep_hues = [[],[],[],[]]

for i in range(len(sep_lengths)): 
    for length in sep_lengths[i]:
        cur_bin = 0
        while length >= bins[cur_bin+1]:
            cur_bin += 1
        sep_hues[i].append(labels[cur_bin])
#sep_hues

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MSE[i], hue = sep_hues[i], palette = lime_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MSE[i], hue = sep_hues[i], palette = shap_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_RMSE[i], hue = sep_hues[i], palette = lime_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_RMSE[i], hue = sep_hues[i], palette = shap_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAE[i], hue = sep_hues[i], palette = lime_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAE[i], hue = sep_hues[i], palette = shap_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

# %%
type_list = ['True Negative', 'True Positive', 'False Negative', 'False Positive']

for i in range(len(type_list)):
    sns.scatterplot(sep_proba[i], sep_lime_MAPE[i], hue = sep_hues[i], palette = lime_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

    sns.scatterplot(sep_proba[i], sep_shap_MAPE[i], hue = sep_hues[i], palette = shap_pal[:len(set(sep_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAPE\nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[],[]]
type_proba = [[],[]]
type_hues = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_hues[0].extend(sep_hues[0])
type_hues[0].extend(sep_hues[2])
type_hues[1].extend(sep_hues[1])
type_hues[1].extend(sep_hues[3])

type_lime_MSE = [[],[]]
type_shap_MSE = [[],[]]

type_lime_MSE[0].extend(sep_lime_MSE[0])
type_lime_MSE[0].extend(sep_lime_MSE[2])
type_lime_MSE[1].extend(sep_lime_MSE[1])
type_lime_MSE[1].extend(sep_lime_MSE[3])

type_shap_MSE[0].extend(sep_shap_MSE[0])
type_shap_MSE[0].extend(sep_shap_MSE[2])
type_shap_MSE[1].extend(sep_shap_MSE[1])
type_shap_MSE[1].extend(sep_shap_MSE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MSE[i], hue = type_hues[i], palette = lime_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MSE[i], hue = type_hues[i], palette = shap_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MSE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_RMSE = [[],[]]
type_shap_RMSE = [[],[]]

type_lime_RMSE[0].extend(sep_lime_RMSE[0])
type_lime_RMSE[0].extend(sep_lime_RMSE[2])
type_lime_RMSE[1].extend(sep_lime_RMSE[1])
type_lime_RMSE[1].extend(sep_lime_RMSE[3])

type_shap_RMSE[0].extend(sep_shap_RMSE[0])
type_shap_RMSE[0].extend(sep_shap_RMSE[2])
type_shap_RMSE[1].extend(sep_shap_RMSE[1])
type_shap_RMSE[1].extend(sep_shap_RMSE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_RMSE[i], hue = type_hues[i], palette = lime_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_RMSE[i], hue = type_hues[i], palette = shap_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and RMSE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_MAE = [[],[]]
type_shap_MAE = [[],[]]

type_lime_MAE[0].extend(sep_lime_MAE[0])
type_lime_MAE[0].extend(sep_lime_MAE[2])
type_lime_MAE[1].extend(sep_lime_MAE[1])
type_lime_MAE[1].extend(sep_lime_MAE[3])

type_shap_MAE[0].extend(sep_shap_MAE[0])
type_shap_MAE[0].extend(sep_shap_MAE[2])
type_shap_MAE[1].extend(sep_shap_MAE[1])
type_shap_MAE[1].extend(sep_shap_MAE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MAE[i], hue = type_hues[i], palette = lime_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MAE[i], hue = type_hues[i], palette = shap_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

# %%
type_list = ['Negatives', 'Positives']

type_lengths = [[], []]
type_proba = [[],[]]

type_lengths[0].extend(sep_lengths[0])
type_lengths[0].extend(sep_lengths[2])
type_lengths[1].extend(sep_lengths[1])
type_lengths[1].extend(sep_lengths[3])

type_proba[0].extend(sep_proba[0])
type_proba[0].extend(sep_proba[2])
type_proba[1].extend(sep_proba[1])
type_proba[1].extend(sep_proba[3])

type_lime_MAPE = [[],[]]
type_shap_MAPE = [[],[]]

type_lime_MAPE[0].extend(sep_lime_MAPE[0])
type_lime_MAPE[0].extend(sep_lime_MAPE[2])
type_lime_MAPE[1].extend(sep_lime_MAPE[1])
type_lime_MAPE[1].extend(sep_lime_MAPE[3])

type_shap_MAPE[0].extend(sep_shap_MAPE[0])
type_shap_MAPE[0].extend(sep_shap_MAPE[2])
type_shap_MAPE[1].extend(sep_shap_MAPE[1])
type_shap_MAPE[1].extend(sep_shap_MAPE[3])

for i in range(len(type_list)):
    sns.scatterplot(type_proba[i], type_lime_MAPE[i], hue = type_hues[i], palette = lime_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - LIME: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

    sns.scatterplot(type_proba[i], type_shap_MAPE[i], hue = type_hues[i], palette = shap_pal[:len(set(type_hues[i]))])
    plt.xlabel("Prediction Probability")
    plt.ylabel("Change in Prediction Probability")
    plt.legend(frameon = False, bbox_to_anchor=(1, 1), loc = 'upper left')
    #plt.yticks(np.arange(0,15,1))
    plt.title(type_list[i]+" - SHAP: Prediction probability and MAPE \nBPIC 2012 Prefix-Length Bucket with Index-Based Encoding")
    plt.show()

# %%
print("Average LIME MSE:", np.mean(all_lime_MSE))
print("Average SHAP MSE:", np.mean(all_shap_MSE))
print("\n")

print("Average LIME RMSE:", np.mean(all_lime_RMSE))
print("Average SHAP RMSE:", np.mean(all_shap_RMSE))
print("\n")

print("Average LIME MAE:", np.mean(all_lime_MAE))
print("Average SHAP MAE:", np.mean(all_shap_MAE))
print("\n")

print("Average LIME MAPE:", np.mean(all_lime_MAPE))
print("Average SHAP MAPE:", np.mean(all_shap_MAPE))
print("\n")

print("LIME Fidelity:", np.mean(all_lime_MAPE))
print("SHAP Fidelity:", np.mean(all_shap_MAPE))
# Out:
# Average LIME MSE: 0.136111381249634
# Average SHAP MSE: 0.33617309543710067
#
#
# Average LIME RMSE: 0.3119303153847695
# Average SHAP RMSE: 0.52744911797397
#
#
# Average LIME MAE: 0.2959834515312624
# Average SHAP MAE: 0.5238970445426976
#
#
# Average LIME MAPE: 0.3917977382107111
# Average SHAP MAPE: 0.6884609581803187
#
#
# LIME Fidelity: 0.3917977382107111
# SHAP Fidelity: 0.6884609581803187

# %%
print(len(all_lime_MSE))
# Out:
# 443
