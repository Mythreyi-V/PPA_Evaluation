# %%
#from google.colab import drive
#drive.mount('/content/drive')
import sys
#PATH = '/content/drive/My Drive/PPM_Stability/'
PATH = "C:/Users/velmurug/Documents/Stability Experiments/benchmark_interpretability/PPM_Stability/"
#PATH = "C:/Users/mythr/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
sys.path.append(PATH)

# %%
#!pip install pandas==0.22.0
# !pip install xgboost==1.0.0
# Out:
# Requirement already satisfied: xgboost==1.0.0 in c:\programdata\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost==1.0.0) (1.18.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost==1.0.0) (1.4.1)

# %%
import EncoderFactory
from DatasetManager import DatasetManager
import BucketFactory

import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import StandardScaler

import time
import os
import sys
from sys import argv
import pickle
from collections import defaultdict

from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import catboost

#import lime
#import lime.lime_tabular
#from lime import submodular_pick;
import warnings
warnings.filterwarnings('ignore')

import joblib

# %%
dataset_ref = "bpic2012"
params_dir = PATH + "params/"
results_dir = "results"
bucket_method = "single"
cls_encoding = "agg"
cls_method = "cb"
gap = 1
n_iter = 1

if bucket_method == "state":
    bucket_encoding = "last"
else:
    bucket_encoding = "agg"

method_name = "%s_%s"%(bucket_method, cls_encoding)

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"]
    #"insurance": ["insurance_activity", "insurance_followup"],
    #"sepsis_cases": ["sepsis_cases_1", "sepsis_cases_2", "sepsis_cases_4"]
}

encoding_dict = {
    "laststate": ["static", "last"],
    "agg": ["static", "agg"],
    "index": ["static", "index"],
    "combined": ["static", "last", "agg"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]
methods = encoding_dict[cls_encoding]
    
train_ratio = 0.8
random_state = 22

# create results directory
if not os.path.exists(os.path.join(params_dir)):
    os.makedirs(os.path.join(params_dir))
    
print(datasets)
# Out:
# ['bpic2012_accepted']

# %%
for dataset_name in datasets:
    
    # load optimal params
    print("Setting up parameters...")
    optimal_params_filename = os.path.join(params_dir, "optimal_params_%s_%s_%s.pickle" % (cls_method, dataset_name, method_name))

    if not os.path.isfile(optimal_params_filename) or os.path.getsize(optimal_params_filename) <= 0:
        print("Parameters not found")
        
    with open(optimal_params_filename, "rb") as fin:
        args = pickle.load(fin)
        
    #print(args)
            
    # read the data
    print("setting up data...")
    dataset_manager = DatasetManager(dataset_name)
    data = dataset_manager.read_dataset()
    #print('Case ID column', dataset_manager.case_id_col)
    cls_encoder_args = {'case_id_col': dataset_manager.case_id_col, 
                        'static_cat_cols': dataset_manager.static_cat_cols,
                        'static_num_cols': dataset_manager.static_num_cols, 
                        'dynamic_cat_cols': dataset_manager.dynamic_cat_cols,
                        'dynamic_num_cols': dataset_manager.dynamic_num_cols, 
                        'fillna': True}

    # determine min and max (truncated) prefix lengths
    min_prefix_length = 1
    if "traffic_fines" in dataset_name:
        max_prefix_length = 10
    elif "bpic2017" in dataset_name:
        max_prefix_length = min(20, dataset_manager.get_pos_case_length_quantile(data, 0.90))
    else:
        max_prefix_length = min(40, dataset_manager.get_pos_case_length_quantile(data, 0.90))

    # split into training and test
    train, test = dataset_manager.split_data_strict(data, train_ratio, split="temporal")
    
    if gap > 1:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s_gap%s.csv" % (cls_method, dataset_name, method_name, gap))
    else:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s.csv" % (cls_method, dataset_name, method_name))
        
    start_test_prefix_generation = time.time()
    dt_test_prefixes = dataset_manager.generate_prefix_data(test, min_prefix_length, max_prefix_length)
    test_prefix_generation_time = time.time() - start_test_prefix_generation
            
    offline_total_times = []
    online_event_times = []
    train_prefix_generation_times = []

    for ii in range(n_iter):
        # create prefix logs
        print("Creating logs...")
        start_train_prefix_generation = time.time()
        dt_train_prefixes = dataset_manager.generate_prefix_data(train, min_prefix_length, max_prefix_length, gap)
        train_prefix_generation_time = time.time() - start_train_prefix_generation
        train_prefix_generation_times.append(train_prefix_generation_time)
            
        # Bucketing prefixes based on control flow
        print("bucketing prefixes...")
        bucketer_args = {'encoding_method':bucket_encoding, 
                         'case_id_col':dataset_manager.case_id_col, 
                         'cat_cols':[dataset_manager.activity_col], 
                         'num_cols':[], 
                         'random_state':random_state}
        if bucket_method == "cluster":
            bucketer_args["n_clusters"] = int(args["n_clusters"])
        bucketer = BucketFactory.get_bucketer(bucket_method, **bucketer_args)

        start_offline_time_bucket = time.time()
        bucket_assignments_train = bucketer.fit_predict(dt_train_prefixes)
        offline_time_bucket = time.time() - start_offline_time_bucket

        bucket_assignments_test = bucketer.predict(dt_test_prefixes)

        preds_all = []
        probas_all = []
        pred_types_all = []
        test_y_all = []
        nr_events_all = []
        offline_time_fit = 0
        current_online_event_times = []
        
        for bucket in set(bucket_assignments_test):
            print("Bucket" , bucket )
            print("sorting bucket...")
            if bucket_method == "prefix":
                current_args = args[bucket]
            else:
                current_args = args
            relevant_train_cases_bucket = dataset_manager.get_indexes(dt_train_prefixes)[bucket_assignments_train == bucket]
            relevant_test_cases_bucket = dataset_manager.get_indexes(dt_test_prefixes)[bucket_assignments_test == bucket]
            dt_test_bucket = dataset_manager.get_relevant_data_by_indexes(dt_test_prefixes, relevant_test_cases_bucket)
            
            nr_events_all.extend(list(dataset_manager.get_prefix_lengths(dt_test_bucket)))
            print('number events', len(nr_events_all))
            
            if len(relevant_train_cases_bucket) == 0:
                preds = [dataset_manager.get_class_ratio(train)] * len(relevant_test_cases_bucket)
                current_online_event_times.extend([0] * len(preds))
            else:
                dt_train_bucket = dataset_manager.get_relevant_data_by_indexes(dt_train_prefixes, relevant_train_cases_bucket) # one row per event
                train_y = dataset_manager.get_label_numeric(dt_train_bucket)

                if len(set(train_y)) < 2:
                    preds = [train_y[0]] * len(relevant_test_cases_bucket)
                    current_online_event_times.extend([0] * len(preds))
                    test_y_all.extend(dataset_manager.get_label_numeric(dt_test_bucket))
                else:
                    print("choosing classifier...")
                    start_offline_time_fit = time.time()
                    feature_combiner = FeatureUnion([(method, EncoderFactory.get_encoder(method, **cls_encoder_args)) for method in methods])

                    if cls_method == "rf":
                        cls = RandomForestClassifier(n_estimators=500,
                                                     max_features=current_args['max_features'],
                                                     random_state=random_state)

                    elif cls_method == "xgboost":
                        cls = xgb.XGBClassifier(objective='binary:logistic',
                                                n_estimators=500,
                                                learning_rate= current_args['learning_rate'],
                                                subsample=current_args['subsample'],
                                                max_depth=int(current_args['max_depth']),
                                                colsample_bytree=current_args['colsample_bytree'],
                                                min_child_weight=int(current_args['min_child_weight']),
                                                seed=random_state)
                    elif cls_method == "cb":
                        cls = catboost.CatBoostClassifier(learning_rate=current_args['learning_rate'],
                                                           subsample=current_args['subsample'], 
                                                          depth=current_args['depth'])

                    elif cls_method == "logit":
                        cls = LogisticRegression(C=2**current_args['C'],
                                                 random_state=random_state)

                    elif cls_method == "svm":
                        cls = SVC(C=2**current_args['C'],
                                  gamma=2**current_args['gamma'],
                                  random_state=random_state)

                    if cls_method == "svm" or cls_method == "logit":
                        pipeline = Pipeline([('encoder', feature_combiner), ('scaler', StandardScaler()), ('cls', cls)])
                    else:
                        pipeline = Pipeline([('encoder', feature_combiner), ('cls', cls)])

                    print("fitting pipeline...")
                    pipeline.fit(dt_train_bucket, train_y)
                    
                    offline_time_fit += time.time() - start_offline_time_fit

                    # predict separately for each prefix case
                    preds = []
                    probas = []
                    pred_types = []
                    
                    test_all_grouped = dt_test_bucket.groupby(dataset_manager.case_id_col)
                    print("test data shape", dt_test_bucket.shape)
                    count_d=0 # count for deviant
                    count_r=0 #count for regular

                    tp_list = []
                    tn_list = []
                    fp_list = []
                    fn_list = []

                    iteration = 1
                    
                    for _, group in test_all_grouped:
                        print ("Testing instance", iteration, 'of', len(test_all_grouped))
                        test_y_group = dataset_manager.get_label_numeric(group)
                        test_y_all.extend(test_y_group)
                            
                        start = time.time()
                        _ = bucketer.predict(group)
                        
                        if cls_method == "svm":
                            pred = pipeline.decision_function(group)
                        else:
                          preds_pos_label_idx = np.where(cls.classes_ == 1)[0][0]
                          pred = pipeline.predict(group)[0]
                          proba = pipeline.predict_proba(group)[:,preds_pos_label_idx]
                        pipeline_pred_time = time.time() - start
                        current_online_event_times.append(pipeline_pred_time / len(group))
                        case_id = dataset_manager.get_case_ids(group)[0]
                        
                        if test_y_group == pred & pred == 0:
                          pred_type = 'TN'

                          instance_dict = {}
                          instance_dict['caseID'] = case_id
                          instance_dict['input'] = group
                          instance_dict['actual'] = test_y_group[0]
                          instance_dict['predicted'] = pred
                          instance_dict['proba'] = 1 - proba[0]
                          instance_dict['nr_events'] = dataset_manager.get_prefix_lengths(group)[0]
                          instance_dict['pred_type'] = pred_type

                          tn_list.append(instance_dict)

                        elif test_y_group == pred & pred == 1:
                          pred_type = 'TP'
                                            
                          instance_dict = {}
                          instance_dict['caseID'] = case_id
                          instance_dict['input'] = group
                          instance_dict['actual'] = test_y_group[0]
                          instance_dict['predicted'] = pred
                          instance_dict['proba'] = proba[0]
                          instance_dict['nr_events'] = dataset_manager.get_prefix_lengths(group)[0]
                          instance_dict['pred_type'] = pred_type

                          tp_list.append(instance_dict)

                        elif test_y_group != pred & pred == 0:
                          pred_type = 'FN'
                          
                          instance_dict = {}
                          instance_dict['caseID'] = case_id
                          instance_dict['input'] = group
                          instance_dict['actual'] = test_y_group[0]
                          instance_dict['predicted'] = pred
                          instance_dict['proba'] = 1 - proba[0]
                          instance_dict['nr_events'] = dataset_manager.get_prefix_lengths(group)[0]
                          instance_dict['pred_type'] = pred_type

                          fn_list.append(instance_dict)

                        elif test_y_group != pred & pred == 1:
                          pred_type = 'FP'
                          
                          instance_dict = {}
                          instance_dict['caseID'] = case_id
                          instance_dict['input'] = group
                          instance_dict['actual'] = test_y_group[0]
                          instance_dict['predicted'] = pred
                          instance_dict['proba'] = proba[0]
                          instance_dict['nr_events'] = dataset_manager.get_prefix_lengths(group)[0]
                          instance_dict['pred_type'] = pred_type

                          fp_list.append(instance_dict)
                        else:
                          print("ERROR: Prediction doesn't fit into any category. Check code.")
                              
                        preds.append(pred)
                        probas.extend(proba)
                        pred_types.append(pred_type)
                        iteration+=1
                        
                    preds_all.extend(preds)
                    probas_all.extend(probas)
                    pred_types_all.extend(pred_types)

                    tn_path = os.path.join(PATH, "%s/%s_%s/instances/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucket))
                    tp_path = os.path.join(PATH, "%s/%s_%s/instances/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucket))
                    fn_path = os.path.join(PATH, "%s/%s_%s/instances/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucket))
                    fp_path = os.path.join(PATH, "%s/%s_%s/instances/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucket))
                    
                    with open (tn_path, 'wb') as f:
                      pickle.dump(tn_list, f)
                    with open (tp_path, 'wb') as f:
                      pickle.dump(tp_list, f)
                    with open (fn_path, 'wb') as f:
                      pickle.dump(fn_list, f)
                    with open (fp_path, 'wb') as f:
                      pickle.dump(fp_list, f)

            #Save models and encoders
            print('Saving models...')
            pipeline_path = os.path.join(PATH, "%s/%s_%s/pipelines/pipeline_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucket))
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucket))
            bucketer_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/bucketer_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucket))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucket))
            joblib.dump(pipeline, pipeline_path)
            joblib.dump(feature_combiner, feat_comb_path)
            joblib.dump(cls, cls_path)
            joblib.dump(bucketer, bucketer_path)

            #Save training data
            print("saving data...")
            X_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucket))
            Y_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucket))
            with open(X_train_path, 'wb') as f:
              pickle.dump(dt_train_bucket, f)
            with open(Y_train_path, 'wb') as f:
              pickle.dump(train_y, f)

            #Save testing data
            X_test_path = os.path.join(PATH, "%s/%s_%s/test_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucket))
            Y_test_path = os.path.join(PATH, "%s/%s_%s/test_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucket))
            with open(X_test_path, 'wb') as f:
                pickle.dump(dt_test_bucket, f)
            with open(Y_test_path, 'wb') as f:
                pickle.dump(test_y_group, f)
        
        print("compiling results...")
        dt_results = pd.DataFrame({"actual": test_y_all, "predicted": preds_all, "nr_events": nr_events_all})
        for nr_events, group in dt_results.groupby("nr_events"):
            if len(set(group.actual)) < 2:
                print(dataset_name, method_name, cls_method, nr_events, "auc", np.nan)
            else:
                print(dataset_name, method_name, cls_method, nr_events, "auc", roc_auc_score(group.actual, group.predicted))
        print(dataset_name, method_name, cls_method, -1, -1, "auc", roc_auc_score(dt_results.actual, dt_results.predicted))
# Out:
# Setting up parameters...
# setting up data...
# Creating logs...
# bucketing prefixes...
# single
# Bucket 1
# sorting bucket...
# number events 30637
# choosing classifier...
# fitting pipeline...
# 0:	learn: 0.6247533	total: 1.03s	remaining: 17m 14s
# 1:	learn: 0.5844566	total: 1.95s	remaining: 16m 11s
# 2:	learn: 0.5424173	total: 2.81s	remaining: 15m 33s
# 3:	learn: 0.5213091	total: 3.69s	remaining: 15m 18s
# 4:	learn: 0.4901712	total: 4.58s	remaining: 15m 11s
# 5:	learn: 0.4779908	total: 5.46s	remaining: 15m 5s
# 6:	learn: 0.4652183	total: 6.37s	remaining: 15m 3s
# 7:	learn: 0.4416899	total: 7.29s	remaining: 15m 3s
# 8:	learn: 0.4268651	total: 8.2s	remaining: 15m 2s
# 9:	learn: 0.4123309	total: 9.11s	remaining: 15m 1s
# 10:	learn: 0.3939760	total: 10s	remaining: 14m 59s
# 11:	learn: 0.3815845	total: 10.9s	remaining: 14m 56s
# 12:	learn: 0.3688500	total: 11.8s	remaining: 14m 57s
# 13:	learn: 0.3568739	total: 12.7s	remaining: 14m 54s
# 14:	learn: 0.3490663	total: 13.6s	remaining: 14m 53s
# 15:	learn: 0.3321240	total: 14.5s	remaining: 14m 52s
# 16:	learn: 0.3198255	total: 15.4s	remaining: 14m 51s
# 17:	learn: 0.3093216	total: 16.3s	remaining: 14m 50s
# 18:	learn: 0.3044253	total: 17.2s	remaining: 14m 48s
# 19:	learn: 0.2954221	total: 18.1s	remaining: 14m 46s
# 20:	learn: 0.2881949	total: 19s	remaining: 14m 45s
# 21:	learn: 0.2849452	total: 19.9s	remaining: 14m 45s
# 22:	learn: 0.2819994	total: 20.8s	remaining: 14m 43s
# 23:	learn: 0.2703254	total: 21.7s	remaining: 14m 40s
# 24:	learn: 0.2622887	total: 22.6s	remaining: 14m 39s
# 25:	learn: 0.2555306	total: 23.5s	remaining: 14m 38s
# 26:	learn: 0.2501608	total: 24.4s	remaining: 14m 37s
# 27:	learn: 0.2429861	total: 25.2s	remaining: 14m 35s
# 28:	learn: 0.2364808	total: 26.1s	remaining: 14m 33s
# 29:	learn: 0.2298351	total: 27s	remaining: 14m 31s
# 30:	learn: 0.2276042	total: 27.8s	remaining: 14m 29s
# 31:	learn: 0.2242978	total: 28.7s	remaining: 14m 27s
# 32:	learn: 0.2154102	total: 29.5s	remaining: 14m 24s
# 33:	learn: 0.2092210	total: 30.4s	remaining: 14m 23s
# 34:	learn: 0.2056048	total: 31.3s	remaining: 14m 22s
# 35:	learn: 0.1996170	total: 32.1s	remaining: 14m 20s
# 36:	learn: 0.1919180	total: 33s	remaining: 14m 17s
# 37:	learn: 0.1896804	total: 33.8s	remaining: 14m 16s
# 38:	learn: 0.1837735	total: 34.7s	remaining: 14m 15s
# 39:	learn: 0.1801672	total: 35.5s	remaining: 14m 13s
# 40:	learn: 0.1756531	total: 36.4s	remaining: 14m 11s
# 41:	learn: 0.1705161	total: 37.2s	remaining: 14m 9s
# 42:	learn: 0.1651461	total: 38.1s	remaining: 14m 7s
# 43:	learn: 0.1609106	total: 39s	remaining: 14m 6s
# 44:	learn: 0.1577039	total: 39.8s	remaining: 14m 4s
# 45:	learn: 0.1554739	total: 40.7s	remaining: 14m 3s
# 46:	learn: 0.1524909	total: 41.5s	remaining: 14m 2s
# 47:	learn: 0.1474157	total: 42.4s	remaining: 14m
# 48:	learn: 0.1440732	total: 43.3s	remaining: 13m 59s
# 49:	learn: 0.1412766	total: 44.1s	remaining: 13m 57s
# 50:	learn: 0.1389153	total: 44.9s	remaining: 13m 55s
# 51:	learn: 0.1373163	total: 45.7s	remaining: 13m 52s
# 52:	learn: 0.1348007	total: 46.5s	remaining: 13m 50s
# 53:	learn: 0.1326485	total: 47.3s	remaining: 13m 48s
# 54:	learn: 0.1299048	total: 48.1s	remaining: 13m 46s
# 55:	learn: 0.1277818	total: 48.9s	remaining: 13m 44s
# 56:	learn: 0.1247761	total: 49.7s	remaining: 13m 42s
# 57:	learn: 0.1232366	total: 50.5s	remaining: 13m 40s
# 58:	learn: 0.1199335	total: 51.4s	remaining: 13m 39s
# 59:	learn: 0.1176432	total: 52.2s	remaining: 13m 37s
# 60:	learn: 0.1162587	total: 53s	remaining: 13m 36s
# 61:	learn: 0.1145828	total: 53.8s	remaining: 13m 34s
# 62:	learn: 0.1120536	total: 54.6s	remaining: 13m 32s
# 63:	learn: 0.1091719	total: 55.4s	remaining: 13m 30s
# 64:	learn: 0.1056471	total: 56.2s	remaining: 13m 29s
# 65:	learn: 0.1040514	total: 57.1s	remaining: 13m 27s
# 66:	learn: 0.1028374	total: 57.9s	remaining: 13m 26s
# 67:	learn: 0.1009359	total: 58.7s	remaining: 13m 24s
# 68:	learn: 0.0999532	total: 59.5s	remaining: 13m 23s
# 69:	learn: 0.0982575	total: 1m	remaining: 13m 22s
# 70:	learn: 0.0960010	total: 1m 1s	remaining: 13m 20s
# 71:	learn: 0.0943862	total: 1m 1s	remaining: 13m 19s
# 72:	learn: 0.0917764	total: 1m 2s	remaining: 13m 17s
# 73:	learn: 0.0896732	total: 1m 3s	remaining: 13m 16s
# 74:	learn: 0.0880267	total: 1m 4s	remaining: 13m 15s
# 75:	learn: 0.0863671	total: 1m 5s	remaining: 13m 13s
# 76:	learn: 0.0851943	total: 1m 6s	remaining: 13m 12s
# 77:	learn: 0.0842752	total: 1m 6s	remaining: 13m 11s
# 78:	learn: 0.0828000	total: 1m 7s	remaining: 13m 10s
# 79:	learn: 0.0813737	total: 1m 8s	remaining: 13m 9s
# 80:	learn: 0.0800016	total: 1m 9s	remaining: 13m 7s
# 81:	learn: 0.0791038	total: 1m 10s	remaining: 13m 6s
# 82:	learn: 0.0782788	total: 1m 11s	remaining: 13m 5s
# 83:	learn: 0.0773878	total: 1m 11s	remaining: 13m 4s
# 84:	learn: 0.0761637	total: 1m 12s	remaining: 13m 3s
# 85:	learn: 0.0744326	total: 1m 13s	remaining: 13m 1s
# 86:	learn: 0.0738009	total: 1m 14s	remaining: 13m
# 87:	learn: 0.0729941	total: 1m 15s	remaining: 12m 59s
# 88:	learn: 0.0723653	total: 1m 16s	remaining: 12m 58s
# 89:	learn: 0.0707914	total: 1m 16s	remaining: 12m 56s
# 90:	learn: 0.0699915	total: 1m 17s	remaining: 12m 55s
# 91:	learn: 0.0684395	total: 1m 18s	remaining: 12m 54s
# 92:	learn: 0.0666698	total: 1m 19s	remaining: 12m 53s
# 93:	learn: 0.0659859	total: 1m 20s	remaining: 12m 52s
# 94:	learn: 0.0653030	total: 1m 20s	remaining: 12m 50s
# 95:	learn: 0.0643638	total: 1m 21s	remaining: 12m 49s
# 96:	learn: 0.0631720	total: 1m 22s	remaining: 12m 48s
# 97:	learn: 0.0620128	total: 1m 23s	remaining: 12m 47s
# 98:	learn: 0.0615666	total: 1m 24s	remaining: 12m 46s
# 99:	learn: 0.0610902	total: 1m 25s	remaining: 12m 45s
# 100:	learn: 0.0603344	total: 1m 25s	remaining: 12m 44s
# 101:	learn: 0.0600160	total: 1m 26s	remaining: 12m 42s
# 102:	learn: 0.0591852	total: 1m 27s	remaining: 12m 41s
# 103:	learn: 0.0587408	total: 1m 28s	remaining: 12m 40s
# 104:	learn: 0.0572689	total: 1m 29s	remaining: 12m 39s
# 105:	learn: 0.0566829	total: 1m 29s	remaining: 12m 37s
# 106:	learn: 0.0556667	total: 1m 30s	remaining: 12m 36s
# 107:	learn: 0.0551851	total: 1m 31s	remaining: 12m 35s
# 108:	learn: 0.0545585	total: 1m 32s	remaining: 12m 33s
# 109:	learn: 0.0536148	total: 1m 32s	remaining: 12m 32s
# 110:	learn: 0.0527737	total: 1m 33s	remaining: 12m 31s
# 111:	learn: 0.0519457	total: 1m 34s	remaining: 12m 30s
# 112:	learn: 0.0514717	total: 1m 35s	remaining: 12m 29s
# 113:	learn: 0.0508717	total: 1m 36s	remaining: 12m 28s
# 114:	learn: 0.0498589	total: 1m 37s	remaining: 12m 27s
# 115:	learn: 0.0494005	total: 1m 37s	remaining: 12m 25s
# 116:	learn: 0.0487572	total: 1m 38s	remaining: 12m 24s
# 117:	learn: 0.0481245	total: 1m 39s	remaining: 12m 24s
# 118:	learn: 0.0476828	total: 1m 40s	remaining: 12m 23s
# 119:	learn: 0.0471119	total: 1m 41s	remaining: 12m 22s
# 120:	learn: 0.0466054	total: 1m 42s	remaining: 12m 21s
# 121:	learn: 0.0462676	total: 1m 42s	remaining: 12m 20s
# 122:	learn: 0.0456059	total: 1m 43s	remaining: 12m 19s
# 123:	learn: 0.0447358	total: 1m 44s	remaining: 12m 19s
# 124:	learn: 0.0441348	total: 1m 45s	remaining: 12m 18s
# 125:	learn: 0.0433986	total: 1m 46s	remaining: 12m 16s
# 126:	learn: 0.0430740	total: 1m 47s	remaining: 12m 16s
# 127:	learn: 0.0426863	total: 1m 47s	remaining: 12m 15s
# 128:	learn: 0.0419922	total: 1m 48s	remaining: 12m 13s
# 129:	learn: 0.0416012	total: 1m 49s	remaining: 12m 12s
# 130:	learn: 0.0412943	total: 1m 50s	remaining: 12m 12s
# 131:	learn: 0.0409106	total: 1m 51s	remaining: 12m 11s
# 132:	learn: 0.0407741	total: 1m 52s	remaining: 12m 10s
# 133:	learn: 0.0403927	total: 1m 52s	remaining: 12m 9s
# 134:	learn: 0.0399966	total: 1m 53s	remaining: 12m 8s
# 135:	learn: 0.0395218	total: 1m 54s	remaining: 12m 7s
# 136:	learn: 0.0393119	total: 1m 55s	remaining: 12m 6s
# 137:	learn: 0.0386492	total: 1m 56s	remaining: 12m 5s
# 138:	learn: 0.0382464	total: 1m 56s	remaining: 12m 4s
# 139:	learn: 0.0378406	total: 1m 57s	remaining: 12m 3s
# 140:	learn: 0.0374277	total: 1m 58s	remaining: 12m 2s
# 141:	learn: 0.0369597	total: 1m 59s	remaining: 12m 1s
# 142:	learn: 0.0366600	total: 2m	remaining: 12m
# 143:	learn: 0.0362209	total: 2m	remaining: 11m 59s
# 144:	learn: 0.0359601	total: 2m 1s	remaining: 11m 58s
# 145:	learn: 0.0354416	total: 2m 2s	remaining: 11m 57s
# 146:	learn: 0.0350400	total: 2m 3s	remaining: 11m 56s
# 147:	learn: 0.0347569	total: 2m 4s	remaining: 11m 55s
# 148:	learn: 0.0344281	total: 2m 5s	remaining: 11m 54s
# 149:	learn: 0.0336632	total: 2m 5s	remaining: 11m 53s
# 150:	learn: 0.0333018	total: 2m 6s	remaining: 11m 52s
# 151:	learn: 0.0328767	total: 2m 7s	remaining: 11m 50s
# 152:	learn: 0.0325491	total: 2m 8s	remaining: 11m 49s
# 153:	learn: 0.0322124	total: 2m 9s	remaining: 11m 48s
# 154:	learn: 0.0318961	total: 2m 9s	remaining: 11m 47s
# 155:	learn: 0.0317503	total: 2m 10s	remaining: 11m 46s
# 156:	learn: 0.0313304	total: 2m 11s	remaining: 11m 46s
# 157:	learn: 0.0310010	total: 2m 12s	remaining: 11m 45s
# 158:	learn: 0.0305858	total: 2m 13s	remaining: 11m 44s
# 159:	learn: 0.0302299	total: 2m 13s	remaining: 11m 43s
# 160:	learn: 0.0299995	total: 2m 14s	remaining: 11m 42s
# 161:	learn: 0.0296375	total: 2m 15s	remaining: 11m 41s
# 162:	learn: 0.0294415	total: 2m 16s	remaining: 11m 40s
# 163:	learn: 0.0290780	total: 2m 17s	remaining: 11m 39s
# 164:	learn: 0.0288876	total: 2m 18s	remaining: 11m 38s
# 165:	learn: 0.0287596	total: 2m 18s	remaining: 11m 38s
# 166:	learn: 0.0284109	total: 2m 19s	remaining: 11m 37s
# 167:	learn: 0.0282154	total: 2m 20s	remaining: 11m 36s
# 168:	learn: 0.0280035	total: 2m 21s	remaining: 11m 35s
# 169:	learn: 0.0278662	total: 2m 22s	remaining: 11m 34s
# 170:	learn: 0.0276542	total: 2m 23s	remaining: 11m 33s
# 171:	learn: 0.0275381	total: 2m 23s	remaining: 11m 32s
# 172:	learn: 0.0273701	total: 2m 24s	remaining: 11m 31s
# 173:	learn: 0.0268960	total: 2m 25s	remaining: 11m 30s
# 174:	learn: 0.0266253	total: 2m 26s	remaining: 11m 29s
# 175:	learn: 0.0263429	total: 2m 27s	remaining: 11m 29s
# 176:	learn: 0.0260383	total: 2m 28s	remaining: 11m 28s
# 177:	learn: 0.0257575	total: 2m 28s	remaining: 11m 27s
# 178:	learn: 0.0256433	total: 2m 29s	remaining: 11m 26s
# 179:	learn: 0.0254509	total: 2m 30s	remaining: 11m 25s
# 180:	learn: 0.0251590	total: 2m 31s	remaining: 11m 24s
# 181:	learn: 0.0248148	total: 2m 32s	remaining: 11m 24s
# 182:	learn: 0.0244996	total: 2m 33s	remaining: 11m 23s
# 183:	learn: 0.0243385	total: 2m 33s	remaining: 11m 22s
# 184:	learn: 0.0241714	total: 2m 34s	remaining: 11m 21s
# 185:	learn: 0.0239116	total: 2m 35s	remaining: 11m 20s
# 186:	learn: 0.0236452	total: 2m 36s	remaining: 11m 19s
# 187:	learn: 0.0234880	total: 2m 37s	remaining: 11m 18s
# 188:	learn: 0.0233011	total: 2m 37s	remaining: 11m 17s
# 189:	learn: 0.0231800	total: 2m 38s	remaining: 11m 16s
# 190:	learn: 0.0230167	total: 2m 39s	remaining: 11m 15s
# 191:	learn: 0.0228916	total: 2m 40s	remaining: 11m 14s
# 192:	learn: 0.0227189	total: 2m 41s	remaining: 11m 13s
# 193:	learn: 0.0224098	total: 2m 41s	remaining: 11m 12s
# 194:	learn: 0.0221066	total: 2m 42s	remaining: 11m 11s
# 195:	learn: 0.0219061	total: 2m 43s	remaining: 11m 10s
# 196:	learn: 0.0217383	total: 2m 44s	remaining: 11m 9s
# 197:	learn: 0.0216032	total: 2m 44s	remaining: 11m 8s
# 198:	learn: 0.0213837	total: 2m 45s	remaining: 11m 7s
# 199:	learn: 0.0212655	total: 2m 46s	remaining: 11m 6s
# 200:	learn: 0.0211664	total: 2m 47s	remaining: 11m 5s
# 201:	learn: 0.0210228	total: 2m 48s	remaining: 11m 4s
# 202:	learn: 0.0208413	total: 2m 49s	remaining: 11m 3s
# 203:	learn: 0.0206464	total: 2m 49s	remaining: 11m 2s
# 204:	learn: 0.0204508	total: 2m 50s	remaining: 11m 1s
# 205:	learn: 0.0203440	total: 2m 51s	remaining: 11m
# 206:	learn: 0.0201235	total: 2m 52s	remaining: 10m 59s
# 207:	learn: 0.0199110	total: 2m 53s	remaining: 10m 58s
# 208:	learn: 0.0197614	total: 2m 53s	remaining: 10m 57s
# 209:	learn: 0.0196662	total: 2m 54s	remaining: 10m 56s
# 210:	learn: 0.0195471	total: 2m 55s	remaining: 10m 55s
# 211:	learn: 0.0194170	total: 2m 56s	remaining: 10m 55s
# 212:	learn: 0.0192914	total: 2m 57s	remaining: 10m 54s
# 213:	learn: 0.0191471	total: 2m 57s	remaining: 10m 53s
# 214:	learn: 0.0190339	total: 2m 58s	remaining: 10m 52s
# 215:	learn: 0.0188333	total: 2m 59s	remaining: 10m 51s
# 216:	learn: 0.0186916	total: 3m	remaining: 10m 50s
# 217:	learn: 0.0184877	total: 3m	remaining: 10m 49s
# 218:	learn: 0.0183291	total: 3m 1s	remaining: 10m 48s
# 219:	learn: 0.0182135	total: 3m 2s	remaining: 10m 47s
# 220:	learn: 0.0180705	total: 3m 3s	remaining: 10m 46s
# 221:	learn: 0.0180185	total: 3m 4s	remaining: 10m 45s
# 222:	learn: 0.0178690	total: 3m 4s	remaining: 10m 44s
# 223:	learn: 0.0176821	total: 3m 5s	remaining: 10m 43s
# 224:	learn: 0.0175869	total: 3m 6s	remaining: 10m 42s
# 225:	learn: 0.0173938	total: 3m 7s	remaining: 10m 41s
# 226:	learn: 0.0172564	total: 3m 8s	remaining: 10m 40s
# 227:	learn: 0.0172564	total: 3m 8s	remaining: 10m 39s
# 228:	learn: 0.0171373	total: 3m 9s	remaining: 10m 38s
# 229:	learn: 0.0169861	total: 3m 10s	remaining: 10m 37s
# 230:	learn: 0.0169506	total: 3m 11s	remaining: 10m 36s
# 231:	learn: 0.0167842	total: 3m 12s	remaining: 10m 35s
# 232:	learn: 0.0166224	total: 3m 12s	remaining: 10m 34s
# 233:	learn: 0.0165696	total: 3m 13s	remaining: 10m 33s
# 234:	learn: 0.0164416	total: 3m 14s	remaining: 10m 32s
# 235:	learn: 0.0163643	total: 3m 15s	remaining: 10m 32s
# 236:	learn: 0.0163171	total: 3m 16s	remaining: 10m 31s
# 237:	learn: 0.0162554	total: 3m 16s	remaining: 10m 30s
# 238:	learn: 0.0160553	total: 3m 17s	remaining: 10m 29s
# 239:	learn: 0.0159413	total: 3m 18s	remaining: 10m 28s
# 240:	learn: 0.0158061	total: 3m 19s	remaining: 10m 27s
# 241:	learn: 0.0156778	total: 3m 20s	remaining: 10m 26s
# 242:	learn: 0.0155854	total: 3m 20s	remaining: 10m 25s
# 243:	learn: 0.0155510	total: 3m 21s	remaining: 10m 25s
# 244:	learn: 0.0153943	total: 3m 22s	remaining: 10m 24s
# 245:	learn: 0.0152651	total: 3m 23s	remaining: 10m 23s
# 246:	learn: 0.0150940	total: 3m 24s	remaining: 10m 22s
# 247:	learn: 0.0149819	total: 3m 24s	remaining: 10m 21s
# 248:	learn: 0.0148861	total: 3m 25s	remaining: 10m 20s
# 249:	learn: 0.0147808	total: 3m 26s	remaining: 10m 19s
# 250:	learn: 0.0146686	total: 3m 27s	remaining: 10m 18s
# 251:	learn: 0.0145410	total: 3m 28s	remaining: 10m 17s
# 252:	learn: 0.0144041	total: 3m 28s	remaining: 10m 16s
# 253:	learn: 0.0142577	total: 3m 29s	remaining: 10m 16s
# 254:	learn: 0.0140653	total: 3m 30s	remaining: 10m 15s
# 255:	learn: 0.0139969	total: 3m 31s	remaining: 10m 14s
# 256:	learn: 0.0138859	total: 3m 32s	remaining: 10m 13s
# 257:	learn: 0.0138059	total: 3m 33s	remaining: 10m 12s
# 258:	learn: 0.0137399	total: 3m 33s	remaining: 10m 11s
# 259:	learn: 0.0136195	total: 3m 34s	remaining: 10m 10s
# 260:	learn: 0.0134647	total: 3m 35s	remaining: 10m 9s
# 261:	learn: 0.0134214	total: 3m 36s	remaining: 10m 9s
# 262:	learn: 0.0133207	total: 3m 37s	remaining: 10m 8s
# 263:	learn: 0.0132571	total: 3m 37s	remaining: 10m 7s
# 264:	learn: 0.0132062	total: 3m 38s	remaining: 10m 6s
# 265:	learn: 0.0131573	total: 3m 39s	remaining: 10m 5s
# 266:	learn: 0.0130855	total: 3m 40s	remaining: 10m 4s
# 267:	learn: 0.0129965	total: 3m 41s	remaining: 10m 4s
# 268:	learn: 0.0128958	total: 3m 41s	remaining: 10m 3s
# 269:	learn: 0.0127635	total: 3m 42s	remaining: 10m 2s
# 270:	learn: 0.0126748	total: 3m 43s	remaining: 10m 1s
# 271:	learn: 0.0125860	total: 3m 44s	remaining: 10m
# 272:	learn: 0.0124915	total: 3m 45s	remaining: 9m 59s
# 273:	learn: 0.0124132	total: 3m 46s	remaining: 9m 58s
# 274:	learn: 0.0123571	total: 3m 46s	remaining: 9m 58s
# 275:	learn: 0.0122825	total: 3m 47s	remaining: 9m 57s
# 276:	learn: 0.0121808	total: 3m 48s	remaining: 9m 56s
# 277:	learn: 0.0120638	total: 3m 49s	remaining: 9m 55s
# 278:	learn: 0.0120105	total: 3m 50s	remaining: 9m 54s
# 279:	learn: 0.0119389	total: 3m 50s	remaining: 9m 53s
# 280:	learn: 0.0118830	total: 3m 51s	remaining: 9m 53s
# 281:	learn: 0.0118187	total: 3m 52s	remaining: 9m 52s
# 282:	learn: 0.0117207	total: 3m 53s	remaining: 9m 51s
# 283:	learn: 0.0116660	total: 3m 54s	remaining: 9m 50s
# 284:	learn: 0.0115933	total: 3m 55s	remaining: 9m 49s
# 285:	learn: 0.0115427	total: 3m 55s	remaining: 9m 48s
# 286:	learn: 0.0114609	total: 3m 56s	remaining: 9m 47s
# 287:	learn: 0.0113504	total: 3m 57s	remaining: 9m 46s
# 288:	learn: 0.0112952	total: 3m 58s	remaining: 9m 46s
# 289:	learn: 0.0112472	total: 3m 59s	remaining: 9m 45s
# 290:	learn: 0.0112062	total: 3m 59s	remaining: 9m 44s
# 291:	learn: 0.0111383	total: 4m	remaining: 9m 43s
# 292:	learn: 0.0110726	total: 4m 1s	remaining: 9m 42s
# 293:	learn: 0.0110150	total: 4m 2s	remaining: 9m 41s
# 294:	learn: 0.0109716	total: 4m 3s	remaining: 9m 41s
# 295:	learn: 0.0108807	total: 4m 3s	remaining: 9m 40s
# 296:	learn: 0.0108239	total: 4m 4s	remaining: 9m 39s
# 297:	learn: 0.0107866	total: 4m 5s	remaining: 9m 38s
# 298:	learn: 0.0106751	total: 4m 6s	remaining: 9m 37s
# 299:	learn: 0.0106307	total: 4m 7s	remaining: 9m 36s
# 300:	learn: 0.0105891	total: 4m 7s	remaining: 9m 35s
# 301:	learn: 0.0105230	total: 4m 8s	remaining: 9m 35s
# 302:	learn: 0.0104973	total: 4m 9s	remaining: 9m 34s
# 303:	learn: 0.0104590	total: 4m 10s	remaining: 9m 33s
# 304:	learn: 0.0103913	total: 4m 11s	remaining: 9m 32s
# 305:	learn: 0.0103248	total: 4m 12s	remaining: 9m 31s
# 306:	learn: 0.0102672	total: 4m 12s	remaining: 9m 30s
# 307:	learn: 0.0102089	total: 4m 13s	remaining: 9m 29s
# 308:	learn: 0.0102089	total: 4m 14s	remaining: 9m 28s
# 309:	learn: 0.0101656	total: 4m 15s	remaining: 9m 27s
# 310:	learn: 0.0101054	total: 4m 15s	remaining: 9m 26s
# 311:	learn: 0.0100254	total: 4m 16s	remaining: 9m 25s
# 312:	learn: 0.0099426	total: 4m 17s	remaining: 9m 25s
# 313:	learn: 0.0099000	total: 4m 18s	remaining: 9m 24s
# 314:	learn: 0.0098362	total: 4m 19s	remaining: 9m 23s
# 315:	learn: 0.0097630	total: 4m 19s	remaining: 9m 22s
# 316:	learn: 0.0097106	total: 4m 20s	remaining: 9m 21s
# 317:	learn: 0.0096749	total: 4m 21s	remaining: 9m 20s
# 318:	learn: 0.0096154	total: 4m 22s	remaining: 9m 19s
# 319:	learn: 0.0095664	total: 4m 23s	remaining: 9m 19s
# 320:	learn: 0.0095663	total: 4m 23s	remaining: 9m 17s
# 321:	learn: 0.0095663	total: 4m 24s	remaining: 9m 16s
# 322:	learn: 0.0095663	total: 4m 24s	remaining: 9m 15s
# 323:	learn: 0.0095221	total: 4m 25s	remaining: 9m 14s
# 324:	learn: 0.0094610	total: 4m 26s	remaining: 9m 13s
# 325:	learn: 0.0094610	total: 4m 27s	remaining: 9m 12s
# 326:	learn: 0.0094259	total: 4m 27s	remaining: 9m 11s
# 327:	learn: 0.0093853	total: 4m 28s	remaining: 9m 10s
# 328:	learn: 0.0093428	total: 4m 29s	remaining: 9m 9s
# 329:	learn: 0.0092415	total: 4m 30s	remaining: 9m 8s
# 330:	learn: 0.0091861	total: 4m 31s	remaining: 9m 8s
# 331:	learn: 0.0091860	total: 4m 31s	remaining: 9m 6s
# 332:	learn: 0.0091438	total: 4m 32s	remaining: 9m 6s
# 333:	learn: 0.0091438	total: 4m 33s	remaining: 9m 4s
# 334:	learn: 0.0091137	total: 4m 34s	remaining: 9m 4s
# 335:	learn: 0.0090844	total: 4m 34s	remaining: 9m 3s
# 336:	learn: 0.0090443	total: 4m 35s	remaining: 9m 2s
# 337:	learn: 0.0089786	total: 4m 36s	remaining: 9m 1s
# 338:	learn: 0.0089070	total: 4m 37s	remaining: 9m
# 339:	learn: 0.0088333	total: 4m 38s	remaining: 8m 59s
# 340:	learn: 0.0087626	total: 4m 38s	remaining: 8m 58s
# 341:	learn: 0.0087626	total: 4m 39s	remaining: 8m 57s
# 342:	learn: 0.0087321	total: 4m 40s	remaining: 8m 56s
# 343:	learn: 0.0087320	total: 4m 40s	remaining: 8m 55s
# 344:	learn: 0.0087125	total: 4m 41s	remaining: 8m 54s
# 345:	learn: 0.0086707	total: 4m 42s	remaining: 8m 54s
# 346:	learn: 0.0086707	total: 4m 43s	remaining: 8m 52s
# 347:	learn: 0.0086219	total: 4m 43s	remaining: 8m 52s
# 348:	learn: 0.0085835	total: 4m 44s	remaining: 8m 51s
# 349:	learn: 0.0085835	total: 4m 45s	remaining: 8m 50s
# 350:	learn: 0.0085833	total: 4m 46s	remaining: 8m 48s
# 351:	learn: 0.0085833	total: 4m 46s	remaining: 8m 47s
# 352:	learn: 0.0085831	total: 4m 47s	remaining: 8m 46s
# 353:	learn: 0.0085831	total: 4m 47s	remaining: 8m 45s
# 354:	learn: 0.0085585	total: 4m 48s	remaining: 8m 44s
# 355:	learn: 0.0085584	total: 4m 49s	remaining: 8m 43s
# 356:	learn: 0.0085584	total: 4m 49s	remaining: 8m 42s
# 357:	learn: 0.0085180	total: 4m 50s	remaining: 8m 41s
# 358:	learn: 0.0084879	total: 4m 51s	remaining: 8m 40s
# 359:	learn: 0.0084879	total: 4m 52s	remaining: 8m 39s
# 360:	learn: 0.0084878	total: 4m 52s	remaining: 8m 38s
# 361:	learn: 0.0084878	total: 4m 53s	remaining: 8m 37s
# 362:	learn: 0.0084876	total: 4m 54s	remaining: 8m 36s
# 363:	learn: 0.0084874	total: 4m 54s	remaining: 8m 34s
# 364:	learn: 0.0084585	total: 4m 55s	remaining: 8m 34s
# 365:	learn: 0.0084189	total: 4m 56s	remaining: 8m 33s
# 366:	learn: 0.0084188	total: 4m 56s	remaining: 8m 32s
# 367:	learn: 0.0084096	total: 4m 57s	remaining: 8m 31s
# 368:	learn: 0.0083633	total: 4m 58s	remaining: 8m 30s
# 369:	learn: 0.0083633	total: 4m 59s	remaining: 8m 29s
# 370:	learn: 0.0083631	total: 4m 59s	remaining: 8m 28s
# 371:	learn: 0.0083631	total: 5m	remaining: 8m 27s
# 372:	learn: 0.0083313	total: 5m 1s	remaining: 8m 26s
# 373:	learn: 0.0083312	total: 5m 1s	remaining: 8m 25s
# 374:	learn: 0.0083101	total: 5m 2s	remaining: 8m 24s
# 375:	learn: 0.0083100	total: 5m 3s	remaining: 8m 23s
# 376:	learn: 0.0082734	total: 5m 4s	remaining: 8m 22s
# 377:	learn: 0.0082220	total: 5m 4s	remaining: 8m 21s
# 378:	learn: 0.0081834	total: 5m 5s	remaining: 8m 20s
# 379:	learn: 0.0081149	total: 5m 6s	remaining: 8m 20s
# 380:	learn: 0.0081148	total: 5m 7s	remaining: 8m 19s
# 381:	learn: 0.0081148	total: 5m 7s	remaining: 8m 18s
# 382:	learn: 0.0081147	total: 5m 8s	remaining: 8m 16s
# 383:	learn: 0.0081147	total: 5m 9s	remaining: 8m 15s
# 384:	learn: 0.0081147	total: 5m 9s	remaining: 8m 14s
# 385:	learn: 0.0081146	total: 5m 10s	remaining: 8m 13s
# 386:	learn: 0.0081146	total: 5m 11s	remaining: 8m 12s
# 387:	learn: 0.0081144	total: 5m 11s	remaining: 8m 11s
# 388:	learn: 0.0081144	total: 5m 12s	remaining: 8m 10s
# 389:	learn: 0.0081143	total: 5m 12s	remaining: 8m 9s
# 390:	learn: 0.0081143	total: 5m 13s	remaining: 8m 8s
# 391:	learn: 0.0081143	total: 5m 14s	remaining: 8m 7s
# 392:	learn: 0.0081143	total: 5m 14s	remaining: 8m 6s
# 393:	learn: 0.0080987	total: 5m 15s	remaining: 8m 5s
# 394:	learn: 0.0080605	total: 5m 16s	remaining: 8m 4s
# 395:	learn: 0.0080184	total: 5m 17s	remaining: 8m 3s
# 396:	learn: 0.0080181	total: 5m 17s	remaining: 8m 2s
# 397:	learn: 0.0080181	total: 5m 18s	remaining: 8m 1s
# 398:	learn: 0.0080181	total: 5m 18s	remaining: 8m
# 399:	learn: 0.0079791	total: 5m 19s	remaining: 7m 59s
# 400:	learn: 0.0079348	total: 5m 20s	remaining: 7m 58s
# 401:	learn: 0.0078760	total: 5m 21s	remaining: 7m 58s
# 402:	learn: 0.0078414	total: 5m 22s	remaining: 7m 57s
# 403:	learn: 0.0078033	total: 5m 22s	remaining: 7m 56s
# 404:	learn: 0.0078033	total: 5m 23s	remaining: 7m 55s
# 405:	learn: 0.0078032	total: 5m 24s	remaining: 7m 54s
# 406:	learn: 0.0077740	total: 5m 24s	remaining: 7m 53s
# 407:	learn: 0.0077738	total: 5m 25s	remaining: 7m 52s
# 408:	learn: 0.0077737	total: 5m 26s	remaining: 7m 51s
# 409:	learn: 0.0077737	total: 5m 26s	remaining: 7m 50s
# 410:	learn: 0.0077305	total: 5m 27s	remaining: 7m 49s
# 411:	learn: 0.0077305	total: 5m 28s	remaining: 7m 48s
# 412:	learn: 0.0077304	total: 5m 28s	remaining: 7m 47s
# 413:	learn: 0.0077303	total: 5m 29s	remaining: 7m 46s
# 414:	learn: 0.0077302	total: 5m 30s	remaining: 7m 45s
# 415:	learn: 0.0077302	total: 5m 30s	remaining: 7m 44s
# 416:	learn: 0.0077302	total: 5m 31s	remaining: 7m 43s
# 417:	learn: 0.0077055	total: 5m 32s	remaining: 7m 42s
# 418:	learn: 0.0076640	total: 5m 32s	remaining: 7m 41s
# 419:	learn: 0.0076144	total: 5m 33s	remaining: 7m 40s
# 420:	learn: 0.0075630	total: 5m 34s	remaining: 7m 40s
# 421:	learn: 0.0075349	total: 5m 35s	remaining: 7m 39s
# 422:	learn: 0.0074864	total: 5m 36s	remaining: 7m 38s
# 423:	learn: 0.0074344	total: 5m 36s	remaining: 7m 37s
# 424:	learn: 0.0073953	total: 5m 37s	remaining: 7m 36s
# 425:	learn: 0.0073547	total: 5m 38s	remaining: 7m 36s
# 426:	learn: 0.0073108	total: 5m 39s	remaining: 7m 35s
# 427:	learn: 0.0073108	total: 5m 39s	remaining: 7m 34s
# 428:	learn: 0.0072707	total: 5m 40s	remaining: 7m 33s
# 429:	learn: 0.0072707	total: 5m 41s	remaining: 7m 32s
# 430:	learn: 0.0072705	total: 5m 41s	remaining: 7m 31s
# 431:	learn: 0.0072705	total: 5m 42s	remaining: 7m 30s
# 432:	learn: 0.0072302	total: 5m 43s	remaining: 7m 29s
# 433:	learn: 0.0071694	total: 5m 44s	remaining: 7m 28s
# 434:	learn: 0.0071234	total: 5m 45s	remaining: 7m 28s
# 435:	learn: 0.0070853	total: 5m 45s	remaining: 7m 27s
# 436:	learn: 0.0070853	total: 5m 46s	remaining: 7m 26s
# 437:	learn: 0.0070853	total: 5m 47s	remaining: 7m 25s
# 438:	learn: 0.0070853	total: 5m 47s	remaining: 7m 24s
# 439:	learn: 0.0070480	total: 5m 48s	remaining: 7m 23s
# 440:	learn: 0.0070471	total: 5m 49s	remaining: 7m 22s
# 441:	learn: 0.0070471	total: 5m 49s	remaining: 7m 21s
# 442:	learn: 0.0070180	total: 5m 50s	remaining: 7m 20s
# 443:	learn: 0.0070180	total: 5m 51s	remaining: 7m 19s
# 444:	learn: 0.0070180	total: 5m 51s	remaining: 7m 18s
# 445:	learn: 0.0070180	total: 5m 52s	remaining: 7m 17s
# 446:	learn: 0.0070179	total: 5m 53s	remaining: 7m 16s
# 447:	learn: 0.0070178	total: 5m 53s	remaining: 7m 15s
# 448:	learn: 0.0070178	total: 5m 54s	remaining: 7m 14s
# 449:	learn: 0.0070177	total: 5m 55s	remaining: 7m 13s
# 450:	learn: 0.0070071	total: 5m 55s	remaining: 7m 13s
# 451:	learn: 0.0070071	total: 5m 56s	remaining: 7m 12s
# 452:	learn: 0.0070071	total: 5m 57s	remaining: 7m 11s
# 453:	learn: 0.0070070	total: 5m 57s	remaining: 7m 10s
# 454:	learn: 0.0070069	total: 5m 58s	remaining: 7m 9s
# 455:	learn: 0.0070069	total: 5m 58s	remaining: 7m 8s
# 456:	learn: 0.0070069	total: 5m 59s	remaining: 7m 7s
# 457:	learn: 0.0070068	total: 6m	remaining: 7m 6s
# 458:	learn: 0.0070068	total: 6m	remaining: 7m 5s
# 459:	learn: 0.0069939	total: 6m 1s	remaining: 7m 4s
# 460:	learn: 0.0069938	total: 6m 2s	remaining: 7m 3s
# 461:	learn: 0.0069938	total: 6m 2s	remaining: 7m 2s
# 462:	learn: 0.0069938	total: 6m 3s	remaining: 7m 1s
# 463:	learn: 0.0069937	total: 6m 3s	remaining: 7m
# 464:	learn: 0.0069935	total: 6m 4s	remaining: 6m 59s
# 465:	learn: 0.0069935	total: 6m 5s	remaining: 6m 58s
# 466:	learn: 0.0069933	total: 6m 5s	remaining: 6m 57s
# 467:	learn: 0.0069933	total: 6m 6s	remaining: 6m 56s
# 468:	learn: 0.0069933	total: 6m 6s	remaining: 6m 55s
# 469:	learn: 0.0069932	total: 6m 7s	remaining: 6m 54s
# 470:	learn: 0.0069587	total: 6m 8s	remaining: 6m 53s
# 471:	learn: 0.0069587	total: 6m 9s	remaining: 6m 52s
# 472:	learn: 0.0069587	total: 6m 9s	remaining: 6m 51s
# 473:	learn: 0.0069587	total: 6m 10s	remaining: 6m 50s
# 474:	learn: 0.0069421	total: 6m 11s	remaining: 6m 50s
# 475:	learn: 0.0069421	total: 6m 11s	remaining: 6m 49s
# 476:	learn: 0.0069421	total: 6m 12s	remaining: 6m 48s
# 477:	learn: 0.0069420	total: 6m 12s	remaining: 6m 47s
# 478:	learn: 0.0069420	total: 6m 13s	remaining: 6m 46s
# 479:	learn: 0.0069419	total: 6m 14s	remaining: 6m 45s
# 480:	learn: 0.0069419	total: 6m 14s	remaining: 6m 44s
# 481:	learn: 0.0069419	total: 6m 15s	remaining: 6m 43s
# 482:	learn: 0.0069419	total: 6m 15s	remaining: 6m 42s
# 483:	learn: 0.0069419	total: 6m 16s	remaining: 6m 41s
# 484:	learn: 0.0069416	total: 6m 17s	remaining: 6m 40s
# 485:	learn: 0.0069416	total: 6m 17s	remaining: 6m 39s
# 486:	learn: 0.0069416	total: 6m 18s	remaining: 6m 38s
# 487:	learn: 0.0069415	total: 6m 19s	remaining: 6m 37s
# 488:	learn: 0.0069415	total: 6m 19s	remaining: 6m 36s
# 489:	learn: 0.0069415	total: 6m 20s	remaining: 6m 35s
# 490:	learn: 0.0069415	total: 6m 20s	remaining: 6m 34s
# 491:	learn: 0.0069415	total: 6m 21s	remaining: 6m 33s
# 492:	learn: 0.0069414	total: 6m 22s	remaining: 6m 33s
# 493:	learn: 0.0069414	total: 6m 22s	remaining: 6m 32s
# 494:	learn: 0.0069413	total: 6m 23s	remaining: 6m 31s
# 495:	learn: 0.0069412	total: 6m 24s	remaining: 6m 30s
# 496:	learn: 0.0069411	total: 6m 24s	remaining: 6m 29s
# 497:	learn: 0.0069411	total: 6m 25s	remaining: 6m 28s
# 498:	learn: 0.0069411	total: 6m 25s	remaining: 6m 27s
# 499:	learn: 0.0069411	total: 6m 26s	remaining: 6m 26s
# 500:	learn: 0.0069263	total: 6m 27s	remaining: 6m 25s
# 501:	learn: 0.0069261	total: 6m 27s	remaining: 6m 24s
# 502:	learn: 0.0069260	total: 6m 28s	remaining: 6m 23s
# 503:	learn: 0.0069260	total: 6m 29s	remaining: 6m 22s
# 504:	learn: 0.0069260	total: 6m 29s	remaining: 6m 22s
# 505:	learn: 0.0069260	total: 6m 30s	remaining: 6m 21s
# 506:	learn: 0.0068946	total: 6m 31s	remaining: 6m 20s
# 507:	learn: 0.0068946	total: 6m 31s	remaining: 6m 19s
# 508:	learn: 0.0068946	total: 6m 32s	remaining: 6m 18s
# 509:	learn: 0.0068510	total: 6m 33s	remaining: 6m 17s
# 510:	learn: 0.0068510	total: 6m 33s	remaining: 6m 16s
# 511:	learn: 0.0068510	total: 6m 34s	remaining: 6m 15s
# 512:	learn: 0.0068509	total: 6m 35s	remaining: 6m 15s
# 513:	learn: 0.0068509	total: 6m 35s	remaining: 6m 14s
# 514:	learn: 0.0068509	total: 6m 36s	remaining: 6m 13s
# 515:	learn: 0.0068509	total: 6m 36s	remaining: 6m 12s
# 516:	learn: 0.0068509	total: 6m 37s	remaining: 6m 11s
# 517:	learn: 0.0068508	total: 6m 38s	remaining: 6m 10s
# 518:	learn: 0.0068508	total: 6m 38s	remaining: 6m 9s
# 519:	learn: 0.0068508	total: 6m 39s	remaining: 6m 8s
# 520:	learn: 0.0068508	total: 6m 39s	remaining: 6m 7s
# 521:	learn: 0.0068507	total: 6m 40s	remaining: 6m 6s
# 522:	learn: 0.0068506	total: 6m 41s	remaining: 6m 5s
# 523:	learn: 0.0068506	total: 6m 41s	remaining: 6m 5s
# 524:	learn: 0.0068505	total: 6m 42s	remaining: 6m 4s
# 525:	learn: 0.0068505	total: 6m 43s	remaining: 6m 3s
# 526:	learn: 0.0068505	total: 6m 43s	remaining: 6m 2s
# 527:	learn: 0.0068182	total: 6m 44s	remaining: 6m 1s
# 528:	learn: 0.0067800	total: 6m 45s	remaining: 6m
# 529:	learn: 0.0067442	total: 6m 46s	remaining: 6m
# 530:	learn: 0.0067442	total: 6m 46s	remaining: 5m 59s
# 531:	learn: 0.0067015	total: 6m 47s	remaining: 5m 58s
# 532:	learn: 0.0066719	total: 6m 48s	remaining: 5m 57s
# 533:	learn: 0.0066719	total: 6m 48s	remaining: 5m 56s
# 534:	learn: 0.0066283	total: 6m 49s	remaining: 5m 56s
# 535:	learn: 0.0066283	total: 6m 50s	remaining: 5m 55s
# 536:	learn: 0.0066283	total: 6m 50s	remaining: 5m 54s
# 537:	learn: 0.0066283	total: 6m 51s	remaining: 5m 53s
# 538:	learn: 0.0065775	total: 6m 52s	remaining: 5m 52s
# 539:	learn: 0.0065774	total: 6m 52s	remaining: 5m 51s
# 540:	learn: 0.0065774	total: 6m 53s	remaining: 5m 50s
# 541:	learn: 0.0065774	total: 6m 54s	remaining: 5m 50s
# 542:	learn: 0.0065773	total: 6m 54s	remaining: 5m 49s
# 543:	learn: 0.0065773	total: 6m 55s	remaining: 5m 48s
# 544:	learn: 0.0065773	total: 6m 56s	remaining: 5m 47s
# 545:	learn: 0.0065772	total: 6m 56s	remaining: 5m 46s
# 546:	learn: 0.0065387	total: 6m 57s	remaining: 5m 45s
# 547:	learn: 0.0065387	total: 6m 58s	remaining: 5m 44s
# 548:	learn: 0.0065386	total: 6m 58s	remaining: 5m 43s
# 549:	learn: 0.0065385	total: 6m 59s	remaining: 5m 43s
# 550:	learn: 0.0065385	total: 6m 59s	remaining: 5m 42s
# 551:	learn: 0.0065384	total: 7m	remaining: 5m 41s
# 552:	learn: 0.0065049	total: 7m 1s	remaining: 5m 40s
# 553:	learn: 0.0065049	total: 7m 1s	remaining: 5m 39s
# 554:	learn: 0.0065049	total: 7m 2s	remaining: 5m 38s
# 555:	learn: 0.0065049	total: 7m 3s	remaining: 5m 37s
# 556:	learn: 0.0065049	total: 7m 3s	remaining: 5m 37s
# 557:	learn: 0.0065049	total: 7m 4s	remaining: 5m 36s
# 558:	learn: 0.0065049	total: 7m 4s	remaining: 5m 35s
# 559:	learn: 0.0065048	total: 7m 5s	remaining: 5m 34s
# 560:	learn: 0.0065048	total: 7m 6s	remaining: 5m 33s
# 561:	learn: 0.0065048	total: 7m 6s	remaining: 5m 32s
# 562:	learn: 0.0065048	total: 7m 7s	remaining: 5m 31s
# 563:	learn: 0.0065048	total: 7m 7s	remaining: 5m 30s
# 564:	learn: 0.0065048	total: 7m 8s	remaining: 5m 29s
# 565:	learn: 0.0065047	total: 7m 9s	remaining: 5m 29s
# 566:	learn: 0.0064986	total: 7m 9s	remaining: 5m 28s
# 567:	learn: 0.0064511	total: 7m 10s	remaining: 5m 27s
# 568:	learn: 0.0063959	total: 7m 11s	remaining: 5m 26s
# 569:	learn: 0.0063958	total: 7m 12s	remaining: 5m 25s
# 570:	learn: 0.0063957	total: 7m 12s	remaining: 5m 25s
# 571:	learn: 0.0063957	total: 7m 13s	remaining: 5m 24s
# 572:	learn: 0.0063957	total: 7m 13s	remaining: 5m 23s
# 573:	learn: 0.0063956	total: 7m 14s	remaining: 5m 22s
# 574:	learn: 0.0063956	total: 7m 15s	remaining: 5m 21s
# 575:	learn: 0.0063956	total: 7m 15s	remaining: 5m 20s
# 576:	learn: 0.0063956	total: 7m 16s	remaining: 5m 19s
# 577:	learn: 0.0063955	total: 7m 17s	remaining: 5m 19s
# 578:	learn: 0.0063954	total: 7m 17s	remaining: 5m 18s
# 579:	learn: 0.0063554	total: 7m 18s	remaining: 5m 17s
# 580:	learn: 0.0063553	total: 7m 19s	remaining: 5m 16s
# 581:	learn: 0.0063285	total: 7m 20s	remaining: 5m 16s
# 582:	learn: 0.0063285	total: 7m 20s	remaining: 5m 15s
# 583:	learn: 0.0063284	total: 7m 21s	remaining: 5m 14s
# 584:	learn: 0.0063284	total: 7m 21s	remaining: 5m 13s
# 585:	learn: 0.0063283	total: 7m 22s	remaining: 5m 12s
# 586:	learn: 0.0063283	total: 7m 23s	remaining: 5m 11s
# 587:	learn: 0.0063283	total: 7m 23s	remaining: 5m 10s
# 588:	learn: 0.0063283	total: 7m 24s	remaining: 5m 10s
# 589:	learn: 0.0063283	total: 7m 25s	remaining: 5m 9s
# 590:	learn: 0.0063283	total: 7m 25s	remaining: 5m 8s
# 591:	learn: 0.0063282	total: 7m 26s	remaining: 5m 7s
# 592:	learn: 0.0063282	total: 7m 26s	remaining: 5m 6s
# 593:	learn: 0.0063282	total: 7m 27s	remaining: 5m 5s
# 594:	learn: 0.0063282	total: 7m 28s	remaining: 5m 5s
# 595:	learn: 0.0063282	total: 7m 28s	remaining: 5m 4s
# 596:	learn: 0.0063282	total: 7m 29s	remaining: 5m 3s
# 597:	learn: 0.0063282	total: 7m 30s	remaining: 5m 2s
# 598:	learn: 0.0063281	total: 7m 30s	remaining: 5m 1s
# 599:	learn: 0.0063281	total: 7m 31s	remaining: 5m
# 600:	learn: 0.0063280	total: 7m 31s	remaining: 5m
# 601:	learn: 0.0063280	total: 7m 32s	remaining: 4m 59s
# 602:	learn: 0.0063280	total: 7m 33s	remaining: 4m 58s
# 603:	learn: 0.0063280	total: 7m 33s	remaining: 4m 57s
# 604:	learn: 0.0063279	total: 7m 34s	remaining: 4m 56s
# 605:	learn: 0.0063278	total: 7m 35s	remaining: 4m 55s
# 606:	learn: 0.0063278	total: 7m 35s	remaining: 4m 55s
# 607:	learn: 0.0063278	total: 7m 36s	remaining: 4m 54s
# 608:	learn: 0.0063278	total: 7m 36s	remaining: 4m 53s
# 609:	learn: 0.0063278	total: 7m 37s	remaining: 4m 52s
# 610:	learn: 0.0063277	total: 7m 38s	remaining: 4m 51s
# 611:	learn: 0.0063277	total: 7m 38s	remaining: 4m 50s
# 612:	learn: 0.0063277	total: 7m 39s	remaining: 4m 49s
# 613:	learn: 0.0063277	total: 7m 39s	remaining: 4m 49s
# 614:	learn: 0.0063277	total: 7m 40s	remaining: 4m 48s
# 615:	learn: 0.0063277	total: 7m 41s	remaining: 4m 47s
# 616:	learn: 0.0063277	total: 7m 41s	remaining: 4m 46s
# 617:	learn: 0.0063276	total: 7m 42s	remaining: 4m 45s
# 618:	learn: 0.0063276	total: 7m 43s	remaining: 4m 45s
# 619:	learn: 0.0062915	total: 7m 43s	remaining: 4m 44s
# 620:	learn: 0.0062914	total: 7m 44s	remaining: 4m 43s
# 621:	learn: 0.0062914	total: 7m 45s	remaining: 4m 42s
# 622:	learn: 0.0062914	total: 7m 45s	remaining: 4m 41s
# 623:	learn: 0.0062914	total: 7m 46s	remaining: 4m 40s
# 624:	learn: 0.0062914	total: 7m 46s	remaining: 4m 40s
# 625:	learn: 0.0062914	total: 7m 47s	remaining: 4m 39s
# 626:	learn: 0.0062914	total: 7m 48s	remaining: 4m 38s
# 627:	learn: 0.0062914	total: 7m 48s	remaining: 4m 37s
# 628:	learn: 0.0062914	total: 7m 49s	remaining: 4m 36s
# 629:	learn: 0.0062914	total: 7m 49s	remaining: 4m 36s
# 630:	learn: 0.0062913	total: 7m 50s	remaining: 4m 35s
# 631:	learn: 0.0062913	total: 7m 51s	remaining: 4m 34s
# 632:	learn: 0.0062913	total: 7m 51s	remaining: 4m 33s
# 633:	learn: 0.0062477	total: 7m 52s	remaining: 4m 32s
# 634:	learn: 0.0062477	total: 7m 53s	remaining: 4m 32s
# 635:	learn: 0.0062477	total: 7m 53s	remaining: 4m 31s
# 636:	learn: 0.0062477	total: 7m 54s	remaining: 4m 30s
# 637:	learn: 0.0062476	total: 7m 55s	remaining: 4m 29s
# 638:	learn: 0.0062476	total: 7m 55s	remaining: 4m 28s
# 639:	learn: 0.0062475	total: 7m 56s	remaining: 4m 27s
# 640:	learn: 0.0062474	total: 7m 56s	remaining: 4m 27s
# 641:	learn: 0.0062474	total: 7m 57s	remaining: 4m 26s
# 642:	learn: 0.0062473	total: 7m 58s	remaining: 4m 25s
# 643:	learn: 0.0062472	total: 7m 58s	remaining: 4m 24s
# 644:	learn: 0.0062472	total: 7m 59s	remaining: 4m 23s
# 645:	learn: 0.0062333	total: 8m	remaining: 4m 23s
# 646:	learn: 0.0062333	total: 8m	remaining: 4m 22s
# 647:	learn: 0.0062333	total: 8m 1s	remaining: 4m 21s
# 648:	learn: 0.0062332	total: 8m 2s	remaining: 4m 20s
# 649:	learn: 0.0062332	total: 8m 2s	remaining: 4m 19s
# 650:	learn: 0.0062332	total: 8m 3s	remaining: 4m 19s
# 651:	learn: 0.0062332	total: 8m 3s	remaining: 4m 18s
# 652:	learn: 0.0062331	total: 8m 4s	remaining: 4m 17s
# 653:	learn: 0.0062331	total: 8m 5s	remaining: 4m 16s
# 654:	learn: 0.0062330	total: 8m 5s	remaining: 4m 15s
# 655:	learn: 0.0062330	total: 8m 6s	remaining: 4m 15s
# 656:	learn: 0.0062330	total: 8m 7s	remaining: 4m 14s
# 657:	learn: 0.0062330	total: 8m 7s	remaining: 4m 13s
# 658:	learn: 0.0062329	total: 8m 8s	remaining: 4m 12s
# 659:	learn: 0.0062329	total: 8m 8s	remaining: 4m 11s
# 660:	learn: 0.0062329	total: 8m 9s	remaining: 4m 11s
# 661:	learn: 0.0062329	total: 8m 10s	remaining: 4m 10s
# 662:	learn: 0.0062328	total: 8m 10s	remaining: 4m 9s
# 663:	learn: 0.0062328	total: 8m 11s	remaining: 4m 8s
# 664:	learn: 0.0062328	total: 8m 12s	remaining: 4m 7s
# 665:	learn: 0.0062328	total: 8m 12s	remaining: 4m 7s
# 666:	learn: 0.0062327	total: 8m 13s	remaining: 4m 6s
# 667:	learn: 0.0062327	total: 8m 14s	remaining: 4m 5s
# 668:	learn: 0.0062326	total: 8m 14s	remaining: 4m 4s
# 669:	learn: 0.0062326	total: 8m 15s	remaining: 4m 3s
# 670:	learn: 0.0062326	total: 8m 15s	remaining: 4m 3s
# 671:	learn: 0.0062326	total: 8m 16s	remaining: 4m 2s
# 672:	learn: 0.0062325	total: 8m 17s	remaining: 4m 1s
# 673:	learn: 0.0062325	total: 8m 17s	remaining: 4m
# 674:	learn: 0.0062325	total: 8m 18s	remaining: 3m 59s
# 675:	learn: 0.0062325	total: 8m 18s	remaining: 3m 59s
# 676:	learn: 0.0062325	total: 8m 19s	remaining: 3m 58s
# 677:	learn: 0.0062323	total: 8m 20s	remaining: 3m 57s
# 678:	learn: 0.0062323	total: 8m 20s	remaining: 3m 56s
# 679:	learn: 0.0062323	total: 8m 21s	remaining: 3m 55s
# 680:	learn: 0.0062323	total: 8m 22s	remaining: 3m 55s
# 681:	learn: 0.0061899	total: 8m 22s	remaining: 3m 54s
# 682:	learn: 0.0061899	total: 8m 23s	remaining: 3m 53s
# 683:	learn: 0.0061898	total: 8m 24s	remaining: 3m 52s
# 684:	learn: 0.0061898	total: 8m 24s	remaining: 3m 52s
# 685:	learn: 0.0061898	total: 8m 25s	remaining: 3m 51s
# 686:	learn: 0.0061897	total: 8m 26s	remaining: 3m 50s
# 687:	learn: 0.0061897	total: 8m 26s	remaining: 3m 49s
# 688:	learn: 0.0061896	total: 8m 27s	remaining: 3m 49s
# 689:	learn: 0.0061895	total: 8m 28s	remaining: 3m 48s
# 690:	learn: 0.0061895	total: 8m 28s	remaining: 3m 47s
# 691:	learn: 0.0061469	total: 8m 29s	remaining: 3m 46s
# 692:	learn: 0.0061469	total: 8m 30s	remaining: 3m 45s
# 693:	learn: 0.0061469	total: 8m 30s	remaining: 3m 45s
# 694:	learn: 0.0061468	total: 8m 31s	remaining: 3m 44s
# 695:	learn: 0.0061467	total: 8m 32s	remaining: 3m 43s
# 696:	learn: 0.0061467	total: 8m 32s	remaining: 3m 42s
# 697:	learn: 0.0061467	total: 8m 33s	remaining: 3m 42s
# 698:	learn: 0.0061112	total: 8m 34s	remaining: 3m 41s
# 699:	learn: 0.0061111	total: 8m 34s	remaining: 3m 40s
# 700:	learn: 0.0061111	total: 8m 35s	remaining: 3m 39s
# 701:	learn: 0.0061111	total: 8m 35s	remaining: 3m 39s
# 702:	learn: 0.0061110	total: 8m 36s	remaining: 3m 38s
# 703:	learn: 0.0061110	total: 8m 37s	remaining: 3m 37s
# 704:	learn: 0.0061110	total: 8m 37s	remaining: 3m 36s
# 705:	learn: 0.0061110	total: 8m 38s	remaining: 3m 35s
# 706:	learn: 0.0061110	total: 8m 39s	remaining: 3m 35s
# 707:	learn: 0.0061110	total: 8m 39s	remaining: 3m 34s
# 708:	learn: 0.0061110	total: 8m 40s	remaining: 3m 33s
# 709:	learn: 0.0061110	total: 8m 41s	remaining: 3m 32s
# 710:	learn: 0.0060746	total: 8m 41s	remaining: 3m 32s
# 711:	learn: 0.0060746	total: 8m 42s	remaining: 3m 31s
# 712:	learn: 0.0060746	total: 8m 43s	remaining: 3m 30s
# 713:	learn: 0.0060746	total: 8m 43s	remaining: 3m 29s
# 714:	learn: 0.0060746	total: 8m 44s	remaining: 3m 29s
# 715:	learn: 0.0060746	total: 8m 44s	remaining: 3m 28s
# 716:	learn: 0.0060746	total: 8m 45s	remaining: 3m 27s
# 717:	learn: 0.0060746	total: 8m 46s	remaining: 3m 26s
# 718:	learn: 0.0060746	total: 8m 46s	remaining: 3m 25s
# 719:	learn: 0.0060745	total: 8m 47s	remaining: 3m 25s
# 720:	learn: 0.0060745	total: 8m 48s	remaining: 3m 24s
# 721:	learn: 0.0060745	total: 8m 48s	remaining: 3m 23s
# 722:	learn: 0.0060744	total: 8m 49s	remaining: 3m 22s
# 723:	learn: 0.0060744	total: 8m 49s	remaining: 3m 22s
# 724:	learn: 0.0060744	total: 8m 50s	remaining: 3m 21s
# 725:	learn: 0.0060743	total: 8m 51s	remaining: 3m 20s
# 726:	learn: 0.0060743	total: 8m 51s	remaining: 3m 19s
# 727:	learn: 0.0060743	total: 8m 52s	remaining: 3m 18s
# 728:	learn: 0.0060743	total: 8m 53s	remaining: 3m 18s
# 729:	learn: 0.0060742	total: 8m 53s	remaining: 3m 17s
# 730:	learn: 0.0060742	total: 8m 54s	remaining: 3m 16s
# 731:	learn: 0.0060742	total: 8m 55s	remaining: 3m 15s
# 732:	learn: 0.0060742	total: 8m 55s	remaining: 3m 15s
# 733:	learn: 0.0060741	total: 8m 56s	remaining: 3m 14s
# 734:	learn: 0.0060741	total: 8m 56s	remaining: 3m 13s
# 735:	learn: 0.0060741	total: 8m 57s	remaining: 3m 12s
# 736:	learn: 0.0060470	total: 8m 58s	remaining: 3m 12s
# 737:	learn: 0.0060470	total: 8m 59s	remaining: 3m 11s
# 738:	learn: 0.0060470	total: 8m 59s	remaining: 3m 10s
# 739:	learn: 0.0060469	total: 9m	remaining: 3m 9s
# 740:	learn: 0.0060468	total: 9m	remaining: 3m 9s
# 741:	learn: 0.0060468	total: 9m 1s	remaining: 3m 8s
# 742:	learn: 0.0060468	total: 9m 2s	remaining: 3m 7s
# 743:	learn: 0.0060467	total: 9m 2s	remaining: 3m 6s
# 744:	learn: 0.0060467	total: 9m 3s	remaining: 3m 6s
# 745:	learn: 0.0060467	total: 9m 4s	remaining: 3m 5s
# 746:	learn: 0.0060466	total: 9m 4s	remaining: 3m 4s
# 747:	learn: 0.0060466	total: 9m 5s	remaining: 3m 3s
# 748:	learn: 0.0060466	total: 9m 5s	remaining: 3m 2s
# 749:	learn: 0.0060466	total: 9m 6s	remaining: 3m 2s
# 750:	learn: 0.0060466	total: 9m 7s	remaining: 3m 1s
# 751:	learn: 0.0060466	total: 9m 7s	remaining: 3m
# 752:	learn: 0.0060466	total: 9m 8s	remaining: 2m 59s
# 753:	learn: 0.0060465	total: 9m 9s	remaining: 2m 59s
# 754:	learn: 0.0060465	total: 9m 9s	remaining: 2m 58s
# 755:	learn: 0.0060465	total: 9m 10s	remaining: 2m 57s
# 756:	learn: 0.0060465	total: 9m 10s	remaining: 2m 56s
# 757:	learn: 0.0060465	total: 9m 11s	remaining: 2m 56s
# 758:	learn: 0.0060464	total: 9m 12s	remaining: 2m 55s
# 759:	learn: 0.0060464	total: 9m 12s	remaining: 2m 54s
# 760:	learn: 0.0060464	total: 9m 13s	remaining: 2m 53s
# 761:	learn: 0.0060464	total: 9m 14s	remaining: 2m 53s
# 762:	learn: 0.0060464	total: 9m 14s	remaining: 2m 52s
# 763:	learn: 0.0060463	total: 9m 15s	remaining: 2m 51s
# 764:	learn: 0.0060463	total: 9m 15s	remaining: 2m 50s
# 765:	learn: 0.0060463	total: 9m 16s	remaining: 2m 50s
# 766:	learn: 0.0060463	total: 9m 17s	remaining: 2m 49s
# 767:	learn: 0.0060463	total: 9m 17s	remaining: 2m 48s
# 768:	learn: 0.0060463	total: 9m 18s	remaining: 2m 47s
# 769:	learn: 0.0060462	total: 9m 19s	remaining: 2m 46s
# 770:	learn: 0.0060462	total: 9m 19s	remaining: 2m 46s
# 771:	learn: 0.0060462	total: 9m 20s	remaining: 2m 45s
# 772:	learn: 0.0060462	total: 9m 20s	remaining: 2m 44s
# 773:	learn: 0.0060462	total: 9m 21s	remaining: 2m 43s
# 774:	learn: 0.0060461	total: 9m 22s	remaining: 2m 43s
# 775:	learn: 0.0060461	total: 9m 22s	remaining: 2m 42s
# 776:	learn: 0.0060461	total: 9m 23s	remaining: 2m 41s
# 777:	learn: 0.0060461	total: 9m 23s	remaining: 2m 40s
# 778:	learn: 0.0060461	total: 9m 24s	remaining: 2m 40s
# 779:	learn: 0.0060461	total: 9m 25s	remaining: 2m 39s
# 780:	learn: 0.0060460	total: 9m 25s	remaining: 2m 38s
# 781:	learn: 0.0060460	total: 9m 26s	remaining: 2m 37s
# 782:	learn: 0.0060460	total: 9m 27s	remaining: 2m 37s
# 783:	learn: 0.0060460	total: 9m 27s	remaining: 2m 36s
# 784:	learn: 0.0060460	total: 9m 28s	remaining: 2m 35s
# 785:	learn: 0.0060460	total: 9m 29s	remaining: 2m 34s
# 786:	learn: 0.0060459	total: 9m 29s	remaining: 2m 34s
# 787:	learn: 0.0060458	total: 9m 30s	remaining: 2m 33s
# 788:	learn: 0.0060458	total: 9m 30s	remaining: 2m 32s
# 789:	learn: 0.0060458	total: 9m 31s	remaining: 2m 31s
# 790:	learn: 0.0060458	total: 9m 32s	remaining: 2m 31s
# 791:	learn: 0.0060458	total: 9m 32s	remaining: 2m 30s
# 792:	learn: 0.0060458	total: 9m 33s	remaining: 2m 29s
# 793:	learn: 0.0060458	total: 9m 34s	remaining: 2m 28s
# 794:	learn: 0.0060458	total: 9m 34s	remaining: 2m 28s
# 795:	learn: 0.0060458	total: 9m 35s	remaining: 2m 27s
# 796:	learn: 0.0060457	total: 9m 35s	remaining: 2m 26s
# 797:	learn: 0.0060457	total: 9m 36s	remaining: 2m 25s
# 798:	learn: 0.0060457	total: 9m 37s	remaining: 2m 25s
# 799:	learn: 0.0060037	total: 9m 38s	remaining: 2m 24s
# 800:	learn: 0.0060037	total: 9m 38s	remaining: 2m 23s
# 801:	learn: 0.0060037	total: 9m 39s	remaining: 2m 23s
# 802:	learn: 0.0060037	total: 9m 39s	remaining: 2m 22s
# 803:	learn: 0.0060037	total: 9m 40s	remaining: 2m 21s
# 804:	learn: 0.0060037	total: 9m 41s	remaining: 2m 20s
# 805:	learn: 0.0060037	total: 9m 41s	remaining: 2m 20s
# 806:	learn: 0.0060037	total: 9m 42s	remaining: 2m 19s
# 807:	learn: 0.0060037	total: 9m 42s	remaining: 2m 18s
# 808:	learn: 0.0060036	total: 9m 43s	remaining: 2m 17s
# 809:	learn: 0.0060036	total: 9m 44s	remaining: 2m 17s
# 810:	learn: 0.0060036	total: 9m 44s	remaining: 2m 16s
# 811:	learn: 0.0060036	total: 9m 45s	remaining: 2m 15s
# 812:	learn: 0.0060036	total: 9m 46s	remaining: 2m 14s
# 813:	learn: 0.0060035	total: 9m 46s	remaining: 2m 14s
# 814:	learn: 0.0060035	total: 9m 47s	remaining: 2m 13s
# 815:	learn: 0.0060035	total: 9m 48s	remaining: 2m 12s
# 816:	learn: 0.0060035	total: 9m 48s	remaining: 2m 11s
# 817:	learn: 0.0060034	total: 9m 49s	remaining: 2m 11s
# 818:	learn: 0.0060034	total: 9m 49s	remaining: 2m 10s
# 819:	learn: 0.0060034	total: 9m 50s	remaining: 2m 9s
# 820:	learn: 0.0060034	total: 9m 51s	remaining: 2m 8s
# 821:	learn: 0.0060034	total: 9m 51s	remaining: 2m 8s
# 822:	learn: 0.0060033	total: 9m 52s	remaining: 2m 7s
# 823:	learn: 0.0060033	total: 9m 53s	remaining: 2m 6s
# 824:	learn: 0.0060033	total: 9m 53s	remaining: 2m 5s
# 825:	learn: 0.0060032	total: 9m 54s	remaining: 2m 5s
# 826:	learn: 0.0060032	total: 9m 55s	remaining: 2m 4s
# 827:	learn: 0.0060031	total: 9m 55s	remaining: 2m 3s
# 828:	learn: 0.0060031	total: 9m 56s	remaining: 2m 3s
# 829:	learn: 0.0060031	total: 9m 56s	remaining: 2m 2s
# 830:	learn: 0.0060031	total: 9m 57s	remaining: 2m 1s
# 831:	learn: 0.0060031	total: 9m 58s	remaining: 2m
# 832:	learn: 0.0060031	total: 9m 58s	remaining: 2m
# 833:	learn: 0.0060031	total: 9m 59s	remaining: 1m 59s
# 834:	learn: 0.0060030	total: 10m	remaining: 1m 58s
# 835:	learn: 0.0060030	total: 10m	remaining: 1m 57s
# 836:	learn: 0.0060030	total: 10m 1s	remaining: 1m 57s
# 837:	learn: 0.0060030	total: 10m 1s	remaining: 1m 56s
# 838:	learn: 0.0060030	total: 10m 2s	remaining: 1m 55s
# 839:	learn: 0.0060030	total: 10m 3s	remaining: 1m 54s
# 840:	learn: 0.0060030	total: 10m 3s	remaining: 1m 54s
# 841:	learn: 0.0060030	total: 10m 4s	remaining: 1m 53s
# 842:	learn: 0.0060029	total: 10m 5s	remaining: 1m 52s
# 843:	learn: 0.0060029	total: 10m 5s	remaining: 1m 51s
# 844:	learn: 0.0060029	total: 10m 6s	remaining: 1m 51s
# 845:	learn: 0.0060029	total: 10m 6s	remaining: 1m 50s
# 846:	learn: 0.0060029	total: 10m 7s	remaining: 1m 49s
# 847:	learn: 0.0060029	total: 10m 8s	remaining: 1m 49s
# 848:	learn: 0.0060029	total: 10m 8s	remaining: 1m 48s
# 849:	learn: 0.0060029	total: 10m 9s	remaining: 1m 47s
# 850:	learn: 0.0060028	total: 10m 10s	remaining: 1m 46s
# 851:	learn: 0.0060028	total: 10m 10s	remaining: 1m 46s
# 852:	learn: 0.0060028	total: 10m 11s	remaining: 1m 45s
# 853:	learn: 0.0060028	total: 10m 12s	remaining: 1m 44s
# 854:	learn: 0.0060028	total: 10m 12s	remaining: 1m 43s
# 855:	learn: 0.0060028	total: 10m 13s	remaining: 1m 43s
# 856:	learn: 0.0060027	total: 10m 13s	remaining: 1m 42s
# 857:	learn: 0.0060027	total: 10m 14s	remaining: 1m 41s
# 858:	learn: 0.0060027	total: 10m 15s	remaining: 1m 40s
# 859:	learn: 0.0060027	total: 10m 15s	remaining: 1m 40s
# 860:	learn: 0.0060027	total: 10m 16s	remaining: 1m 39s
# 861:	learn: 0.0060027	total: 10m 17s	remaining: 1m 38s
# 862:	learn: 0.0060027	total: 10m 17s	remaining: 1m 38s
# 863:	learn: 0.0060027	total: 10m 18s	remaining: 1m 37s
# 864:	learn: 0.0060026	total: 10m 18s	remaining: 1m 36s
# 865:	learn: 0.0060026	total: 10m 19s	remaining: 1m 35s
# 866:	learn: 0.0060025	total: 10m 20s	remaining: 1m 35s
# 867:	learn: 0.0060025	total: 10m 20s	remaining: 1m 34s
# 868:	learn: 0.0060025	total: 10m 21s	remaining: 1m 33s
# 869:	learn: 0.0060025	total: 10m 22s	remaining: 1m 32s
# 870:	learn: 0.0060024	total: 10m 22s	remaining: 1m 32s
# 871:	learn: 0.0060024	total: 10m 23s	remaining: 1m 31s
# 872:	learn: 0.0060023	total: 10m 24s	remaining: 1m 30s
# 873:	learn: 0.0060023	total: 10m 24s	remaining: 1m 30s
# 874:	learn: 0.0060023	total: 10m 25s	remaining: 1m 29s
# 875:	learn: 0.0060023	total: 10m 25s	remaining: 1m 28s
# 876:	learn: 0.0060023	total: 10m 26s	remaining: 1m 27s
# 877:	learn: 0.0060023	total: 10m 27s	remaining: 1m 27s
# 878:	learn: 0.0060022	total: 10m 27s	remaining: 1m 26s
# 879:	learn: 0.0060022	total: 10m 28s	remaining: 1m 25s
# 880:	learn: 0.0060021	total: 10m 29s	remaining: 1m 24s
# 881:	learn: 0.0060021	total: 10m 29s	remaining: 1m 24s
# 882:	learn: 0.0060020	total: 10m 30s	remaining: 1m 23s
# 883:	learn: 0.0060020	total: 10m 30s	remaining: 1m 22s
# 884:	learn: 0.0060020	total: 10m 31s	remaining: 1m 22s
# 885:	learn: 0.0060020	total: 10m 32s	remaining: 1m 21s
# 886:	learn: 0.0059584	total: 10m 33s	remaining: 1m 20s
# 887:	learn: 0.0059584	total: 10m 33s	remaining: 1m 19s
# 888:	learn: 0.0059583	total: 10m 34s	remaining: 1m 19s
# 889:	learn: 0.0059583	total: 10m 34s	remaining: 1m 18s
# ...
# Testing instance 30214 of 30637
# Testing instance 30215 of 30637
# Testing instance 30216 of 30637
# Testing instance 30217 of 30637
# Testing instance 30218 of 30637
# Testing instance 30219 of 30637
# Testing instance 30220 of 30637
# Testing instance 30221 of 30637
# Testing instance 30222 of 30637
# Testing instance 30223 of 30637
# Testing instance 30224 of 30637
# Testing instance 30225 of 30637
# Testing instance 30226 of 30637
# Testing instance 30227 of 30637
# Testing instance 30228 of 30637
# Testing instance 30229 of 30637
# Testing instance 30230 of 30637
# Testing instance 30231 of 30637
# Testing instance 30232 of 30637
# Testing instance 30233 of 30637
# Testing instance 30234 of 30637
# Testing instance 30235 of 30637
# Testing instance 30236 of 30637
# Testing instance 30237 of 30637
# Testing instance 30238 of 30637
# Testing instance 30239 of 30637
# Testing instance 30240 of 30637
# Testing instance 30241 of 30637
# Testing instance 30242 of 30637
# Testing instance 30243 of 30637
# Testing instance 30244 of 30637
# Testing instance 30245 of 30637
# Testing instance 30246 of 30637
# Testing instance 30247 of 30637
# Testing instance 30248 of 30637
# Testing instance 30249 of 30637
# Testing instance 30250 of 30637
# Testing instance 30251 of 30637
# Testing instance 30252 of 30637
# Testing instance 30253 of 30637
# Testing instance 30254 of 30637
# Testing instance 30255 of 30637
# Testing instance 30256 of 30637
# Testing instance 30257 of 30637
# Testing instance 30258 of 30637
# Testing instance 30259 of 30637
# Testing instance 30260 of 30637
# Testing instance 30261 of 30637
# Testing instance 30262 of 30637
# Testing instance 30263 of 30637
# Testing instance 30264 of 30637
# Testing instance 30265 of 30637
# Testing instance 30266 of 30637
# Testing instance 30267 of 30637
# Testing instance 30268 of 30637
# Testing instance 30269 of 30637
# Testing instance 30270 of 30637
# Testing instance 30271 of 30637
# Testing instance 30272 of 30637
# Testing instance 30273 of 30637
# Testing instance 30274 of 30637
# Testing instance 30275 of 30637
# Testing instance 30276 of 30637
# Testing instance 30277 of 30637
# Testing instance 30278 of 30637
# Testing instance 30279 of 30637
# Testing instance 30280 of 30637
# Testing instance 30281 of 30637
# Testing instance 30282 of 30637
# Testing instance 30283 of 30637
# Testing instance 30284 of 30637
# Testing instance 30285 of 30637
# Testing instance 30286 of 30637
# Testing instance 30287 of 30637
# Testing instance 30288 of 30637
# Testing instance 30289 of 30637
# Testing instance 30290 of 30637
# Testing instance 30291 of 30637
# Testing instance 30292 of 30637
# Testing instance 30293 of 30637
# Testing instance 30294 of 30637
# Testing instance 30295 of 30637
# Testing instance 30296 of 30637
# Testing instance 30297 of 30637
# Testing instance 30298 of 30637
# Testing instance 30299 of 30637
# Testing instance 30300 of 30637
# Testing instance 30301 of 30637
# Testing instance 30302 of 30637
# Testing instance 30303 of 30637
# Testing instance 30304 of 30637
# Testing instance 30305 of 30637
# Testing instance 30306 of 30637
# Testing instance 30307 of 30637
# Testing instance 30308 of 30637
# Testing instance 30309 of 30637
# Testing instance 30310 of 30637
# Testing instance 30311 of 30637
# Testing instance 30312 of 30637
# Testing instance 30313 of 30637
# Testing instance 30314 of 30637
# Testing instance 30315 of 30637
# Testing instance 30316 of 30637
# Testing instance 30317 of 30637
# Testing instance 30318 of 30637
# Testing instance 30319 of 30637
# Testing instance 30320 of 30637
# Testing instance 30321 of 30637
# Testing instance 30322 of 30637
# Testing instance 30323 of 30637
# Testing instance 30324 of 30637
# Testing instance 30325 of 30637
# Testing instance 30326 of 30637
# Testing instance 30327 of 30637
# Testing instance 30328 of 30637
# Testing instance 30329 of 30637
# Testing instance 30330 of 30637
# Testing instance 30331 of 30637
# Testing instance 30332 of 30637
# Testing instance 30333 of 30637
# Testing instance 30334 of 30637
# Testing instance 30335 of 30637
# Testing instance 30336 of 30637
# Testing instance 30337 of 30637
# Testing instance 30338 of 30637
# Testing instance 30339 of 30637
# Testing instance 30340 of 30637
# Testing instance 30341 of 30637
# Testing instance 30342 of 30637
# Testing instance 30343 of 30637
# Testing instance 30344 of 30637
# Testing instance 30345 of 30637
# Testing instance 30346 of 30637
# Testing instance 30347 of 30637
# Testing instance 30348 of 30637
# Testing instance 30349 of 30637
# Testing instance 30350 of 30637
# Testing instance 30351 of 30637
# Testing instance 30352 of 30637
# Testing instance 30353 of 30637
# Testing instance 30354 of 30637
# Testing instance 30355 of 30637
# Testing instance 30356 of 30637
# Testing instance 30357 of 30637
# Testing instance 30358 of 30637
# Testing instance 30359 of 30637
# Testing instance 30360 of 30637
# Testing instance 30361 of 30637
# Testing instance 30362 of 30637
# Testing instance 30363 of 30637
# Testing instance 30364 of 30637
# Testing instance 30365 of 30637
# Testing instance 30366 of 30637
# Testing instance 30367 of 30637
# Testing instance 30368 of 30637
# Testing instance 30369 of 30637
# Testing instance 30370 of 30637
# Testing instance 30371 of 30637
# Testing instance 30372 of 30637
# Testing instance 30373 of 30637
# Testing instance 30374 of 30637
# Testing instance 30375 of 30637
# Testing instance 30376 of 30637
# Testing instance 30377 of 30637
# Testing instance 30378 of 30637
# Testing instance 30379 of 30637
# Testing instance 30380 of 30637
# Testing instance 30381 of 30637
# Testing instance 30382 of 30637
# Testing instance 30383 of 30637
# Testing instance 30384 of 30637
# Testing instance 30385 of 30637
# Testing instance 30386 of 30637
# Testing instance 30387 of 30637
# Testing instance 30388 of 30637
# Testing instance 30389 of 30637
# Testing instance 30390 of 30637
# Testing instance 30391 of 30637
# Testing instance 30392 of 30637
# Testing instance 30393 of 30637
# Testing instance 30394 of 30637
# Testing instance 30395 of 30637
# Testing instance 30396 of 30637
# Testing instance 30397 of 30637
# Testing instance 30398 of 30637
# Testing instance 30399 of 30637
# Testing instance 30400 of 30637
# Testing instance 30401 of 30637
# Testing instance 30402 of 30637
# Testing instance 30403 of 30637
# Testing instance 30404 of 30637
# Testing instance 30405 of 30637
# Testing instance 30406 of 30637
# Testing instance 30407 of 30637
# Testing instance 30408 of 30637
# Testing instance 30409 of 30637
# Testing instance 30410 of 30637
# Testing instance 30411 of 30637
# Testing instance 30412 of 30637
# Testing instance 30413 of 30637
# Testing instance 30414 of 30637
# Testing instance 30415 of 30637
# Testing instance 30416 of 30637
# Testing instance 30417 of 30637
# Testing instance 30418 of 30637
# Testing instance 30419 of 30637
# Testing instance 30420 of 30637
# Testing instance 30421 of 30637
# Testing instance 30422 of 30637
# Testing instance 30423 of 30637
# Testing instance 30424 of 30637
# Testing instance 30425 of 30637
# Testing instance 30426 of 30637
# Testing instance 30427 of 30637
# Testing instance 30428 of 30637
# Testing instance 30429 of 30637
# Testing instance 30430 of 30637
# Testing instance 30431 of 30637
# Testing instance 30432 of 30637
# Testing instance 30433 of 30637
# Testing instance 30434 of 30637
# Testing instance 30435 of 30637
# Testing instance 30436 of 30637
# Testing instance 30437 of 30637
# Testing instance 30438 of 30637
# Testing instance 30439 of 30637
# Testing instance 30440 of 30637
# Testing instance 30441 of 30637
# Testing instance 30442 of 30637
# Testing instance 30443 of 30637
# Testing instance 30444 of 30637
# Testing instance 30445 of 30637
# Testing instance 30446 of 30637
# Testing instance 30447 of 30637
# Testing instance 30448 of 30637
# Testing instance 30449 of 30637
# Testing instance 30450 of 30637
# Testing instance 30451 of 30637
# Testing instance 30452 of 30637
# Testing instance 30453 of 30637
# Testing instance 30454 of 30637
# Testing instance 30455 of 30637
# Testing instance 30456 of 30637
# Testing instance 30457 of 30637
# Testing instance 30458 of 30637
# Testing instance 30459 of 30637
# Testing instance 30460 of 30637
# Testing instance 30461 of 30637
# Testing instance 30462 of 30637
# Testing instance 30463 of 30637
# Testing instance 30464 of 30637
# Testing instance 30465 of 30637
# Testing instance 30466 of 30637
# Testing instance 30467 of 30637
# Testing instance 30468 of 30637
# Testing instance 30469 of 30637
# Testing instance 30470 of 30637
# Testing instance 30471 of 30637
# Testing instance 30472 of 30637
# Testing instance 30473 of 30637
# Testing instance 30474 of 30637
# Testing instance 30475 of 30637
# Testing instance 30476 of 30637
# Testing instance 30477 of 30637
# Testing instance 30478 of 30637
# Testing instance 30479 of 30637
# Testing instance 30480 of 30637
# Testing instance 30481 of 30637
# Testing instance 30482 of 30637
# Testing instance 30483 of 30637
# Testing instance 30484 of 30637
# Testing instance 30485 of 30637
# Testing instance 30486 of 30637
# Testing instance 30487 of 30637
# Testing instance 30488 of 30637
# Testing instance 30489 of 30637
# Testing instance 30490 of 30637
# Testing instance 30491 of 30637
# Testing instance 30492 of 30637
# Testing instance 30493 of 30637
# Testing instance 30494 of 30637
# Testing instance 30495 of 30637
# Testing instance 30496 of 30637
# Testing instance 30497 of 30637
# Testing instance 30498 of 30637
# Testing instance 30499 of 30637
# Testing instance 30500 of 30637
# Testing instance 30501 of 30637
# Testing instance 30502 of 30637
# Testing instance 30503 of 30637
# Testing instance 30504 of 30637
# Testing instance 30505 of 30637
# Testing instance 30506 of 30637
# Testing instance 30507 of 30637
# Testing instance 30508 of 30637
# Testing instance 30509 of 30637
# Testing instance 30510 of 30637
# Testing instance 30511 of 30637
# Testing instance 30512 of 30637
# Testing instance 30513 of 30637
# Testing instance 30514 of 30637
# Testing instance 30515 of 30637
# Testing instance 30516 of 30637
# Testing instance 30517 of 30637
# Testing instance 30518 of 30637
# Testing instance 30519 of 30637
# Testing instance 30520 of 30637
# Testing instance 30521 of 30637
# Testing instance 30522 of 30637
# Testing instance 30523 of 30637
# Testing instance 30524 of 30637
# Testing instance 30525 of 30637
# Testing instance 30526 of 30637
# Testing instance 30527 of 30637
# Testing instance 30528 of 30637
# Testing instance 30529 of 30637
# Testing instance 30530 of 30637
# Testing instance 30531 of 30637
# Testing instance 30532 of 30637
# Testing instance 30533 of 30637
# Testing instance 30534 of 30637
# Testing instance 30535 of 30637
# Testing instance 30536 of 30637
# Testing instance 30537 of 30637
# Testing instance 30538 of 30637
# Testing instance 30539 of 30637
# Testing instance 30540 of 30637
# Testing instance 30541 of 30637
# Testing instance 30542 of 30637
# Testing instance 30543 of 30637
# Testing instance 30544 of 30637
# Testing instance 30545 of 30637
# Testing instance 30546 of 30637
# Testing instance 30547 of 30637
# Testing instance 30548 of 30637
# Testing instance 30549 of 30637
# Testing instance 30550 of 30637
# Testing instance 30551 of 30637
# Testing instance 30552 of 30637
# Testing instance 30553 of 30637
# Testing instance 30554 of 30637
# Testing instance 30555 of 30637
# Testing instance 30556 of 30637
# Testing instance 30557 of 30637
# Testing instance 30558 of 30637
# Testing instance 30559 of 30637
# Testing instance 30560 of 30637
# Testing instance 30561 of 30637
# Testing instance 30562 of 30637
# Testing instance 30563 of 30637
# Testing instance 30564 of 30637
# Testing instance 30565 of 30637
# Testing instance 30566 of 30637
# Testing instance 30567 of 30637
# Testing instance 30568 of 30637
# Testing instance 30569 of 30637
# Testing instance 30570 of 30637
# Testing instance 30571 of 30637
# Testing instance 30572 of 30637
# Testing instance 30573 of 30637
# Testing instance 30574 of 30637
# Testing instance 30575 of 30637
# Testing instance 30576 of 30637
# Testing instance 30577 of 30637
# Testing instance 30578 of 30637
# Testing instance 30579 of 30637
# Testing instance 30580 of 30637
# Testing instance 30581 of 30637
# Testing instance 30582 of 30637
# Testing instance 30583 of 30637
# Testing instance 30584 of 30637
# Testing instance 30585 of 30637
# Testing instance 30586 of 30637
# Testing instance 30587 of 30637
# Testing instance 30588 of 30637
# Testing instance 30589 of 30637
# Testing instance 30590 of 30637
# Testing instance 30591 of 30637
# Testing instance 30592 of 30637
# Testing instance 30593 of 30637
# Testing instance 30594 of 30637
# Testing instance 30595 of 30637
# Testing instance 30596 of 30637
# Testing instance 30597 of 30637
# Testing instance 30598 of 30637
# Testing instance 30599 of 30637
# Testing instance 30600 of 30637
# Testing instance 30601 of 30637
# Testing instance 30602 of 30637
# Testing instance 30603 of 30637
# Testing instance 30604 of 30637
# Testing instance 30605 of 30637
# Testing instance 30606 of 30637
# Testing instance 30607 of 30637
# Testing instance 30608 of 30637
# Testing instance 30609 of 30637
# Testing instance 30610 of 30637
# Testing instance 30611 of 30637
# Testing instance 30612 of 30637
# Testing instance 30613 of 30637
# Testing instance 30614 of 30637
# Testing instance 30615 of 30637
# Testing instance 30616 of 30637
# Testing instance 30617 of 30637
# Testing instance 30618 of 30637
# Testing instance 30619 of 30637
# Testing instance 30620 of 30637
# Testing instance 30621 of 30637
# Testing instance 30622 of 30637
# Testing instance 30623 of 30637
# Testing instance 30624 of 30637
# Testing instance 30625 of 30637
# Testing instance 30626 of 30637
# Testing instance 30627 of 30637
# Testing instance 30628 of 30637
# Testing instance 30629 of 30637
# Testing instance 30630 of 30637
# Testing instance 30631 of 30637
# Testing instance 30632 of 30637
# Testing instance 30633 of 30637
# Testing instance 30634 of 30637
# Testing instance 30635 of 30637
# Testing instance 30636 of 30637
# Testing instance 30637 of 30637
# Saving models...
# saving data...
# compiling results...
# bpic2012_accepted single_agg cb 1 auc 0.5293055492225617
# bpic2012_accepted single_agg cb 2 auc 0.5207605672335963
# bpic2012_accepted single_agg cb 3 auc 0.5200310063380603
# bpic2012_accepted single_agg cb 4 auc 0.5282157676348547
# bpic2012_accepted single_agg cb 5 auc 0.538712325019379
# bpic2012_accepted single_agg cb 6 auc 0.5184487711458665
# bpic2012_accepted single_agg cb 7 auc 0.5274246500387579
# bpic2012_accepted single_agg cb 8 auc 0.5272399799370754
# bpic2012_accepted single_agg cb 9 auc 0.5363914094204552
# bpic2012_accepted single_agg cb 10 auc 0.5097806757557795
# bpic2012_accepted single_agg cb 11 auc 0.5158200720441385
# bpic2012_accepted single_agg cb 12 auc 0.5125233687474352
# bpic2012_accepted single_agg cb 13 auc 0.5234508230358853
# bpic2012_accepted single_agg cb 14 auc 0.5368223063243811
# bpic2012_accepted single_agg cb 15 auc 0.5751516118736035
# bpic2012_accepted single_agg cb 16 auc 0.575696502667457
# bpic2012_accepted single_agg cb 17 auc 0.5744354360670785
# bpic2012_accepted single_agg cb 18 auc 0.5846980920529358
# bpic2012_accepted single_agg cb 19 auc 0.5925636154576813
# bpic2012_accepted single_agg cb 20 auc 0.6152456974068902
# bpic2012_accepted single_agg cb 21 auc 0.6268220023406745
# bpic2012_accepted single_agg cb 22 auc 0.6430014555408312
# bpic2012_accepted single_agg cb 23 auc 0.6496603067891298
# bpic2012_accepted single_agg cb 24 auc 0.6687109723461195
# bpic2012_accepted single_agg cb 25 auc 0.6670527225583405
# bpic2012_accepted single_agg cb 26 auc 0.6764277389277389
# bpic2012_accepted single_agg cb 27 auc 0.6789412357758513
# bpic2012_accepted single_agg cb 28 auc 0.6923463938636987
# bpic2012_accepted single_agg cb 29 auc 0.7009298094901208
# bpic2012_accepted single_agg cb 30 auc 0.6987109206285922
# bpic2012_accepted single_agg cb 31 auc 0.7201680672268909
# bpic2012_accepted single_agg cb 32 auc 0.7084445401061845
# bpic2012_accepted single_agg cb 33 auc 0.7077326343381388
# bpic2012_accepted single_agg cb 34 auc 0.7101190476190476
# bpic2012_accepted single_agg cb 35 auc 0.6847816612917283
# bpic2012_accepted single_agg cb 36 auc 0.693103448275862
# bpic2012_accepted single_agg cb 37 auc 0.6617826617826618
# bpic2012_accepted single_agg cb 38 auc 0.7035717678350908
# bpic2012_accepted single_agg cb 39 auc 0.6917611489040061
# bpic2012_accepted single_agg cb 40 auc 0.6874946631372214
# bpic2012_accepted single_agg cb -1 -1 auc 0.6051217220502261
