# %%
#from google.colab import drive
#drive.mount('/content/drive')
import sys
#PATH = '/content/drive/My Drive/PPM_Stability/'
#PATH = "C:/Users/velmurug/Documents/Stability Experiments/benchmark_interpretability/PPM_Stability/"
PATH = "C:/Users/mythr/Documents/GitHub/Stability-Experiments/benchmark_interpretability/PPM_Stability/"
sys.path.append(PATH)

# %%
#!pip install pandas==0.22.0
# !pip install xgboost==1.0.0
# Out:
# Requirement already satisfied: xgboost==1.0.0 in c:\programdata\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost==1.0.0) (1.4.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost==1.0.0) (1.19.1)

# %%
import EncoderFactory
from DatasetManager import DatasetManager
import BucketFactory

import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_recall_fscore_support	

import time
import os
import sys
from sys import argv
import pickle
from collections import defaultdict

from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

#import lime
#import lime.lime_tabular
#from lime import submodular_pick;
import warnings
warnings.filterwarnings('ignore')

import joblib
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dask\dataframe\utils.py:14: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
dataset_ref = "bpic2012"
params_dir = "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "agg"
cls_method = "xgboost"
gap = 1
n_iter = 1

if bucket_method == "state":
    bucket_encoding = "last"
else:
    bucket_encoding = "agg"

method_name = "%s_%s"%(bucket_method, cls_encoding)

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"]
    #"insurance": ["insurance_activity", "insurance_followup"],
    #"sepsis_cases": ["sepsis_cases_1", "sepsis_cases_2", "sepsis_cases_4"]
}

encoding_dict = {
    "laststate": ["static", "last"],
    "agg": ["static", "agg"],
    "index": ["static", "index"],
    "combined": ["static", "last", "agg"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]
methods = encoding_dict[cls_encoding]
    
train_ratio = 0.8
random_state = 22

# create results directory
if not os.path.exists(os.path.join(params_dir)):
    os.makedirs(os.path.join(params_dir))
    
print(datasets)
# Out:
# ['bpic2012_accepted']

# %%
for dataset_name in datasets:
    
    # load optimal params
    print("Setting up parameters...")
    optimal_params_filename = os.path.join(PATH, params_dir, "optimal_params_%s_%s_%s.pickle" % (cls_method, dataset_name, method_name))

    if not os.path.isfile(optimal_params_filename) or os.path.getsize(optimal_params_filename) <= 0:
        print("Parameters not found")
        
    with open(optimal_params_filename, "rb") as fin:
        args = pickle.load(fin)
        
    print(args)
    bucket_list=[5,10,15,20,25] #:)	
            
    # read the data
    print("setting up data...")
    dataset_manager = DatasetManager(dataset_name)
    data = dataset_manager.read_dataset()
    #print('Case ID column', dataset_manager.case_id_col)
    cls_encoder_args = {'case_id_col': dataset_manager.case_id_col, 
                        'static_cat_cols': dataset_manager.static_cat_cols,
                        'static_num_cols': dataset_manager.static_num_cols, 
                        'dynamic_cat_cols': dataset_manager.dynamic_cat_cols,
                        'dynamic_num_cols': dataset_manager.dynamic_num_cols, 
                        'fillna': True}

    # determine min and max (truncated) prefix lengths
    min_prefix_length = 1
    if "traffic_fines" in dataset_name:
        max_prefix_length = 10
    elif "bpic2017" in dataset_name:
        max_prefix_length = min(20, dataset_manager.get_pos_case_length_quantile(data, 0.90))
    else:
        max_prefix_length = min(40, dataset_manager.get_pos_case_length_quantile(data, 0.90))

    # split into training and test
    train, test = dataset_manager.split_data_strict(data, train_ratio, split="temporal")
    
    if gap > 1:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s_gap%s.csv" % (cls_method, dataset_name, method_name, gap))
    else:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s.csv" % (cls_method, dataset_name, method_name))
        
    start_test_prefix_generation = time.time()
    dt_test_prefixes = dataset_manager.generate_prefix_data(test, min_prefix_length, max_prefix_length)
    test_prefix_generation_time = time.time() - start_test_prefix_generation
            
    offline_total_times = []
    online_event_times = []
    train_prefix_generation_times = []

    for ii in range(n_iter):
        # create prefix logs
        print("Creating logs...")
        start_train_prefix_generation = time.time()
        dt_train_prefixes = dataset_manager.generate_prefix_data(train, min_prefix_length, max_prefix_length, gap)
        train_prefix_generation_time = time.time() - start_train_prefix_generation
        train_prefix_generation_times.append(train_prefix_generation_time)
            
        # Bucketing prefixes based on control flow
        print("bucketing prefixes...")
        bucketer_args = {'encoding_method':bucket_encoding, 
                         'case_id_col':dataset_manager.case_id_col, 
                         'cat_cols':[dataset_manager.activity_col], 
                         'num_cols':[], 
                         'random_state':random_state}
        if bucket_method == "cluster":
            bucketer_args["n_clusters"] = int(args["n_clusters"])
        bucketer = BucketFactory.get_bucketer(bucket_method, **bucketer_args)

        start_offline_time_bucket = time.time()
        bucket_assignments_train = bucketer.fit_predict(dt_train_prefixes)
        offline_time_bucket = time.time() - start_offline_time_bucket

        bucket_assignments_test = bucketer.predict(dt_test_prefixes)

        preds_all = []
        probas_all = []
        pred_types_all = []
        test_y_all = []
        nr_events_all = []
        offline_time_fit = 0
        current_online_event_times = []
        
        for bucket in set(bucket_assignments_test):
            print("Bucket" , bucket, "of", len(set(bucket_assignments_test)))
            print("sorting bucket...")
            #args has only one value - some error and so just using it
            #if bucket_method == "prefix":
            #    current_args = args[bucket]
            #else:
            current_args = args
            
            relevant_train_cases_bucket = dataset_manager.get_indexes(dt_train_prefixes)[bucket_assignments_train == bucket]
            relevant_test_cases_bucket = dataset_manager.get_indexes(dt_test_prefixes)[bucket_assignments_test == bucket]
            dt_test_bucket = dataset_manager.get_relevant_data_by_indexes(dt_test_prefixes, relevant_test_cases_bucket)
            
            nr_events_all.extend(list(dataset_manager.get_prefix_lengths(dt_test_bucket)))
            print('number events', len(nr_events_all))
            
            if len(relevant_train_cases_bucket) == 0:
                preds = [dataset_manager.get_class_ratio(train)] * len(relevant_test_cases_bucket)
                current_online_event_times.extend([0] * len(preds))
            else:
                dt_train_bucket = dataset_manager.get_relevant_data_by_indexes(dt_train_prefixes, relevant_train_cases_bucket) # one row per event
                train_y = dataset_manager.get_label_numeric(dt_train_bucket)

                if len(set(train_y)) < 2:
                    preds = [train_y[0]] * len(relevant_test_cases_bucket)
                    current_online_event_times.extend([0] * len(preds))
                    test_y_all.extend(dataset_manager.get_label_numeric(dt_test_bucket))
                else:
                    print("choosing classifier...")
                    start_offline_time_fit = time.time()
                    feature_combiner = FeatureUnion([(method, EncoderFactory.get_encoder(method, **cls_encoder_args)) for method in methods])

                    if cls_method == "rf":
                        cls = RandomForestClassifier(n_estimators=500,
                                                     max_features=current_args['max_features'],
                                                     random_state=random_state)

                    elif cls_method == "xgboost":
                        cls = xgb.XGBClassifier(objective='binary:logistic',
                                                n_estimators=500,
                                                learning_rate= current_args['learning_rate'],
                                                subsample=current_args['subsample'],
                                                max_depth=int(current_args['max_depth']),
                                                colsample_bytree=current_args['colsample_bytree'],
                                                min_child_weight=int(current_args['min_child_weight']),
                                                seed=random_state)

                    elif cls_method == "logit":
                        cls = LogisticRegression(C=2**current_args['C'],
                                                 random_state=random_state)

                    elif cls_method == "svm":
                        cls = SVC(C=2**current_args['C'],
                                  gamma=2**current_args['gamma'],
                                  random_state=random_state)

                    if cls_method == "svm" or cls_method == "logit":
                        pipeline = Pipeline([('encoder', feature_combiner), ('scaler', StandardScaler()), ('cls', cls)])
                    else:
                        pipeline = Pipeline([('encoder', feature_combiner), ('cls', cls)])

                    print("fitting pipeline...")
                    pipeline.fit(dt_train_bucket, train_y)
                    
                    offline_time_fit += time.time() - start_offline_time_fit

                    # predict separately for each prefix case
                    preds = []
                    probas = []
                    pred_types = []
                    
                    test_all_grouped = dt_test_bucket.groupby(dataset_manager.case_id_col)
                    print("test data shape", dt_test_bucket.shape)
                    count_d=0 # count for deviant
                    count_r=0 #count for regular

                    tp_list = []
                    tn_list = []
                    fp_list = []
                    fn_list = []

                    iteration = 1
                    
                    for _, group in test_all_grouped:
                        print ("Testing instance", iteration, 'of', len(test_all_grouped))
                        test_y_group = dataset_manager.get_label_numeric(group)
                        test_y_all.extend(test_y_group)
                            
                        start = time.time()
                        _ = bucketer.predict(group)
                        
                        if cls_method == "svm":
                            pred = pipeline.decision_function(group)
                        else:
                          preds_pos_label_idx = np.where(cls.classes_ == 1)[0][0]
                          pred = pipeline.predict(group)[0]
                          proba = pipeline.predict_proba(group)[:,preds_pos_label_idx]
                        pipeline_pred_time = time.time() - start
                        current_online_event_times.append(pipeline_pred_time / len(group))
                        case_id = dataset_manager.get_case_ids(group)[0]
                        
                        if test_y_group == pred & pred == 0:
                          pred_type = 'TN'

                          instance_dict = {}
                          instance_dict['caseID'] = case_id
                          instance_dict['input'] = group
                          instance_dict['actual'] = test_y_group[0]
                          instance_dict['predicted'] = pred
                          instance_dict['proba'] = 1 - proba[0]
                          instance_dict['nr_events'] = dataset_manager.get_prefix_lengths(group)[0]
                          instance_dict['pred_type'] = pred_type

                          tn_list.append(instance_dict)

                        elif test_y_group == pred & pred == 1:
                          pred_type = 'TP'
                                            
                          instance_dict = {}
                          instance_dict['caseID'] = case_id
                          instance_dict['input'] = group
                          instance_dict['actual'] = test_y_group[0]
                          instance_dict['predicted'] = pred
                          instance_dict['proba'] = proba[0]
                          instance_dict['nr_events'] = dataset_manager.get_prefix_lengths(group)[0]
                          instance_dict['pred_type'] = pred_type

                          tp_list.append(instance_dict)

                        elif test_y_group != pred & pred == 0:
                          pred_type = 'FN'
                          
                          instance_dict = {}
                          instance_dict['caseID'] = case_id
                          instance_dict['input'] = group
                          instance_dict['actual'] = test_y_group[0]
                          instance_dict['predicted'] = pred
                          instance_dict['proba'] = 1 - proba[0]
                          instance_dict['nr_events'] = dataset_manager.get_prefix_lengths(group)[0]
                          instance_dict['pred_type'] = pred_type

                          fn_list.append(instance_dict)

                        elif test_y_group != pred & pred == 1:
                          pred_type = 'FP'
                          
                          instance_dict = {}
                          instance_dict['caseID'] = case_id
                          instance_dict['input'] = group
                          instance_dict['actual'] = test_y_group[0]
                          instance_dict['predicted'] = pred
                          instance_dict['proba'] = proba[0]
                          instance_dict['nr_events'] = dataset_manager.get_prefix_lengths(group)[0]
                          instance_dict['pred_type'] = pred_type

                          fp_list.append(instance_dict)
                        else:
                          print("ERROR: Prediction doesn't fit into any category. Check code.")
                              
                        preds.append(pred)
                        probas.extend(proba)
                        pred_types.append(pred_type)
                        iteration+=1
                        
                    preds_all.extend(preds)
                    probas_all.extend(probas)
                    pred_types_all.extend(pred_types)

                    tn_path = os.path.join(PATH, "%s/%s_%s/instances/true_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucket))
                    tp_path = os.path.join(PATH, "%s/%s_%s/instances/true_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucket))
                    fn_path = os.path.join(PATH, "%s/%s_%s/instances/false_neg_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucket))
                    fp_path = os.path.join(PATH, "%s/%s_%s/instances/false_pos_bucket_%s_.pickle" % (dataset_ref, cls_method, method_name, bucket))
                    
                    with open (tn_path, 'wb') as f:
                      pickle.dump(tn_list, f)
                    with open (tp_path, 'wb') as f:
                      pickle.dump(tp_list, f)
                    with open (fn_path, 'wb') as f:
                      pickle.dump(fn_list, f)
                    with open (fp_path, 'wb') as f:
                      pickle.dump(fp_list, f)

            #Save models and encoders
            print('Saving models...')
            pipeline_path = os.path.join(PATH, "%s/%s_%s/pipelines/pipeline_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucket))
            feat_comb_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/feature_combiner_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucket))
            bucketer_path = os.path.join(PATH, "%s/%s_%s/bucketers_and_encoders/bucketer_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucket))
            cls_path = os.path.join(PATH, "%s/%s_%s/models/cls_bucket_%s.joblib" % (dataset_ref, cls_method, method_name, bucket))
            joblib.dump(pipeline, pipeline_path)
            joblib.dump(feature_combiner, feat_comb_path)
            joblib.dump(cls, cls_path)
            joblib.dump(bucketer, bucketer_path)

            #Save training data
            print("saving data...")
            X_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucket))
            Y_train_path = os.path.join(PATH, "%s/%s_%s/train_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucket))
            with open(X_train_path, 'wb') as f:
              pickle.dump(dt_train_bucket, f)
            with open(Y_train_path, 'wb') as f:
              pickle.dump(train_y, f)

            #Save testing data
            X_test_path = os.path.join(PATH, "%s/%s_%s/test_data/bucket_%s_prefixes.pickle" % (dataset_ref, cls_method, method_name, bucket))
            Y_test_path = os.path.join(PATH, "%s/%s_%s/test_data/bucket_%s_labels.pickle" % (dataset_ref, cls_method, method_name, bucket))
            with open(X_test_path, 'wb') as f:
                pickle.dump(dt_test_bucket, f)
            with open(Y_test_path, 'wb') as f:
                pickle.dump(test_y_group, f)
        
        print("compiling results...")
        dt_results = pd.DataFrame({"actual": test_y_all, "predicted": preds_all, "nr_events": nr_events_all})
        for nr_events, group in dt_results.groupby("nr_events"):
            if len(set(group.actual)) < 2:
                print(dataset_name, method_name, cls_method, nr_events, "auc", np.nan)
            else:
                print(dataset_name, method_name, cls_method, nr_events, "auc", roc_auc_score(group.actual, group.predicted))
        print(dataset_name, method_name, cls_method, -1, -1, "auc", roc_auc_score(dt_results.actual, dt_results.predicted))
# Out:
# Setting up parameters...
# {'colsample_bytree': 0.8900457400494606, 'learning_rate': 0.0943151977477894, 'max_depth': 19, 'min_child_weight': 4, 'subsample': 0.9715617893959018}
# setting up data...
# Creating logs...
# bucketing prefixes...
# prefix
# Bucket 1 of 40
# sorting bucket...
# number events 937
# choosing classifier...
# fitting pipeline...
# test data shape (937, 18)
# Testing instance 1 of 937
# Testing instance 2 of 937
# Testing instance 3 of 937
# Testing instance 4 of 937
# Testing instance 5 of 937
# Testing instance 6 of 937
# Testing instance 7 of 937
# Testing instance 8 of 937
# Testing instance 9 of 937
# Testing instance 10 of 937
# Testing instance 11 of 937
# Testing instance 12 of 937
# Testing instance 13 of 937
# Testing instance 14 of 937
# Testing instance 15 of 937
# Testing instance 16 of 937
# Testing instance 17 of 937
# Testing instance 18 of 937
# Testing instance 19 of 937
# Testing instance 20 of 937
# Testing instance 21 of 937
# Testing instance 22 of 937
# Testing instance 23 of 937
# Testing instance 24 of 937
# Testing instance 25 of 937
# Testing instance 26 of 937
# Testing instance 27 of 937
# Testing instance 28 of 937
# Testing instance 29 of 937
# Testing instance 30 of 937
# Testing instance 31 of 937
# Testing instance 32 of 937
# Testing instance 33 of 937
# Testing instance 34 of 937
# Testing instance 35 of 937
# Testing instance 36 of 937
# Testing instance 37 of 937
# Testing instance 38 of 937
# Testing instance 39 of 937
# Testing instance 40 of 937
# Testing instance 41 of 937
# Testing instance 42 of 937
# Testing instance 43 of 937
# Testing instance 44 of 937
# Testing instance 45 of 937
# Testing instance 46 of 937
# Testing instance 47 of 937
# Testing instance 48 of 937
# Testing instance 49 of 937
# Testing instance 50 of 937
# Testing instance 51 of 937
# Testing instance 52 of 937
# Testing instance 53 of 937
# Testing instance 54 of 937
# Testing instance 55 of 937
# Testing instance 56 of 937
# Testing instance 57 of 937
# Testing instance 58 of 937
# Testing instance 59 of 937
# Testing instance 60 of 937
# Testing instance 61 of 937
# Testing instance 62 of 937
# Testing instance 63 of 937
# Testing instance 64 of 937
# Testing instance 65 of 937
# Testing instance 66 of 937
# Testing instance 67 of 937
# Testing instance 68 of 937
# Testing instance 69 of 937
# Testing instance 70 of 937
# Testing instance 71 of 937
# Testing instance 72 of 937
# Testing instance 73 of 937
# Testing instance 74 of 937
# Testing instance 75 of 937
# Testing instance 76 of 937
# Testing instance 77 of 937
# Testing instance 78 of 937
# Testing instance 79 of 937
# Testing instance 80 of 937
# Testing instance 81 of 937
# Testing instance 82 of 937
# Testing instance 83 of 937
# Testing instance 84 of 937
# Testing instance 85 of 937
# Testing instance 86 of 937
# Testing instance 87 of 937
# Testing instance 88 of 937
# Testing instance 89 of 937
# Testing instance 90 of 937
# Testing instance 91 of 937
# Testing instance 92 of 937
# Testing instance 93 of 937
# Testing instance 94 of 937
# Testing instance 95 of 937
# Testing instance 96 of 937
# Testing instance 97 of 937
# Testing instance 98 of 937
# Testing instance 99 of 937
# Testing instance 100 of 937
# Testing instance 101 of 937
# Testing instance 102 of 937
# Testing instance 103 of 937
# Testing instance 104 of 937
# Testing instance 105 of 937
# Testing instance 106 of 937
# Testing instance 107 of 937
# Testing instance 108 of 937
# Testing instance 109 of 937
# Testing instance 110 of 937
# Testing instance 111 of 937
# Testing instance 112 of 937
# Testing instance 113 of 937
# Testing instance 114 of 937
# Testing instance 115 of 937
# Testing instance 116 of 937
# Testing instance 117 of 937
# Testing instance 118 of 937
# Testing instance 119 of 937
# Testing instance 120 of 937
# Testing instance 121 of 937
# Testing instance 122 of 937
# Testing instance 123 of 937
# Testing instance 124 of 937
# Testing instance 125 of 937
# Testing instance 126 of 937
# Testing instance 127 of 937
# Testing instance 128 of 937
# Testing instance 129 of 937
# Testing instance 130 of 937
# Testing instance 131 of 937
# Testing instance 132 of 937
# Testing instance 133 of 937
# Testing instance 134 of 937
# Testing instance 135 of 937
# Testing instance 136 of 937
# Testing instance 137 of 937
# Testing instance 138 of 937
# Testing instance 139 of 937
# Testing instance 140 of 937
# Testing instance 141 of 937
# Testing instance 142 of 937
# Testing instance 143 of 937
# Testing instance 144 of 937
# Testing instance 145 of 937
# Testing instance 146 of 937
# Testing instance 147 of 937
# Testing instance 148 of 937
# Testing instance 149 of 937
# Testing instance 150 of 937
# Testing instance 151 of 937
# Testing instance 152 of 937
# Testing instance 153 of 937
# Testing instance 154 of 937
# Testing instance 155 of 937
# Testing instance 156 of 937
# Testing instance 157 of 937
# Testing instance 158 of 937
# Testing instance 159 of 937
# Testing instance 160 of 937
# Testing instance 161 of 937
# Testing instance 162 of 937
# Testing instance 163 of 937
# Testing instance 164 of 937
# Testing instance 165 of 937
# Testing instance 166 of 937
# Testing instance 167 of 937
# Testing instance 168 of 937
# Testing instance 169 of 937
# Testing instance 170 of 937
# Testing instance 171 of 937
# Testing instance 172 of 937
# Testing instance 173 of 937
# Testing instance 174 of 937
# Testing instance 175 of 937
# Testing instance 176 of 937
# Testing instance 177 of 937
# Testing instance 178 of 937
# Testing instance 179 of 937
# Testing instance 180 of 937
# Testing instance 181 of 937
# Testing instance 182 of 937
# Testing instance 183 of 937
# Testing instance 184 of 937
# Testing instance 185 of 937
# Testing instance 186 of 937
# Testing instance 187 of 937
# Testing instance 188 of 937
# Testing instance 189 of 937
# Testing instance 190 of 937
# Testing instance 191 of 937
# Testing instance 192 of 937
# Testing instance 193 of 937
# Testing instance 194 of 937
# Testing instance 195 of 937
# Testing instance 196 of 937
# Testing instance 197 of 937
# Testing instance 198 of 937
# Testing instance 199 of 937
# Testing instance 200 of 937
# Testing instance 201 of 937
# Testing instance 202 of 937
# Testing instance 203 of 937
# Testing instance 204 of 937
# Testing instance 205 of 937
# Testing instance 206 of 937
# Testing instance 207 of 937
# Testing instance 208 of 937
# Testing instance 209 of 937
# Testing instance 210 of 937
# Testing instance 211 of 937
# Testing instance 212 of 937
# Testing instance 213 of 937
# Testing instance 214 of 937
# Testing instance 215 of 937
# Testing instance 216 of 937
# Testing instance 217 of 937
# Testing instance 218 of 937
# Testing instance 219 of 937
# Testing instance 220 of 937
# Testing instance 221 of 937
# Testing instance 222 of 937
# Testing instance 223 of 937
# Testing instance 224 of 937
# Testing instance 225 of 937
# Testing instance 226 of 937
# Testing instance 227 of 937
# Testing instance 228 of 937
# Testing instance 229 of 937
# Testing instance 230 of 937
# Testing instance 231 of 937
# Testing instance 232 of 937
# Testing instance 233 of 937
# Testing instance 234 of 937
# Testing instance 235 of 937
# Testing instance 236 of 937
# Testing instance 237 of 937
# Testing instance 238 of 937
# Testing instance 239 of 937
# Testing instance 240 of 937
# Testing instance 241 of 937
# Testing instance 242 of 937
# Testing instance 243 of 937
# Testing instance 244 of 937
# Testing instance 245 of 937
# Testing instance 246 of 937
# Testing instance 247 of 937
# Testing instance 248 of 937
# Testing instance 249 of 937
# Testing instance 250 of 937
# Testing instance 251 of 937
# Testing instance 252 of 937
# Testing instance 253 of 937
# Testing instance 254 of 937
# Testing instance 255 of 937
# Testing instance 256 of 937
# Testing instance 257 of 937
# Testing instance 258 of 937
# Testing instance 259 of 937
# Testing instance 260 of 937
# Testing instance 261 of 937
# Testing instance 262 of 937
# Testing instance 263 of 937
# Testing instance 264 of 937
# Testing instance 265 of 937
# Testing instance 266 of 937
# Testing instance 267 of 937
# Testing instance 268 of 937
# Testing instance 269 of 937
# Testing instance 270 of 937
# Testing instance 271 of 937
# Testing instance 272 of 937
# Testing instance 273 of 937
# Testing instance 274 of 937
# Testing instance 275 of 937
# Testing instance 276 of 937
# Testing instance 277 of 937
# Testing instance 278 of 937
# Testing instance 279 of 937
# Testing instance 280 of 937
# Testing instance 281 of 937
# Testing instance 282 of 937
# Testing instance 283 of 937
# Testing instance 284 of 937
# Testing instance 285 of 937
# Testing instance 286 of 937
# Testing instance 287 of 937
# Testing instance 288 of 937
# Testing instance 289 of 937
# Testing instance 290 of 937
# Testing instance 291 of 937
# Testing instance 292 of 937
# Testing instance 293 of 937
# Testing instance 294 of 937
# Testing instance 295 of 937
# Testing instance 296 of 937
# Testing instance 297 of 937
# Testing instance 298 of 937
# Testing instance 299 of 937
# Testing instance 300 of 937
# Testing instance 301 of 937
# Testing instance 302 of 937
# Testing instance 303 of 937
# Testing instance 304 of 937
# Testing instance 305 of 937
# Testing instance 306 of 937
# Testing instance 307 of 937
# Testing instance 308 of 937
# Testing instance 309 of 937
# Testing instance 310 of 937
# Testing instance 311 of 937
# Testing instance 312 of 937
# Testing instance 313 of 937
# Testing instance 314 of 937
# Testing instance 315 of 937
# Testing instance 316 of 937
# Testing instance 317 of 937
# Testing instance 318 of 937
# Testing instance 319 of 937
# Testing instance 320 of 937
# Testing instance 321 of 937
# Testing instance 322 of 937
# Testing instance 323 of 937
# Testing instance 324 of 937
# Testing instance 325 of 937
# Testing instance 326 of 937
# Testing instance 327 of 937
# Testing instance 328 of 937
# Testing instance 329 of 937
# Testing instance 330 of 937
# Testing instance 331 of 937
# Testing instance 332 of 937
# Testing instance 333 of 937
# Testing instance 334 of 937
# Testing instance 335 of 937
# Testing instance 336 of 937
# Testing instance 337 of 937
# Testing instance 338 of 937
# Testing instance 339 of 937
# Testing instance 340 of 937
# Testing instance 341 of 937
# Testing instance 342 of 937
# Testing instance 343 of 937
# Testing instance 344 of 937
# Testing instance 345 of 937
# Testing instance 346 of 937
# Testing instance 347 of 937
# Testing instance 348 of 937
# Testing instance 349 of 937
# Testing instance 350 of 937
# Testing instance 351 of 937
# Testing instance 352 of 937
# Testing instance 353 of 937
# Testing instance 354 of 937
# Testing instance 355 of 937
# Testing instance 356 of 937
# Testing instance 357 of 937
# Testing instance 358 of 937
# Testing instance 359 of 937
# Testing instance 360 of 937
# Testing instance 361 of 937
# Testing instance 362 of 937
# Testing instance 363 of 937
# Testing instance 364 of 937
# Testing instance 365 of 937
# Testing instance 366 of 937
# Testing instance 367 of 937
# Testing instance 368 of 937
# Testing instance 369 of 937
# Testing instance 370 of 937
# Testing instance 371 of 937
# Testing instance 372 of 937
# Testing instance 373 of 937
# Testing instance 374 of 937
# Testing instance 375 of 937
# Testing instance 376 of 937
# Testing instance 377 of 937
# Testing instance 378 of 937
# Testing instance 379 of 937
# Testing instance 380 of 937
# Testing instance 381 of 937
# Testing instance 382 of 937
# Testing instance 383 of 937
# Testing instance 384 of 937
# Testing instance 385 of 937
# Testing instance 386 of 937
# Testing instance 387 of 937
# Testing instance 388 of 937
# Testing instance 389 of 937
# Testing instance 390 of 937
# Testing instance 391 of 937
# Testing instance 392 of 937
# Testing instance 393 of 937
# Testing instance 394 of 937
# Testing instance 395 of 937
# Testing instance 396 of 937
# Testing instance 397 of 937
# Testing instance 398 of 937
# Testing instance 399 of 937
# Testing instance 400 of 937
# Testing instance 401 of 937
# Testing instance 402 of 937
# Testing instance 403 of 937
# Testing instance 404 of 937
# Testing instance 405 of 937
# Testing instance 406 of 937
# Testing instance 407 of 937
# Testing instance 408 of 937
# Testing instance 409 of 937
# Testing instance 410 of 937
# Testing instance 411 of 937
# Testing instance 412 of 937
# Testing instance 413 of 937
# Testing instance 414 of 937
# Testing instance 415 of 937
# Testing instance 416 of 937
# Testing instance 417 of 937
# Testing instance 418 of 937
# Testing instance 419 of 937
# Testing instance 420 of 937
# Testing instance 421 of 937
# Testing instance 422 of 937
# Testing instance 423 of 937
# Testing instance 424 of 937
# Testing instance 425 of 937
# Testing instance 426 of 937
# Testing instance 427 of 937
# Testing instance 428 of 937
# Testing instance 429 of 937
# Testing instance 430 of 937
# Testing instance 431 of 937
# Testing instance 432 of 937
# Testing instance 433 of 937
# Testing instance 434 of 937
# Testing instance 435 of 937
# Testing instance 436 of 937
# Testing instance 437 of 937
# Testing instance 438 of 937
# Testing instance 439 of 937
# Testing instance 440 of 937
# Testing instance 441 of 937
# Testing instance 442 of 937
# Testing instance 443 of 937
# Testing instance 444 of 937
# Testing instance 445 of 937
# Testing instance 446 of 937
# Testing instance 447 of 937
# Testing instance 448 of 937
# Testing instance 449 of 937
# Testing instance 450 of 937
# Testing instance 451 of 937
# Testing instance 452 of 937
# Testing instance 453 of 937
# Testing instance 454 of 937
# Testing instance 455 of 937
# Testing instance 456 of 937
# Testing instance 457 of 937
# Testing instance 458 of 937
# Testing instance 459 of 937
# Testing instance 460 of 937
# Testing instance 461 of 937
# Testing instance 462 of 937
# Testing instance 463 of 937
# Testing instance 464 of 937
# Testing instance 465 of 937
# Testing instance 466 of 937
# Testing instance 467 of 937
# Testing instance 468 of 937
# Testing instance 469 of 937
# Testing instance 470 of 937
# Testing instance 471 of 937
# Testing instance 472 of 937
# Testing instance 473 of 937
# Testing instance 474 of 937
# Testing instance 475 of 937
# Testing instance 476 of 937
# Testing instance 477 of 937
# Testing instance 478 of 937
# Testing instance 479 of 937
# Testing instance 480 of 937
# Testing instance 481 of 937
# Testing instance 482 of 937
# Testing instance 483 of 937
# Testing instance 484 of 937
# Testing instance 485 of 937
# Testing instance 486 of 937
# Testing instance 487 of 937
# Testing instance 488 of 937
# Testing instance 489 of 937
# Testing instance 490 of 937
# Testing instance 491 of 937
# Testing instance 492 of 937
# Testing instance 493 of 937
# Testing instance 494 of 937
# Testing instance 495 of 937
# Testing instance 496 of 937
# Testing instance 497 of 937
# Testing instance 498 of 937
# Testing instance 499 of 937
# Testing instance 500 of 937
# Testing instance 501 of 937
# Testing instance 502 of 937
# Testing instance 503 of 937
# Testing instance 504 of 937
# Testing instance 505 of 937
# Testing instance 506 of 937
# Testing instance 507 of 937
# Testing instance 508 of 937
# Testing instance 509 of 937
# Testing instance 510 of 937
# Testing instance 511 of 937
# Testing instance 512 of 937
# Testing instance 513 of 937
# Testing instance 514 of 937
# Testing instance 515 of 937
# Testing instance 516 of 937
# Testing instance 517 of 937
# Testing instance 518 of 937
# Testing instance 519 of 937
# Testing instance 520 of 937
# Testing instance 521 of 937
# Testing instance 522 of 937
# Testing instance 523 of 937
# Testing instance 524 of 937
# Testing instance 525 of 937
# Testing instance 526 of 937
# Testing instance 527 of 937
# Testing instance 528 of 937
# Testing instance 529 of 937
# Testing instance 530 of 937
# Testing instance 531 of 937
# Testing instance 532 of 937
# Testing instance 533 of 937
# Testing instance 534 of 937
# Testing instance 535 of 937
# Testing instance 536 of 937
# Testing instance 537 of 937
# Testing instance 538 of 937
# Testing instance 539 of 937
# Testing instance 540 of 937
# Testing instance 541 of 937
# Testing instance 542 of 937
# Testing instance 543 of 937
# Testing instance 544 of 937
# Testing instance 545 of 937
# Testing instance 546 of 937
# Testing instance 547 of 937
# Testing instance 548 of 937
# Testing instance 549 of 937
# Testing instance 550 of 937
# Testing instance 551 of 937
# Testing instance 552 of 937
# Testing instance 553 of 937
# Testing instance 554 of 937
# Testing instance 555 of 937
# Testing instance 556 of 937
# Testing instance 557 of 937
# Testing instance 558 of 937
# Testing instance 559 of 937
# Testing instance 560 of 937
# Testing instance 561 of 937
# Testing instance 562 of 937
# Testing instance 563 of 937
# Testing instance 564 of 937
# Testing instance 565 of 937
# Testing instance 566 of 937
# Testing instance 567 of 937
# Testing instance 568 of 937
# Testing instance 569 of 937
# Testing instance 570 of 937
# Testing instance 571 of 937
# Testing instance 572 of 937
# Testing instance 573 of 937
# Testing instance 574 of 937
# Testing instance 575 of 937
# Testing instance 576 of 937
# Testing instance 577 of 937
# Testing instance 578 of 937
# Testing instance 579 of 937
# Testing instance 580 of 937
# Testing instance 581 of 937
# Testing instance 582 of 937
# Testing instance 583 of 937
# Testing instance 584 of 937
# Testing instance 585 of 937
# Testing instance 586 of 937
# Testing instance 587 of 937
# Testing instance 588 of 937
# Testing instance 589 of 937
# Testing instance 590 of 937
# Testing instance 591 of 937
# Testing instance 592 of 937
# Testing instance 593 of 937
# Testing instance 594 of 937
# Testing instance 595 of 937
# Testing instance 596 of 937
# Testing instance 597 of 937
# Testing instance 598 of 937
# Testing instance 599 of 937
# Testing instance 600 of 937
# Testing instance 601 of 937
# Testing instance 602 of 937
# Testing instance 603 of 937
# Testing instance 604 of 937
# Testing instance 605 of 937
# Testing instance 606 of 937
# Testing instance 607 of 937
# Testing instance 608 of 937
# Testing instance 609 of 937
# Testing instance 610 of 937
# Testing instance 611 of 937
# Testing instance 612 of 937
# Testing instance 613 of 937
# Testing instance 614 of 937
# Testing instance 615 of 937
# Testing instance 616 of 937
# Testing instance 617 of 937
# Testing instance 618 of 937
# Testing instance 619 of 937
# Testing instance 620 of 937
# Testing instance 621 of 937
# Testing instance 622 of 937
# Testing instance 623 of 937
# Testing instance 624 of 937
# Testing instance 625 of 937
# Testing instance 626 of 937
# Testing instance 627 of 937
# Testing instance 628 of 937
# Testing instance 629 of 937
# Testing instance 630 of 937
# Testing instance 631 of 937
# Testing instance 632 of 937
# Testing instance 633 of 937
# Testing instance 634 of 937
# Testing instance 635 of 937
# Testing instance 636 of 937
# Testing instance 637 of 937
# Testing instance 638 of 937
# Testing instance 639 of 937
# Testing instance 640 of 937
# Testing instance 641 of 937
# Testing instance 642 of 937
# Testing instance 643 of 937
# Testing instance 644 of 937
# Testing instance 645 of 937
# Testing instance 646 of 937
# Testing instance 647 of 937
# Testing instance 648 of 937
# Testing instance 649 of 937
# Testing instance 650 of 937
# Testing instance 651 of 937
# Testing instance 652 of 937
# Testing instance 653 of 937
# Testing instance 654 of 937
# Testing instance 655 of 937
# Testing instance 656 of 937
# Testing instance 657 of 937
# Testing instance 658 of 937
# Testing instance 659 of 937
# Testing instance 660 of 937
# Testing instance 661 of 937
# Testing instance 662 of 937
# Testing instance 663 of 937
# Testing instance 664 of 937
# Testing instance 665 of 937
# Testing instance 666 of 937
# Testing instance 667 of 937
# Testing instance 668 of 937
# Testing instance 669 of 937
# Testing instance 670 of 937
# Testing instance 671 of 937
# Testing instance 672 of 937
# Testing instance 673 of 937
# Testing instance 674 of 937
# Testing instance 675 of 937
# Testing instance 676 of 937
# Testing instance 677 of 937
# Testing instance 678 of 937
# Testing instance 679 of 937
# Testing instance 680 of 937
# Testing instance 681 of 937
# Testing instance 682 of 937
# Testing instance 683 of 937
# Testing instance 684 of 937
# Testing instance 685 of 937
# Testing instance 686 of 937
# Testing instance 687 of 937
# Testing instance 688 of 937
# Testing instance 689 of 937
# Testing instance 690 of 937
# Testing instance 691 of 937
# Testing instance 692 of 937
# Testing instance 693 of 937
# Testing instance 694 of 937
# Testing instance 695 of 937
# Testing instance 696 of 937
# Testing instance 697 of 937
# Testing instance 698 of 937
# Testing instance 699 of 937
# Testing instance 700 of 937
# Testing instance 701 of 937
# Testing instance 702 of 937
# Testing instance 703 of 937
# Testing instance 704 of 937
# Testing instance 705 of 937
# Testing instance 706 of 937
# Testing instance 707 of 937
# Testing instance 708 of 937
# Testing instance 709 of 937
# Testing instance 710 of 937
# Testing instance 711 of 937
# Testing instance 712 of 937
# Testing instance 713 of 937
# Testing instance 714 of 937
# Testing instance 715 of 937
# Testing instance 716 of 937
# Testing instance 717 of 937
# Testing instance 718 of 937
# Testing instance 719 of 937
# Testing instance 720 of 937
# Testing instance 721 of 937
# Testing instance 722 of 937
# Testing instance 723 of 937
# Testing instance 724 of 937
# Testing instance 725 of 937
# Testing instance 726 of 937
# Testing instance 727 of 937
# Testing instance 728 of 937
# Testing instance 729 of 937
# Testing instance 730 of 937
# Testing instance 731 of 937
# Testing instance 732 of 937
# Testing instance 733 of 937
# Testing instance 734 of 937
# Testing instance 735 of 937
# Testing instance 736 of 937
# Testing instance 737 of 937
# Testing instance 738 of 937
# Testing instance 739 of 937
# Testing instance 740 of 937
# Testing instance 741 of 937
# Testing instance 742 of 937
# Testing instance 743 of 937
# Testing instance 744 of 937
# Testing instance 745 of 937
# Testing instance 746 of 937
# Testing instance 747 of 937
# Testing instance 748 of 937
# Testing instance 749 of 937
# Testing instance 750 of 937
# Testing instance 751 of 937
# Testing instance 752 of 937
# Testing instance 753 of 937
# Testing instance 754 of 937
# Testing instance 755 of 937
# Testing instance 756 of 937
# Testing instance 757 of 937
# Testing instance 758 of 937
# Testing instance 759 of 937
# Testing instance 760 of 937
# Testing instance 761 of 937
# Testing instance 762 of 937
# Testing instance 763 of 937
# Testing instance 764 of 937
# Testing instance 765 of 937
# Testing instance 766 of 937
# Testing instance 767 of 937
# Testing instance 768 of 937
# Testing instance 769 of 937
# Testing instance 770 of 937
# Testing instance 771 of 937
# Testing instance 772 of 937
# Testing instance 773 of 937
# Testing instance 774 of 937
# Testing instance 775 of 937
# Testing instance 776 of 937
# Testing instance 777 of 937
# Testing instance 778 of 937
# Testing instance 779 of 937
# Testing instance 780 of 937
# Testing instance 781 of 937
# Testing instance 782 of 937
# Testing instance 783 of 937
# Testing instance 784 of 937
# Testing instance 785 of 937
# Testing instance 786 of 937
# Testing instance 787 of 937
# Testing instance 788 of 937
# Testing instance 789 of 937
# Testing instance 790 of 937
# Testing instance 791 of 937
# Testing instance 792 of 937
# Testing instance 793 of 937
# Testing instance 794 of 937
# Testing instance 795 of 937
# Testing instance 796 of 937
# Testing instance 797 of 937
# Testing instance 798 of 937
# Testing instance 799 of 937
# Testing instance 800 of 937
# Testing instance 801 of 937
# Testing instance 802 of 937
# Testing instance 803 of 937
# Testing instance 804 of 937
# Testing instance 805 of 937
# Testing instance 806 of 937
# Testing instance 807 of 937
# Testing instance 808 of 937
# Testing instance 809 of 937
# Testing instance 810 of 937
# Testing instance 811 of 937
# Testing instance 812 of 937
# Testing instance 813 of 937
# Testing instance 814 of 937
# Testing instance 815 of 937
# Testing instance 816 of 937
# Testing instance 817 of 937
# Testing instance 818 of 937
# Testing instance 819 of 937
# Testing instance 820 of 937
# Testing instance 821 of 937
# Testing instance 822 of 937
# Testing instance 823 of 937
# Testing instance 824 of 937
# Testing instance 825 of 937
# Testing instance 826 of 937
# Testing instance 827 of 937
# Testing instance 828 of 937
# Testing instance 829 of 937
# Testing instance 830 of 937
# Testing instance 831 of 937
# Testing instance 832 of 937
# Testing instance 833 of 937
# Testing instance 834 of 937
# Testing instance 835 of 937
# Testing instance 836 of 937
# Testing instance 837 of 937
# Testing instance 838 of 937
# Testing instance 839 of 937
# Testing instance 840 of 937
# Testing instance 841 of 937
# Testing instance 842 of 937
# Testing instance 843 of 937
# Testing instance 844 of 937
# Testing instance 845 of 937
# Testing instance 846 of 937
# Testing instance 847 of 937
# Testing instance 848 of 937
# Testing instance 849 of 937
# Testing instance 850 of 937
# Testing instance 851 of 937
# Testing instance 852 of 937
# Testing instance 853 of 937
# Testing instance 854 of 937
# Testing instance 855 of 937
# Testing instance 856 of 937
# Testing instance 857 of 937
# Testing instance 858 of 937
# Testing instance 859 of 937
# Testing instance 860 of 937
# Testing instance 861 of 937
# Testing instance 862 of 937
# Testing instance 863 of 937
# Testing instance 864 of 937
# Testing instance 865 of 937
# Testing instance 866 of 937
# Testing instance 867 of 937
# Testing instance 868 of 937
# Testing instance 869 of 937
# Testing instance 870 of 937
# Testing instance 871 of 937
# Testing instance 872 of 937
# Testing instance 873 of 937
# Testing instance 874 of 937
# Testing instance 875 of 937
# Testing instance 876 of 937
# Testing instance 877 of 937
# Testing instance 878 of 937
# Testing instance 879 of 937
# Testing instance 880 of 937
# Testing instance 881 of 937
# Testing instance 882 of 937
# Testing instance 883 of 937
# Testing instance 884 of 937
# Testing instance 885 of 937
# Testing instance 886 of 937
# Testing instance 887 of 937
# Testing instance 888 of 937
# Testing instance 889 of 937
# Testing instance 890 of 937
# Testing instance 891 of 937
# Testing instance 892 of 937
# Testing instance 893 of 937
# Testing instance 894 of 937
# Testing instance 895 of 937
# Testing instance 896 of 937
# Testing instance 897 of 937
# Testing instance 898 of 937
# Testing instance 899 of 937
# Testing instance 900 of 937
# Testing instance 901 of 937
# Testing instance 902 of 937
# Testing instance 903 of 937
# Testing instance 904 of 937
# Testing instance 905 of 937
# Testing instance 906 of 937
# Testing instance 907 of 937
# Testing instance 908 of 937
# Testing instance 909 of 937
# Testing instance 910 of 937
# Testing instance 911 of 937
# Testing instance 912 of 937
# Testing instance 913 of 937
# Testing instance 914 of 937
# Testing instance 915 of 937
# Testing instance 916 of 937
# Testing instance 917 of 937
# Testing instance 918 of 937
# Testing instance 919 of 937
# Testing instance 920 of 937
# Testing instance 921 of 937
# Testing instance 922 of 937
# Testing instance 923 of 937
# Testing instance 924 of 937
# Testing instance 925 of 937
# Testing instance 926 of 937
# Testing instance 927 of 937
# Testing instance 928 of 937
# Testing instance 929 of 937
# Testing instance 930 of 937
# Testing instance 931 of 937
# Testing instance 932 of 937
# Testing instance 933 of 937
# Testing instance 934 of 937
# Testing instance 935 of 937
# Testing instance 936 of 937
# Testing instance 937 of 937
# Saving models...
# saving data...
# Bucket 2 of 40
# sorting bucket...
# number events 1874
# choosing classifier...
# fitting pipeline...
# test data shape (1874, 18)
# Testing instance 1 of 937
# Testing instance 2 of 937
# Testing instance 3 of 937
# Testing instance 4 of 937
# Testing instance 5 of 937
# Testing instance 6 of 937
# Testing instance 7 of 937
# Testing instance 8 of 937
# Testing instance 9 of 937
# Testing instance 10 of 937
# Testing instance 11 of 937
# Testing instance 12 of 937
# Testing instance 13 of 937
# Testing instance 14 of 937
# Testing instance 15 of 937
# Testing instance 16 of 937
# Testing instance 17 of 937
# Testing instance 18 of 937
# Testing instance 19 of 937
# Testing instance 20 of 937
# Testing instance 21 of 937
# Testing instance 22 of 937
# Testing instance 23 of 937
# Testing instance 24 of 937
# Testing instance 25 of 937
# Testing instance 26 of 937
# Testing instance 27 of 937
# Testing instance 28 of 937
# Testing instance 29 of 937
# Testing instance 30 of 937
# Testing instance 31 of 937
# Testing instance 32 of 937
# Testing instance 33 of 937
# Testing instance 34 of 937
# Testing instance 35 of 937
# Testing instance 36 of 937
# Testing instance 37 of 937
# Testing instance 38 of 937
# Testing instance 39 of 937
# Testing instance 40 of 937
# Testing instance 41 of 937
# Testing instance 42 of 937
# Testing instance 43 of 937
# Testing instance 44 of 937
# Testing instance 45 of 937
# Testing instance 46 of 937
# Testing instance 47 of 937
# Testing instance 48 of 937
# Testing instance 49 of 937
# Testing instance 50 of 937
# Testing instance 51 of 937
# Testing instance 52 of 937
# Testing instance 53 of 937
# Testing instance 54 of 937
# Testing instance 55 of 937
# Testing instance 56 of 937
# Testing instance 57 of 937
# Testing instance 58 of 937
# Testing instance 59 of 937
# Testing instance 60 of 937
# Testing instance 61 of 937
# Testing instance 62 of 937
# Testing instance 63 of 937
# Testing instance 64 of 937
# Testing instance 65 of 937
# Testing instance 66 of 937
# Testing instance 67 of 937
# Testing instance 68 of 937
# Testing instance 69 of 937
# Testing instance 70 of 937
# Testing instance 71 of 937
# Testing instance 72 of 937
# Testing instance 73 of 937
# Testing instance 74 of 937
# Testing instance 75 of 937
# Testing instance 76 of 937
# Testing instance 77 of 937
# Testing instance 78 of 937
# Testing instance 79 of 937
# Testing instance 80 of 937
# Testing instance 81 of 937
# Testing instance 82 of 937
# Testing instance 83 of 937
# Testing instance 84 of 937
# Testing instance 85 of 937
# Testing instance 86 of 937
# Testing instance 87 of 937
# Testing instance 88 of 937
# Testing instance 89 of 937
# Testing instance 90 of 937
# Testing instance 91 of 937
# Testing instance 92 of 937
# Testing instance 93 of 937
# Testing instance 94 of 937
# Testing instance 95 of 937
# Testing instance 96 of 937
# Testing instance 97 of 937
# Testing instance 98 of 937
# Testing instance 99 of 937
# Testing instance 100 of 937
# Testing instance 101 of 937
# Testing instance 102 of 937
# Testing instance 103 of 937
# Testing instance 104 of 937
# Testing instance 105 of 937
# Testing instance 106 of 937
# Testing instance 107 of 937
# Testing instance 108 of 937
# Testing instance 109 of 937
# Testing instance 110 of 937
# Testing instance 111 of 937
# Testing instance 112 of 937
# Testing instance 113 of 937
# Testing instance 114 of 937
# Testing instance 115 of 937
# Testing instance 116 of 937
# Testing instance 117 of 937
# Testing instance 118 of 937
# Testing instance 119 of 937
# Testing instance 120 of 937
# Testing instance 121 of 937
# Testing instance 122 of 937
# Testing instance 123 of 937
# Testing instance 124 of 937
# Testing instance 125 of 937
# Testing instance 126 of 937
# Testing instance 127 of 937
# Testing instance 128 of 937
# Testing instance 129 of 937
# Testing instance 130 of 937
# Testing instance 131 of 937
# Testing instance 132 of 937
# Testing instance 133 of 937
# Testing instance 134 of 937
# Testing instance 135 of 937
# Testing instance 136 of 937
# Testing instance 137 of 937
# Testing instance 138 of 937
# Testing instance 139 of 937
# Testing instance 140 of 937
# Testing instance 141 of 937
# Testing instance 142 of 937
# Testing instance 143 of 937
# Testing instance 144 of 937
# Testing instance 145 of 937
# Testing instance 146 of 937
# Testing instance 147 of 937
# Testing instance 148 of 937
# Testing instance 149 of 937
# Testing instance 150 of 937
# Testing instance 151 of 937
# Testing instance 152 of 937
# Testing instance 153 of 937
# Testing instance 154 of 937
# Testing instance 155 of 937
# Testing instance 156 of 937
# Testing instance 157 of 937
# Testing instance 158 of 937
# Testing instance 159 of 937
# Testing instance 160 of 937
# Testing instance 161 of 937
# Testing instance 162 of 937
# Testing instance 163 of 937
# Testing instance 164 of 937
# Testing instance 165 of 937
# Testing instance 166 of 937
# Testing instance 167 of 937
# Testing instance 168 of 937
# Testing instance 169 of 937
# Testing instance 170 of 937
# Testing instance 171 of 937
# Testing instance 172 of 937
# Testing instance 173 of 937
# Testing instance 174 of 937
# Testing instance 175 of 937
# Testing instance 176 of 937
# Testing instance 177 of 937
# Testing instance 178 of 937
# Testing instance 179 of 937
# Testing instance 180 of 937
# Testing instance 181 of 937
# Testing instance 182 of 937
# Testing instance 183 of 937
# Testing instance 184 of 937
# Testing instance 185 of 937
# Testing instance 186 of 937
# Testing instance 187 of 937
# Testing instance 188 of 937
# Testing instance 189 of 937
# Testing instance 190 of 937
# Testing instance 191 of 937
# Testing instance 192 of 937
# Testing instance 193 of 937
# Testing instance 194 of 937
# Testing instance 195 of 937
# Testing instance 196 of 937
# Testing instance 197 of 937
# Testing instance 198 of 937
# Testing instance 199 of 937
# Testing instance 200 of 937
# Testing instance 201 of 937
# Testing instance 202 of 937
# Testing instance 203 of 937
# Testing instance 204 of 937
# Testing instance 205 of 937
# Testing instance 206 of 937
# Testing instance 207 of 937
# Testing instance 208 of 937
# Testing instance 209 of 937
# Testing instance 210 of 937
# Testing instance 211 of 937
# Testing instance 212 of 937
# Testing instance 213 of 937
# Testing instance 214 of 937
# Testing instance 215 of 937
# Testing instance 216 of 937
# Testing instance 217 of 937
# Testing instance 218 of 937
# Testing instance 219 of 937
# Testing instance 220 of 937
# Testing instance 221 of 937
# Testing instance 222 of 937
# Testing instance 223 of 937
# Testing instance 224 of 937
# Testing instance 225 of 937
# Testing instance 226 of 937
# Testing instance 227 of 937
# Testing instance 228 of 937
# Testing instance 229 of 937
# Testing instance 230 of 937
# Testing instance 231 of 937
# Testing instance 232 of 937
# Testing instance 233 of 937
# Testing instance 234 of 937
# Testing instance 235 of 937
# Testing instance 236 of 937
# Testing instance 237 of 937
# Testing instance 238 of 937
# Testing instance 239 of 937
# Testing instance 240 of 937
# Testing instance 241 of 937
# Testing instance 242 of 937
# Testing instance 243 of 937
# Testing instance 244 of 937
# Testing instance 245 of 937
# Testing instance 246 of 937
# Testing instance 247 of 937
# Testing instance 248 of 937
# Testing instance 249 of 937
# Testing instance 250 of 937
# Testing instance 251 of 937
# Testing instance 252 of 937
# Testing instance 253 of 937
# Testing instance 254 of 937
# Testing instance 255 of 937
# Testing instance 256 of 937
# Testing instance 257 of 937
# Testing instance 258 of 937
# Testing instance 259 of 937
# Testing instance 260 of 937
# Testing instance 261 of 937
# Testing instance 262 of 937
# Testing instance 263 of 937
# Testing instance 264 of 937
# Testing instance 265 of 937
# Testing instance 266 of 937
# Testing instance 267 of 937
# Testing instance 268 of 937
# Testing instance 269 of 937
# Testing instance 270 of 937
# Testing instance 271 of 937
# Testing instance 272 of 937
# Testing instance 273 of 937
# Testing instance 274 of 937
# Testing instance 275 of 937
# Testing instance 276 of 937
# Testing instance 277 of 937
# Testing instance 278 of 937
# Testing instance 279 of 937
# Testing instance 280 of 937
# Testing instance 281 of 937
# Testing instance 282 of 937
# Testing instance 283 of 937
# Testing instance 284 of 937
# Testing instance 285 of 937
# Testing instance 286 of 937
# Testing instance 287 of 937
# Testing instance 288 of 937
# Testing instance 289 of 937
# Testing instance 290 of 937
# Testing instance 291 of 937
# Testing instance 292 of 937
# Testing instance 293 of 937
# Testing instance 294 of 937
# Testing instance 295 of 937
# Testing instance 296 of 937
# Testing instance 297 of 937
# Testing instance 298 of 937
# Testing instance 299 of 937
# Testing instance 300 of 937
# Testing instance 301 of 937
# Testing instance 302 of 937
# Testing instance 303 of 937
# Testing instance 304 of 937
# Testing instance 305 of 937
# Testing instance 306 of 937
# Testing instance 307 of 937
# Testing instance 308 of 937
# Testing instance 309 of 937
# Testing instance 310 of 937
# Testing instance 311 of 937
# Testing instance 312 of 937
# Testing instance 313 of 937
# Testing instance 314 of 937
# Testing instance 315 of 937
# Testing instance 316 of 937
# Testing instance 317 of 937
# Testing instance 318 of 937
# Testing instance 319 of 937
# Testing instance 320 of 937
# Testing instance 321 of 937
# Testing instance 322 of 937
# Testing instance 323 of 937
# Testing instance 324 of 937
# Testing instance 325 of 937
# Testing instance 326 of 937
# Testing instance 327 of 937
# Testing instance 328 of 937
# Testing instance 329 of 937
# Testing instance 330 of 937
# Testing instance 331 of 937
# Testing instance 332 of 937
# Testing instance 333 of 937
# Testing instance 334 of 937
# Testing instance 335 of 937
# Testing instance 336 of 937
# Testing instance 337 of 937
# Testing instance 338 of 937
# Testing instance 339 of 937
# Testing instance 340 of 937
# Testing instance 341 of 937
# Testing instance 342 of 937
# Testing instance 343 of 937
# Testing instance 344 of 937
# Testing instance 345 of 937
# Testing instance 346 of 937
# Testing instance 347 of 937
# Testing instance 348 of 937
# Testing instance 349 of 937
# Testing instance 350 of 937
# Testing instance 351 of 937
# Testing instance 352 of 937
# Testing instance 353 of 937
# Testing instance 354 of 937
# Testing instance 355 of 937
# Testing instance 356 of 937
# Testing instance 357 of 937
# Testing instance 358 of 937
# Testing instance 359 of 937
# Testing instance 360 of 937
# Testing instance 361 of 937
# Testing instance 362 of 937
# Testing instance 363 of 937
# Testing instance 364 of 937
# Testing instance 365 of 937
# Testing instance 366 of 937
# Testing instance 367 of 937
# Testing instance 368 of 937
# Testing instance 369 of 937
# Testing instance 370 of 937
# Testing instance 371 of 937
# Testing instance 372 of 937
# Testing instance 373 of 937
# Testing instance 374 of 937
# Testing instance 375 of 937
# Testing instance 376 of 937
# Testing instance 377 of 937
# Testing instance 378 of 937
# Testing instance 379 of 937
# Testing instance 380 of 937
# Testing instance 381 of 937
# Testing instance 382 of 937
# Testing instance 383 of 937
# Testing instance 384 of 937
# Testing instance 385 of 937
# Testing instance 386 of 937
# Testing instance 387 of 937
# Testing instance 388 of 937
# Testing instance 389 of 937
# Testing instance 390 of 937
# Testing instance 391 of 937
# Testing instance 392 of 937
# Testing instance 393 of 937
# Testing instance 394 of 937
# Testing instance 395 of 937
# Testing instance 396 of 937
# Testing instance 397 of 937
# Testing instance 398 of 937
# Testing instance 399 of 937
# Testing instance 400 of 937
# Testing instance 401 of 937
# Testing instance 402 of 937
# Testing instance 403 of 937
# Testing instance 404 of 937
# Testing instance 405 of 937
# Testing instance 406 of 937
# Testing instance 407 of 937
# Testing instance 408 of 937
# Testing instance 409 of 937
# Testing instance 410 of 937
# Testing instance 411 of 937
# Testing instance 412 of 937
# Testing instance 413 of 937
# Testing instance 414 of 937
# Testing instance 415 of 937
# Testing instance 416 of 937
# Testing instance 417 of 937
# Testing instance 418 of 937
# Testing instance 419 of 937
# Testing instance 420 of 937
# Testing instance 421 of 937
# Testing instance 422 of 937
# Testing instance 423 of 937
# Testing instance 424 of 937
# Testing instance 425 of 937
# Testing instance 426 of 937
# Testing instance 427 of 937
# Testing instance 428 of 937
# Testing instance 429 of 937
# Testing instance 430 of 937
# Testing instance 431 of 937
# Testing instance 432 of 937
# Testing instance 433 of 937
# Testing instance 434 of 937
# Testing instance 435 of 937
# Testing instance 436 of 937
# Testing instance 437 of 937
# Testing instance 438 of 937
# Testing instance 439 of 937
# Testing instance 440 of 937
# Testing instance 441 of 937
# Testing instance 442 of 937
# Testing instance 443 of 937
# Testing instance 444 of 937
# Testing instance 445 of 937
# Testing instance 446 of 937
# Testing instance 447 of 937
# Testing instance 448 of 937
# Testing instance 449 of 937
# Testing instance 450 of 937
# Testing instance 451 of 937
# Testing instance 452 of 937
# Testing instance 453 of 937
# Testing instance 454 of 937
# Testing instance 455 of 937
# Testing instance 456 of 937
# Testing instance 457 of 937
# Testing instance 458 of 937
# Testing instance 459 of 937
# Testing instance 460 of 937
# Testing instance 461 of 937
# Testing instance 462 of 937
# Testing instance 463 of 937
# Testing instance 464 of 937
# Testing instance 465 of 937
# Testing instance 466 of 937
# Testing instance 467 of 937
# Testing instance 468 of 937
# Testing instance 469 of 937
# Testing instance 470 of 937
# Testing instance 471 of 937
# Testing instance 472 of 937
# Testing instance 473 of 937
# Testing instance 474 of 937
# Testing instance 475 of 937
# Testing instance 476 of 937
# Testing instance 477 of 937
# Testing instance 478 of 937
# Testing instance 479 of 937
# Testing instance 480 of 937
# Testing instance 481 of 937
# Testing instance 482 of 937
# Testing instance 483 of 937
# Testing instance 484 of 937
# Testing instance 485 of 937
# Testing instance 486 of 937
# Testing instance 487 of 937
# Testing instance 488 of 937
# Testing instance 489 of 937
# Testing instance 490 of 937
# Testing instance 491 of 937
# Testing instance 492 of 937
# Testing instance 493 of 937
# Testing instance 494 of 937
# Testing instance 495 of 937
# Testing instance 496 of 937
# Testing instance 497 of 937
# Testing instance 498 of 937
# Testing instance 499 of 937
# Testing instance 500 of 937
# Testing instance 501 of 937
# Testing instance 502 of 937
# Testing instance 503 of 937
# Testing instance 504 of 937
# Testing instance 505 of 937
# Testing instance 506 of 937
# Testing instance 507 of 937
# Testing instance 508 of 937
# Testing instance 509 of 937
# Testing instance 510 of 937
# Testing instance 511 of 937
# Testing instance 512 of 937
# Testing instance 513 of 937
# Testing instance 514 of 937
# Testing instance 515 of 937
# Testing instance 516 of 937
# Testing instance 517 of 937
# Testing instance 518 of 937
# Testing instance 519 of 937
# Testing instance 520 of 937
# Testing instance 521 of 937
# Testing instance 522 of 937
# Testing instance 523 of 937
# Testing instance 524 of 937
# Testing instance 525 of 937
# Testing instance 526 of 937
# Testing instance 527 of 937
# Testing instance 528 of 937
# Testing instance 529 of 937
# Testing instance 530 of 937
# Testing instance 531 of 937
# Testing instance 532 of 937
# Testing instance 533 of 937
# Testing instance 534 of 937
# Testing instance 535 of 937
# Testing instance 536 of 937
# Testing instance 537 of 937
# Testing instance 538 of 937
# Testing instance 539 of 937
# Testing instance 540 of 937
# Testing instance 541 of 937
# Testing instance 542 of 937
# Testing instance 543 of 937
# Testing instance 544 of 937
# Testing instance 545 of 937
# Testing instance 546 of 937
# Testing instance 547 of 937
# Testing instance 548 of 937
# Testing instance 549 of 937
# Testing instance 550 of 937
# Testing instance 551 of 937
# Testing instance 552 of 937
# Testing instance 553 of 937
# Testing instance 554 of 937
# Testing instance 555 of 937
# Testing instance 556 of 937
# Testing instance 557 of 937
# Testing instance 558 of 937
# Testing instance 559 of 937
# Testing instance 560 of 937
# Testing instance 561 of 937
# Testing instance 562 of 937
# Testing instance 563 of 937
# Testing instance 564 of 937
# Testing instance 565 of 937
# Testing instance 566 of 937
# Testing instance 567 of 937
# Testing instance 568 of 937
# Testing instance 569 of 937
# Testing instance 570 of 937
# Testing instance 571 of 937
# Testing instance 572 of 937
# Testing instance 573 of 937
# Testing instance 574 of 937
# Testing instance 575 of 937
# Testing instance 576 of 937
# Testing instance 577 of 937
# Testing instance 578 of 937
# Testing instance 579 of 937
# Testing instance 580 of 937
# Testing instance 581 of 937
# Testing instance 582 of 937
# Testing instance 583 of 937
# Testing instance 584 of 937
# Testing instance 585 of 937
# Testing instance 586 of 937
# Testing instance 587 of 937
# Testing instance 588 of 937
# Testing instance 589 of 937
# Testing instance 590 of 937
# Testing instance 591 of 937
# Testing instance 592 of 937
# Testing instance 593 of 937
# Testing instance 594 of 937
# Testing instance 595 of 937
# Testing instance 596 of 937
# Testing instance 597 of 937
# Testing instance 598 of 937
# Testing instance 599 of 937
# Testing instance 600 of 937
# Testing instance 601 of 937
# Testing instance 602 of 937
# Testing instance 603 of 937
# Testing instance 604 of 937
# Testing instance 605 of 937
# Testing instance 606 of 937
# Testing instance 607 of 937
# Testing instance 608 of 937
# Testing instance 609 of 937
# Testing instance 610 of 937
# Testing instance 611 of 937
# Testing instance 612 of 937
# Testing instance 613 of 937
# Testing instance 614 of 937
# Testing instance 615 of 937
# Testing instance 616 of 937
# Testing instance 617 of 937
# Testing instance 618 of 937
# Testing instance 619 of 937
# Testing instance 620 of 937
# Testing instance 621 of 937
# Testing instance 622 of 937
# Testing instance 623 of 937
# Testing instance 624 of 937
# Testing instance 625 of 937
# Testing instance 626 of 937
# Testing instance 627 of 937
# Testing instance 628 of 937
# Testing instance 629 of 937
# Testing instance 630 of 937
# Testing instance 631 of 937
# Testing instance 632 of 937
# Testing instance 633 of 937
# Testing instance 634 of 937
# Testing instance 635 of 937
# Testing instance 636 of 937
# Testing instance 637 of 937
# Testing instance 638 of 937
# Testing instance 639 of 937
# Testing instance 640 of 937
# Testing instance 641 of 937
# Testing instance 642 of 937
# Testing instance 643 of 937
# Testing instance 644 of 937
# Testing instance 645 of 937
# Testing instance 646 of 937
# Testing instance 647 of 937
# Testing instance 648 of 937
# Testing instance 649 of 937
# Testing instance 650 of 937
# Testing instance 651 of 937
# Testing instance 652 of 937
# Testing instance 653 of 937
# Testing instance 654 of 937
# Testing instance 655 of 937
# Testing instance 656 of 937
# Testing instance 657 of 937
# Testing instance 658 of 937
# Testing instance 659 of 937
# Testing instance 660 of 937
# Testing instance 661 of 937
# Testing instance 662 of 937
# Testing instance 663 of 937
# Testing instance 664 of 937
# Testing instance 665 of 937
# Testing instance 666 of 937
# Testing instance 667 of 937
# Testing instance 668 of 937
# Testing instance 669 of 937
# Testing instance 670 of 937
# Testing instance 671 of 937
# Testing instance 672 of 937
# Testing instance 673 of 937
# Testing instance 674 of 937
# Testing instance 675 of 937
# Testing instance 676 of 937
# Testing instance 677 of 937
# Testing instance 678 of 937
# Testing instance 679 of 937
# Testing instance 680 of 937
# Testing instance 681 of 937
# Testing instance 682 of 937
# Testing instance 683 of 937
# Testing instance 684 of 937
# Testing instance 685 of 937
# Testing instance 686 of 937
# Testing instance 687 of 937
# Testing instance 688 of 937
# Testing instance 689 of 937
# Testing instance 690 of 937
# Testing instance 691 of 937
# Testing instance 692 of 937
# Testing instance 693 of 937
# Testing instance 694 of 937
# Testing instance 695 of 937
# Testing instance 696 of 937
# Testing instance 697 of 937
# Testing instance 698 of 937
# Testing instance 699 of 937
# Testing instance 700 of 937
# Testing instance 701 of 937
# Testing instance 702 of 937
# Testing instance 703 of 937
# Testing instance 704 of 937
# Testing instance 705 of 937
# Testing instance 706 of 937
# Testing instance 707 of 937
# Testing instance 708 of 937
# Testing instance 709 of 937
# Testing instance 710 of 937
# Testing instance 711 of 937
# Testing instance 712 of 937
# Testing instance 713 of 937
# Testing instance 714 of 937
# Testing instance 715 of 937
# Testing instance 716 of 937
# Testing instance 717 of 937
# Testing instance 718 of 937
# Testing instance 719 of 937
# Testing instance 720 of 937
# Testing instance 721 of 937
# Testing instance 722 of 937
# Testing instance 723 of 937
# Testing instance 724 of 937
# Testing instance 725 of 937
# Testing instance 726 of 937
# Testing instance 727 of 937
# Testing instance 728 of 937
# Testing instance 729 of 937
# Testing instance 730 of 937
# Testing instance 731 of 937
# Testing instance 732 of 937
# Testing instance 733 of 937
# Testing instance 734 of 937
# Testing instance 735 of 937
# Testing instance 736 of 937
# Testing instance 737 of 937
# Testing instance 738 of 937
# Testing instance 739 of 937
# Testing instance 740 of 937
# Testing instance 741 of 937
# Testing instance 742 of 937
# Testing instance 743 of 937
# Testing instance 744 of 937
# Testing instance 745 of 937
# Testing instance 746 of 937
# Testing instance 747 of 937
# Testing instance 748 of 937
# Testing instance 749 of 937
# Testing instance 750 of 937
# Testing instance 751 of 937
# Testing instance 752 of 937
# Testing instance 753 of 937
# Testing instance 754 of 937
# Testing instance 755 of 937
# Testing instance 756 of 937
# Testing instance 757 of 937
# Testing instance 758 of 937
# Testing instance 759 of 937
# Testing instance 760 of 937
# Testing instance 761 of 937
# Testing instance 762 of 937
# Testing instance 763 of 937
# Testing instance 764 of 937
# Testing instance 765 of 937
# Testing instance 766 of 937
# ...
# Testing instance 216 of 353
# Testing instance 217 of 353
# Testing instance 218 of 353
# Testing instance 219 of 353
# Testing instance 220 of 353
# Testing instance 221 of 353
# Testing instance 222 of 353
# Testing instance 223 of 353
# Testing instance 224 of 353
# Testing instance 225 of 353
# Testing instance 226 of 353
# Testing instance 227 of 353
# Testing instance 228 of 353
# Testing instance 229 of 353
# Testing instance 230 of 353
# Testing instance 231 of 353
# Testing instance 232 of 353
# Testing instance 233 of 353
# Testing instance 234 of 353
# Testing instance 235 of 353
# Testing instance 236 of 353
# Testing instance 237 of 353
# Testing instance 238 of 353
# Testing instance 239 of 353
# Testing instance 240 of 353
# Testing instance 241 of 353
# Testing instance 242 of 353
# Testing instance 243 of 353
# Testing instance 244 of 353
# Testing instance 245 of 353
# Testing instance 246 of 353
# Testing instance 247 of 353
# Testing instance 248 of 353
# Testing instance 249 of 353
# Testing instance 250 of 353
# Testing instance 251 of 353
# Testing instance 252 of 353
# Testing instance 253 of 353
# Testing instance 254 of 353
# Testing instance 255 of 353
# Testing instance 256 of 353
# Testing instance 257 of 353
# Testing instance 258 of 353
# Testing instance 259 of 353
# Testing instance 260 of 353
# Testing instance 261 of 353
# Testing instance 262 of 353
# Testing instance 263 of 353
# Testing instance 264 of 353
# Testing instance 265 of 353
# Testing instance 266 of 353
# Testing instance 267 of 353
# Testing instance 268 of 353
# Testing instance 269 of 353
# Testing instance 270 of 353
# Testing instance 271 of 353
# Testing instance 272 of 353
# Testing instance 273 of 353
# Testing instance 274 of 353
# Testing instance 275 of 353
# Testing instance 276 of 353
# Testing instance 277 of 353
# Testing instance 278 of 353
# Testing instance 279 of 353
# Testing instance 280 of 353
# Testing instance 281 of 353
# Testing instance 282 of 353
# Testing instance 283 of 353
# Testing instance 284 of 353
# Testing instance 285 of 353
# Testing instance 286 of 353
# Testing instance 287 of 353
# Testing instance 288 of 353
# Testing instance 289 of 353
# Testing instance 290 of 353
# Testing instance 291 of 353
# Testing instance 292 of 353
# Testing instance 293 of 353
# Testing instance 294 of 353
# Testing instance 295 of 353
# Testing instance 296 of 353
# Testing instance 297 of 353
# Testing instance 298 of 353
# Testing instance 299 of 353
# Testing instance 300 of 353
# Testing instance 301 of 353
# Testing instance 302 of 353
# Testing instance 303 of 353
# Testing instance 304 of 353
# Testing instance 305 of 353
# Testing instance 306 of 353
# Testing instance 307 of 353
# Testing instance 308 of 353
# Testing instance 309 of 353
# Testing instance 310 of 353
# Testing instance 311 of 353
# Testing instance 312 of 353
# Testing instance 313 of 353
# Testing instance 314 of 353
# Testing instance 315 of 353
# Testing instance 316 of 353
# Testing instance 317 of 353
# Testing instance 318 of 353
# Testing instance 319 of 353
# Testing instance 320 of 353
# Testing instance 321 of 353
# Testing instance 322 of 353
# Testing instance 323 of 353
# Testing instance 324 of 353
# Testing instance 325 of 353
# Testing instance 326 of 353
# Testing instance 327 of 353
# Testing instance 328 of 353
# Testing instance 329 of 353
# Testing instance 330 of 353
# Testing instance 331 of 353
# Testing instance 332 of 353
# Testing instance 333 of 353
# Testing instance 334 of 353
# Testing instance 335 of 353
# Testing instance 336 of 353
# Testing instance 337 of 353
# Testing instance 338 of 353
# Testing instance 339 of 353
# Testing instance 340 of 353
# Testing instance 341 of 353
# Testing instance 342 of 353
# Testing instance 343 of 353
# Testing instance 344 of 353
# Testing instance 345 of 353
# Testing instance 346 of 353
# Testing instance 347 of 353
# Testing instance 348 of 353
# Testing instance 349 of 353
# Testing instance 350 of 353
# Testing instance 351 of 353
# Testing instance 352 of 353
# Testing instance 353 of 353
# Saving models...
# saving data...
# Bucket 40 of 40
# sorting bucket...
# number events 30637
# choosing classifier...
# fitting pipeline...
# test data shape (13480, 18)
# Testing instance 1 of 337
# Testing instance 2 of 337
# Testing instance 3 of 337
# Testing instance 4 of 337
# Testing instance 5 of 337
# Testing instance 6 of 337
# Testing instance 7 of 337
# Testing instance 8 of 337
# Testing instance 9 of 337
# Testing instance 10 of 337
# Testing instance 11 of 337
# Testing instance 12 of 337
# Testing instance 13 of 337
# Testing instance 14 of 337
# Testing instance 15 of 337
# Testing instance 16 of 337
# Testing instance 17 of 337
# Testing instance 18 of 337
# Testing instance 19 of 337
# Testing instance 20 of 337
# Testing instance 21 of 337
# Testing instance 22 of 337
# Testing instance 23 of 337
# Testing instance 24 of 337
# Testing instance 25 of 337
# Testing instance 26 of 337
# Testing instance 27 of 337
# Testing instance 28 of 337
# Testing instance 29 of 337
# Testing instance 30 of 337
# Testing instance 31 of 337
# Testing instance 32 of 337
# Testing instance 33 of 337
# Testing instance 34 of 337
# Testing instance 35 of 337
# Testing instance 36 of 337
# Testing instance 37 of 337
# Testing instance 38 of 337
# Testing instance 39 of 337
# Testing instance 40 of 337
# Testing instance 41 of 337
# Testing instance 42 of 337
# Testing instance 43 of 337
# Testing instance 44 of 337
# Testing instance 45 of 337
# Testing instance 46 of 337
# Testing instance 47 of 337
# Testing instance 48 of 337
# Testing instance 49 of 337
# Testing instance 50 of 337
# Testing instance 51 of 337
# Testing instance 52 of 337
# Testing instance 53 of 337
# Testing instance 54 of 337
# Testing instance 55 of 337
# Testing instance 56 of 337
# Testing instance 57 of 337
# Testing instance 58 of 337
# Testing instance 59 of 337
# Testing instance 60 of 337
# Testing instance 61 of 337
# Testing instance 62 of 337
# Testing instance 63 of 337
# Testing instance 64 of 337
# Testing instance 65 of 337
# Testing instance 66 of 337
# Testing instance 67 of 337
# Testing instance 68 of 337
# Testing instance 69 of 337
# Testing instance 70 of 337
# Testing instance 71 of 337
# Testing instance 72 of 337
# Testing instance 73 of 337
# Testing instance 74 of 337
# Testing instance 75 of 337
# Testing instance 76 of 337
# Testing instance 77 of 337
# Testing instance 78 of 337
# Testing instance 79 of 337
# Testing instance 80 of 337
# Testing instance 81 of 337
# Testing instance 82 of 337
# Testing instance 83 of 337
# Testing instance 84 of 337
# Testing instance 85 of 337
# Testing instance 86 of 337
# Testing instance 87 of 337
# Testing instance 88 of 337
# Testing instance 89 of 337
# Testing instance 90 of 337
# Testing instance 91 of 337
# Testing instance 92 of 337
# Testing instance 93 of 337
# Testing instance 94 of 337
# Testing instance 95 of 337
# Testing instance 96 of 337
# Testing instance 97 of 337
# Testing instance 98 of 337
# Testing instance 99 of 337
# Testing instance 100 of 337
# Testing instance 101 of 337
# Testing instance 102 of 337
# Testing instance 103 of 337
# Testing instance 104 of 337
# Testing instance 105 of 337
# Testing instance 106 of 337
# Testing instance 107 of 337
# Testing instance 108 of 337
# Testing instance 109 of 337
# Testing instance 110 of 337
# Testing instance 111 of 337
# Testing instance 112 of 337
# Testing instance 113 of 337
# Testing instance 114 of 337
# Testing instance 115 of 337
# Testing instance 116 of 337
# Testing instance 117 of 337
# Testing instance 118 of 337
# Testing instance 119 of 337
# Testing instance 120 of 337
# Testing instance 121 of 337
# Testing instance 122 of 337
# Testing instance 123 of 337
# Testing instance 124 of 337
# Testing instance 125 of 337
# Testing instance 126 of 337
# Testing instance 127 of 337
# Testing instance 128 of 337
# Testing instance 129 of 337
# Testing instance 130 of 337
# Testing instance 131 of 337
# Testing instance 132 of 337
# Testing instance 133 of 337
# Testing instance 134 of 337
# Testing instance 135 of 337
# Testing instance 136 of 337
# Testing instance 137 of 337
# Testing instance 138 of 337
# Testing instance 139 of 337
# Testing instance 140 of 337
# Testing instance 141 of 337
# Testing instance 142 of 337
# Testing instance 143 of 337
# Testing instance 144 of 337
# Testing instance 145 of 337
# Testing instance 146 of 337
# Testing instance 147 of 337
# Testing instance 148 of 337
# Testing instance 149 of 337
# Testing instance 150 of 337
# Testing instance 151 of 337
# Testing instance 152 of 337
# Testing instance 153 of 337
# Testing instance 154 of 337
# Testing instance 155 of 337
# Testing instance 156 of 337
# Testing instance 157 of 337
# Testing instance 158 of 337
# Testing instance 159 of 337
# Testing instance 160 of 337
# Testing instance 161 of 337
# Testing instance 162 of 337
# Testing instance 163 of 337
# Testing instance 164 of 337
# Testing instance 165 of 337
# Testing instance 166 of 337
# Testing instance 167 of 337
# Testing instance 168 of 337
# Testing instance 169 of 337
# Testing instance 170 of 337
# Testing instance 171 of 337
# Testing instance 172 of 337
# Testing instance 173 of 337
# Testing instance 174 of 337
# Testing instance 175 of 337
# Testing instance 176 of 337
# Testing instance 177 of 337
# Testing instance 178 of 337
# Testing instance 179 of 337
# Testing instance 180 of 337
# Testing instance 181 of 337
# Testing instance 182 of 337
# Testing instance 183 of 337
# Testing instance 184 of 337
# Testing instance 185 of 337
# Testing instance 186 of 337
# Testing instance 187 of 337
# Testing instance 188 of 337
# Testing instance 189 of 337
# Testing instance 190 of 337
# Testing instance 191 of 337
# Testing instance 192 of 337
# Testing instance 193 of 337
# Testing instance 194 of 337
# Testing instance 195 of 337
# Testing instance 196 of 337
# Testing instance 197 of 337
# Testing instance 198 of 337
# Testing instance 199 of 337
# Testing instance 200 of 337
# Testing instance 201 of 337
# Testing instance 202 of 337
# Testing instance 203 of 337
# Testing instance 204 of 337
# Testing instance 205 of 337
# Testing instance 206 of 337
# Testing instance 207 of 337
# Testing instance 208 of 337
# Testing instance 209 of 337
# Testing instance 210 of 337
# Testing instance 211 of 337
# Testing instance 212 of 337
# Testing instance 213 of 337
# Testing instance 214 of 337
# Testing instance 215 of 337
# Testing instance 216 of 337
# Testing instance 217 of 337
# Testing instance 218 of 337
# Testing instance 219 of 337
# Testing instance 220 of 337
# Testing instance 221 of 337
# Testing instance 222 of 337
# Testing instance 223 of 337
# Testing instance 224 of 337
# Testing instance 225 of 337
# Testing instance 226 of 337
# Testing instance 227 of 337
# Testing instance 228 of 337
# Testing instance 229 of 337
# Testing instance 230 of 337
# Testing instance 231 of 337
# Testing instance 232 of 337
# Testing instance 233 of 337
# Testing instance 234 of 337
# Testing instance 235 of 337
# Testing instance 236 of 337
# Testing instance 237 of 337
# Testing instance 238 of 337
# Testing instance 239 of 337
# Testing instance 240 of 337
# Testing instance 241 of 337
# Testing instance 242 of 337
# Testing instance 243 of 337
# Testing instance 244 of 337
# Testing instance 245 of 337
# Testing instance 246 of 337
# Testing instance 247 of 337
# Testing instance 248 of 337
# Testing instance 249 of 337
# Testing instance 250 of 337
# Testing instance 251 of 337
# Testing instance 252 of 337
# Testing instance 253 of 337
# Testing instance 254 of 337
# Testing instance 255 of 337
# Testing instance 256 of 337
# Testing instance 257 of 337
# Testing instance 258 of 337
# Testing instance 259 of 337
# Testing instance 260 of 337
# Testing instance 261 of 337
# Testing instance 262 of 337
# Testing instance 263 of 337
# Testing instance 264 of 337
# Testing instance 265 of 337
# Testing instance 266 of 337
# Testing instance 267 of 337
# Testing instance 268 of 337
# Testing instance 269 of 337
# Testing instance 270 of 337
# Testing instance 271 of 337
# Testing instance 272 of 337
# Testing instance 273 of 337
# Testing instance 274 of 337
# Testing instance 275 of 337
# Testing instance 276 of 337
# Testing instance 277 of 337
# Testing instance 278 of 337
# Testing instance 279 of 337
# Testing instance 280 of 337
# Testing instance 281 of 337
# Testing instance 282 of 337
# Testing instance 283 of 337
# Testing instance 284 of 337
# Testing instance 285 of 337
# Testing instance 286 of 337
# Testing instance 287 of 337
# Testing instance 288 of 337
# Testing instance 289 of 337
# Testing instance 290 of 337
# Testing instance 291 of 337
# Testing instance 292 of 337
# Testing instance 293 of 337
# Testing instance 294 of 337
# Testing instance 295 of 337
# Testing instance 296 of 337
# Testing instance 297 of 337
# Testing instance 298 of 337
# Testing instance 299 of 337
# Testing instance 300 of 337
# Testing instance 301 of 337
# Testing instance 302 of 337
# Testing instance 303 of 337
# Testing instance 304 of 337
# Testing instance 305 of 337
# Testing instance 306 of 337
# Testing instance 307 of 337
# Testing instance 308 of 337
# Testing instance 309 of 337
# Testing instance 310 of 337
# Testing instance 311 of 337
# Testing instance 312 of 337
# Testing instance 313 of 337
# Testing instance 314 of 337
# Testing instance 315 of 337
# Testing instance 316 of 337
# Testing instance 317 of 337
# Testing instance 318 of 337
# Testing instance 319 of 337
# Testing instance 320 of 337
# Testing instance 321 of 337
# Testing instance 322 of 337
# Testing instance 323 of 337
# Testing instance 324 of 337
# Testing instance 325 of 337
# Testing instance 326 of 337
# Testing instance 327 of 337
# Testing instance 328 of 337
# Testing instance 329 of 337
# Testing instance 330 of 337
# Testing instance 331 of 337
# Testing instance 332 of 337
# Testing instance 333 of 337
# Testing instance 334 of 337
# Testing instance 335 of 337
# Testing instance 336 of 337
# Testing instance 337 of 337
# Saving models...
# saving data...
# compiling results...
# bpic2012_accepted prefix_agg xgboost 1 auc 0.5442592677032511
# bpic2012_accepted prefix_agg xgboost 2 auc 0.525463955132005
# bpic2012_accepted prefix_agg xgboost 3 auc 0.5269413159454653
# bpic2012_accepted prefix_agg xgboost 4 auc 0.5315557886097304
# bpic2012_accepted prefix_agg xgboost 5 auc 0.5374903105193563
# bpic2012_accepted prefix_agg xgboost 6 auc 0.5177192102503305
# bpic2012_accepted prefix_agg xgboost 7 auc 0.5397679084401076
# bpic2012_accepted prefix_agg xgboost 8 auc 0.5532533856185309
# bpic2012_accepted prefix_agg xgboost 9 auc 0.5348707309288222
# bpic2012_accepted prefix_agg xgboost 10 auc 0.5529980393050933
# bpic2012_accepted prefix_agg xgboost 11 auc 0.5580616478956728
# bpic2012_accepted prefix_agg xgboost 12 auc 0.5350462815193106
# bpic2012_accepted prefix_agg xgboost 13 auc 0.5286991017281474
# bpic2012_accepted prefix_agg xgboost 14 auc 0.5589143221923305
# bpic2012_accepted prefix_agg xgboost 15 auc 0.5783958779809403
# bpic2012_accepted prefix_agg xgboost 16 auc 0.5884706579727327
# bpic2012_accepted prefix_agg xgboost 17 auc 0.6144138287091038
# bpic2012_accepted prefix_agg xgboost 18 auc 0.6290092282924306
# bpic2012_accepted prefix_agg xgboost 19 auc 0.6283032545118232
# bpic2012_accepted prefix_agg xgboost 20 auc 0.6486215626977986
# bpic2012_accepted prefix_agg xgboost 21 auc 0.668698797744441
# bpic2012_accepted prefix_agg xgboost 22 auc 0.6764408768004172
# bpic2012_accepted prefix_agg xgboost 23 auc 0.6782679197045735
# bpic2012_accepted prefix_agg xgboost 24 auc 0.6995180394489048
# bpic2012_accepted prefix_agg xgboost 25 auc 0.6624546240276579
# bpic2012_accepted prefix_agg xgboost 26 auc 0.678962703962704
# bpic2012_accepted prefix_agg xgboost 27 auc 0.6783297110132304
# bpic2012_accepted prefix_agg xgboost 28 auc 0.6948487549981023
# bpic2012_accepted prefix_agg xgboost 29 auc 0.7217039769568951
# bpic2012_accepted prefix_agg xgboost 30 auc 0.7189109272733314
# bpic2012_accepted prefix_agg xgboost 31 auc 0.7154808590102708
# bpic2012_accepted prefix_agg xgboost 32 auc 0.6901564069450423
# bpic2012_accepted prefix_agg xgboost 33 auc 0.6659777531337163
# bpic2012_accepted prefix_agg xgboost 34 auc 0.721031746031746
# bpic2012_accepted prefix_agg xgboost 35 auc 0.6855443214503618
# bpic2012_accepted prefix_agg xgboost 36 auc 0.6652856407617087
# bpic2012_accepted prefix_agg xgboost 37 auc 0.6858974358974359
# bpic2012_accepted prefix_agg xgboost 38 auc 0.6905734460593395
# bpic2012_accepted prefix_agg xgboost 39 auc 0.6834467120181406
# bpic2012_accepted prefix_agg xgboost 40 auc 0.6856587823413884
# bpic2012_accepted prefix_agg xgboost -1 -1 auc 0.621816778845272
